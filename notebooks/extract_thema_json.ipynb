# %%
import json
from json import JSONDecoder

import sys
sys.path.append('../')
sys.path.append('../andre')
import andre.utils as utils

# %% [markdown]
# # json extraction

# %%
# Specify the path to the JSON file
file_path = '../book_themes_alignment_data/thema_v1.5_fr.json'


class CustomDecoder(JSONDecoder):
    def decode(self, s):
        s = s.replace('\xa0', ' ')
        return super().decode(s)

# Read the JSON file
with open(file_path, 'r', encoding="utf8") as file:
    data = json.load(file, cls=CustomDecoder)

print(data.keys())
# Access the extracted data
thema_codes = data["CodeList"]["ThemaCodes"]["Code"]

# Print the extracted data
print(len(thema_codes))
# Out:
# dict_keys(['CodeList'])
# 8645

# %%
thema_codes
# Out:
# [{'CodeValue': 'A',
#   'CodeDescription': 'Arts',
#   'CodeNotes': 'Utilisez tous les codes A* pour les ouvrages spécialisés et généraux, qu’ils soient richement illustrés ou majoritairement textuel. Préférez les codes WF* pour les ouvrages liés à un loisir ou un passe-temps, en le complétant au besoin par le(s) code(s) A*. Utilisez au besoin tous les codes A* avec d’autres codes et qualificateurs, particulièrement avec les qualificateurs de style 6*, de lieux 1* et historiques 3*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AB',
#   'CodeDescription': 'Arts\xa0: généralités',
#   'CodeNotes': '',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ABA',
#   'CodeDescription': 'Théorie de l’art',
#   'CodeNotes': 'Lié\xa0: QDTN',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ABC',
#   'CodeDescription': 'Conservation, restauration et entretien d’œuvres d’art',
#   'CodeNotes': 'Utilisez tous les codes A* pour les ouvrages sur la conservation, la préservation, la rénovation, la restauration ou l’entretien de tout type d’art, y compris les bâtiments, les structures, les sculptures, les photos, les peintures, les arts décoratifs, etc.',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ABK',
#   'CodeDescription': 'Contrefaçon, falsification et vol d’œuvres d’art',
#   'CodeNotes': '',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ABQ',
#   'CodeDescription': 'Art\xa0: aspects financiers',
#   'CodeNotes': 'Classez ici\xa0: les ventes d’art et vente aux enchères, le financement, le parrainage et le sponsoring, les ventes organisées, le marché crypto-art et NFT, le marché de l’art blockchain, l’art en tant qu’investissement financier ou spéculatif, la valeur commerciale de l’art, le commerce de l’art',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AF',
#   'CodeDescription': 'Arts\xa0: formes d’art',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les beaux-arts, les arts visuels et appliqués. Utilisez pour tous les codes AF*, le(s) code(s) AG* approprié(s), AGA pour l’histoire de l’art et des œuvres, AGZ pour les ouvrages spécialisés sur la technique, et au besoin le(s) qualificateur(s) de style 6*. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFC',
#   'CodeDescription': 'Peinture et tableaux',
#   'CodeNotes': 'Classez ici : la peinture ou les peintures, ou tout support sans catégorie plus spécifique se trouvant ci-dessous. Utilisez tous les codes AFC* pour les ouvrages concernant la ou les peintures, réalisé(es) par une personne ou un groupe de personnes, l’histoire de peintures spécifiques ou du style spécifique de la peinture. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s). Utilisez avec AGA pour l’histoire des œuvres d’art, AGB pour les monographies sur les peintres, AGZ pour les ouvrages spécialisés sur la technique, etc. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFCC',
#   'CodeDescription': 'Tableaux, aquarelle et pastels',
#   'CodeNotes': 'Classez ici : la gouache',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFCL',
#   'CodeDescription': 'Tableaux et peinture à l’huile',
#   'CodeNotes': 'Classez ici : les tableaux et peintures acryliques',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AFCM',
#   'CodeDescription': 'Peintures murales et fresques',
#   'CodeNotes': 'Classez ici\xa0: le trompe l’œil, les fresques, les peintures au plafond, le muralisme, le marouflage',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  {'CodeValue': 'AFCP',
#   'CodeDescription': 'Tableaux et peinture à l’encre',
#   'CodeNotes': 'Classez ici : le lavis d’encre Lié\xa0: AFFK',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AFF',
#   'CodeDescription': 'Dessin et dessins',
#   'CodeNotes': 'Classez ici : les croquis. Utilisez tous les codes AFF* pour les ouvrages concernant le ou les dessin(s), réalisé(s) par une personne ou un groupe de personnes, l’histoire de dessins spécifiques ou du style spécifique du dessin. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s). Utilisez avec AGA pour l’histoire des œuvres d’art, AGB pour les monographies sur les peintres, AGZ pour les ouvrages spécialisés sur la technique. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFFC',
#   'CodeDescription': 'Dessin et dessins au crayon, fusain ou pastel',
#   'CodeNotes': 'Classez ici : le crayon graphite, la craie, Conté',
#   'CodeParent': 'AFF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AFFK',
#   'CodeDescription': 'Dessin et dessins à la plume, au pinceau et à l’encre',
#   'CodeNotes': 'Lié\xa0: AFCP',
#   'CodeParent': 'AFF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AFH',
#   'CodeDescription': 'Estampes et gravure',
#   'CodeNotes': 'Classez ici : l’eau-forte, les sérigraphies les gravures sur bois, les lithographies, les gravures au trait, les aquatintes, la pointe sèche, la manière noire, les monotypes, les blocs de bois',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFJ',
#   'CodeDescription': 'Autres formes d’art graphique ou visuel',
#   'CodeNotes': 'Classez ici\xa0: le collage, le montage photographique. Utilisez pour les ouvrages généraux ou pour les formes d’arts qui n’ont pas de code spécifique dans les codes AFC*, AFF* ou AFH*',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFJY',
#   'CodeDescription': 'Body art et tatouage',
#   'CodeNotes': 'Classez ici : le body piercing, la peinture sur corps en tant qu’art. Utilisez avec le code AFKP pour les performances artistiques',
#   'CodeParent': 'AFJ',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AFK',
#   'CodeDescription': 'Formes d’art non graphique et électroniques',
#   'CodeNotes': 'Utilisez pour les ouvrages généraux sur les formes d’art non graphique ou pour les formes d’art non listées ci-dessous, y compris les nouvelles formes de média',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFKB',
#   'CodeDescription': 'Sculpture',
#   'CodeNotes': 'Classez ici : les statues, les figurines, les sculptures monumentales. Utilisez pour les ouvrages sur les arts en trois dimensions dans n’importe quel matériau, sur la forme d’art, ou sur les traditions et techniques associées',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFKC',
#   'CodeDescription': 'Sculptures, masques, reliefs',
#   'CodeNotes': 'Classez ici : les pétroglyphes, les sculptures à petite échelle et monumentales. Utilisez pour les ouvrages aussi bien sur la technique, que sur les objets sculptés spécifiques ou les réalisations sculptées dans n’importe quel matériau',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFKG',
#   'CodeDescription': 'Métal précieux, pierres précieuses et bijoux\xa0: techniques et procédés',
#   'CodeNotes': 'Classez ici\xa0: l’Orfèvrerie, Fabergé, etc. Lié\xa0: WFJ WCP WCR WFP',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AFKN',
#   'CodeDescription': 'Installation artistique',
#   'CodeNotes': 'Classez ici : le land art, l’art in situ, l’art environnemental',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFKP',
#   'CodeDescription': 'Performance artistique',
#   'CodeNotes': '',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AFKV',
#   'CodeDescription': 'Art digital, vidéo et des nouveaux médias',
#   'CodeNotes': 'Classez ici : les arts informatique, électronique, holographique, virtuel, cyborg, interactif, en ligne, génératif, télématique, sonore et évolutionnaire, le crypto-art, l’art du jeu vidéo, l’art logiciel Lié\xa0: UG*',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AFP',
#   'CodeDescription': 'Céramique, mosaïque et verre\xa0: œuvres d’art',
#   'CodeNotes': 'Classez ici\xa0: la poterie (inclut la porcelaine, la faïence, le grès, le biscuit), les vitraux, carreaux ou émail considérés comme œuvres d’art Lié\xa0: WFN',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AFT',
#   'CodeDescription': 'Arts décoratifs',
#   'CodeNotes': 'Classez ici\xa0: les ornements, les motifs ornementaux, les détails décoratifs, les motifs ou les formes, la fausse peinture ou finition, la ferronnerie, la laque et les autres arts décoratifs. Utilisez pour les ouvrages qui abordent le sujet sous l’angle des beaux-arts ou de l’histoire de l’art, ou qui visent un public plus professionnel, technique ou qualifié Lié\xa0: WF*',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AFW',
#   'CodeDescription': 'Arts du textile',
#   'CodeNotes': 'Classez ici\xa0: les tapis, les tapisseries, les kilims, les moquettes, les courtepointes et les autres arts du textile considérés comme œuvres d’art Lié\xa0: AKT WFB* WFF WFG',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AG',
#   'CodeDescription': 'Arts\xa0: techniques et sujets',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les beaux-arts, les arts visuels et appliqués. Utilisez tous les codes AG* avec le(s) code(s) AB*, AF*, AG*, AJ* approprié(s) et au besoin avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* approprié(s)',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGA',
#   'CodeDescription': 'Histoire de l’art',
#   'CodeNotes': 'Utilisez avec les autres codes Arts A* et également avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3*',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AGB',
#   'CodeDescription': 'Artistes, monographies',
#   'CodeNotes': 'Utilisez pour les ouvrages sur des artistes individuels et des ateliers ou des ateliers produisent sous le nom d’un seul artiste',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGC',
#   'CodeDescription': 'Catalogues d’exposition et collections',
#   'CodeNotes': 'Utilisez pour les catalogues d’exposition temporaire ou permanente de galeries d’art, musées ou de collectionneurs. Utilisez avec d’autres codes A* pour indiquer la forme d’art et également le(s) qualificateurs(s) de lieux si le catalogue est lié à un lieu permanent comme pour une galerie spécifique ou un musée Lié\xa0: WTHM GLZ',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGH',
#   'CodeDescription': 'Figures humaines dans l’art',
#   'CodeNotes': 'Classez ici : les peintures ou dessins de figures humaines, les illustrations par des artistes de l’anatomie humaine, les dessins anatomiques, ou tout art qui représente l’humain ou une partie du corps humain. Utilisez avec AGZ pour les ouvrages sur la technique du dessin',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGHF',
#   'CodeDescription': 'Portraits et autoportraits dans l’art',
#   'CodeNotes': '',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AGHN',
#   'CodeDescription': 'Nus dans l’art',
#   'CodeNotes': '',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AGHX',
#   'CodeDescription': 'Art érotique',
#   'CodeNotes': 'Utilisez le qualificateur 5X approprié Lié\xa0: AJCX',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AGK',
#   'CodeDescription': 'Scènes de vie, profanes et domestiques dans l’art',
#   'CodeNotes': 'Classez ici\xa0: les scènes de genre, les scènes et évènements quotidiens dans l’art',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AGN',
#   'CodeDescription': 'Nature dans l’art',
#   'CodeNotes': 'Utilisez pour les représentations de la nature sous n’importe quelle forme ou tradition artistique. Utilisez avec AKLB pour l’illustration, ou PS* pour l’art qui est ou a été créée à des fins scientifiques',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGNA',
#   'CodeDescription': 'Animaux dans l’art',
#   'CodeNotes': 'Classez ici\xa0: les peintres animaliers, l’art de la faune, les oiseaux, les insectes, les poissons, etc. dans l’art. Utilisez pour les représentations de la faune sous n’importe quelle forme ou tradition artistique. Utilisez avec AKLB pour l’illustration, ou PS* pour l’art qui est ou a été créée à des fins scientifiques',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  {'CodeValue': 'AGNB',
#   'CodeDescription': 'Plantes dans l’art',
#   'CodeNotes': 'Classez ici : les illustrations botaniques. Utilisez pour : tous les types de représentation artistique et précise d’arbres, de fleurs ou de plantes dans n’importe quelle forme ou tradition artistique. Utilisez avec PST pour l’art botanique à vocation scientifique, en général des oeuvres contenant du textes sur les plantes ou des reproductions d’oeuvres botaniques historiques, ou avec AKLB pour les œuvres sur l’art botanique comme exemples de l’art de l’illustration',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AGNL',
#   'CodeDescription': 'Paysages, paysages marins dans l’art',
#   'CodeNotes': 'Classez ici : les paysages célestes, les paysages nuageux, les paysages fluviaux, les scènes fluviales, l’art du paysage, la veduta, les paysages urbains, les paysages urbains, les paysages lunaires, les paysages aquatiques, les paysages intérieurs, les Weltlandschaft. Utilisez pour : les œuvres sur les types de paysages dans les arts visuels, ou des exemples individuels',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  {'CodeValue': 'AGNS',
#   'CodeDescription': 'Natures mortes',
#   'CodeNotes': 'Classez ici\xa0: les vanités, les natures mortes, les memento mori. Utilisez pour la représentation des scènes à petite échelle de sujets principalement inanimés, naturels ou faits par l’homme, essentiellement, un sujet qui ne bouge pas ou qui est mort dans une peinture, une photo, une sculpture ou une autre forme d’art de nature morte',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  {'CodeValue': 'AGP',
#   'CodeDescription': 'Réalisations humaines dans l’art',
#   'CodeNotes': 'Classez ici : les immeubles, les paysages urbains, les machines, les transports, etc. représenté(e)s sous n’importe quelle forme ou tradition artistique',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AGR',
#   'CodeDescription': 'Art religieux',
#   'CodeNotes': 'Classez ici : l’art sacré ou rituel, les icônes, les images votives. Utilisez pour : les œuvres sur l’imagerie artistique utilisant une inspiration ou des motifs religieux, la représentation artistique de figures, de motifs, de formes, de calligraphie, etc. à des fins spirituelles ou religieuses. Utilisez au besoin les codes QR* pour indiquer une religion particulière et d’autres codes A* pour les ouvrages sur des types d’art particuliers',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AGT',
#   'CodeDescription': 'Art public',
#   'CodeNotes': 'Utilisez pour les ouvrages sur tout art qui a été conçu et exécuté dans l’intention d’être diffusé dans l’espace public, le plus souvent à l’extérieur et accessible à tous, pouvant être permanent ou temporaire, et spécialement commandé pour un lieu ou non-officiel ou non autorisé',
#   'CodeParent': 'AG',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AGTS',
#   'CodeDescription': 'Arts urbains',
#   'CodeNotes': 'Classez ici : l’art de la guérilla, les graffitis, le flyposting, le sticker art, le bombardement de fils, les installations dans la rue, les styles urbains, etc. Utilisez pour les ouvrages sur les formes d’art visuel ou appliqué à l’espace urbain, inspirés des modes de vie urbain ou l’environnement et présent dans l’espace public',
#   'CodeParent': 'AGT',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AGZ',
#   'CodeDescription': 'Arts : techniques et principes',
#   'CodeNotes': 'Utilisez pour les manuels, les études et ouvrages spécialisés sur les techniques, la perspective, etc. Utilisez avec le(s) code(s) AF* ou AK* approprié(s) pour indiquer la forme d’art, par exemple AFF pour les techniques en dessin. Pour les ouvrages destinés aux amateurs ou liés à un loisir ou passe-temps, préférez les codes WF* Lié\xa0: WFA',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AGZC',
#   'CodeDescription': 'Théorie des couleurs',
#   'CodeNotes': 'Classez ici : la science de la couleur dans l’art. Utilisez avec le(s) code(s) P* ou T* pour une approche plus scientifique ou technique',
#   'CodeParent': 'AGZ',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AJ',
#   'CodeDescription': 'Photographie et photographies',
#   'CodeNotes': '',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AJC',
#   'CodeDescription': 'Photographies\xa0: collections',
#   'CodeNotes': 'Utilisez pour les ouvrages qui sont ou au sujet d’une collection ou une sélection réfléchie de photographies généralement autour d’un thème, d’un concept ou représentant la collection d’un musée, d’une galerie, d’une agence ou d’un collectionneur. Utilisez avec le(s) code(s) AG* pour les traitements plus spécifiques ou tout autre code pour indiquer le code approprié Lié\xa0: WQP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AJCD',
#   'CodeDescription': 'Photographes',
#   'CodeNotes': 'Classez ici : les monographies de photographies',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AJCP',
#   'CodeDescription': 'Photographie\xa0: art du portrait et de l’autoportrait',
#   'CodeNotes': 'Utilisez pour les ouvrages de photographies présentant une personne, des personnes ou un groupe de personnes, y compris les selfies et les modèles, et également les portraits. Utilisez avec AJTF pour les techniques pratiques du portrait',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1.1,
#   'Modified': 1.4},
#  {'CodeValue': 'AJCX',
#   'CodeDescription': 'Nus et photographies érotiques',
#   'CodeNotes': 'Utilisez le qualificateur 5X approprié Lié\xa0: AGHX',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AJF',
#   'CodeDescription': 'Photoreportage et photographie documentaire',
#   'CodeNotes': 'Classez ici : les reportages photographiques, la photographie documentaire / sociale et de rue, la photographie d’évènements et de célébrités Lié\xa0: DNP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AJT',
#   'CodeDescription': 'Equipement photographique et techniques\xa0: généralités',
#   'CodeNotes': 'Classez ici : les appareils photographiques, les objectifs, l’éclairage, la pellicule, le flash, les techniques de chambre noire et le traitement photographique, la retouche et la manipulation numérique, les principes de couleurs, la composition, le noir et blanc, etc. Lié\xa0: UGP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AJTA',
#   'CodeDescription': 'Manuels spécifiques pour appareils photo',
#   'CodeNotes': 'Utilisez pour les ouvrages au sujet d’un type ou marque d’appareil photographique',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AJTF',
#   'CodeDescription': 'Photographie\xa0: techniques et principes pour sujets spécifiques',
#   'CodeNotes': 'Classez ici\xa0: la photographie aérienne, avec drone, en studio, de rue, de paysage, de la nature et de la faune, du portrait, sous-marine, les techniques et guides de micro et astrophotographie. Utilisez pour les ouvrages sur la composition, etc.',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AJTH',
#   'CodeDescription': 'Photographie numérique',
#   'CodeNotes': '',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AJTR',
#   'CodeDescription': 'Photographie monochrome',
#   'CodeNotes': 'Classez ici : la photographie monochrome en niveaux de gris, noir et blanc, sépia, cyanotype, monochrome marron. Utilisez avec AJTV pour les techniques monochromes pour le film / la vidéo',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'AJTS',
#   'CodeDescription': 'Lumière et éclairage',
#   'CodeNotes': 'Classez ici : la photographie au flash, l’utilisation de la lumière ou de l’éclairage naturel ou artificiel. Utilisez avec AJTV pour les techniques d’éclairage pour le film / la vidéo ou avec les codes AT* pour les techniques d’éclairage ou la conception d’éclairage dans les arts de la scène',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'AJTV',
#   'CodeDescription': 'Direction de la photographie et de la vidéo',
#   'CodeNotes': 'Lié\xa0: AFKV ATFX ATJX',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AK',
#   'CodeDescription': 'Design, arts industriel et commercial, illustration',
#   'CodeNotes': 'Utilisez tous les codes AK* pour les ouvrages qui abordent le sujet sous l’angle des beaux-arts ou de l’histoire de l’art, ou qui visent un public plus professionnel, technique ou qualifié. Utilisez avec le(s) qualificateur(s) de style 6*, de lieux 1* ou historique(s) 3* appropriés. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKB',
#   'CodeDescription': 'Designers ou collectif de designers',
#   'CodeNotes': 'Classez ici : les agences de design, les marques, les entreprises, les firmes et maisons et les personnes. Utilisez au besoin ce code avec d’autres codes pour indiquer le domaine concerné, par exemple le code AKT pour le design dans la mode et le textile ou avec le code AGA pour l’approche historique',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKC',
#   'CodeDescription': 'Graphisme',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AKD',
#   'CodeDescription': 'Typographie et lettrage',
#   'CodeNotes': 'Classez ici : les polices d’écriture, les polices de caractères et leur conception, la peinture de signes, le shufa, le shodo, le khatt et les autres formes de calligraphie considérées comme un art Lié\xa0: WFU',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKH',
#   'CodeDescription': 'Conception et reliure des livres',
#   'CodeNotes': 'Classez ici : la conception de la couverture, l’art de la reliure, le papier marbré, etc. en tant qu’art. Utilisez pour les ouvrages sur l’art de concevoir et réaliser des livres Lié\xa0: WFT AKLB KNTP1',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKHM',
#   'CodeDescription': 'Manuscrits et enluminures',
#   'CodeNotes': 'Classez ici\xa0: les miniatures, les manuscrits enluminés ou les manuscrits à peintures, les parchemins et codex',
#   'CodeParent': 'AKH',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  {'CodeValue': 'AKL',
#   'CodeDescription': 'Illustration et dessin publicitaire',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AKLB',
#   'CodeDescription': 'Illustration',
#   'CodeNotes': 'Classez ici : les illustrations de livres et les graphiques d’informations d’art. Utilisez pour les ouvrages sur les illustrations d’art aussi bien que les illustrations, contemporaines ou historiques, réalisées à des fins scientifiques, techniques, de narration ou autres Lié\xa0: AFF',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKLC',
#   'CodeDescription': 'Comics et bandes dessinées',
#   'CodeNotes': 'Utilisez les codes AKLC* avec les codes X* pour indiquer le style de bandes dessinées impliqué, avec AGZ pour les ouvrages spécialisés dans la technique du de la bande dessinée ou des personnages, avec AKX pour l’histoire de la bandes dessinées. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps ou UGL pour les illustrations numériques plus techniques Lié\xa0: AFF',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKLC1',
#   'CodeDescription': 'Roman graphique et manga',
#   'CodeNotes': 'Associez au besoin la forme de l’œuvre à l’aide du code X* approprié Lié\xa0: XA* XR* AFF',
#   'CodeParent': 'AKLC',
#   'IssueNumber': 1,
#   'Modified': 1.2},
#  {'CodeValue': 'AKLF',
#   'CodeDescription': 'Jeux vidéos',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les aspects artistiques de la conception du jeu vidéo, les dessins, le graphisme, l’art, etc. Lié\xa0: UGG',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1.1,
#   'Modified': 1.5},
#  {'CodeValue': 'AKLP',
#   'CodeDescription': 'Art de l’affiche',
#   'CodeNotes': '',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AKP',
#   'CodeDescription': 'Conception de produit',
#   'CodeNotes': 'Classez ici : la conception universelle et accessible des produits, la conception industriel. Utilisez pour les ouvrages sur la conception de produits en général, y compris les noms de commerces ou de marques associés, sur la conception d’un produit ou d’un type de produits, et sur la fonctionnalité, sécurité et conception durable des produits, etc. Lié\xa0: TBD UGC',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AKR',
#   'CodeDescription': 'Art du mobilier',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AKT',
#   'CodeDescription': 'Mode et textiles',
#   'CodeNotes': 'Utilisez pour : les styles et tendances de la mode, les ouvrages généraux et de référence, les ouvrages sur des pièces vestimentaires spécifiques, les ouvrages illustrés sur la mode, etc. Utilisez tous les codes AKT* avec AKB pour les créateurs, avec AGZ pour l’histoire de la mode, en y associant le(s) qualificateur(s) de style 6*, de lieux et historique(s) approprié(s), avec AJC* pour les photographies de et sur la mode, avec AGZ pour les ouvrages techniques pour les étudiants en mode et créateurs. Préférez les codes WF* pour les ouvrages destinés au grand public sur la façon de s’habiller, les guides pour un look élégant et conseils pratiques Lié\xa0: TDPF* KNDD KNSX WJF',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AKTF',
#   'CodeDescription': 'Mode et textiles : accessoires',
#   'CodeNotes': 'Classez ici : la chapellerie, la cordonnerie, la ganterie, les sacs, les chapeaux, les chaussures, les baskets et autres accessoires. Utilisez pour les ouvrages, généralement illustrés, qui abordent les aspects de la conception ou de l’esthétique des différents accessoires de mode ou de costume',
#   'CodeParent': 'AKT',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  {'CodeValue': 'AKTR',
#   'CodeDescription': 'Costume/textile national ou régional',
#   'CodeNotes': 'Classez ici\xa0: les costumes / vêtements / habits folkloriques, ethniques, nationaux ou traditionnels, les textiles ou tissus traditionnels associés à des groupes ou régions particuliers, etc. Utilisez pour les ouvrages qui abordent les costumes du passé autant que contemporains. Utilisez avec des qualificateurs de lieux 1* appropriés',
#   'CodeParent': 'AKT',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  {'CodeValue': 'AKX',
#   'CodeDescription': 'Histoire du design',
#   'CodeNotes': 'Utilisez avec les autres codes AK* et également avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés',
#   'CodeParent': 'AK',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AM',
#   'CodeDescription': 'Architecture',
#   'CodeNotes': 'Utilisez tous les codes AM* avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés, avec TNKK ou ABC pour les ouvrages concernant la réutilisation adaptative, la réaffectation, la restauration ou la conservation des bâtiments et des structures, avec d’autres codes TNK* pour les ouvrages plus techniques sur le bâtiment et la construction',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AMA',
#   'CodeDescription': 'Théorie de l’architecture',
#   'CodeNotes': '',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AMB',
#   'CodeDescription': 'Architectes et cabinets d’architecture',
#   'CodeNotes': 'Classez ici : les monographies d’architecture',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMC',
#   'CodeDescription': 'Structure architecturale et conception',
#   'CodeNotes': 'Classez ici\xa0: les dessins d’architecture, les dessins de section ou en coupe, les élévations, les matériaux, le génie architectural, les rendus architecturaux, les plans d’étage. Utilisez pour les ouvrages qui abordent le sujet d’un point de vue architectural. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s), Préférez les codes TN* pour les ouvrages qui examinent la technique du bâtiment et de la construction Lié\xa0: TN*',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMCD',
#   'CodeDescription': 'Détails, composants et motifs architecturaux',
#   'CodeNotes': 'Utilisez pour les ouvrages concernant les éléments individuels d’un bâtiment ou d’une structure, par exemple les fenêtres, les portes, la conception d’un toit, l’ornementation, etc.',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'AMCM',
#   'CodeDescription': 'Architecture : matériau',
#   'CodeNotes': 'Utilisez pour les ouvrages, généralement très illustrés, qui abordent les structures d’un point de vue du matériau dans lequel elles sont construites, tels que le béton, la brique, l’acier, le verre, le bois, etc. Préférez les codes TN* pour les approches plus techniques ou d’ingénierie Lié\xa0: TN*',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'AMCR',
#   'CodeDescription': 'Architecture durable',
#   'CodeNotes': 'Classez ici\xa0: l’architecture à faible impact, l’architecture durable et économe en énergie, la conception et les technologies du bâtiment et de l’intérieur, l’arcologie, les bâtiments verts, l’écoconception et la conception environnementale, l’architecture biophilique et biomimétisme, les plans de maisons durables, les techniques de construction neutres en carbone, les guides pratiques sur les matériaux, les projets de construction écologique, la conception d’habitats passifs, etc. Utilisez avec le code RNU pour les ouvrages sur la durabilité et les codes TNK* pour les ouvrages sur la conception et la construction durables',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'AMD',
#   'CodeDescription': 'Architecture\xa0: pratique professionnelle',
#   'CodeNotes': '',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AMG',
#   'CodeDescription': 'Architecture\xa0: bâtiments publics, commerciaux et industriels',
#   'CodeNotes': 'Classez ici\xa0: les édifices publics, commerciaux et industriels\xa0; également les salles de concerts, stades, mémoriaux, monuments, hôpitaux, phares, bibliothèques, musées, galeries, espaces d’exposition, gares, aéroports, les hôtels, les spas, les usines, les entrepôts, les bureaux, les magasins, les boutiques, etc. Utilisez pour les ouvrages sur les bâtiments qui ont une fonction principale autre que résidentielle ou domestique, et qui sont accessibles à un grand groupe de personnes. Utilisez avec AMR si approprié Lié\xa0: JWT WTHM',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMK',
#   'CodeDescription': 'Architecture\xa0: constructions résidentiels ou domestiques',
#   'CodeNotes': 'Classez ici\xa0: les maisons privées, les demeures, les immeubles, les appartements, les lofts, les cottages, les villas. Utilisez pour les ouvrages sur la conception de maisons ou de logements résidentiels, contemporains et historiques, qui peuvent être des structures construites à cet effet ou converties. Utilisez au besoin avec le code AMR d’architecture d’intérieur Lié\xa0: WJK AMR',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMKH',
#   'CodeDescription': 'Architecture\xa0: petites constructions domestiques',
#   'CodeNotes': 'Classez ici : les chalets, les huttes, les remises, les cabanes dans les arbres, les folies, les petites maisons, les maisons d’été, les dépendances, les hangars à bateaux, etc. Utilisez pour les ouvrages qui abordent les petites constructions, mais pas nécessairement résidentielles, les constructions et structures qui sont généralement liés aux loisirs, aux vacances, à la détente et au plaisir',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1.2,
#   'Modified': 1.4},
#  {'CodeValue': 'AMKL',
#   'CodeDescription': 'Architecture\xa0: châteaux et fortifications',
#   'CodeNotes': '',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AMKS',
#   'CodeDescription': 'Architecture\xa0: palais, maisons de maître et hôtels particuliers',
#   'CodeNotes': '',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1.2,
#   'Modified': ''},
#  {'CodeValue': 'AMN',
#   'CodeDescription': 'Architecture\xa0: édifices religieux',
#   'CodeNotes': 'Classez ici\xa0: les aspects architecturaux des abbayes, des cathédrales, des églises, des mosquées, des synagogues, des temples, et autres constructions et structures religieuses',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMR',
#   'CodeDescription': 'Architecture d’intérieur',
#   'CodeNotes': 'Utilisez pour les ouvrages qui abordent le sujet d’un point de vue des arts décoratifs, généralement des beaux livres d’art et destinés à un public de professionnels ou qualifié, cela inclut les études sur l’architecture et le design d’intérieur, la conception de l’éclairage et les autres spécialisations du design d’intérieur résidentiel ou commercial. Utilisez avec AKB pour les architectes d’intérieur. Préférez WJK pour les approches plus amateurs et domestiques Lié\xa0: WJK',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'AMV',
#   'CodeDescription': 'Paysagisme (architecture & design)',
#   'CodeNotes': 'Lié\xa0: WMD',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'AMVD',
#   'CodeDescription': 'Aménagement urbain\xa0: aspects architecturaux',
#   'CodeNotes': 'Lié\xa0: RPC',
#   'CodeParent': 'AMV',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AMX',
#   'CodeDescription': 'Histoire de l’architecture',
#   'CodeNotes': 'Associez au besoin des qualificateurs de style, de lieux et historiques',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'AT',
#   'CodeDescription': 'Arts du spectacle',
#   'CodeNotes': 'Utilisez tous les codes AT* avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATC',
#   'CodeDescription': 'Acteurs et artistes / interprètes',
#   'CodeNotes': 'Classez ici\xa0: les personnalités médiatiques, les présentateurs. Utilisez le code AT* approprié afin d’indiquer s’il s’agit de théâtre, cinéma, télévision, radio, etc. Lié\xa0: DNBF*',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'ATD',
#   'CodeDescription': 'Etudes sur le théâtre',
#   'CodeNotes': 'Lié\xa0: DD*',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATDC',
#   'CodeDescription': 'Techniques de jeu d’acteurs',
#   'CodeNotes': 'Classez ici\xa0: les monologues, la documentation pour les auditions, les conseils et techniques, le doublage, les techniques vocales, les méthodes de jeu, le jeu devant caméra, les techniques d’improvisation, les techniques de mouvement pour acteurs, etc.',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ATDF',
#   'CodeDescription': 'Production et mise en scène',
#   'CodeNotes': '',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATDH',
#   'CodeDescription': 'Théâtre\xa0: régie et techniques de scène',
#   'CodeNotes': 'Classez ici\xa0: les techniques de la scène, les costumes et le maquillage, la conception et la réalisation de la lumière, les décors et les accessoires, la conception et la création scénique, des scènes et des décors, la régie, les effets spéciaux, la conception et la production sonores théâtrales',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ATDS',
#   'CodeDescription': 'Gestion de théâtre',
#   'CodeNotes': '',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATF',
#   'CodeDescription': 'Films, cinéma',
#   'CodeNotes': 'Utilisez les codes ATF* pour les aspects artistiques uniquement, à la fois pour le grand écran que pour les téléfilms ou pour les long-métrages venant des nouveaux médias, y compris le streaming, les films à la demande et autres services (mais cela exclut les présentations par épisodes) Lié\xa0: KNTC',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATFA',
#   'CodeDescription': 'Histoire, théorie ou critique cinématographique',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les cinémas nationaux, l’histoire ou la critique de films, les studios de cinéma, les franchises de films',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATFB',
#   'CodeDescription': 'Réalisateurs et producteurs de films',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATFD',
#   'CodeDescription': 'Scripts et scénarios',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATFG',
#   'CodeDescription': 'Guides et critiques de film',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATFN',
#   'CodeDescription': 'Film\xa0: styles et genres',
#   'CodeNotes': 'Utilisez pour les études sur les genres ou les styles. Utilisez avec les codes ATM* ou les autres codes ATF* pour spécifier au besoin le style ou le genre du film Lié\xa0: ATM*',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATFR',
#   'CodeDescription': 'Documentaires',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les documentaires courts ou longs, destinés au petit ou grand écran, et sur les programmes scénarisés largement factuels',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATFV',
#   'CodeDescription': 'Films d’animations',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les films ou courts-métrages animés. Utilisez avec AGZ pour les techniques de l’animation Lié\xa0: UGN',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATFV1',
#   'CodeDescription': 'Anime (japanimation)',
#   'CodeNotes': 'Utilisez pour les films d’animation de style japonais Lié\xa0: AKLC1',
#   'CodeParent': 'ATFV',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'ATFX',
#   'CodeDescription': 'Réalisation et production de film\xa0: techniques de plateau / studio',
#   'CodeNotes': 'Classez ici\xa0: la cinématographie, le montage, la lumière, les décors, les costumes, les effets spéciaux, l’art et la conception, le maquillage et la coiffure, les accessoires, le casting Lié\xa0: CBVS UG*',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATJ',
#   'CodeDescription': 'Télévision',
#   'CodeNotes': 'Utilisez les codes ATJ* : pour les aspects artistiques uniquement, à la fois pour la télévision traditionnelle et des nouveaux médias, y compris le streaming, la télévision à la demande ou les autres formes de consommation de divertissement sur le petit écran (y compris les présentations par épisodes) Lié\xa0: KNTC',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATJD',
#   'CodeDescription': 'Scripts et scénarios pour la télévision et programmes télévisés',
#   'CodeNotes': 'Lié\xa0: WHG',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.2},
#  {'CodeValue': 'ATJS',
#   'CodeDescription': 'Télévisions : styles et genres',
#   'CodeNotes': 'Classez ici\xa0: les études sur les séries, les soap opéras, les pièces de théâtre pour la télévision, les comédies de situation, les émissions de télévision, etc. à la fois en direct et animées, fiction ou non, les œuvres dramatiques, la téléréalité, les documentaires, les informations et actualités, etc. Utilisez pour les ouvrages sur n’importe quel genre ou style de divertissements à la télévision ou sur petit écran. Utilisez avec les codes ATM* ou d’autres codes AT* pour spécifier au besoin le style ou le genre Lié\xa0: ATM*',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ATJS1',
#   'CodeDescription': 'Télévision : téléréalité',
#   'CodeNotes': 'Classez ici : les émissions de talents, les concours ou les jeux télévisés de téléréalité, les émissions de téléréalité de style documentaire, les émissions de téléréalité scénarisée, les émissions de rencontres, les émissions d’amélioration, les émissions-débats, etc. Utilisez pour les ouvrages concernant les aspects de la téléréalité ou des émissions spécifiques ou des personnes qui participent à des émissions de téléréalité à la télévision, sur des services de streaming, sur des médias en ligne, etc. Utilisez avec DNBF pour les biographies d’artistes de téléréalité, avec des codes AV* pour des types spécifiques d’émissions de téléréalité, etc',
#   'CodeParent': 'ATJS',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'ATJX',
#   'CodeDescription': 'Production pour la télévision\xa0: techniques de plateau / studio',
#   'CodeNotes': 'Classez ici\xa0: la prise de vue à la télévision, le montage, la lumière, les décors, les costumes, les effets spéciaux, l’art et la conception, le maquillage et la coiffure, les accessoires, le casting',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATL',
#   'CodeDescription': 'Radio / podcasts',
#   'CodeNotes': 'Utilisez les codes ATL* pour les aspects artistiques uniquement, à la fois pour la radio traditionnelle et des nouveaux médias, y compris le streaming, la télévision à la demande ou les autres formes de consommation de divertissement audio Lié\xa0: KNT',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATLD',
#   'CodeDescription': 'Pièces radiophoniques, scripts et représentations',
#   'CodeNotes': 'Classez ici : les pièces de théâtre radiophoniques, le théâtre audio, les spectacles de créations orales uniquement',
#   'CodeParent': 'ATL',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ATM',
#   'CodeDescription': 'Cinéma, télévision, radio et arts du spectacle : genres',
#   'CodeNotes': 'Utilisez pour les aspects artistiques uniquement. Utilisez avec les autres codes AT* pour spécifier le genre du film, de l’émission de télévision, de la performance audio, de la production théâtrale, etc. Préférez les codes F* pour les ouvrages de fiction sur ces genres, et ce qui s’y rapporte ou avec AVLM pour les ouvrages sur les films musicaux Lié\xa0: ATJS ATFN',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  {'CodeValue': 'ATMB',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : action, aventure, policier and thrillers',
#   'CodeNotes': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les arts martiaux, les catastrophes, les mystères, le suspense, les gangsters, les braquages, les espions, l’espionnage, les westerns, les films de guerre basés sur l’action',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'ATMC',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : comédie et humour',
#   'CodeNotes': 'Classez ici : les ouvrages sur les comédies romantiques, les romcoms, les infodivertissements humoristiques. Utilisez pour les ouvrages concernant les films, émissions, programmes ou séries humoristiques ou légères. Utilisez avec ATJS pour les ouvrages concernant les sitcoms télé',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  {'CodeValue': 'ATMF',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : drames',
#   'CodeNotes': 'Classez ici : les drames romantiques, de la vie quotidienne ou réaliste. Utilisez pour les ouvrages concernant des films, des émissions, des programmes ou des séries. Utilisez avec ATJS pour les ouvrages sur les feuilletons télévisés ou les séries dramatiques, ou avec ATN pour les séries ou les émissions web',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  {'CodeValue': 'ATMH',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : historique',
#   'CodeNotes': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les drames historiques, les péplums, les biographies historiques, les épopées, les samouraïs, etc. Utilisez pour les ouvrages sur les films, émissions, programmes ou séries où la période historique est l’un des aspects le plus important',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'ATMN',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : science fiction, fantasy et horreur',
#   'CodeNotes': '',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'ATMP',
#   'CodeDescription': 'Cinéma, télévision, radio : genres : super héros et inspirés des bandes dessinées',
#   'CodeNotes': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les personnages ou histoires inspirés par les bandes dessinées',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'ATN',
#   'CodeDescription': 'Internet et médias numériques\xa0: art et pratiques',
#   'CodeNotes': 'Classez ici\xa0: tous les aspects de l’internet en tant que vecteur médiatique, en particulier pour le contenu d’origine numérique\xa0: les célébrités provenant de l’internet, les blogueurs, les vloggers, les podcasts, etc. Lié\xa0: UD* KNTV KNTX',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.2,
#   'Modified': ''},
#  {'CodeValue': 'ATQ',
#   'CodeDescription': 'Danse',
#   'CodeNotes': 'Utilisez pour les ouvrages sur les techniques, les études, les ouvrages de référence. Utilisez avec JBC* pour les aspects des études culturelles ou les ouvrages académiques. Utilisez tous les codes AT* avec au besoin le(s) qualificateur(s) de style 6* appropriés',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'ATQC',
#   'CodeDescription': 'Chorégraphie',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATQL',
#   'CodeDescription': 'Ballet',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATQR',
#   'CodeDescription': 'Danse de salon',
#   'CodeNotes': 'Classez ici\xa0: les danses latines',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  {'CodeValue': 'ATQT',
#   'CodeDescription': 'Danse contemporaine',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'ATQV',
#   'CodeDescription': 'Danseurs / chorégraphes',
#   'CodeNotes': 'Classez ici\xa0: les troupes de danse, les groupes de danse, les compagnies',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'ATQZ',
#   'CodeDescription': 'Danse folklorique',
#   'CodeNotes': 'Classez ici : les danses traditionnelles',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'ATS',
#   'CodeDescription': 'Arts de la scène : le maquillage',
# ...
#   'CodeParent': 'LAF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  {'CodeValue': 'LAFR',
#   'CodeDescription': 'Systèmes juridiques\xa0: droit romain',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAFS',
#   'CodeDescription': 'Systèmes juridiques\xa0: droit islamique',
#   'CodeNotes': 'Lié\xa0: LW',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAFT',
#   'CodeDescription': 'Systèmes juridiques\xa0: droit juif',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAFX',
#   'CodeDescription': 'Systèmes juridiques\xa0: droit canonique',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAM',
#   'CodeDescription': 'Droit comparé',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAP',
#   'CodeDescription': 'Technologie juridique',
#   'CodeNotes': 'Utilisez pour les travaux qui examinent l’utilisation de la technologie dans le droit et le secteur juridique, les nouvelles technologies dans le secteur des services juridiques, l’impact de la technologie sur les services juridiques, la technologie juridique et la pratique juridique, les services juridiques virtuels, la technologie des cabinets d’avocats. Utilisez avec les codes U* pour les approches techniques',
#   'CodeParent': 'LA',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'LAQ',
#   'CodeDescription': 'Droit et société, sociologie du droit',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAQG',
#   'CodeDescription': 'Droit et société, questions de l’identité sexuelle',
#   'CodeNotes': '',
#   'CodeParent': 'LAQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAR',
#   'CodeDescription': 'Aspects juridiques de la criminologie',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAS',
#   'CodeDescription': 'Compétences et pratique juridiques',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LASD',
#   'CodeDescription': 'Plaidoirie',
#   'CodeNotes': '',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LASH',
#   'CodeDescription': 'Ecrits et rédaction juridiques',
#   'CodeNotes': 'Classez ici\xa0: la rédaction juridique académique',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'LASK',
#   'CodeDescription': 'Compétences juridiques\xa0: négociation et entrevue',
#   'CodeNotes': 'Classez ici\xa0: la communication orale en tant que compétence juridique',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'LASN',
#   'CodeDescription': 'Compétences juridiques\xa0: méthodes de recherche',
#   'CodeNotes': 'Classez ici\xa0: l’utilisation d’outils en ligne, les bases de données juridiques, etc.',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  {'CodeValue': 'LASP',
#   'CodeDescription': 'Auxiliaires juridiques',
#   'CodeNotes': '',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAT',
#   'CodeDescription': 'Profession juridique / pratique du droit\xa0: généralités',
#   'CodeNotes': 'Classez ici : les ouvrages qui portent sur les professionnels du droit et ceux qui pratiquent le droit, comme un avocat. Utilisez tous les codes LAT* pour\xa0les travaux sur les professionnels du droit, leurs rôles, la nature de leur travail, leurs responsabilités Lié\xa0: LNAL',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LATC',
#   'CodeDescription': 'Déontologie et conduite professionnelle',
#   'CodeNotes': '',
#   'CodeParent': 'LAT',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAY',
#   'CodeDescription': 'Droit s’appliquant à d’autres professions et disciplines',
#   'CodeNotes': 'Lié\xa0: VSD',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LAZ',
#   'CodeDescription': 'Histoire du droit',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LB',
#   'CodeDescription': 'Droit international',
#   'CodeNotes': '',
#   'CodeParent': 'L',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBB',
#   'CodeDescription': 'Droit international public',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBC',
#   'CodeDescription': 'Droit international public\xa0: traités et autres sources',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBC1',
#   'CodeDescription': 'Droit international public\xa0: droit coutumier',
#   'CodeNotes': '',
#   'CodeParent': 'LBBC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBD',
#   'CodeDescription': 'Droit international public\xa0: droit diplomatique',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBF',
#   'CodeDescription': 'Droit international public\xa0: juridiction et immunité',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBJ',
#   'CodeDescription': 'Droit international public\xa0: territoire et structure de l’Etat',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBK',
#   'CodeDescription': 'Droit international public\xa0: droit de la mer',
#   'CodeNotes': 'Classez ici\xa0: les lois concernant les frontières maritimes, les ressources maritimes, etc. affectant les états souverains Lié\xa0: LBDM LNCB5',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBL',
#   'CodeDescription': 'Droit international public\xa0: santé',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBM',
#   'CodeDescription': 'Droit international public\xa0: économie et commerce',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBM1',
#   'CodeDescription': 'Droit international public, économie et commerce\xa0: droits de douane',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBM3',
#   'CodeDescription': 'Droit international public, économie et commerce\xa0: traités d’investissement et conflits',
#   'CodeNotes': 'Classez ici : les lois et réglementations internationales en matière d’investissement, les accords internationaux d’investissement, le règlement des différends entre investisseurs et états, l’arbitrage des traités d’investissement',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LBBM5',
#   'CodeDescription': 'Droit international public\xa0: énergie et ressources naturelles',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBM7',
#   'CodeDescription': 'Droit international public, économie et commerce\xa0: sociétés',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBP',
#   'CodeDescription': 'Droit international public\xa0: environnement',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBP1',
#   'CodeDescription': 'Droit international public, environnement\xa0: droit agricole',
#   'CodeNotes': '',
#   'CodeParent': 'LBBP',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBQ',
#   'CodeDescription': 'Droit international public\xa0: administration',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBR',
#   'CodeDescription': 'Droit international public\xa0: droits de l’homme',
#   'CodeNotes': 'Classez ici : les droits substantiels et les droits inaliénables en droit international',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'LBBR1',
#   'CodeDescription': 'Droit international public, droits de l’homme\xa0: travail et droits sociaux',
#   'CodeNotes': '',
#   'CodeParent': 'LBBR',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBS',
#   'CodeDescription': 'Droit international public\xa0: droit humanitaire',
#   'CodeNotes': 'Classez ici\xa0: le droit des réfugiés, le droit de la guerre',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBU',
#   'CodeDescription': 'Droit international public\xa0: organisations et institutions internationales',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBV',
#   'CodeDescription': 'Droit international public\xa0: responsabilité des états et des autres entités',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBBZ',
#   'CodeDescription': 'Droit international public\xa0: droit pénal',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBD',
#   'CodeDescription': 'Droit international\xa0: transport, communications et commerce',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBDA',
#   'CodeDescription': 'Droit international, transport\xa0: droit de l’espace et de l’aérospatiale',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBDK',
#   'CodeDescription': 'Droit international\xa0: droit du commerce transnational et de la vente internationale de marchandises',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBDM',
#   'CodeDescription': 'Droit international, transport et commerce\xa0: droit maritime',
#   'CodeNotes': 'Classez ici\xa0: les lois concernant la navigation, le fret, les assurances, la piraterie, etc. affectant les organismes commerciaux et non les états souverains Lié\xa0: LBBK LNCB5',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBDT',
#   'CodeDescription': 'Droit international\xa0: communications, télécommunications et média',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBG',
#   'CodeDescription': 'Droit international privé et conflit de lois',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBH',
#   'CodeDescription': 'Droit international\xa0: conflits internationaux et procédure civile',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBHG',
#   'CodeDescription': 'Droit international\xa0: tribunaux et procédures',
#   'CodeNotes': '',
#   'CodeParent': 'LBH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBHT',
#   'CodeDescription': 'Droit international\xa0: arbitrage',
#   'CodeNotes': '',
#   'CodeParent': 'LBH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBJ',
#   'CodeDescription': 'Droit international\xa0: propriété intellectuelle',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBK',
#   'CodeDescription': 'Droit international\xa0: sports',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LBL',
#   'CodeDescription': 'Rapports de droit international',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LN',
#   'CodeDescription': 'Droit des juridictions spécialisées et domaines particuliers du droit',
#   'CodeNotes': 'Avec les codes LN*, associez également des qualificateurs de lieux appropriés pour indiquer la juridiction',
#   'CodeParent': 'L',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNA',
#   'CodeDescription': 'Systèmes juridiques\xa0: généralités',
#   'CodeNotes': '',
#   'CodeParent': 'LN',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAA',
#   'CodeDescription': 'Systèmes juridiques\xa0: tribunaux et procédure',
#   'CodeNotes': 'Classez ici : le système inquisitoire, le système accusatoire, les règles des tribunaux. Utilisez pour\xa0les ouvrages sur différents types de tribunaux, lois et aspects juridiques des procédures et processus de ces tribunaux',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LNAA1',
#   'CodeDescription': 'Systèmes juridiques\xa0: juges et pouvoirs judiciaires',
#   'CodeNotes': 'Classez ici : le juge d’instruction. Utilisez pour les différents types de juges, la magistrature et les ouvrages sur les pouvoirs judiciaires',
#   'CodeParent': 'LNAA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LNAA12',
#   'CodeDescription': 'Systèmes juridiques\xa0: juges/jurés non professionnels et citoyens',
#   'CodeNotes': 'Classez ici : les assesseurs et les magistrats non professionnels, les jurés, etc. Utilisez pour\xa0les ouvrages sur ou pour des citoyens qui ne sont pas des professionnels du droit, ou qui ont une formation juridique minimale et qui participent à des procès en tant que citoyens ou juges non professionnels ou en tant que membres du jury',
#   'CodeParent': 'LNAA1',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'LNAA2',
#   'CodeDescription': 'Systèmes juridiques\xa0: délit d’outrage',
#   'CodeNotes': '',
#   'CodeParent': 'LNAA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC',
#   'CodeDescription': 'Systèmes juridiques\xa0: procédure civile, litige et règlement des conflits',
#   'CodeNotes': 'Classez ici : le délai de prescription, le droit réparateur, les règles de procédure, le droit des adjectifs, le droit procédural Lié\xa0: LNFX',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LNAC1',
#   'CodeDescription': 'Recours civils',
#   'CodeNotes': 'Classez ici : l’enrichissement injuste / injustifié, le traçage équitable',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'LNAC12',
#   'CodeDescription': 'Réparation',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC14',
#   'CodeDescription': 'Dommages-intérêts et indemnisation',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC16',
#   'CodeDescription': 'Injonctions et autres ordres des tribunaux',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC3',
#   'CodeDescription': 'Procédure civile\xa0: droit de la preuve',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC4',
#   'CodeDescription': 'Procédure civile\xa0: instruction et procédures particulières',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAC5',
#   'CodeDescription': 'Arbitrage, médiation et modes de règlement alternatif des conflits',
#   'CodeNotes': 'Classez ici : la modération et la négociation juridique',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'LNAD',
#   'CodeDescription': 'Systèmes juridiques : partie générale / dispositions générales',
#   'CodeNotes': 'Utilisez pour\xa0les ouvrages sur les systèmes juridiques, les codes civils, les constitutions, qui contiennent des sections générales de règles et de définitions de base, des réglementations généralement applicables. Utilisez, au besoin, avec d’autres codes L* pour les ouvrages sur l’application de ces règles à des domaines spécifiques du droit',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  {'CodeValue': 'LNAF',
#   'CodeDescription': 'Systèmes juridiques\xa0: coûts et financement',
#   'CodeNotes': '',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNAL',
#   'CodeDescription': 'Systèmes juridiques\xa0: règlementation des professions juridiques',
#   'CodeNotes': '',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  {'CodeValue': 'LNB',
#   'CodeDescription': 'Droit privé ou civil\xa0: généralités',
#   'CodeNotes': '',
#   'CodeParent': 'LN',
#   'IssueNumber': 1,
#   'Modified': ''},
#  ...]

# %%
thema_dict = {}
for node in thema_codes:
    thema_dict[node["CodeValue"]] = node
thema_dict
# Out:
# {'A': {'CodeValue': 'A',
#   'CodeDescription': 'The Arts',
#   'CodeNotes': 'Use all A* codes for: specialist and general adult titles, including both highly illustrated and more text-based works. For a hobby or recreational approach, prefer a WF* code as the main subject and supplement with A* code(s) where appropriate. Use all A* codes with: other subject categories and qualifiers as appropriate, in particular STYLE 6*, plus PLACE 1* and TIME PERIOD 3* Qualifiers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AB': {'CodeValue': 'AB',
#   'CodeDescription': 'The arts: general topics',
#   'CodeNotes': '',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ABA': {'CodeValue': 'ABA',
#   'CodeDescription': 'Theory of art',
#   'CodeNotes': 'See also: QDTN',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ABC': {'CodeValue': 'ABC',
#   'CodeDescription': 'Conservation, restoration and care of artworks',
#   'CodeNotes': 'Use with: other A* codes for works about the conservation, preservation, renovation, restoration or care of any type of art, including buildings, structures, sculptures, photos, paintings, decorative arts, etc',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ABK': {'CodeValue': 'ABK',
#   'CodeDescription': 'Forgery, falsification and theft of artworks',
#   'CodeNotes': '',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ABQ': {'CodeValue': 'ABQ',
#   'CodeDescription': 'Art: financial aspects',
#   'CodeNotes': 'Class here: art sales and auctioneering, funding, patronage and sponsorship, curated sales, the Crypto art NFT market, the blockchain art market, art as a financial investment or speculation, commercial value of art, the business of art',
#   'CodeParent': 'AB',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AF': {'CodeValue': 'AF',
#   'CodeDescription': 'The Arts: art forms',
#   'CodeNotes': 'Use for: works on the fine, visual and applied arts. Use all AF* codes with: the relevant AG* code(s), AGA for History of art and artworks, AGZ for specialist works about technique, and STYLE Qualifiers 6* as appropriate. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFC': {'CodeValue': 'AFC',
#   'CodeDescription': 'Paintings and painting',
#   'CodeNotes': 'Class here: painting or paintings in general, or in any medium with no more specific category below. Use all AFC* codes for: works about a painting or paintings, by individuals or groups, including the history of particular paintings, or a particular style of painting. Use with: STYLE 6* Qualifiers as appropriate, AGA for History of artworks, AGB for monographs of painters, AGZ for specialist works about technique, etc. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFCC': {'CodeValue': 'AFCC',
#   'CodeDescription': 'Paintings and painting in watercolours or pastels',
#   'CodeNotes': 'Class here: gouache',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFCL': {'CodeValue': 'AFCL',
#   'CodeDescription': 'Paintings and painting in oils',
#   'CodeNotes': 'Class here: acrylic paintings and painting',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AFCM': {'CodeValue': 'AFCM',
#   'CodeDescription': 'Murals and wall paintings',
#   'CodeNotes': 'Class here: trompe l’oeil, frescos, ceiling paintings, muralism, marouflage',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  'AFCP': {'CodeValue': 'AFCP',
#   'CodeDescription': 'Paintings and painting in ink',
#   'CodeNotes': 'Class here: ink wash, See also: AFFK',
#   'CodeParent': 'AFC',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AFF': {'CodeValue': 'AFF',
#   'CodeDescription': 'Drawing and drawings',
#   'CodeNotes': 'Class here: sketches. Use all AFF* codes for: works about a drawing or drawings, by individual artists or groups, including the history of particular drawings, or a particular style or technique of drawing. Use with: STYLE 6* Qualifiers as appropriate, AGA for History of artworks, AGB for monographs of artists, AGZ for specialist works about technique. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFFC': {'CodeValue': 'AFFC',
#   'CodeDescription': 'Drawing and drawings in pencil, charcoal, crayon or pastel',
#   'CodeNotes': 'Class here: graphite, chalk, conté',
#   'CodeParent': 'AFF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AFFK': {'CodeValue': 'AFFK',
#   'CodeDescription': 'Drawing and drawings in pen or brush and ink',
#   'CodeNotes': 'See also: AFCP',
#   'CodeParent': 'AFF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AFH': {'CodeValue': 'AFH',
#   'CodeDescription': 'Prints and printmaking',
#   'CodeNotes': 'Class here: etchings, silk screens, screenprints, woodcuts, lithographs, line engravings, aquatints, dry point, mezzotints, monotypes, woodblocks',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFJ': {'CodeValue': 'AFJ',
#   'CodeDescription': 'Other graphic or visual art forms',
#   'CodeNotes': 'Class here: collage, photomontage. Use for: general works or art forms that do not have a specific code in AFC*, AFF* or AFH*',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFJY': {'CodeValue': 'AFJY',
#   'CodeDescription': 'Body art and tattoos',
#   'CodeNotes': 'Class here: body piercing, body painting as art. Use with: AFKP for performance art',
#   'CodeParent': 'AFJ',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AFK': {'CodeValue': 'AFK',
#   'CodeDescription': 'Non-graphic and electronic art forms',
#   'CodeNotes': 'Use for: general works on non-graphic forms of art, or art using forms not listed below, including newer forms of media',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFKB': {'CodeValue': 'AFKB',
#   'CodeDescription': 'Sculpture',
#   'CodeNotes': 'Class here: statues, figurines, monumental sculpture. Use for: works about three-dimensional art made in any material, and for works about the art form, or associated traditions and techniques',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFKC': {'CodeValue': 'AFKC',
#   'CodeDescription': 'Carvings, masks, reliefs',
#   'CodeNotes': 'Class here: petroglyphs, small-scale and monumental carvings. Use for: both the technique and works about specific carved objects or carved designs in any material',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFKG': {'CodeValue': 'AFKG',
#   'CodeDescription': 'Precious metal, precious stones and jewellery: artworks and design',
#   'CodeNotes': 'Class here: gold and silversmithing, Fabergé, etc, See also: WFJ WCP WCR WFP',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AFKN': {'CodeValue': 'AFKN',
#   'CodeDescription': 'Installation art',
#   'CodeNotes': 'Class here: land art, site-specific art, environmental art',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFKP': {'CodeValue': 'AFKP',
#   'CodeDescription': 'Performance art',
#   'CodeNotes': '',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AFKV': {'CodeValue': 'AFKV',
#   'CodeDescription': 'Digital, video and new media arts',
#   'CodeNotes': 'Class here: computer, electronic, holographic, virtual, cyborg, interactive, internet, generative, telematic, sound and evolutionary arts, crypto art, video game art, software art, See also: UG*',
#   'CodeParent': 'AFK',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AFP': {'CodeValue': 'AFP',
#   'CodeDescription': 'Ceramics, mosaic and glass: artworks',
#   'CodeNotes': 'Class here: pottery (including porcelain, earthenware, stoneware, bisque), stained glass, tiles or enamelwork as artworks, See also: WFN',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AFT': {'CodeValue': 'AFT',
#   'CodeDescription': 'Decorative arts',
#   'CodeNotes': 'Class here: ornament, ornamental motifs, decorative details, patterns or shapes, faux painting or finishing, decorative metalwork, lacquerware and other decorative arts. Use for: works that look at the subject from a fine arts or history of art perspective, or aimed at a more professional, technical or skilled audience, See also: WF*',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AFW': {'CodeValue': 'AFW',
#   'CodeDescription': 'Textile artworks',
#   'CodeNotes': 'Class here: carpets, kilims, rugs, quilts, tapestries and other textiles as art, See also: AKT WFB* WFF WFG',
#   'CodeParent': 'AF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AG': {'CodeValue': 'AG',
#   'CodeDescription': 'The Arts: treatments and subjects',
#   'CodeNotes': 'Use for: works on the fine, visual and applied arts. Use all AG* codes with: the relevant\xa0AB*, AF*, AG*, AJ* code(s) and also STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGA': {'CodeValue': 'AGA',
#   'CodeDescription': 'History of art',
#   'CodeNotes': 'Use with: other Arts codes A* and also STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AGB': {'CodeValue': 'AGB',
#   'CodeDescription': 'Individual artists, art monographs',
#   'CodeNotes': 'Use for: works on both individual artists and ateliers or workshops that produced under a single artist’s name',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGC': {'CodeValue': 'AGC',
#   'CodeDescription': 'Exhibition catalogues and specific collections',
#   'CodeNotes': 'Use for: publications that are linked to either a temporary exhibition or the catalogues of permanent collections such as art galleries, museums or individual collectors. Use with: other A* codes to indicate Art form and a PLACE 1* Qualifiers if it is the catalogue of a permanent location such as a specific gallery or museum, See also: WTHM GLZ',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGH': {'CodeValue': 'AGH',
#   'CodeDescription': 'Human figures depicted in art',
#   'CodeNotes': 'Class here: figure painting or drawing, illustrations of human anatomy for artists, anatomical drawing, or any art that depicts the human or parts of the human body. Use with: AGZ for techniques of drawing',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGHF': {'CodeValue': 'AGHF',
#   'CodeDescription': 'Portraits and self-portraiture in art',
#   'CodeNotes': '',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AGHN': {'CodeValue': 'AGHN',
#   'CodeDescription': 'Nudes depicted in art',
#   'CodeNotes': '',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AGHX': {'CodeValue': 'AGHX',
#   'CodeDescription': 'Erotic art',
#   'CodeNotes': 'Use with: Qualifier 5X as appropriate, See also: AJCX',
#   'CodeParent': 'AGH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AGK': {'CodeValue': 'AGK',
#   'CodeDescription': 'Small-scale, secular and domestic scenes in art',
#   'CodeNotes': 'Class here: ‘genre’ subjects, everyday scenes and events in art',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AGN': {'CodeValue': 'AGN',
#   'CodeDescription': 'Nature in art',
#   'CodeNotes': 'Use for: any depiction of nature in any artistic form or tradition. Use with: AKLB for illustration, or PS* for art that has or was originally for, a scientific purpose',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGNA': {'CodeValue': 'AGNA',
#   'CodeDescription': 'Animals in art',
#   'CodeNotes': 'Class here: animal painters, wildlife art, birds, insects, fish in art. Use for: any depiction of fauna in any artistic form or tradition. Use with: AKLB for illustration, or PS* for art that has or was originally for, a scientific purpose',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  'AGNB': {'CodeValue': 'AGNB',
#   'CodeDescription': 'Botanical art',
#   'CodeNotes': 'Class here: botanical illustration. Use for: any kind of artistic, accurate representation of trees, flowers or plants depicted in any art form or tradition. Use with: PST for works about botanical art that has a scientific purpose, often works that have text about the plants, or reproductions of historic botanical works, or with AKLB for works about botanical art as examples of the art of illustration',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AGNL': {'CodeValue': 'AGNL',
#   'CodeDescription': 'Landscapes / seascapes',
#   'CodeNotes': 'Class here: skyscapes, cloudscapes, riverscapes, river scenes, landscape art, veduta, cityscapes, townscapes, moonscapes, waterscapes, inscapes, Weltlandschaft. Use for: works about types of ‘scapes’ in visual arts, or individual examples',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  'AGNS': {'CodeValue': 'AGNS',
#   'CodeDescription': 'Still life',
#   'CodeNotes': 'Class here: vanitas, nature morte, memento mori. Use for: depictions of small scale scenes of mostly inanimate objects both natural and man-made, essentially, the subject matter of a still life painting, photo, sculpture or other art form is anything that does not move or is dead',
#   'CodeParent': 'AGN',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  'AGP': {'CodeValue': 'AGP',
#   'CodeDescription': 'Man-made objects depicted in art',
#   'CodeNotes': 'Class here: buildings, machines, transport etc, depicted in any art form or tradition',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AGR': {'CodeValue': 'AGR',
#   'CodeDescription': 'Religious and ceremonial art',
#   'CodeNotes': 'Class here: sacred or ritual art, icons, votive images. Use for: works about artistic imagery using religious inspiration or motifs, artistic representation of figures, patterns, shapes, calligraphy etc for spiritual or religious purposes. Use with: QR* codes to denote a particular religion as appropriate and other A* codes for works on particular types of art',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AGT': {'CodeValue': 'AGT',
#   'CodeDescription': 'Public art',
#   'CodeNotes': 'Use for: works on art in any media that were planned and executed with the intention of being staged in the public realm, often outside and accessible to all, either permanent or temporary, and which may be specially commissioned for a site or unofficial or unauthorised',
#   'CodeParent': 'AG',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AGTS': {'CodeValue': 'AGTS',
#   'CodeDescription': 'Urban arts',
#   'CodeNotes': 'Class here: guerrilla art, graffiti art, flyposting, sticker art, yarn bombing, street installations, urban styles etc. Use for: works about visual or applied art forms in urban areas, inspired by urban lifestyles or environment and in the public space',
#   'CodeParent': 'AGT',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AGZ': {'CodeValue': 'AGZ',
#   'CodeDescription': 'The Arts: techniques and principles',
#   'CodeNotes': 'Use for: textbooks, advanced level and specialised works on techniques, perspective etc. Use with: appropriate AF* or AK* codes to indicate the art form, for example AFF for drawing techniques. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches, See also: WFA',
#   'CodeParent': 'AG',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AGZC': {'CodeValue': 'AGZC',
#   'CodeDescription': 'Colours and colour theory',
#   'CodeNotes': 'Class here: colour science in art. Use with: P* or T* codes for more scientific or technical works',
#   'CodeParent': 'AGZ',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AJ': {'CodeValue': 'AJ',
#   'CodeDescription': 'Photography and photographs',
#   'CodeNotes': '',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AJC': {'CodeValue': 'AJC',
#   'CodeDescription': 'Photographs: collections',
#   'CodeNotes': 'Use for: works that are or are about collections or curated selections of photos usually with a common theme or principle or representing the collection of a museum, gallery, agency or collector. Use with: AG* codes for specific treatments or subjects or other codes indicating the theme as appropriate, See also: WQP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AJCD': {'CodeValue': 'AJCD',
#   'CodeDescription': 'Individual photographers',
#   'CodeNotes': 'Class here: photographic monographs',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AJCP': {'CodeValue': 'AJCP',
#   'CodeDescription': 'Photography: portraits and self-portraiture',
#   'CodeNotes': 'Use for: works that present an individual or individuals and groups through photos, including selfies and individual models, as well as works on portrait photography. Use with: AJTF for works on the practical techniques of portrait photography',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1.1,
#   'Modified': 1.4},
#  'AJCX': {'CodeValue': 'AJCX',
#   'CodeDescription': 'Erotic and nude photography',
#   'CodeNotes': 'Use with: Qualifier 5X as appropriate, See also: AGHX',
#   'CodeParent': 'AJC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AJF': {'CodeValue': 'AJF',
#   'CodeDescription': 'Photojournalism and documentary photography',
#   'CodeNotes': 'Class here: photographic reportage, social documentary and street photography, event and celebrity photography, See also: DNP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AJT': {'CodeValue': 'AJT',
#   'CodeDescription': 'Photographic equipment and techniques: general',
#   'CodeNotes': 'Class here: cameras, lenses, film, darkroom techniques and photo processing, retouching and digital manipulation, principles of colour, composition, etc, See also: UGP',
#   'CodeParent': 'AJ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AJTA': {'CodeValue': 'AJTA',
#   'CodeDescription': 'Camera-specific manuals',
#   'CodeNotes': 'Use for: any publication about a specific camera type or brand',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AJTF': {'CodeValue': 'AJTF',
#   'CodeDescription': 'Photography: subject-specific techniques and principles',
#   'CodeNotes': 'Class here: aerial, drone, studio, street, landscape, nature and wildlife, portrait, underwater photography, micro- and astrophotography techniques and guides. Use for: works on composition, etc',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AJTH': {'CodeValue': 'AJTH',
#   'CodeDescription': 'Digital photography',
#   'CodeNotes': '',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AJTR': {'CodeValue': 'AJTR',
#   'CodeDescription': 'Monochrome photography',
#   'CodeNotes': 'Class here: greyscale monochrome, black-and-white, sepia, cyanotype, brown monochrome photography. Use with: AJTV for monochrome techniques in film / video',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'AJTS': {'CodeValue': 'AJTS',
#   'CodeDescription': 'Light and lighting',
#   'CodeNotes': 'Class here: flash photography, use of natural or artificial light or lighting. Use with: AJTV for lighting techniques in film / video or with AT* codes for lighting techniques or lighting design in the performing arts',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'AJTV': {'CodeValue': 'AJTV',
#   'CodeDescription': 'Video photography / videography',
#   'CodeNotes': 'See also: AFKV ATFX ATJX',
#   'CodeParent': 'AJT',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AK': {'CodeValue': 'AK',
#   'CodeDescription': 'Design, Industrial and commercial arts, illustration',
#   'CodeNotes': 'Use all AK* codes for: works that look at the subject from a fine arts or history of art perspective, or aimed at a professional, technical or skilled audience. Use with: STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKB': {'CodeValue': 'AKB',
#   'CodeDescription': 'Individual designers or design groups',
#   'CodeNotes': 'Class here: design agencies, brands, companies, firms or houses as well as named individuals. Use with: other subject codes to indicate what field of design as appropriate, e.g. AKT for fashion designers, plus AKX for historical approaches',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKC': {'CodeValue': 'AKC',
#   'CodeDescription': 'Graphic design',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AKD': {'CodeValue': 'AKD',
#   'CodeDescription': 'Typography and lettering',
#   'CodeNotes': 'Class here: typefaces, font design and fonts, sign painting, shufa, shodo, khatt and other forms of calligraphy as an art, See also: WFU',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKH': {'CodeValue': 'AKH',
#   'CodeDescription': 'Book design and Bookbinding',
#   'CodeNotes': 'Class here: cover design, fine binding, paper marbling, etc as arts. Use for: works on the arts of designing and creating books, See also: WFT AKLB KNTP1',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKHM': {'CodeValue': 'AKHM',
#   'CodeDescription': 'Manuscripts and illumination',
#   'CodeNotes': 'Class here: miniatures, illuminated or painted manuscripts, scrolls and codices',
#   'CodeParent': 'AKH',
#   'IssueNumber': 1.3,
#   'Modified': 1.4},
#  'AKL': {'CodeValue': 'AKL',
#   'CodeDescription': 'Illustration and commercial art',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AKLB': {'CodeValue': 'AKLB',
#   'CodeDescription': 'Illustration',
#   'CodeNotes': 'Class here: book illustrations and information graphics as an art. Use for: works on illustration as an art form as well as illustration, both contemporary and historical, used for scientific, technical, narrative and other purposes, See also: AFF',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKLC': {'CodeValue': 'AKLC',
#   'CodeDescription': 'Comic book and cartoon artwork',
#   'CodeNotes': 'Use all AKLC* codes with: X* subject codes to indicate the form of the comic book involved, with AGZ for specialist works about the techniques of drawing comic book art or characters, with AKX for histories of comic book art. Prefer: WF* codes as the main subject for more amateur, hobby or recreational approaches or UGL for more technical digital illustration, See also: AFF',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKLC1': {'CodeValue': 'AKLC1',
#   'CodeDescription': 'Graphic novel and Manga artwork',
#   'CodeNotes': 'Use with: X* subject codes to indicate the form of the artwork involved, See also: XA* XR* AFF',
#   'CodeParent': 'AKLC',
#   'IssueNumber': 1,
#   'Modified': 1.2},
#  'AKLF': {'CodeValue': 'AKLF',
#   'CodeDescription': 'Computer game art',
#   'CodeNotes': 'Use for: works on artistic aspects of game design, artwork, graphics, video game art, etc, See also: UGG',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1.1,
#   'Modified': 1.5},
#  'AKLP': {'CodeValue': 'AKLP',
#   'CodeDescription': 'Poster art',
#   'CodeNotes': '',
#   'CodeParent': 'AKL',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AKP': {'CodeValue': 'AKP',
#   'CodeDescription': 'Product design',
#   'CodeNotes': 'Class here: universal or accessible design for products, Industrial design. Use for: works about product design in general, including associated trade or brand names, about design of an individual product or types of products, about functionality and safety, sustainable design of products etc, See also: TBD UGC',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AKR': {'CodeValue': 'AKR',
#   'CodeDescription': 'Furniture design',
#   'CodeNotes': '',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AKT': {'CodeValue': 'AKT',
#   'CodeDescription': 'Fashion and textile design',
#   'CodeNotes': 'Use for: fashion styles and trends in fashion design, general and reference works, works about specific items of clothing, illustrated works about fashion etc. Use all AKT* codes with: AKB for individual fashion designers, with AKX for history of fashion, plus STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate, with AJC* for photographic collections or fashion photography, with AGZ for practical techniques for fashion students and designers. Prefer: WJF as the main subject code for works aimed at a general audience about how to dress, guides to looking stylish, practical tips etc, See also: TDPF* KNDD KNSX WJF',
#   'CodeParent': 'AK',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AKTF': {'CodeValue': 'AKTF',
#   'CodeDescription': 'Fashion and textile design: accessories',
#   'CodeNotes': 'Class here: millinery, cordwainer, glove making, fashion and style in bags, hats, shoes, sneakers and other accessories. Use for: works, usually illustrated, that look at aspects of the design, or the aesthetics of different accessories in fashion or costume',
#   'CodeParent': 'AKT',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  'AKTR': {'CodeValue': 'AKTR',
#   'CodeDescription': 'National or regional costume / textiles',
#   'CodeNotes': 'Class here: folk, ethnic and traditional costume, traditional garments, national dress, traditional textiles or cloth associated with particular groups or regions, etc. Use for: works that look at costumes of the past as well as contemporary costume. Use with: PLACE 1* Qualifiers codes as appropriate',
#   'CodeParent': 'AKT',
#   'IssueNumber': 1.3,
#   'Modified': 1.5},
#  'AKX': {'CodeValue': 'AKX',
#   'CodeDescription': 'History of design',
#   'CodeNotes': 'Use with: other AK* and also STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate',
#   'CodeParent': 'AK',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AM': {'CodeValue': 'AM',
#   'CodeDescription': 'Architecture',
#   'CodeNotes': 'Use all AM* codes with: STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate, with TNKK or ABC for works about adaptive reuse, repurposing, restoration or conservation of buildings and structures, with other TNK* codes for topics that also concern more technical works on building and construction',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AMA': {'CodeValue': 'AMA',
#   'CodeDescription': 'Theory of architecture',
#   'CodeNotes': '',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AMB': {'CodeValue': 'AMB',
#   'CodeDescription': 'Individual architects and architectural firms',
#   'CodeNotes': 'Class here: architectural monographs',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMC': {'CodeValue': 'AMC',
#   'CodeDescription': 'Architectural structure and design',
#   'CodeNotes': 'Class here: architectural drawings, sections, elevations, architectural renderings, floor plans. Use for: works that look at the subject from an architectural perspective. Use with: STYLE 6* Qualifiers as appropriate. Prefer: TN* codes for works that look at the technical nature of building and construction, See also: TN*',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMCD': {'CodeValue': 'AMCD',
#   'CodeDescription': 'Architectural details, components and motifs',
#   'CodeNotes': 'Use for: works that examine the individual elements of a building or structure, e.g. windows, doors, roof design, ornamentation etc',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'AMCM': {'CodeValue': 'AMCM',
#   'CodeDescription': 'Materials in architecture',
#   'CodeNotes': 'Use for: works, often highly illustrated, that look at structures specifically from the point of view of the materials they are made from, such as concrete, brick, steel, glass, wood etc. Prefer: TN* codes for more technical, structural engineering approaches, See also: TN*',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'AMCR': {'CodeValue': 'AMCR',
#   'CodeDescription': 'Environmentally-friendly (‘green’) architecture and design',
#   'CodeNotes': 'Class here: low-impact, sustainable and energy-efficient or energy-neutral architecture, building and interior design and technologies, arcology, green buildings, ecodesign and environmental design, biophilic and biomimetic architecture, plans for sustainable homes, carbon-neutral building techniques, practical guides to materials, green building projects, passive building design, etc. Use with: RNU for works about sustainability and TNK* codes for works about sustainable building and construction',
#   'CodeParent': 'AMC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'AMD': {'CodeValue': 'AMD',
#   'CodeDescription': 'Architecture: professional practice',
#   'CodeNotes': '',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AMG': {'CodeValue': 'AMG',
#   'CodeDescription': 'Architecture: public, commercial and industrial buildings',
#   'CodeNotes': 'Class here: agricultural, industrial, commercial and civic buildings, such as, concert halls, arenas, stadia, memorials and monuments, hospitals, lighthouses, libraries, museums, galleries, exhibition spaces, stations, airports, hotels, spas, factories, warehouses, offices, shops, stores etc. Use for: works on buildings which have a primary function other than residential or domestic, and which are usually accessible to large groups of people. Use with: AMR as appropriate, See also: JWT WTHM',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMK': {'CodeValue': 'AMK',
#   'CodeDescription': 'Architecture: residential and domestic buildings',
#   'CodeNotes': 'Class here: private homes, houses, apartments, flats, lofts, cottages, villas. Use for: works on house design, or about residential dwellings, both contemporary and historical, that can either be purpose built or converted structures. Use with: AMR interior design as appropriate, See also: WJK AMR',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMKH': {'CodeValue': 'AMKH',
#   'CodeDescription': 'Architecture: small-scale domestic buildings',
#   'CodeNotes': 'Class here: works on cabins, huts, sheds, tree houses, follies, tiny houses, summerhouses, outhouses, boathouses etc. Use for: works about smaller domestic, but not necessarily residential, buildings and structures, often connected with leisure, holidays, recreation or pleasure',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1.2,
#   'Modified': 1.4},
#  'AMKL': {'CodeValue': 'AMKL',
#   'CodeDescription': 'Architecture: castles and fortifications',
#   'CodeNotes': '',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AMKS': {'CodeValue': 'AMKS',
#   'CodeDescription': 'Architecture: palaces, stately homes and mansions',
#   'CodeNotes': '',
#   'CodeParent': 'AMK',
#   'IssueNumber': 1.2,
#   'Modified': ''},
#  'AMN': {'CodeValue': 'AMN',
#   'CodeDescription': 'Architecture: religious buildings',
#   'CodeNotes': 'Class here: architectural aspects of abbeys, cathedrals, churches, mosques, synagogues, temples and other religious buildings or structures',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMR': {'CodeValue': 'AMR',
#   'CodeDescription': 'Architecture: interior design',
#   'CodeNotes': 'Use for: works that look at the subject as a decorative art, often presented in well illustrated editions and aimed at a more professional or skilled audience, including studies of interior architecture and design, lighting design, residential, commercial or other interior design specialisations. Use with: AKB for individual interior designers. Prefer: WJK as a main subject code for more amateur and domestic approaches, See also: WJK',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AMV': {'CodeValue': 'AMV',
#   'CodeDescription': 'Landscape architecture and design',
#   'CodeNotes': 'See also: WMD',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'AMVD': {'CodeValue': 'AMVD',
#   'CodeDescription': 'City and town planning: architectural aspects',
#   'CodeNotes': 'See also: RPC',
#   'CodeParent': 'AMV',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AMX': {'CodeValue': 'AMX',
#   'CodeDescription': 'History of architecture',
#   'CodeNotes': 'Use with: STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate',
#   'CodeParent': 'AM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'AT': {'CodeValue': 'AT',
#   'CodeDescription': 'Performing arts',
#   'CodeNotes': 'Use all AT* codes with: STYLE 6*, PLACE 1* and TIME PERIOD 3* Qualifiers as appropriate',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATC': {'CodeValue': 'ATC',
#   'CodeDescription': 'Individual actors and performers',
#   'CodeNotes': 'Class here: media personalities, presenters. Use with: relevant AT* code to indicate whether specifically theatre, film, TV, radio etc, See also: DNBF*',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'ATD': {'CodeValue': 'ATD',
#   'CodeDescription': 'Theatre studies',
#   'CodeNotes': 'See also: DD*',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATDC': {'CodeValue': 'ATDC',
#   'CodeDescription': 'Acting techniques',
#   'CodeNotes': 'Class here: monologues, audition material, advice and techniques, voice acting, voice techniques, acting methods, acting for camera, improvisation techniques, movement techniques for actors etc',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ATDF': {'CodeValue': 'ATDF',
#   'CodeDescription': 'Theatre direction and production',
#   'CodeNotes': '',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATDH': {'CodeValue': 'ATDH',
#   'CodeDescription': 'Theatre: technical and background skills',
#   'CodeNotes': 'Class here: stagecraft, wardrobe, costume, hair and makeup, lighting design and production, scenery and props, stage, set and scenic design and creation, stage management, special effects, theatrical sound design and production',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ATDS': {'CodeValue': 'ATDS',
#   'CodeDescription': 'Theatre management',
#   'CodeNotes': '',
#   'CodeParent': 'ATD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATF': {'CodeValue': 'ATF',
#   'CodeDescription': 'Films, cinema',
#   'CodeNotes': 'Use all ATF* codes for: performing arts aspects only, both for the traditional big screen and made-for-TV movies or for long-form films made for new media, including streaming, on demand or other services (but excluding episodic presentations), See also: KNTC',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATFA': {'CodeValue': 'ATFA',
#   'CodeDescription': 'Film history, theory or criticism',
#   'CodeNotes': 'Use for: works on national cinemas, history or critiques of individual films, film studios, movie franchises',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATFB': {'CodeValue': 'ATFB',
#   'CodeDescription': 'Individual film directors, film-makers',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATFD': {'CodeValue': 'ATFD',
#   'CodeDescription': 'Film scripts and screenplays',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATFG': {'CodeValue': 'ATFG',
#   'CodeDescription': 'Film guides and reviews',
#   'CodeNotes': '',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATFN': {'CodeValue': 'ATFN',
#   'CodeDescription': 'Film: styles and genres',
#   'CodeNotes': 'Use for: works about specific styles or genres of cinema. Use with: ATM* codes or other ATF* codes to describe the specific style or genre of film, as appropriate, See also: ATM*',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATFR': {'CodeValue': 'ATFR',
#   'CodeDescription': 'Documentary films',
#   'CodeNotes': 'Use for: works on short or long form documentaries, for documentary film making for the big and small screen, works on scripted, largely factual programming',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATFV': {'CodeValue': 'ATFV',
#   'CodeDescription': 'Animated films and animation',
#   'CodeNotes': 'Use for: works about animated films or shorts. Use with: AGZ for techniques of animation, See also: UGN',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATFV1': {'CodeValue': 'ATFV1',
#   'CodeDescription': 'Anime',
#   'CodeNotes': 'Use for: Japanese style animated films, See also: AKLC1',
#   'CodeParent': 'ATFV',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'ATFX': {'CodeValue': 'ATFX',
#   'CodeDescription': 'Filmmaking and production: technical and background skills',
#   'CodeNotes': 'Class here: cinematography, editing, lighting, scenery, costume, special effects, artwork and design, makeup and hair, props, casting, See also: CBVS UG*',
#   'CodeParent': 'ATF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATJ': {'CodeValue': 'ATJ',
#   'CodeDescription': 'Television',
#   'CodeNotes': 'Use all ATJ* codes for: performing arts aspects only, both for traditional television or for new media, including streaming, on demand or other forms of consuming small screen entertainment (including episodic presentations), See also: KNTC',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATJD': {'CodeValue': 'ATJD',
#   'CodeDescription': 'Television screenplays, scripts and performances',
#   'CodeNotes': 'See also: WHG',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.2},
#  'ATJS': {'CodeValue': 'ATJS',
#   'CodeDescription': 'Television: styles and genres',
#   'CodeNotes': 'Class here: works on series, soap operas, plays for TV, situation comedies, made for TV shows etc both live-action and animated, fiction and non-fiction, dramas, documentaries, news and current affairs etc. Use for: works about any particular genre or style of television or small screen entertainment. Use with: ATM* codes or other AT* codes to describe the specific style or genre, as appropriate, See also: ATM*',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ATJS1': {'CodeValue': 'ATJS1',
#   'CodeDescription': 'Television: reality shows',
#   'CodeNotes': 'Class here: talent shows, reality competition or game shows, documentary-style reality shows, structured-reality shows, dating shows, improvement shows, talk shows, etc. Use for: works that examine aspects of reality TV or specific shows or types of reality TV or people who participate in reality shows, on TV, streaming services, online media, etc. Use with: DNBF for biographies of reality performers, with AV* codes for specific kinds of reality music shows, etc',
#   'CodeParent': 'ATJS',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'ATJX': {'CodeValue': 'ATJX',
#   'CodeDescription': 'Television production: technical and background skills',
#   'CodeNotes': 'Class here: television camerawork, editing, lighting, scenery, costume, special effects, art and design, makeup and hair, props, casting',
#   'CodeParent': 'ATJ',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATL': {'CodeValue': 'ATL',
#   'CodeDescription': 'Radio / podcasts',
#   'CodeNotes': 'Use all ATL* codes for: performing arts aspects only, both for traditional radio or for new media, including streaming, on demand or other forms of consuming audio content, See also: KNT',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATLD': {'CodeValue': 'ATLD',
#   'CodeDescription': 'Radio plays, scripts and performances',
#   'CodeNotes': 'Class here: radio drama, audio theatre, spoken word only performances',
#   'CodeParent': 'ATL',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ATM': {'CodeValue': 'ATM',
#   'CodeDescription': 'Film, television, radio and performing arts genres',
#   'CodeNotes': 'Use for: the performing arts aspects of these genres only. Use with: other AT* codes to indicate that a work is about a particular genre of film, TV show, audio performance, stage production or with AVLM for works about musical films. Prefer: F* codes for fictionalised works in particular genres, including tie-ins, See also: ATJS ATFN',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  'ATMB': {'CodeValue': 'ATMB',
#   'CodeDescription': 'Film, television, radio genres: Action, adventure, crime and thrillers',
#   'CodeNotes': 'Class here: works about martial arts, disaster, mysteries, suspense, gangster, heist, spy, espionage, westerns, action-based war films, shows, programmes or series',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'ATMC': {'CodeValue': 'ATMC',
#   'CodeDescription': 'Film, television, radio genres: Comedy and humour',
#   'CodeNotes': 'Class here: romantic comedies, romcoms, humorous infotainment. Use for: works about humour-based or light-hearted films, shows, programmes or series. Use with: ATJS for works about TV sitcoms',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  'ATMF': {'CodeValue': 'ATMF',
#   'CodeDescription': 'Film, television, radio genres: Drama',
#   'CodeNotes': 'Class here: romance, everyday life, or realistic drama. Use for: works about films, shows, programmes or series. Use with: ATJS for works about TV soap operas or dramatic series, or with ATN for web series or web shows',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  'ATMH': {'CodeValue': 'ATMH',
#   'CodeDescription': 'Film, television, radio genres: Historical',
#   'CodeNotes': 'Class here: period drama, peplums, historical biographies, historical epic films, samurai cinema, etc. Use for: works on films, shows, programmes or series where the historical period is one of the most important aspects',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'ATMN': {'CodeValue': 'ATMN',
#   'CodeDescription': 'Film, television, radio genres: Science fiction, fantasy and horror',
#   'CodeNotes': '',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'ATMP': {'CodeValue': 'ATMP',
#   'CodeDescription': 'Film, television, radio genres: Superhero and comic book inspired',
#   'CodeNotes': 'Use for: works about films, shows, programmes or series inspired by comic book characters or stories',
#   'CodeParent': 'ATM',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'ATN': {'CodeValue': 'ATN',
#   'CodeDescription': 'Internet and digital media: arts and performance',
#   'CodeNotes': 'Class here: all aspects of Internet as media channel, especially for material that originates online; internet celebrities, bloggers and blogging, vloggers, podcasts etc, See also: UD* KNTV KNTX',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.2,
#   'Modified': ''},
#  'ATQ': {'CodeValue': 'ATQ',
#   'CodeDescription': 'Dance',
#   'CodeNotes': 'Use for: general works on techniques, studies, reference etc. Use with: JBC* for cultural studies aspects or academic works as appropriate. Use all ATQ* codes with: STYLE 6* Qualifiers as appropriate',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'ATQC': {'CodeValue': 'ATQC',
#   'CodeDescription': 'Choreography',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATQL': {'CodeValue': 'ATQL',
#   'CodeDescription': 'Ballet',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATQR': {'CodeValue': 'ATQR',
#   'CodeDescription': 'Ballroom dancing',
#   'CodeNotes': 'Class here: Latin dance',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'ATQT': {'CodeValue': 'ATQT',
#   'CodeDescription': 'Contemporary dance',
#   'CodeNotes': '',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATQV': {'CodeValue': 'ATQV',
#   'CodeDescription': 'Dancers / choreographers',
#   'CodeNotes': 'Class here: dance troupes, dance groups, companies',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'ATQZ': {'CodeValue': 'ATQZ',
#   'CodeDescription': 'Folk dancing',
#   'CodeNotes': 'Class here: traditional dances',
#   'CodeParent': 'ATQ',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'ATS': {'CodeValue': 'ATS',
#   'CodeDescription': 'Performing arts: makeup',
#   'CodeNotes': 'Class here: special effects makeup, SFX makeup, prosthetic makeup, hair design, professional and media makeup artistry, stage and theatrical makeup, professional works for makeup artists, cosplay makeup. Use with: other AT* codes for works for specific performance arts or with other A* codes if the work is about makeup art for fashion, photography or with 4CP* or other EDUCATIONAL 4* qualifiers for vocational titles, See also: ATDH ATFX ATJX',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'ATT': {'CodeValue': 'ATT',
#   'CodeDescription': 'Performing arts: costume / props',
#   'CodeNotes': 'Class here: designing and making costumes or props, costume play or cosplay, fancy dress. Use with: other AT* codes for works for specific performance arts or with 4CP* or other EDUCATIONAL 4* qualifiers for vocational titles, See also: ATDH ATFX ATJX',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'ATX': {'CodeValue': 'ATX',
#   'CodeDescription': 'Other performing arts',
#   'CodeNotes': 'Class here: mime, noh, street theatre, variety shows, music hall, cabaret, juggling, ventriloquism etc',
#   'CodeParent': 'AT',
#   'IssueNumber': 1,
#   'Modified': 1.3},
#  'ATXB': {'CodeValue': 'ATXB',
#   'CodeDescription': 'Drag culture and performance',
#   'CodeNotes': 'Class here: drag artists, drag balls, drag queens, drag kings, See also: JBCC3',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'ATXC': {'CodeValue': 'ATXC',
#   'CodeDescription': 'Circus and circus skills',
#   'CodeNotes': 'Class here: clowns, funambulism, acrobatics, See also: ATXZ',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'ATXD': {'CodeValue': 'ATXD',
#   'CodeDescription': 'Comedy and stand-up',
#   'CodeNotes': 'Class here: Improvisational comedy, impressionists, alternative comedy, sketch comedy, comedians',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'ATXF': {'CodeValue': 'ATXF',
#   'CodeDescription': 'Conjuring and magic',
#   'CodeNotes': 'Class here: illusions, prestidigitation, card tricks, magicians as performers, See also: QRYX2 VXWM',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'ATXM': {'CodeValue': 'ATXM',
#   'CodeDescription': 'Puppetry, miniature and toy theatre',
#   'CodeNotes': '',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATXP': {'CodeValue': 'ATXP',
#   'CodeDescription': 'Pageants, parades, festivals',
#   'CodeNotes': '',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATXZ': {'CodeValue': 'ATXZ',
#   'CodeDescription': 'Animal spectacles, performing animals',
#   'CodeNotes': '',
#   'CodeParent': 'ATX',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATXZ1': {'CodeValue': 'ATXZ1',
#   'CodeDescription': 'Bullfighting',
#   'CodeNotes': '',
#   'CodeParent': 'ATXZ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'ATY': {'CodeValue': 'ATY',
#   'CodeDescription': 'History of Performing Arts',
#   'CodeNotes': 'Use with: other AT* codes as appropriate',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'ATZ': {'CodeValue': 'ATZ',
#   'CodeDescription': 'Film, television, radio and performing arts: companion works',
#   'CodeNotes': 'Use for: non-fiction style, companion works to TV series, films, shows, franchises, etc. These are typically uncritical, such as a compendium of characters, or places, or guides to the objects, machines, vehicles, weapons, props, costumes (even if these are purely fictional) or a guide to the making of, or art of a series. Use with: other AT* codes as appropriate. Prefer: FYV or FZ for tie-in versions of novels, novelisations or novels inspired by a particular film, series, show or franchise, See also: FYV FZ YFZZ',
#   'CodeParent': 'AT',
#   'IssueNumber': 1.4,
#   'Modified': 1.5},
#  'AV': {'CodeValue': 'AV',
#   'CodeDescription': 'Music',
#   'CodeNotes': 'Use all AV* codes with: STYLE 6* Qualifiers to indicate the specific style or genre of music, PLACE 1* Qualifiers if specific to a particular region and TIME PERIOD 3* Qualifiers if historical',
#   'CodeParent': 'A',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'AVA': {'CodeValue': 'AVA',
#   'CodeDescription': 'Theory of music and musicology',
# ...
#   'CodeDescription': 'Systems of law: civil codes / civil law',
#   'CodeNotes': 'Use for: works about bodies of law or civil law systems that are based on a code of law, legal codes or law codes, See also: LAFR',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'LAFF': {'CodeValue': 'LAFF',
#   'CodeDescription': 'Systems of law: customary law',
#   'CodeNotes': 'Use for: works about bodies of law or legal systems wholly or partially based on custom and precedent',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'LAFG': {'CodeValue': 'LAFG',
#   'CodeDescription': 'Systems of law: mixed systems',
#   'CodeNotes': 'Use for: works about bodies of law or legal systems that are based on more than one legal system',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1.4,
#   'Modified': ''},
#  'LAFR': {'CodeValue': 'LAFR',
#   'CodeDescription': 'Systems of law: Roman law',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAFS': {'CodeValue': 'LAFS',
#   'CodeDescription': 'Systems of law: Islamic law',
#   'CodeNotes': 'See also: LW',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAFT': {'CodeValue': 'LAFT',
#   'CodeDescription': 'Systems of law: Jewish Law',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAFX': {'CodeValue': 'LAFX',
#   'CodeDescription': 'Systems of law: ecclesiastical (canon) law',
#   'CodeNotes': '',
#   'CodeParent': 'LAF',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAM': {'CodeValue': 'LAM',
#   'CodeDescription': 'Comparative law',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAP': {'CodeValue': 'LAP',
#   'CodeDescription': 'Legal technology',
#   'CodeNotes': 'Use for: works that look at the use of technology in the law and the legal sector, new technologies in the legal services sector, the impact of technology on legal services, legal tech and legal practice, virtual legal services, law office technology. Use with: U* codes for technical approaches',
#   'CodeParent': 'LA',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'LAQ': {'CodeValue': 'LAQ',
#   'CodeDescription': 'Law and society, sociology of law',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAQG': {'CodeValue': 'LAQG',
#   'CodeDescription': 'Law and society, gender issues',
#   'CodeNotes': '',
#   'CodeParent': 'LAQ',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAR': {'CodeValue': 'LAR',
#   'CodeDescription': 'Legal aspects of criminology',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAS': {'CodeValue': 'LAS',
#   'CodeDescription': 'Legal skills and practice',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LASD': {'CodeValue': 'LASD',
#   'CodeDescription': 'Legal skills: advocacy',
#   'CodeNotes': '',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LASH': {'CodeValue': 'LASH',
#   'CodeDescription': 'Legal skills: drafting and legal writing',
#   'CodeNotes': 'Class here: academic legal writing',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'LASK': {'CodeValue': 'LASK',
#   'CodeDescription': 'Legal skills: negotiating and interviewing',
#   'CodeNotes': 'Class here: legal skills: oral communication',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'LASN': {'CodeValue': 'LASN',
#   'CodeDescription': 'Legal skills: research methods',
#   'CodeNotes': 'Class here: legal skills: using online tools, legal databases etc',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1.3,
#   'Modified': ''},
#  'LASP': {'CodeValue': 'LASP',
#   'CodeDescription': 'Legal practice: paralegals and paralegalism',
#   'CodeNotes': '',
#   'CodeParent': 'LAS',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAT': {'CodeValue': 'LAT',
#   'CodeDescription': 'Legal profession / practice of law: general',
#   'CodeNotes': 'Class here: works that look at legal professionals and those who practice the law, such as a lawyer or attorney. Use all LAT* code for: works about legal professionals, their roles, the nature of their work, their responsibilities, See also: LNAL',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LATC': {'CodeValue': 'LATC',
#   'CodeDescription': 'Legal ethics and professional conduct',
#   'CodeNotes': '',
#   'CodeParent': 'LAT',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAY': {'CodeValue': 'LAY',
#   'CodeDescription': 'Law as it applies to other professions and disciplines',
#   'CodeNotes': 'See also: VSD',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LAZ': {'CodeValue': 'LAZ',
#   'CodeDescription': 'Legal history',
#   'CodeNotes': '',
#   'CodeParent': 'LA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LB': {'CodeValue': 'LB',
#   'CodeDescription': 'International law',
#   'CodeNotes': '',
#   'CodeParent': 'L',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBB': {'CodeValue': 'LBB',
#   'CodeDescription': 'Public international law',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBC': {'CodeValue': 'LBBC',
#   'CodeDescription': 'Public international law: treaties and other sources',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBC1': {'CodeValue': 'LBBC1',
#   'CodeDescription': 'Public International law: customary law',
#   'CodeNotes': '',
#   'CodeParent': 'LBBC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBD': {'CodeValue': 'LBBD',
#   'CodeDescription': 'Public international law: diplomatic law',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBF': {'CodeValue': 'LBBF',
#   'CodeDescription': 'Public international law: jurisdiction and immunities',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBJ': {'CodeValue': 'LBBJ',
#   'CodeDescription': 'Public international law: territory and statehood',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBK': {'CodeValue': 'LBBK',
#   'CodeDescription': 'Public international law: law of the sea',
#   'CodeNotes': 'Class here: law concerning maritime boundaries, marine resources, etc as it affects sovereign states, See also: LBDM LNCB5',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBL': {'CodeValue': 'LBBL',
#   'CodeDescription': 'Public International law: health',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBM': {'CodeValue': 'LBBM',
#   'CodeDescription': 'Public international law: economic and trade',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBM1': {'CodeValue': 'LBBM1',
#   'CodeDescription': 'Public international law, economic and trade: tariffs',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBM3': {'CodeValue': 'LBBM3',
#   'CodeDescription': 'Public international law, economic and trade: investment treaties and disputes',
#   'CodeNotes': 'Class here: international investment law and regulations, International Investment Agreements, Investor-State Dispute Settlements, Investment treaty arbitration',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LBBM5': {'CodeValue': 'LBBM5',
#   'CodeDescription': 'Public international law: energy and natural resources',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBM7': {'CodeValue': 'LBBM7',
#   'CodeDescription': 'Public international law, economic and trade: corporations',
#   'CodeNotes': '',
#   'CodeParent': 'LBBM',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBP': {'CodeValue': 'LBBP',
#   'CodeDescription': 'Public international law: environment',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBP1': {'CodeValue': 'LBBP1',
#   'CodeDescription': 'Public international law, environment: agricultural law',
#   'CodeNotes': '',
#   'CodeParent': 'LBBP',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBQ': {'CodeValue': 'LBBQ',
#   'CodeDescription': 'Public international law: administration',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBR': {'CodeValue': 'LBBR',
#   'CodeDescription': 'Public international law: human rights',
#   'CodeNotes': 'Class here: substantive rights and inalienable rights in International Law',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'LBBR1': {'CodeValue': 'LBBR1',
#   'CodeDescription': 'Public international law, human rights: labour and social',
#   'CodeNotes': '',
#   'CodeParent': 'LBBR',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBS': {'CodeValue': 'LBBS',
#   'CodeDescription': 'Public international law: humanitarian law',
#   'CodeNotes': 'Class here: refugee law, law of war',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBU': {'CodeValue': 'LBBU',
#   'CodeDescription': 'Public international law: international organizations and institutions',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBV': {'CodeValue': 'LBBV',
#   'CodeDescription': 'Public international law: responsibility of states and other entities',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBBZ': {'CodeValue': 'LBBZ',
#   'CodeDescription': 'Public international law: criminal law',
#   'CodeNotes': '',
#   'CodeParent': 'LBB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBD': {'CodeValue': 'LBD',
#   'CodeDescription': 'International law: transport, communications and commerce',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBDA': {'CodeValue': 'LBDA',
#   'CodeDescription': 'International law, transport: space and aerospace law',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBDK': {'CodeValue': 'LBDK',
#   'CodeDescription': 'International law: transnational commerce and international sale of goods law',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBDM': {'CodeValue': 'LBDM',
#   'CodeDescription': 'International law, transport and commerce: maritime law',
#   'CodeNotes': 'Class here: law concerning shipping, cargo, insurance, piracy etc as it affects commercial bodies but not sovereign states, See also: LBBK LNCB5',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBDT': {'CodeValue': 'LBDT',
#   'CodeDescription': 'International law: communications, telecommunications and media',
#   'CodeNotes': '',
#   'CodeParent': 'LBD',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBG': {'CodeValue': 'LBG',
#   'CodeDescription': 'Private international law and conflict of laws',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBH': {'CodeValue': 'LBH',
#   'CodeDescription': 'International law: international disputes and civil procedure',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBHG': {'CodeValue': 'LBHG',
#   'CodeDescription': 'International law: courts and procedures',
#   'CodeNotes': '',
#   'CodeParent': 'LBH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBHT': {'CodeValue': 'LBHT',
#   'CodeDescription': 'International law: arbitration',
#   'CodeNotes': '',
#   'CodeParent': 'LBH',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBJ': {'CodeValue': 'LBJ',
#   'CodeDescription': 'International law: intellectual property',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBK': {'CodeValue': 'LBK',
#   'CodeDescription': 'International law: sports',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LBL': {'CodeValue': 'LBL',
#   'CodeDescription': 'International law reports',
#   'CodeNotes': '',
#   'CodeParent': 'LB',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LN': {'CodeValue': 'LN',
#   'CodeDescription': 'Laws of specific jurisdictions and specific areas of law',
#   'CodeNotes': 'Use all LN* codes with: PLACE 1* Qualifiers to indicate jurisdiction, as appropriate',
#   'CodeParent': 'L',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNA': {'CodeValue': 'LNA',
#   'CodeDescription': 'Legal systems: general',
#   'CodeNotes': '',
#   'CodeParent': 'LN',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAA': {'CodeValue': 'LNAA',
#   'CodeDescription': 'Legal systems: courts and procedures',
#   'CodeNotes': 'Class here: inquisitorial system, adversarial / adversary system, court rules. Use for: works on different types of courts, laws and legal aspects of the procedures and processes in those courts',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LNAA1': {'CodeValue': 'LNAA1',
#   'CodeDescription': 'Legal systems: judges and judicial powers',
#   'CodeNotes': 'Class here: examining magistrate. Use for: different types of judges, the judiciary and works on judicial powers',
#   'CodeParent': 'LNAA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LNAA12': {'CodeValue': 'LNAA12',
#   'CodeDescription': 'Legal systems: lay and citizen judges / juries',
#   'CodeNotes': 'Class here: lay assessors, lay magistrates, jurors etc. Use for: works about or for citizens who are not legal professionals, or with minimal legal training who participate in trials either as citizen or lay judges or as members of juries',
#   'CodeParent': 'LNAA1',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'LNAA2': {'CodeValue': 'LNAA2',
#   'CodeDescription': 'Legal systems: law of contempt',
#   'CodeNotes': '',
#   'CodeParent': 'LNAA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC': {'CodeValue': 'LNAC',
#   'CodeDescription': 'Legal systems: civil procedure, litigation and dispute resolution',
#   'CodeNotes': 'Class here: statute of limitations, prescriptive period, remedial law, rules of court, adjective law, procedural law, See also: LNFX',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LNAC1': {'CodeValue': 'LNAC1',
#   'CodeDescription': 'Civil remedies',
#   'CodeNotes': 'Class here: unjust / unjustified enrichment, equitable tracing',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  'LNAC12': {'CodeValue': 'LNAC12',
#   'CodeDescription': 'Restitution',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC14': {'CodeValue': 'LNAC14',
#   'CodeDescription': 'Damages and compensation',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC16': {'CodeValue': 'LNAC16',
#   'CodeDescription': 'Injunctions and other orders',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC1',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC3': {'CodeValue': 'LNAC3',
#   'CodeDescription': 'Civil procedure: law of evidence',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC4': {'CodeValue': 'LNAC4',
#   'CodeDescription': 'Civil procedure: investigation and specific proceedings',
#   'CodeNotes': '',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAC5': {'CodeValue': 'LNAC5',
#   'CodeDescription': 'Arbitration, mediation and alternative dispute resolution',
#   'CodeNotes': 'Class here: moderation and legal negotiation',
#   'CodeParent': 'LNAC',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  'LNAD': {'CodeValue': 'LNAD',
#   'CodeDescription': 'Legal systems: General Part / General Provisions',
#   'CodeNotes': 'Use for: works about legal systems, civil codes, constitutions, that have general sections of basic rules and definitions, generally applicable regulations. Use with: other L* codes as appropriate, for works about applications of these rules to specific areas of law',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1.5,
#   'Modified': ''},
#  'LNAF': {'CodeValue': 'LNAF',
#   'CodeDescription': 'Legal systems: costs and funding',
#   'CodeNotes': '',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNAL': {'CodeValue': 'LNAL',
#   'CodeDescription': 'Legal systems: regulation of legal profession',
#   'CodeNotes': '',
#   'CodeParent': 'LNA',
#   'IssueNumber': 1,
#   'Modified': ''},
#  'LNB': {'CodeValue': 'LNB',
#   'CodeDescription': 'Private or civil law: general',
#   'CodeNotes': '',
#   'CodeParent': 'LN',
#   'IssueNumber': 1,
#   'Modified': ''},
#  ...}

# %%
len(thema_dict)
# Out:
# 8645

# %%
import re
from collections import defaultdict

depth_dict = defaultdict(list)
for code in thema_dict:
    code_temp = str(code)
    
    if "-" in code_temp:
        # print(code)
        code_temp = re.sub(r'-.*-', 'Z', code_temp)  # replace "-*-" pattern with "Z"
        # print(code_temp)
        # print(len(code_temp)-1)
    else:
        code_length = len(code_temp) - 1 # root has depth 0

    depth_dict[code_length].append(code)
    
depth_dict
# Out:
# defaultdict(list,
#             {0: ['A',
#               'C',
#               'D',
#               'F',
#               'G',
#               'J',
#               'K',
#               'L',
#               'M',
#               'N',
#               'P',
#               'Q',
#               'R',
#               'S',
#               'T',
#               'U',
#               'V',
#               'W',
#               'X',
#               'Y',
#               1,
#               2,
#               3,
#               4,
#               5,
#               6],
#              1: ['AB',
#               'AF',
#               'AG',
#               'AJ',
#               'AK',
#               'AM',
#               'AT',
#               'AV',
#               'CB',
#               'CF',
#               'CJ',
#               'DB',
#               'DC',
#               'DD',
#               'DN',
#               'DS',
#               'FB',
#               'FC',
#               'FD',
#               'FF',
#               'FG',
#               'FH',
#               'FJ',
#               'FK',
#               'FL',
#               'FM',
#               'FN',
#               'FP',
#               'FQ',
#               'FR',
#               'FS',
#               'FT',
#               'FU',
#               'FV',
#               'FW',
#               'FX',
#               'FY',
#               'FZ',
#               'GB',
#               'GL',
#               'GP',
#               'GT',
#               'JB',
#               'JH',
#               'JK',
#               'JM',
#               'JN',
#               'JP',
#               'JW',
#               'KC',
#               'KF',
#               'KJ',
#               'KN',
#               'LA',
#               'LB',
#               'LN',
#               'LW',
#               'LX',
#               'MB',
#               'MF',
#               'MJ',
#               'MK',
#               'MN',
#               'MQ',
#               'MR',
#               'MX',
#               'MZ',
#               'NH',
#               'NK',
#               'PB',
#               'PD',
#               'PG',
#               'PH',
#               'PN',
#               'PS',
#               'QD',
#               'QR',
#               'RB',
#               'RG',
#               'RN',
#               'RP',
#               'SC',
#               'SF',
#               'SH',
#               'SK',
#               'SM',
#               'SP',
#               'SR',
#               'ST',
#               'SV',
#               'SX',
#               'SZ',
#               'TB',
#               'TC',
#               'TD',
#               'TG',
#               'TH',
#               'TJ',
#               'TN',
#               'TQ',
#               'TR',
#               'TT',
#               'TV',
#               'UB',
#               'UD',
#               'UF',
#               'UG',
#               'UK',
#               'UL',
#               'UM',
#               'UN',
#               'UP',
#               'UQ',
#               'UR',
#               'UT',
#               'UX',
#               'UY',
#               'VF',
#               'VS',
#               'VX',
#               'WB',
#               'WC',
#               'WD',
#               'WF',
#               'WG',
#               'WH',
#               'WJ',
#               'WK',
#               'WM',
#               'WN',
#               'WQ',
#               'WT',
#               'WZ',
#               'XA',
#               'XQ',
#               'XR',
#               'XY',
#               'YB',
#               'YD',
#               'YF',
#               'YN',
#               'YP',
#               'YR',
#               'YX',
#               'YZ',
#               '1A',
#               '1D',
#               '1F',
#               '1H',
#               '1K',
#               '1M',
#               '1Q',
#               '1Z',
#               '2A',
#               '2B',
#               '2C',
#               '2F',
#               '2G',
#               '2H',
#               '2J',
#               '2P',
#               '2S',
#               '2Z',
#               '3A',
#               '3B',
#               '3C',
#               '3K',
#               '3M',
#               '4C',
#               '4G',
#               '4L',
#               '4T',
#               '4Z',
#               '4Z-AA-',
#               '4Z-AA-E',
#               '4Z-AA-EA',
#               '4Z-AR-',
#               '4Z-AR-A',
#               '4Z-AR-B',
#               '4Z-AR-BA',
#               '4Z-AR-BC',
#               '4Z-AR-BD',
#               '4Z-AR-C',
#               '4Z-AR-CA',
#               '4Z-AR-CB',
#               '4Z-AR-CC',
#               '4Z-AU-',
#               '4Z-AU-A',
#               '4Z-AU-AA',
#               '4Z-AU-AB',
#               '4Z-AU-B',
#               '4Z-AU-BA',
#               '4Z-AU-BB',
#               '4Z-AU-BC',
#               '4Z-AU-BD',
#               '4Z-AU-BE',
#               '4Z-AU-BF',
#               '4Z-AU-C',
#               '4Z-AU-CA',
#               '4Z-AU-CB',
#               '4Z-AU-CC',
#               '4Z-AU-CD',
#               '4Z-AU-CE',
#               '4Z-AU-CF',
#               '4Z-AU-D',
#               '4Z-AU-H',
#               '4Z-AU-N',
#               '4Z-AU-NH',
#               '4Z-AU-Q',
#               '4Z-AU-QH',
#               '4Z-AU-S',
#               '4Z-AU-SH',
#               '4Z-AU-T',
#               '4Z-AU-TH',
#               '4Z-AU-V',
#               '4Z-AU-VH',
#               '4Z-AU-W',
#               '4Z-AU-WH',
#               '4Z-AU-X',
#               '4Z-AU-XH',
#               '4Z-AU-Y',
#               '4Z-AU-YH',
#               '4Z-BE-',
#               '4Z-BE-B',
#               '4Z-BE-BA',
#               '4Z-BE-BB',
#               '4Z-BE-BC',
#               '4Z-BE-BD',
#               '4Z-BE-BE',
#               '4Z-BE-BEA',
#               '4Z-BE-BEAA',
#               '4Z-BE-BEAB',
#               '4Z-BE-BEB',
#               '4Z-BE-BEBA',
#               '4Z-BE-BEBB',
#               '4Z-BE-BEBC',
#               '4Z-BE-BEBD',
#               '4Z-BE-BEC',
#               '4Z-BE-BECA',
#               '4Z-BE-BECB',
#               '4Z-BE-BECC',
#               '4Z-BE-BECD',
#               '4Z-BE-BECE',
#               '4Z-BE-D',
#               '4Z-BE-DA',
#               '4Z-BE-DC',
#               '4Z-BE-DE',
#               '4Z-BE-H',
#               '4Z-BE-HA',
#               '4Z-BE-HC',
#               '4Z-BE-HE',
#               '4Z-BO-',
#               '4Z-BR-',
#               '4Z-CA-',
#               '4Z-CA-A',
#               '4Z-CA-C',
#               '4Z-CA-F',
#               '4Z-CA-H',
#               '4Z-CA-J',
#               '4Z-CA-L',
#               '4Z-CA-M',
#               '4Z-CA-Q',
#               '4Z-CA-QA',
#               '4Z-CA-QC',
#               '4Z-CA-QF',
#               '4Z-CA-QH',
#               '4Z-CA-QJ',
#               '4Z-CA-QK',
#               '4Z-CA-QL',
#               '4Z-CB-',
#               '4Z-CB-C',
#               '4Z-CB-CB',
#               '4Z-CB-CD',
#               '4Z-CB-CF',
#               '4Z-CB-CS',
#               '4Z-CB-CV',
#               '4Z-CB-E',
#               '4Z-CL-',
#               '4Z-CO-',
#               '4Z-CO-A',
#               '4Z-CO-B',
#               '4Z-CO-C',
#               '4Z-CO-D',
#               '4Z-CO-E',
#               '4Z-CR-',
#               '4Z-CU-',
#               '4Z-CZ-',
#               '4Z-DE-',
#               '4Z-DE-A',
#               '4Z-DE-B',
#               '4Z-DE-BA',
#               '4Z-DE-C',
#               '4Z-DE-D',
#               '4Z-DE-DA',
#               '4Z-DE-DAB',
#               '4Z-DE-DAD',
#               '4Z-DE-DAE',
#               '4Z-DE-DAF',
#               '4Z-DE-DAG',
#               '4Z-DE-DAH',
#               '4Z-DE-DAJ',
#               '4Z-DE-DAK',
#               '4Z-DE-DAL',
#               '4Z-DE-DB',
#               '4Z-DE-DBA',
#               '4Z-DE-DBB',
#               '4Z-DE-DBC',
#               '4Z-DE-DBD',
#               '4Z-DE-DBE',
#               '4Z-DE-DBF',
#               '4Z-DE-DBG',
#               '4Z-DE-DC',
#               '4Z-DE-DD',
#               '4Z-DE-DDA',
#               '4Z-DE-DDB',
#               '4Z-DE-DJ',
#               '4Z-DE-DL',
#               '4Z-DE-F',
#               '4Z-DE-FA',
#               '4Z-DE-FAB',
#               '4Z-DE-FAD',
#               '4Z-DE-FAF',
#               '4Z-DE-FAH',
#               '4Z-DE-FAJ',
#               '4Z-DE-FAL',
#               '4Z-DE-FAM',
#               '4Z-DE-FAN',
#               '4Z-DE-FAP',
#               '4Z-DE-FB',
#               '4Z-DE-FBB',
#               '4Z-DE-FBD',
#               '4Z-DE-FBF',
#               '4Z-DE-FBH',
#               '4Z-DE-FBJ',
#               '4Z-DE-FBL',
#               '4Z-DE-FBM',
#               '4Z-DE-FBN',
#               '4Z-DE-FBP',
#               '4Z-DE-FBR',
#               '4Z-DE-FC',
#               '4Z-DE-FCB',
#               '4Z-DE-FCD',
#               '4Z-DE-FCF',
#               '4Z-DE-FCH',
#               '4Z-DE-FCJ',
#               '4Z-DE-FD',
#               '4Z-DE-FF',
#               '4Z-DE-FH',
#               '4Z-DE-FJ',
#               '4Z-DE-FL',
#               '4Z-DE-FN',
#               '4Z-DE-G',
#               '4Z-DE-GA',
#               '4Z-DE-GC',
#               '4Z-DE-GE',
#               '4Z-DE-GH',
#               '4Z-DE-GJ',
#               '4Z-DE-GL',
#               '4Z-DE-GN',
#               '4Z-DE-H',
#               '4Z-DE-J',
#               '4Z-DE-JB',
#               '4Z-DE-L',
#               '4Z-DE-LA',
#               '4Z-DE-LB',
#               '4Z-DE-LC',
#               '4Z-DE-LD',
#               '4Z-DE-LE',
#               '4Z-DE-LF',
#               '4Z-DE-LG',
#               '4Z-DE-LH',
#               '4Z-DE-LJ',
#               '4Z-DE-LK',
#               '4Z-DE-LL',
#               '4Z-DE-LM',
#               '4Z-DE-LN',
#               '4Z-DE-U',
#               '4Z-DE-UD',
#               '4Z-DE-UDA',
#               '4Z-DE-UDB',
#               '4Z-DE-UDC',
#               '4Z-DE-UDD',
#               '4Z-DE-UDE',
#               '4Z-DE-UDF',
#               '4Z-DE-UDG',
#               '4Z-DE-UDH',
#               '4Z-DE-UDI',
#               '4Z-DE-UDJ',
#               '4Z-DE-UDK',
#               '4Z-DE-UH',
#               '4Z-DE-UHA',
#               '4Z-DE-UHAA',
#               '4Z-DE-UHAB',
#               '4Z-DE-UHB',
#               '4Z-DE-UHBA',
#               '4Z-DE-UHBB',
#               '4Z-DE-UHBC',
#               '4Z-DE-UHBD',
#               '4Z-DE-UHD',
#               '4Z-DE-UHDA',
#               '4Z-DE-UHDB',
#               '4Z-DE-UHDC',
#               '4Z-DE-UHDD',
#               '4Z-DE-UHE',
#               '4Z-DE-UHEA',
#               '4Z-DE-UHEB',
#               '4Z-DE-UHF',
#               '4Z-DE-UHFA',
#               '4Z-DE-UHFB',
#               '4Z-DE-UHH',
#               '4Z-DE-UHHA',
#               '4Z-DE-UHHB',
#               '4Z-DE-UHHC',
#               '4Z-DE-UHHD',
#               '4Z-DE-UHHE',
#               '4Z-DE-UHHF',
#               '4Z-DE-UHHG',
#               '4Z-DE-UHJ',
#               '4Z-DE-UHJA',
#               '4Z-DE-UHJB',
#               '4Z-DE-UHL',
#               '4Z-DE-UHLA',
#               '4Z-DE-UHLB',
#               '4Z-DE-UHLC',
#               '4Z-DE-UHLD',
#               '4Z-DE-UHLE',
#               '4Z-DE-UHLF',
#               '4Z-DE-UHLG',
#               '4Z-DE-UHM',
#               '4Z-DE-UHMA',
#               '4Z-DE-UHMB',
#               '4Z-DE-UHMC',
#               '4Z-DE-UHMD',
#               '4Z-DE-UHP',
#               '4Z-DE-UHPA',
#               '4Z-DE-UHPB',
#               '4Z-DE-UHPC',
#               '4Z-DE-UHPD',
#               '4Z-DE-UHPE',
#               '4Z-DE-UHPF',
#               '4Z-DE-UHPG',
#               '4Z-DE-UHQ',
#               '4Z-DE-UHQA',
#               '4Z-DE-UHQB',
#               '4Z-DE-UHQC',
#               '4Z-DE-UHQD',
#               '4Z-DE-UHQE',
#               '4Z-DE-UHS',
#               '4Z-DE-UHSA',
#               '4Z-DE-UHSB',
#               '4Z-DE-UHSC',
#               '4Z-DE-UHSD',
#               '4Z-DK-',
#               '4Z-DK-A',
#               '4Z-DK-F',
#               '4Z-DK-FA',
#               '4Z-DK-FB',
#               '4Z-DK-FC',
#               '4Z-DK-FD',
#               '4Z-DK-FE',
#               '4Z-DK-FF',
#               '4Z-DK-FG',
#               '4Z-DK-FH',
#               '4Z-DK-FI',
#               '4Z-DK-FJ',
#               '4Z-DK-FK',
#               '4Z-DK-FL',
#               '4Z-DK-G',
#               '4Z-DK-GA',
#               '4Z-DK-GB',
#               '4Z-DK-GC',
#               '4Z-DK-GD',
#               '4Z-DK-H',
#               '4Z-DK-K',
#               '4Z-DK-N',
#               '4Z-DK-V',
#               '4Z-DK-X',
#               '4Z-DO-',
#               '4Z-EC-',
#               '4Z-EC-A',
#               '4Z-EC-B',
#               '4Z-EC-C',
#               '4Z-ES-',
#               '4Z-ES-A',
#               '4Z-ES-AA',
#               '4Z-ES-AB',
#               '4Z-ES-AC',
#               '4Z-ES-AD',
#               '4Z-ES-AE',
#               '4Z-ES-AF',
#               '4Z-ES-B',
#               '4Z-ES-C',
#               '4Z-ES-D',
#               '4Z-ES-E',
#               '4Z-ES-F',
#               '4Z-ES-G',
#               '4Z-ES-H',
#               '4Z-ES-J',
#               '4Z-ES-K',
#               '4Z-ES-L',
#               '4Z-ES-X',
#               '4Z-FI-',
#               '4Z-FI-A',
#               '4Z-FI-B',
#               '4Z-FI-BA',
#               '4Z-FI-BB',
#               '4Z-FI-BD',
#               '4Z-FI-C',
#               '4Z-FI-CB',
#               '4Z-FI-CC',
#               '4Z-FI-D',
#               '4Z-FR-',
#               '4Z-GB-',
#               '4Z-GB-A',
#               '4Z-GB-AC',
#               '4Z-GB-ACA',
#               '4Z-GB-ACF',
#               '4Z-GB-ACJ',
#               '4Z-GB-ACL',
#               '4Z-GB-ACN',
#               '4Z-GB-ACT',
#               '4Z-GB-AL',
#               '4Z-GB-E',
#               '4Z-GB-EA',
#               '4Z-GB-EC',
#               '4Z-GB-ED',
#               '4Z-GB-EE',
#               '4Z-GB-EF',
#               '4Z-GB-ER',
#               '4Z-GB-ES',
#               '4Z-GB-EW',
#               '4Z-GB-N',
#               '4Z-GB-NC',
#               '4Z-GB-NCA',
#               '4Z-GB-NCF',
#               '4Z-GB-NCJ',
#               '4Z-GB-NCN',
#               '4Z-GB-NCT',
#               '4Z-GB-NL',
#               '4Z-GB-NV',
#               '4Z-GB-S',
#               '4Z-GB-SA',
#               '4Z-GB-SAA',
#               '4Z-GB-SAB',
#               '4Z-GB-SAC',
#               '4Z-GB-SAD',
#               '4Z-GB-SB',
#               '4Z-GB-SD',
#               '4Z-GB-SE',
#               '4Z-GB-SG',
#               '4Z-GB-SK',
#               '4Z-GB-SL',
#               '4Z-GB-V',
#               '4Z-GB-VC',
#               '4Z-GB-VCT',
#               '4Z-GB-VN',
#               '4Z-GB-VS',
#               '4Z-GB-VSA',
#               '4Z-GB-VSB',
#               '4Z-GB-VSC',
#               '4Z-GB-VSD',
#               '4Z-GB-VSE',
#               '4Z-GB-VT',
#               '4Z-GB-VTA',
#               '4Z-GB-VTB',
#               '4Z-GB-VTC',
#               '4Z-GB-VTD',
#               '4Z-GB-W',
#               '4Z-GB-WB',
#               '4Z-GB-WD',
#               '4Z-GB-WF',
#               '4Z-GB-WH',
#               '4Z-GB-WV',
#               '4Z-GT-',
#               '4Z-HN-',
#               '4Z-HU-',
#               '4Z-IE-',
#               '4Z-IE-P',
#               '4Z-IE-S',
#               '4Z-IE-SJ',
#               '4Z-IE-SL',
#               '4Z-IN-',
#               '4Z-IN-A',
#               '4Z-IN-AA',
#               '4Z-IN-AB',
#               '4Z-IN-AC',
#               '4Z-IN-AD',
#               '4Z-IN-AE',
#               '4Z-IN-B',
#               '4Z-IN-BA',
#               '4Z-IN-BB',
#               '4Z-IN-BC',
#               '4Z-IN-C',
#               '4Z-IN-CA',
#               '4Z-IN-CB',
#               '4Z-IN-D',
#               '4Z-IN-DA',
#               '4Z-IN-DB',
#               '4Z-IN-E',
#               '4Z-IN-EB',
#               '4Z-IN-ED',
#               '4Z-IN-EG',
#               '4Z-IN-EJ',
#               '4Z-IN-EN',
#               '4Z-IN-F',
#               '4Z-IN-FB',
#               '4Z-IN-FD',
#               '4Z-IN-FF',
#               '4Z-IN-FH',
#               '4Z-IN-G',
#               '4Z-IN-GB',
#               '4Z-IN-GBB',
#               '4Z-IN-GBD',
#               '4Z-IN-GD',
#               '4Z-IN-H',
#               '4Z-IN-HB',
#               '4Z-IN-HD',
#               '4Z-IN-HF',
#               '4Z-IN-K',
#               '4Z-IN-KA',
#               '4Z-IN-KB',
#               '4Z-IN-KC',
#               '4Z-IN-KF',
#               '4Z-IN-L',
#               '4Z-IN-M',
#               '4Z-IN-N',
#               '4Z-IN-NA',
#               '4Z-IN-P',
#               '4Z-IN-PB',
#               '4Z-IN-PD',
#               '4Z-IN-PE',
#               '4Z-IN-PF',
#               '4Z-IN-Q',
#               '4Z-IN-QB',
#               '4Z-IN-QD',
#               '4Z-IN-QF',
#               '4Z-IN-QT',
#               '4Z-IN-QTB',
#               '4Z-IN-QTD',
#               '4Z-IN-QTF',
#               '4Z-IN-QTH',
#               '4Z-IN-R',
#               '4Z-IN-RB',
#               '4Z-IN-RD',
#               '4Z-IN-RE',
#               '4Z-IN-RF',
#               '4Z-IN-RH',
#               '4Z-IN-RJ',
#               '4Z-IN-RK',
#               '4Z-IN-T',
#               '4Z-IN-TC',
#               '4Z-IN-TD',
#               '4Z-IN-TN',
#               '4Z-IN-U',
#               '4Z-IN-UB',
#               '4Z-IN-UC',
#               '4Z-IN-UD',
#               '4Z-IN-UE',
#               '4Z-IN-UF',
#               '4Z-IN-UG',
#               '4Z-IN-UH',
#               '4Z-IN-V',
#               '4Z-IN-VB',
#               '4Z-IN-VBT',
#               '4Z-IN-VD',
#               '4Z-IN-VF',
#               '4Z-IT-',
#               '4Z-IT-A',
#               '4Z-IT-AC',
#               '4Z-IT-AD',
#               '4Z-IT-AG',
#               '4Z-IT-AH',
#               '4Z-IT-AL',
#               '4Z-IT-AN',
#               '4Z-IT-AP',
#               '4Z-IT-AR',
#               '4Z-IT-AS',
#               '4Z-IT-C',
#               '4Z-IT-CB',
#               '4Z-IT-CE',
#               '4Z-IT-E',
#               '4Z-IT-EA',
#               '4Z-IT-EC',
#               '4Z-IT-EF',
#               '4Z-IT-EH',
#               '4Z-IT-EL',
#               '4Z-IT-EN',
#               '4Z-IT-EQ',
#               '4Z-IT-ER',
#               '4Z-IT-ES',
#               '4Z-IT-G',
#               '4Z-IT-GB',
#               '4Z-IT-GD',
#               '4Z-IT-GF',
#               '4Z-IT-GH',
#               '4Z-IT-GL',
#               '4Z-IT-GM',
#               '4Z-IT-GP',
#               '4Z-IT-GT',
#               '4Z-IT-GZ',
#               '4Z-JP-',
#               '4Z-JP-A',
#               '4Z-JP-AA',
#               '4Z-JP-AB',
#               '4Z-JP-AC',
#               '4Z-JP-ACA',
#               '4Z-JP-ACB',
#               '4Z-JP-ACC',
#               '4Z-JP-B',
#               '4Z-JP-BA',
#               '4Z-JP-BB',
#               '4Z-JP-BC',
#               '4Z-JP-BD',
#               '4Z-JP-BE',
#               '4Z-JP-BF',
#               '4Z-JP-C',
#               '4Z-JP-CA',
#               '4Z-JP-CB',
#               '4Z-JP-CC',
#               '4Z-JP-D',
#               '4Z-JP-DA',
#               '4Z-JP-DAA',
#               '4Z-JP-DAB',
#               '4Z-JP-DAC',
#               '4Z-JP-DB',
#               '4Z-JP-DBA',
#               '4Z-JP-DBB',
#               '4Z-JP-DBC',
#               '4Z-JP-DC',
#               '4Z-JP-E',
#               '4Z-JP-EA',
#               '4Z-JP-EB',
#               '4Z-JP-EC',
#               '4Z-JP-ED',
#               '4Z-JP-F',
#               '4Z-JP-G',
#               '4Z-JP-H',
#               '4Z-JP-K',
#               '4Z-JP-KA',
#               '4Z-JP-KB',
#               '4Z-JP-KC',
#               '4Z-JP-KD',
#               '4Z-JP-KE',
#               '4Z-JP-KF',
#               '4Z-JP-KH',
#               '4Z-JP-KJ',
#               '4Z-JP-KJA',
#               '4Z-JP-KK',
#               '4Z-KR-',
#               '4Z-KR-A',
#               '4Z-KR-AB',
#               '4Z-KR-AC',
#               '4Z-KR-AD',
#               '4Z-KR-AE',
#               '4Z-KR-AEA',
#               '4Z-KR-AEB',
#               '4Z-KR-AEC',
#               '4Z-KR-AED',
#               '4Z-KR-AEF',
#               '4Z-KR-AEG',
#               '4Z-KR-AF',
#               '4Z-KR-AG',
#               '4Z-KR-AGA',
#               '4Z-KR-AGB',
#               '4Z-KR-AGC',
#               '4Z-KR-AH',
#               '4Z-KR-AJ',
#               '4Z-KR-AJA',
#               '4Z-KR-AJB',
#               '4Z-KR-AJC',
#               '4Z-KR-B',
#               '4Z-KR-BA',
#               '4Z-KR-BE',
#               '4Z-KR-BH',
#               '4Z-KR-BI',
#               '4Z-KR-BJ',
#               '4Z-KR-BK',
#               '4Z-KR-BL',
#               '4Z-MX-',
#               '4Z-MX-A',
#               '4Z-MX-B',
#               '4Z-MX-C',
#               '4Z-MX-D',
#               '4Z-MX-E',
#               '4Z-MX-F',
#               '4Z-NI-',
#               '4Z-NO-',
#               '4Z-NO-A',
#               '4Z-NO-B',
#               '4Z-NO-C',
#               '4Z-NZ-',
#               '4Z-PA-',
#               '4Z-PA-A',
#               '4Z-PA-B',
#               '4Z-PA-C',
#               '4Z-PE-',
#               '4Z-PL-',
#               '4Z-PL-A',
#               '4Z-PL-B',
#               '4Z-PL-C',
#               '4Z-PL-CA',
#               '4Z-PL-CB',
#               '4Z-PL-CD',
#               '4Z-PL-D',
#               '4Z-PL-E',
#               '4Z-PT-',
#               '4Z-PY-',
#               '4Z-RO-',
#               '4Z-SG-',
#               '4Z-SK-',
#               '4Z-SV-',
#               '4Z-TR-',
#               '4Z-UA-',
#               '4Z-US-',
#               '4Z-US-A',
#               '4Z-US-B',
#               '4Z-US-C',
#               '4Z-US-D',
#               '4Z-US-E',
#               '4Z-US-F',
#               '4Z-US-G',
#               '4Z-US-H',
#               '4Z-US-I',
#               '4Z-US-J',
#               '4Z-US-L',
#               '4Z-US-M',
#               '4Z-US-N',
#               '4Z-US-O',
#               '4Z-US-P',
#               '4Z-UY-',
#               '4Z-VE-',
#               '4Z-ZA-',
#               '5A',
#               '5H',
#               '5J',
#               '5L',
#               '5P',
#               '5X',
#               '5Y',
#               '6A',
#               '6B',
#               '6C',
#               '6D',
#               '6E',
#               '6F',
#               '6G',
#               '6H',
#               '6J',
#               '6K',
#               '6L',
#               '6M',
#               '6N',
#               '6P',
#               '6Q',
#               '6R',
#               '6S',
#               '6T',
#               '6U',
#               '6V',
#               '6W',
#               '6X'],
#              2: ['ABA',
#               'ABC',
#               'ABK',
#               'ABQ',
#               'AFC',
#               'AFF',
#               'AFH',
#               'AFJ',
#               'AFK',
#               'AFP',
#               'AFT',
#               'AFW',
#               'AGA',
#               'AGB',
#               'AGC',
#               'AGH',
#               'AGK',
#               'AGN',
#               'AGP',
#               'AGR',
#               'AGT',
#               'AGZ',
#               'AJC',
#               'AJF',
#               'AJT',
#               'AKB',
#               'AKC',
#               'AKD',
#               'AKH',
#               'AKL',
#               'AKP',
#               'AKR',
#               'AKT',
#               'AKX',
#               'AMA',
#               'AMB',
#               'AMC',
#               'AMD',
#               'AMG',
#               'AMK',
#               'AMN',
#               'AMR',
#               'AMV',
#               'AMX',
#               'ATC',
#               'ATD',
#               'ATF',
#               'ATJ',
#               'ATL',
#               'ATM',
#               'ATN',
#               'ATQ',
#               'ATS',
#               'ATT',
#               'ATX',
#               'ATY',
#               'ATZ',
#               'AVA',
#               'AVC',
#               'AVD',
#               'AVL',
#               'AVM',
#               'AVN',
#               'AVP',
#               'AVQ',
#               'AVR',
#               'AVS',
#               'AVX',
#               'CBD',
#               'CBF',
#               'CBG',
#               'CBP',
#               'CBV',
#               'CBW',
#               'CBX',
#               'CFA',
#               'CFB',
#               'CFC',
#               'CFD',
#               'CFF',
#               'CFG',
#               'CFH',
#               'CFK',
#               'CFL',
#               'CFM',
#               'CFP',
#               'CFX',
#               'CFZ',
#               'CJA',
#               'CJB',
#               'CJC',
#               'CJP',
#               'DBS',
#               'DCA',
#               'DCC',
#               'DCF',
#               'DCQ',
#               'DCR',
#               'DDA',
#               'DDC',
#               'DDL',
#               'DDT',
#               'DDV',
#               'DNB',
#               'DNC',
#               'DND',
#               'DNG',
#               'DNL',
#               'DNP',
#               'DNS',
#               'DNT',
#               'DNX',
#               'DSA',
#               'DSB',
#               'DSC',
#               'DSG',
#               'DSK',
#               'DSM',
#               'DSR',
#               'DSY',
#               'FBA',
#               'FBC',
#               'FDB',
#               'FDK',
#               'FDM',
#               'FDV',
#               'FFC',
#               'FFD',
#               'FFH',
#               'FFJ',
#               'FFK',
#               'FFL',
#               'FFP',
#               'FFS',
#               'FHD',
#               'FHK',
#               'FHM',
#               'FHP',
#               'FHQ',
#               'FHR',
#               'FHS',
#               'FHT',
#               'FHX',
#               'FJD',
#               'FJH',
#               'FJM',
#               'FJN',
#               'FJW',
#               'FKC',
#               'FKM',
#               'FKW',
#               'FLC',
#               'FLG',
#               'FLH',
#               'FLM',
#               'FLP',
#               'FLQ',
#               'FLR',
#               'FLS',
#               'FLU',
#               'FLW',
#               'FMB',
#               'FMH',
#               'FMK',
#               'FMM',
#               'FMR',
#               'FMS',
#               'FMT',
#               'FMW',
#               'FMX',
#               'FNF',
#               'FNM',
#               'FRD',
#               'FRF',
#               'FRH',
#               'FRJ',
#               'FRM',
#               'FRP',
#               'FRQ',
#               'FRR',
#               'FRT',
#               'FRU',
#               'FRV',
#               'FRX',
#               'FUP',
#               'FXB',
#               'FXD',
#               'FXE',
#               'FXK',
#               'FXL',
#               'FXM',
#               'FXN',
#               'FXP',
#               'FXQ',
#               'FXR',
#               'FXS',
#               'FXT',
#               'FXV',
#               'FYB',
#               'FYC',
#               'FYD',
#               'FYH',
#               'FYM',
#               'FYP',
#               'FYQ',
#               'FYR',
#               'FYS',
#               'FYT',
#               'FYV',
#               'FYW',
#               'GBA',
#               'GBC',
#               'GBD',
#               'GLC',
#               'GLF',
#               'GLH',
#               'GLK',
#               'GLM',
#               'GLP',
#               'GLZ',
#               'GPF',
#               'GPH',
#               'GPJ',
#               'GPQ',
#               'GPS',
#               'GTB',
#               'GTC',
#               'GTD',
#               'GTK',
#               'GTM',
#               'GTP',
#               'GTQ',
#               'GTS',
#               'GTT',
#               'GTU',
#               'GTV',
#               'GTZ',
#               'JBC',
#               'JBF',
#               'JBG',
#               'JBS',
#               'JHB',
#               'JHM',
#               'JKS',
#               'JKV',
#               'JMA',
#               'JMB',
#               'JMC',
#               'JMD',
#               'JMF',
#               'JMG',
#               'JMH',
#               'JMJ',
#               'JMK',
#               'JML',
#               'JMM',
#               'JMP',
#               'JMQ',
#               'JMR',
#               'JMS',
#               'JMT',
#               'JMU',
#               'JMX',
#               'JNA',
#               'JNB',
#               'JNC',
#               'JND',
#               'JNE',
#               'JNF',
#               'JNG',
#               'JNH',
#               'JNK',
#               'JNL',
#               'JNM',
#               'JNP',
#               'JNQ',
#               'JNR',
#               'JNS',
#               'JNT',
#               'JNU',
#               'JNV',
#               'JNW',
#               'JNZ',
#               'JPA',
#               'JPB',
#               'JPF',
#               'JPH',
#               'JPL',
#               'JPN',
#               'JPP',
#               'JPQ',
#               'JPR',
#               'JPS',
#               'JPT',
#               'JPV',
#               'JPW',
#               'JPZ',
#               'JWA',
#               'JWC',
#               'JWD',
#               'JWJ',
#               'JWK',
#               'JWL',
#               'JWM',
#               'JWT',
#               'JWX',
#               'KCA',
#               'KCB',
#               'KCC',
#               'KCD',
#               'KCF',
#               'KCG',
#               'KCH',
#               'KCJ',
#               'KCK',
#               'KCL',
#               'KCM',
#               'KCP',
#               'KCS',
#               'KCV',
#               'KCX',
#               'KCY',
#               'KCZ',
#               'KFC',
#               'KFF',
#               'KJB',
#               'KJC',
#               'KJD',
#               'KJE',
#               'KJF',
#               'KJG',
#               'KJH',
#               'KJJ',
#               'KJK',
#               'KJL',
#               'KJM',
#               'KJN',
#               'KJP',
#               'KJQ',
#               'KJR',
#               'KJS',
#               'KJT',
#               'KJU',
#               'KJV',
#               'KJW',
#               'KJZ',
#               'KNA',
#               'KNB',
#               'KND',
#               'KNG',
#               'KNJ',
#               'KNP',
#               'KNS',
#               'KNT',
#               'KNV',
#               'KNX',
#               'LAB',
#               'LAF',
#               'LAM',
#               'LAP',
#               'LAQ',
#               'LAR',
#               'LAS',
#               'LAT',
#               'LAY',
#               'LAZ',
#               'LBB',
#               'LBD',
#               'LBG',
#               'LBH',
#               'LBJ',
#               'LBK',
#               'LBL',
#               'LNA',
#               'LNB',
#               'LNC',
#               'LND',
#               'LNE',
#               'LNF',
#               'LNH',
#               'LNJ',
#               'LNK',
#               'LNL',
#               'LNM',
#               'LNP',
#               'LNQ',
#               'LNR',
#               'LNS',
#               'LNT',
#               'LNU',
#               'LNV',
#               'LNW',
#               'LNX',
#               'LNZ',
#               'LWF',
#               'LWK',
#               'MBD',
#               'MBF',
#               'MBG',
#               'MBN',
#               'MBP',
#               'MBQ',
#               'MBS',
#               'MBX',
#               'MFC',
#               'MFG',
#               'MFK',
#               'MFN',
#               'MJA',
#               'MJC',
#               'MJD',
#               'MJE',
#               'MJF',
#               'MJG',
#               'MJH',
#               'MJJ',
#               'MJK',
#               'MJL',
#               'MJM',
#               'MJP',
#               'MJQ',
#               'MJR',
#               'MJS',
#               'MKA',
#               'MKB',
#               'MKC',
#               'MKD',
#               'MKE',
#               'MKF',
#               'MKG',
#               'MKH',
#               'MKJ',
#               'MKL',
#               'MKM',
#               'MKN',
#               'MKP',
#               'MKR',
#               'MKS',
#               'MKT',
#               'MKV',
#               'MKW',
#               'MKZ',
#               'MNB',
#               'MNC',
#               'MND',
#               'MNG',
#               'MNH',
#               'MNJ',
#               'MNK',
#               'MNL',
#               'MNN',
#               'MNP',
#               'MNQ',
#               'MNS',
#               'MNZ',
#               'MQC',
#               'MQD',
#               'MQF',
#               'MQG',
#               'MQH',
#               'MQK',
#               'MQP',
#               'MQR',
#               'MQS',
#               'MQT',
#               'MQU',
#               'MQV',
#               'MQW',
#               'MQZ',
#               'MRG',
#               'MRP',
#               'MRT',
#               'MXH',
#               'MXN',
#               'MZA',
#               'MZB',
#               'MZC',
#               'MZD',
#               'MZF',
#               'MZG',
#               'MZH',
#               'MZK',
#               'MZL',
#               'MZM',
#               'MZP',
#               'MZR',
#               'MZS',
#               'MZT',
#               'MZV',
#               'MZX',
#               'NHA',
#               'NHB',
#               'NHC',
#               'NHD',
#               'NHF',
#               'NHG',
#               'NHH',
#               'NHK',
#               'NHM',
#               'NHQ',
#               'NHT',
#               'NHW',
#               'NKA',
#               'NKD',
#               'NKL',
#               'NKP',
#               'NKR',
#               'NKT',
#               'NKV',
#               'NKX',
#               'PBB',
#               'PBC',
#               'PBD',
#               'PBF',
#               'PBG',
#               'PBH',
#               'PBJ',
#               'PBK',
#               'PBM',
#               'PBP',
#               'PBT',
#               'PBU',
#               'PBV',
#               'PBW',
#               'PBX',
#               'PDA',
#               'PDC',
#               'PDD',
#               'PDE',
#               'PDG',
#               'PDJ',
#               'PDK',
#               'PDM',
#               'PDN',
#               'PDR',
#               'PDT',
#               'PDX',
#               'PDZ',
#               'PGC',
#               'PGG',
#               'PGK',
#               'PGM',
#               'PGS',
#               'PGT',
#               'PGZ',
#               'PHD',
#               'PHF',
#               'PHH',
#               'PHJ',
#               'PHK',
#               'PHM',
#               'PHN',
#               'PHP',
#               'PHQ',
#               'PHR',
#               'PHS',
#               'PHU',
#               'PHV',
#               'PNB',
#               'PNC',
#               'PND',
#               'PNF',
#               'PNK',
#               'PNN',
#               'PNR',
#               'PNT',
#               'PNV',
#               'PSA',
#               'PSB',
#               'PSC',
#               'PSD',
#               'PSE',
#               'PSF',
#               'PSG',
#               'PSP',
#               'PSQ',
#               'PST',
#               'PSV',
#               'PSX',
#               'QDH',
#               'QDT',
#               'QDX',
#               'QRA',
#               'QRD',
#               'QRF',
#               'QRJ',
#               'QRM',
#               'QRP',
#               'QRR',
#               'QRS',
#               'QRV',
#               'QRY',
#               'RBC',
#               'RBG',
#               'RBK',
#               'RBP',
#               'RBX',
#               'RGB',
#               'RGC',
#               'RGL',
#               'RGM',
#               'RGR',
#               'RGV',
#               'RGW',
#               'RGX',
#               'RNA',
#               'RNB',
#               'RNC',
#               'RND',
#               'RNF',
#               'RNH',
#               'RNK',
#               'RNP',
#               'RNQ',
#               'RNR',
#               'RNT',
#               'RNU',
#               'RPC',
#               'RPG',
#               'RPT',
#               'SCB',
#               'SCG',
#               'SCK',
#               'SCL',
#               'SCX',
#               'SFB',
#               'SFC',
#               'SFD',
#               'SFG',
#               'SFH',
#               'SFJ',
#               'SFK',
#               'SFL',
#               'SFM',
#               'SFN',
#               'SFP',
#               'SFQ',
#               'SFT',
#               'SFV',
#               'SFX',
#               'SHB',
#               'SHG',
#               'SHP',
#               'SKG',
#               'SKL',
#               'SKR',
#               'SMC',
#               'SMF',
#               'SMQ',
#               'SMX',
#               'SPC',
#               'SPG',
#               'SPN',
#               'SRB',
#               'SRC',
#               'SRF',
#               'SRM',
#               'STA',
#               'STC',
#               'STG',
#               'STH',
#               'STJ',
#               'STK',
#               'STL',
#               'STP',
#               'SVB',
#               'SVF',
#               'SVH',
#               'SVR',
#               'SVS',
#               'SVT',
#               'SXB',
#               'SXD',
#               'SXE',
#               'SXQ',
#               'SZC',
#               'SZD',
#               'SZE',
#               'SZG',
#               'SZK',
#               'SZN',
#               'SZR',
#               'SZV',
#               'TBC',
#               'TBD',
#               'TBG',
#               'TBJ',
#               'TBM',
#               'TBN',
#               'TBR',
#               'TBX',
#               'TBY',
#               'TCB',
#               'TDC',
#               'TDP',
#               'TGB',
#               'TGH',
#               'TGM',
#               'TGP',
#               'TGX',
#               'THD',
#               'THF',
#               'THK',
#               'THN',
#               'THR',
#               'THV',
#               'THY',
#               'TJD',
#               'TJF',
#               'TJK',
#               'TJS',
#               'TNC',
#               'TNF',
#               'TNH',
#               'TNK',
#               'TNT',
#               'TQD',
#               'TQK',
#               'TQP',
#               'TQS',
#               'TRC',
#               'TRF',
#               'TRL',
#               'TRP',
#               'TRT',
#               'TRV',
#               'TTA',
#               'TTB',
#               'TTD',
#               'TTG',
#               'TTM',
#               'TTP',
#               'TTS',
#               'TTU',
#               'TTV',
#               'TTW',
#               'TTX',
#               'TVB',
#               'TVD',
#               'TVF',
#               'TVG',
#               'TVH',
#               'TVK',
#               'TVM',
#               'TVP',
#               'TVQ',
#               'TVR',
#               'TVS',
#               'TVT',
#               'TVU',
#               'UBB',
#               'UBH',
#               'UBJ',
#               'UBL',
#               'UBM',
#               'UBW',
#               'UDA',
#               'UDB',
#               'UDD',
#               'UDF',
#               'UDH',
#               'UDM',
#               'UDP',
#               'UDQ',
#               'UDT',
#               'UDV',
#               'UDX',
#               'UDY',
#               'UFB',
#               'UFC',
#               'UFD',
#               'UFG',
#               'UFK',
#               'UFL',
#               'UFM',
#               'UFP',
#               'UFS',
#               'UGA',
#               'UGB',
#               'UGC',
#               'UGD',
#               'UGG',
#               'UGK',
#               'UGL',
#               'UGM',
#               'UGN',
#               'UGP',
#               'UGV',
#               'UKC',
#               'UKD',
#               'UKF',
#               'UKG',
#               'UKL',
#               'UKM',
#               'UKN',
#               'UKP',
#               'UKR',
#               'UKS',
#               'UKX',
#               'ULD',
#               'ULH',
#               'ULJ',
#               'ULP',
#               'ULQ',
#               'ULR',
#               'UMA',
#               'UMB',
#               'UMC',
#               'UMF',
#               'UMG',
#               'UMH',
#               'UMJ',
#               'UMK',
#               'UML',
#               'UMN',
#               'UMP',
#               'UMQ',
#               'UMR',
#               'UMS',
#               'UMT',
#               'UMW',
#               'UMX',
#               'UMZ',
#               'UNA',
#               'UNC',
#               'UND',
#               'UNF',
#               'UNH',
#               'UNJ',
#               'UNK',
#               'UNN',
#               'UNS',
#               'UQF',
#               'UQJ',
#               'UQL',
#               'UQR',
#               'UQT',
#               'URD',
#               'URH',
#               'URJ',
#               'URQ',
#               'URS',
#               'URW',
#               'URY',
#               'UTC',
#               'UTD',
#               'UTE',
#               'UTF',
#               'UTG',
#               'UTM',
#               'UTN',
#               'UTP',
#               'UTR',
#               'UTS',
#               'UTV',
#               'UTW',
#               'UTX',
#               'UXA',
#               'UXJ',
#               'UXT',
#               'UYA',
#               'UYD',
#               'UYF',
#               'UYM',
#               'UYQ',
#               'UYS',
#               'UYT',
#               'UYU',
#               'UYV',
#               'UYW',
#               'UYX',
#               'UYY',
#               'UYZ',
#               'VFB',
#               'VFD',
#               'VFG',
#               'VFJ',
#               'VFL',
#               'VFM',
#               'VFV',
#               'VFX',
#               'VSA',
#               'VSB',
#               'VSC',
#               'VSD',
#               'VSF',
#               'VSG',
#               'VSH',
#               'VSK',
#               'VSL',
#               'VSN',
#               'VSP',
#               'VSR',
#               'VSS',
#               'VSW',
#               'VSY',
#               'VSZ',
#               'VXA',
#               'VXF',
#               'VXH',
#               'VXK',
#               'VXM',
#               'VXN',
#               'VXP',
#               'VXQ',
#               'VXV',
#               'VXW',
#               'WBA',
#               'WBB',
#               'WBC',
#               'WBD',
#               'WBF',
#               'WBH',
#               'WBJ',
#               'WBK',
#               'WBL',
#               'WBN',
#               'WBQ',
#               'WBR',
#               'WBS',
#               'WBT',
#               'WBV',
#               'WBW',
#               'WBX',
#               'WBZ',
#               'WCB',
#               'WCC',
#               'WCF',
#               'WCG',
#               'WCJ',
#               'WCK',
#               'WCL',
#               'WCN',
#               'WCP',
#               'WCR',
#               'WCS',
#               'WCT',
#               'WCU',
#               'WCV',
#               'WCW',
#               'WCX',
#               'WDH',
#               'WDJ',
#               'WDK',
#               'WDM',
#               'WDP',
#               'WFA',
#               'WFB',
#               'WFC',
#               'WFD',
#               'WFF',
#               'WFG',
#               'WFH',
#               'WFJ',
#               'WFK',
#               'WFL',
#               'WFN',
#               'WFP',
#               'WFQ',
#               'WFS',
#               'WFT',
#               'WFU',
#               'WFV',
#               'WFW',
#               'WFX',
#               'WGC',
#               'WGD',
#               'WGF',
#               'WGG',
#               'WGM',
#               'WHG',
#               'WHJ',
#               'WHL',
#               'WHP',
#               'WHX',
#               'WJF',
#               'WJH',
#               'WJJ',
#               'WJK',
#               'WJS',
#               'WJW',
#               'WJX',
#               'WJY',
#               'WKD',
#               'WKH',
#               'WKR',
#               'WKU',
#               'WMB',
#               'WMD',
#               'WMF',
#               'WMP',
#               'WMQ',
#               'WMT',
#               'WNA',
#               'WNC',
#               'WND',
#               'WNF',
#               'WNG',
#               'WNH',
#               'WNJ',
#               ...],
#              3: ['AFCC',
#               'AFCL',
#               'AFCM',
#               'AFCP',
#               'AFFC',
#               'AFFK',
#               'AFJY',
#               'AFKB',
#               'AFKC',
#               'AFKG',
#               'AFKN',
#               'AFKP',
#               'AFKV',
#               'AGHF',
#               'AGHN',
#               'AGHX',
#               'AGNA',
#               'AGNB',
#               'AGNL',
#               'AGNS',
#               'AGTS',
#               'AGZC',
#               'AJCD',
#               'AJCP',
#               'AJCX',
#               'AJTA',
#               'AJTF',
#               'AJTH',
#               'AJTR',
#               'AJTS',
#               'AJTV',
#               'AKHM',
#               'AKLB',
#               'AKLC',
#               'AKLF',
#               'AKLP',
#               'AKTF',
#               'AKTR',
#               'AMCD',
#               'AMCM',
#               'AMCR',
#               'AMKH',
#               'AMKL',
#               'AMKS',
#               'AMVD',
#               'ATDC',
#               'ATDF',
#               'ATDH',
#               'ATDS',
#               'ATFA',
#               'ATFB',
#               'ATFD',
#               'ATFG',
#               'ATFN',
#               'ATFR',
#               'ATFV',
#               'ATFX',
#               'ATJD',
#               'ATJS',
#               'ATJX',
#               'ATLD',
#               'ATMB',
#               'ATMC',
#               'ATMF',
#               'ATMH',
#               'ATMN',
#               'ATMP',
#               'ATQC',
#               'ATQL',
#               'ATQR',
#               'ATQT',
#               'ATQV',
#               'ATQZ',
#               'ATXB',
#               'ATXC',
#               'ATXD',
#               'ATXF',
#               'ATXM',
#               'ATXP',
#               'ATXZ',
#               'AVLA',
#               'AVLC',
#               'AVLF',
#               'AVLK',
#               'AVLM',
#               'AVLP',
#               'AVLT',
#               'AVLW',
#               'AVLX',
#               'AVQS',
#               'AVRG',
#               'AVRJ',
#               'AVRL',
#               'AVRN',
#               'AVRQ',
#               'AVRS',
#               'AVSA',
#               'AVSD',
#               'CBDX',
#               'CBVS',
#               'CFDC',
#               'CFDM',
#               'CFFD',
#               'CFLA',
#               'CJAB',
#               'CJAD',
#               'CJBC',
#               'CJBG',
#               'CJBR',
#               'CJBT',
#               'CJCK',
#               'CJCL',
#               'CJCR',
#               'CJCW',
#               'CJPD',
#               'CJPG',
#               'DBSG',
#               'DBSN',
#               'DCRB',
#               'DCRC',
#               'DCRG',
#               'DCRH',
#               'DCRL',
#               'DCRS',
#               'DNBA',
#               'DNBB',
#               'DNBF',
#               'DNBG',
#               'DNBH',
#               'DNBL',
#               'DNBM',
#               'DNBP',
#               'DNBR',
#               'DNBS',
#               'DNBT',
#               'DNBX',
#               'DNBZ',
#               'DNPB',
#               'DNXC',
#               'DNXH',
#               'DNXM',
#               'DNXP',
#               'DNXR',
#               'DNXZ',
#               'DSBB',
#               'DSBC',
#               'DSBD',
#               'DSBF',
#               'DSBH',
#               'DSBJ',
#               'DSRC',
#               'DSYC',
#               'FBAN',
#               'FJMC',
#               'FJMF',
#               'FJMS',
#               'FJMV',
#               'FLPB',
#               'GBCB',
#               'GBCD',
#               'GBCQ',
#               'GBCR',
#               'GBCS',
#               'GBCT',
#               'GBCY',
#               'GLCA',
#               'GPFC',
#               'GPQD',
#               'JBCC',
#               'JBCT',
#               'JBFA',
#               'JBFB',
#               'JBFC',
#               'JBFD',
#               'JBFF',
#               'JBFG',
#               'JBFH',
#               'JBFJ',
#               'JBFK',
#               'JBFL',
#               'JBFM',
#               'JBFN',
#               'JBFQ',
#               'JBFS',
#               'JBFU',
#               'JBFV',
#               'JBFW',
#               'JBFX',
#               'JBFZ',
#               'JBGB',
#               'JBGX',
#               'JBSA',
#               'JBSC',
#               'JBSD',
#               'JBSF',
#               'JBSJ',
#               'JBSL',
#               'JBSP',
#               'JBSR',
#               'JBSW',
#               'JBSX',
#               'JBSY',
#               'JHBA',
#               'JHBC',
#               'JHBD',
#               'JHBK',
#               'JHBL',
#               'JHBS',
#               'JHBZ',
#               'JHMC',
#               'JKSB',
#               'JKSF',
#               'JKSG',
#               'JKSL',
#               'JKSM',
#               'JKSN',
#               'JKSR',
#               'JKSW',
#               'JKVC',
#               'JKVF',
#               'JKVG',
#               'JKVJ',
#               'JKVK',
#               'JKVM',
#               'JKVN',
#               'JKVP',
#               'JKVQ',
#               'JKVS',
#               'JKVV',
#               'JMAF',
#               'JMAJ',
#               'JMAL',
#               'JMAN',
#               'JMAP',
#               'JMAQ',
#               'JMBT',
#               'JMHC',
#               'JNAM',
#               'JNAS',
#               'JNDG',
# ...
#               '1HFMS-ZA-B',
#               '1HFMS-ZA-BB',
#               '1HFMS-ZA-D',
#               '1HFMS-ZA-DB',
#               '1HFMS-ZA-DD',
#               '1HFMS-ZA-F',
#               '1HFMS-ZA-FB',
#               '1HFMS-ZA-H',
#               '1HFMS-ZA-J',
#               '1HFMS-ZA-K',
#               '1HFMS-ZA-M',
#               '1HFMS-ZA-N',
#               '1HFMS-ZA-NB',
#               '1HFMS-ZA-Z',
#               '1HFMS-ZA-ZD',
#               '1HFMS-ZA-ZK',
#               '1HFMW',
#               '1HFMW-ZW-A',
#               '1HFMZ',
#               '1HFMZ-ZM-A',
#               '1HZAC',
#               '1HZAG',
#               '1HZAM',
#               '1HZAN',
#               '1HZAS',
#               '1HZAT',
#               '1HZAV',
#               '1HZAZ',
#               '1HZTA',
#               '1HZTK',
#               '1HZTR',
#               '1HZTS',
#               '1HZTT',
#               '1KBZA',
#               '1KBZT',
#               '1KJWB',
#               '1KJWB-BS-A',
#               '1KJWJ',
#               '1KJWJ-JM-B',
#               '1KJWT',
#               '1KJWV',
#               '1KJWW',
#               '1KJXA',
#               '1KJXN',
#               '1KJX-BL-B',
#               '1KJX-BQ-B',
#               '1KJX-BQ-E',
#               '1KJX-BQ-S',
#               '1KJX-CW-C',
#               '1KJX-MF-M',
#               '1KJX-SX-M',
#               '1KLCB',
#               '1KLCG',
#               '1KLCG-GT-A',
#               '1KLCG-GT-AC',
#               '1KLCG-GT-E',
#               '1KLCG-GT-EB',
#               '1KLCG-GT-EBA',
#               '1KLCG-GT-F',
#               '1KLCG-GT-FB',
#               '1KLCG-GT-H',
#               '1KLCG-GT-HF',
#               '1KLCH',
#               '1KLCH-HN-A',
#               '1KLCH-HN-AC',
#               '1KLCH-HN-C',
#               '1KLCH-HN-CJ',
#               '1KLCH-HN-E',
#               '1KLCH-HN-EA',
#               '1KLCH-HN-EAB',
#               '1KLCM',
#               '1KLCM-MX-A',
#               '1KLCM-MX-AA',
#               '1KLCM-MX-AAB',
#               '1KLCM-MX-AB',
#               '1KLCM-MX-ABB',
#               '1KLCM-MX-AC',
#               '1KLCM-MX-AD',
#               '1KLCM-MX-AE',
#               '1KLCM-MX-AEB',
#               '1KLCM-MX-AF',
#               '1KLCM-MX-B',
#               '1KLCM-MX-BA',
#               '1KLCM-MX-BB',
#               '1KLCM-MX-BC',
#               '1KLCM-MX-C',
#               '1KLCM-MX-CA',
#               '1KLCM-MX-CB',
#               '1KLCM-MX-CBA',
#               '1KLCM-MX-CBD',
#               '1KLCM-MX-CC',
#               '1KLCM-MX-CD',
#               '1KLCM-MX-D',
#               '1KLCM-MX-DA',
#               '1KLCM-MX-DB',
#               '1KLCM-MX-DC',
#               '1KLCM-MX-DD',
#               '1KLCM-MX-E',
#               '1KLCM-MX-EA',
#               '1KLCM-MX-EB',
#               '1KLCM-MX-EBB',
#               '1KLCM-MX-EC',
#               '1KLCM-MX-ED',
#               '1KLCM-MX-EE',
#               '1KLCM-MX-F',
#               '1KLCM-MX-FA',
#               '1KLCM-MX-FB',
#               '1KLCM-MX-FBM',
#               '1KLCM-MX-FC',
#               '1KLCM-MX-G',
#               '1KLCM-MX-GA',
#               '1KLCM-MX-GB',
#               '1KLCM-MX-GBB',
#               '1KLCM-MX-GBE',
#               '1KLCM-MX-GC',
#               '1KLCM-MX-GCA',
#               '1KLCM-MX-H',
#               '1KLCM-MX-HA',
#               '1KLCM-MX-HB',
#               '1KLCM-MX-HBB',
#               '1KLCM-MX-HBC',
#               '1KLCM-MX-HBD',
#               '1KLCM-MX-HBM',
#               '1KLCM-MX-HBN',
#               '1KLCM-MX-HC',
#               '1KLCM-MX-HD',
#               '1KLCM-MX-HDA',
#               '1KLCM-MX-HDM',
#               '1KLCM-MX-HX',
#               '1KLCM-MX-HXP',
#               '1KLCM-MX-Z',
#               '1KLCM-MX-ZC',
#               '1KLCN',
#               '1KLCN-NI-A',
#               '1KLCN-NI-B',
#               '1KLCN-NI-C',
#               '1KLCN-NI-M',
#               '1KLCP',
#               '1KLCP-PA-A',
#               '1KLCP-PA-C',
#               '1KLCP-PA-D',
#               '1KLCR',
#               '1KLCR-CR-A',
#               '1KLCS',
#               '1KLCS-SV-A',
#               '1KLCS-SV-B',
#               '1KLCS-SV-BA',
#               '1KLCS-SV-C',
#               '1KLSA',
#               '1KLSA-AR-A',
#               '1KLSA-AR-AA',
#               '1KLSA-AR-AB',
#               '1KLSA-AR-AC',
#               '1KLSA-AR-AD',
#               '1KLSA-AR-AE',
#               '1KLSA-AR-AF',
#               '1KLSA-AR-B',
#               '1KLSA-AR-BA',
#               '1KLSA-AR-BB',
#               '1KLSA-AR-BC',
#               '1KLSA-AR-BD',
#               '1KLSA-AR-C',
#               '1KLSA-AR-CA',
#               '1KLSA-AR-CAM',
#               '1KLSA-AR-CB',
#               '1KLSA-AR-CC',
#               '1KLSA-AR-D',
#               '1KLSA-AR-DA',
#               '1KLSA-AR-DB',
#               '1KLSA-AR-DC',
#               '1KLSA-AR-DD',
#               '1KLSA-AR-DE',
#               '1KLSA-AR-E',
#               '1KLSA-AR-EA',
#               '1KLSA-AR-EB',
#               '1KLSA-AR-EC',
#               '1KLSA-AR-ED',
#               '1KLSA-AR-EDM',
#               '1KLSA-AR-EE',
#               '1KLSA-AR-EEA',
#               '1KLSB',
#               '1KLSB-BR-A',
#               '1KLSB-BR-AA',
#               '1KLSB-BR-AB',
#               '1KLSB-BR-AC',
#               '1KLSB-BR-AD',
#               '1KLSB-BR-AE',
#               '1KLSB-BR-AF',
#               '1KLSB-BR-AG',
#               '1KLSB-BR-B',
#               '1KLSB-BR-BA',
#               '1KLSB-BR-BB',
#               '1KLSB-BR-BBB',
#               '1KLSB-BR-BC',
#               '1KLSB-BR-BD',
#               '1KLSB-BR-BE',
#               '1KLSB-BR-BF',
#               '1KLSB-BR-BFB',
#               '1KLSB-BR-BG',
#               '1KLSB-BR-BH',
#               '1KLSB-BR-BJ',
#               '1KLSB-BR-C',
#               '1KLSB-BR-CA',
#               '1KLSB-BR-CAB',
#               '1KLSB-BR-CB',
#               '1KLSB-BR-CC',
#               '1KLSB-BR-CD',
#               '1KLSB-BR-CZ',
#               '1KLSB-BR-CZP',
#               '1KLSB-BR-D',
#               '1KLSB-BR-DA',
#               '1KLSB-BR-DB',
#               '1KLSB-BR-DC',
#               '1KLSB-BR-DCA',
#               '1KLSB-BR-DD',
#               '1KLSB-BR-E',
#               '1KLSB-BR-EA',
#               '1KLSB-BR-EB',
#               '1KLSB-BR-EC',
#               '1KLSC',
#               '1KLSC-CO-A',
#               '1KLSC-CO-B',
#               '1KLSC-CO-BA',
#               '1KLSC-CO-BAA',
#               '1KLSC-CO-BB',
#               '1KLSC-CO-BD',
#               '1KLSC-CO-BDA',
#               '1KLSC-CO-BF',
#               '1KLSC-CO-BJ',
#               '1KLSC-CO-C',
#               '1KLSC-CO-CB',
#               '1KLSC-CO-CBA',
#               '1KLSC-CO-CG',
#               '1KLSC-CO-D',
#               '1KLSC-CO-E',
#               '1KLSC-CO-ED',
#               '1KLSC-CO-EDA',
#               '1KLSE',
#               '1KLSE-EC-A',
#               '1KLSE-EC-B',
#               '1KLSE-EC-BA',
#               '1KLSE-EC-BAA',
#               '1KLSE-EC-BE',
#               '1KLSE-EC-BF',
#               '1KLSE-EC-BJ',
#               '1KLSE-EC-BJA',
#               '1KLSE-EC-C',
#               '1KLSF',
#               '1KLSF-FR-A',
#               '1KLSF-FR-B',
#               '1KLSG',
#               '1KLSG-GY-G',
#               '1KLSH',
#               '1KLSH-CL-A',
#               '1KLSH-CL-B',
#               '1KLSH-CL-C',
#               '1KLSH-CL-CD',
#               '1KLSH-CL-CV',
#               '1KLSH-CL-D',
#               '1KLSH-CL-DA',
#               '1KLSH-CL-DAA',
#               '1KLSH-CL-DC',
#               '1KLSH-CL-DCA',
#               '1KLSH-CL-DD',
#               '1KLSH-CL-DDA',
#               '1KLSH-CL-E',
#               '1KLSH-CL-EA',
#               '1KLSL',
#               '1KLSL-BO-A',
#               '1KLSL-BO-B',
#               '1KLSL-BO-C',
#               '1KLSL-BO-D',
#               '1KLSL-BO-E',
#               '1KLSL-BO-F',
#               '1KLSL-BO-G',
#               '1KLSL-BO-H',
#               '1KLSL-BO-HA',
#               '1KLSL-BO-J',
#               '1KLSP',
#               '1KLSP-PY-A',
#               '1KLSP-PY-B',
#               '1KLSP-PY-C',
#               '1KLSR',
#               '1KLSR-PE-A',
#               '1KLSR-PE-AA',
#               '1KLSR-PE-AAB',
#               '1KLSR-PE-AC',
#               '1KLSR-PE-ACT',
#               '1KLSR-PE-B',
#               '1KLSR-PE-BD',
#               '1KLSR-PE-BDC',
#               '1KLSR-PE-BDD',
#               '1KLSR-PE-BDM',
#               '1KLSR-PE-BDV',
#               '1KLSR-PE-C',
#               '1KLSR-PE-D',
#               '1KLSR-PE-DA',
#               '1KLSR-PE-DAB',
#               '1KLSR-PE-DAS',
#               '1KLSR-PE-DAY',
#               '1KLSR-PE-DC',
#               '1KLSR-PE-DD',
#               '1KLSR-PE-DDL',
#               '1KLSR-PE-E',
#               '1KLSR-PE-EA',
#               '1KLSR-PE-EB',
#               '1KLSR-PE-EBN',
#               '1KLSS',
#               '1KLSS-SR-P',
#               '1KLSU',
#               '1KLSU-UY-A',
#               '1KLSU-UY-B',
#               '1KLSU-UY-C',
#               '1KLSU-UY-D',
#               '1KLSU-UY-E',
#               '1KLSU-UY-EF',
#               '1KLSV',
#               '1KLSV-VE-A',
#               '1KLSV-VE-AA',
#               '1KLSV-VE-B',
#               '1KLSV-VE-C',
#               '1KLSV-VE-D',
#               '1KLSV-VE-E',
#               '1KLSV-VE-EA',
#               '1KLSV-VE-F',
#               '1KLSV-VE-G',
#               '1KLSV-VE-H',
#               '1KLSV-VE-J',
#               '1KLZA',
#               '1KLZT',
#               '1MBZA',
#               '1MBZT',
#               '1MKCB',
#               '1MKCC',
#               '1MKCF',
#               '1MKCG',
#               '1MKCM',
#               '1MKCN',
#               '1MKCU',
#               '1MKCV',
#               '1MKLF',
#               '1MKLN',
#               '1MKLN-FR-N',
#               '1MKLP',
#               '1MKLS',
#               '1MKLV',
#               '1MKPC',
#               '1MKPE',
#               '1MKPF',
#               '1MKPH',
#               '1MKPK',
#               '1MKPN',
#               '1MKPP',
#               '1MKPR',
#               '1MKPT',
#               '1MKPU',
#               '1MKPV',
#               '1MKPW',
#               '1MKPW-FR-M',
#               ...],
#              5: ['JBSF11',
#               'JBSL11',
#               'JBSL13',
#               'KJMV21',
#               'KJMV22',
#               'LNAA12',
#               'LNAC12',
#               'LNAC14',
#               'LNAC16',
#               'LNFX31',
#               'LNFX51',
#               'QRFB21',
#               'QRFB23',
#               'QRMB31',
#               'QRMB32',
#               'QRMB33',
#               'QRMB34',
#               'QRMB35',
#               'QRMB36',
#               'QRMB37',
#               'QRMB39',
#               'QRMF12',
#               'QRMF13',
#               'QRMF14',
#               'QRMF19',
#               'VFJB31',
#               'WBXN12',
#               'YNNJ14',
#               'YNNJ21',
#               'YNNJ22',
#               'YNNJ23',
#               'YNNJ24',
#               'YNNJ25',
#               'YNNJ26',
#               'YNNJ27',
#               'YNNJ28',
#               'YNNJ29',
#               'YNNJ31',
#               'YPCA21',
#               'YPCA22',
#               'YPCA23',
#               'YPCA91',
#               'YPCK21',
#               'YPCK22',
#               'YPCK91',
#               'YPCS91',
#               'YPMP51',
#               '1DZADT',
#               '1DZARC',
#               '1DZAR-DE-M',
#               '1DZAR-DE-MS',
#               '1DZAR-DE-N',
#               '1DZTAP',
#               '1DZTCB',
#               '1DZTCT',
#               '1DZTJS',
#               '1FBZJD',
#               '1FZTHA',
#               '1FZTHK',
#               '1FZTHM',
#               '1HFGSR',
#               '1HZAZV',
#               '1KBZAA',
#               '1KBZAC',
#               '1KBZAG',
#               '1KBZAK',
#               '1KBZAM',
#               '1KBZAS',
#               '1KBZAS-CA-L',
#               '1KBZAY',
#               '1KBZA-US-H',
#               '1KBZA-US-L',
#               '1KBZA-US-O',
#               '1KBZA-US-P',
#               '1KBZTA',
#               '1KBZTG',
#               '1KBZTP',
#               '1KBZTR',
#               '1KBZTS',
#               '1KBZT-US-D',
#               '1KJWVA',
#               '1KJWVB',
#               '1KJWVG',
#               '1KJWVG-FR-A',
#               '1KJWVG-FR-B',
#               '1KJWVK',
#               '1KJWVM',
#               '1KJWVV',
#               '1KJWWB',
#               '1KJWWD',
#               '1KJWWG',
#               '1KJWWL',
#               '1KJWWM',
#               '1KJWWM-FR-A',
#               '1KJWWM-FR-B',
#               '1KJWWM-FR-C',
#               '1KJWWM-FR-D',
#               '1KJWWT',
#               '1KJWWT-TT-P',
#               '1KJWWV',
#               '1KLZAA',
#               '1KLZAC',
#               '1KLZAO',
#               '1KLZAP',
#               '1KLZAT',
#               '1KLZTA',
#               '1KLZTG',
#               '1KLZTM',
#               '1MBZAD',
#               '1MBZTB',
#               '1MBZTD',
#               '1MBZTU',
#               '1MKLPN',
#               '1MKPCR',
#               '1MKPFT',
#               '1MKPFT-FR-P',
#               '1MKPRA',
#               '1MKPRW',
#               '1MTANB',
#               '1MTANC',
#               '1MTANM',
#               '1MTANZ',
#               '1MTAN-FR-P',
#               '1MTASC',
#               '1MTASF',
#               '1MTASG',
#               '1MTASH',
#               '1MTAST',
#               '1QBKMA',
#               '1QBKMM',
#               '1QBK-CA-Q',
#               '1QBK-CA-QA',
#               '1QBK-CA-QL',
#               '1QBK-CO-B',
#               '1QBK-CO-C',
#               '1ZMCEL',
#               '2ACSNB',
#               '2ACSNK',
#               '2HCBBC',
#               '2HCBBF',
#               '2HCBBH',
#               '2HCBBJ',
#               '2HCBBL',
#               '2HCBBN',
#               '2HCBBP',
#               '2HCBBQ',
#               '2HCBBR',
#               '2HCBBS',
#               '2HCBBU',
#               '2HCBLG',
#               '2HCBLR',
#               '2HCBSA',
#               '2HCBSB',
#               '2HCBSD',
#               '2HCBSF',
#               '2HCWVB',
#               '2HCWVD',
#               '2HCWVE',
#               '2HCWVG',
#               '2HCWVN',
#               '2HCWVS',
#               '2HCWVT',
#               '2HCWVY',
#               '2JNCEA',
#               '2JNCEB',
#               '2JNCEC',
#               '2JNCED',
#               '2JNCJB',
#               '2JNCJC',
#               '2JNCJD',
#               '2JNDDB',
#               '2JNDDH',
#               '2PGPXK',
#               '2PGPXM',
#               '2PGPXN',
#               '2PGPXP',
#               '2PGPXT',
#               '3MPBFB',
#               '3MPBF-FI-A',
#               '3MPBF-IE-R',
#               '3MPBF-MX-R',
#               '3MPBF-RU-R',
#               '3MPBGH',
#               '3MPBGH-ES-A',
#               '3MPBGH-IE-C',
#               '3MPBGH-US-J',
#               '3MPBGJ',
#               '3MPBGJ-AR-A',
#               '3MPBGJ-DE-H',
#               '3MPBGJ-ES-A',
#               '3MPBGJ-ES-B',
#               '3MPBGJ-US-K',
#               '3MPBG-DE-G',
#               '3MPBG-IE-S',
#               '3MPBG-IT-S',
#               '3MPBLB',
#               '3MPBLB-FI-A',
#               '3MPBLB-PL-A',
#               '3MPBLB-PL-B',
#               '3MPBL-AR-C',
#               '3MPBL-BE-F',
#               '3MPBL-DK-B',
#               '3MPBL-ES-A',
#               '3MPBL-IT-T',
#               '3MPBL-IT-U',
#               '3MPB-AR-B',
#               '3MPB-ES-A',
#               '3MPB-FI-A',
#               '3MPB-IT-R',
#               '3MPB-JP-B',
#               '3MPB-JP-D',
#               '3MPB-KR-S',
#               '3MPB-US-H'],
#              6: ['1DZTAPM',
#               '1DZTAPR',
#               '1DZTA-CH-A',
#               '1DZTA-CH-AD',
#               '1DZTA-CH-ADA',
#               '1DZTA-CH-ADE',
#               '1DZTA-CH-ADJ',
#               '1DZTA-CH-AG',
#               '1DZTA-CH-B',
#               '1DZTA-DE-B',
#               '1DZTA-FR-B',
#               '1DZTA-FR-BM',
#               '1DZTA-SI-C',
#               '1DZTCBB',
#               '1DZTCBP',
#               '1DZTJSH',
#               '1FZTHKK',
#               '1FZTHME',
#               '1KBZAAN',
#               '1KJWVVK',
#               '1KJWVVS',
#               '1KLZAPF',
#               '1KLZTAB',
#               '2JNDDBK',
#               '2JNDDBP',
#               '2JNDDBR',
#               '2JNDDHJ']})

# %%
from tabulate import tabulate
for key in depth_dict:
    print(key, len(depth_dict[key]))    
    table = []
    for key in depth_dict:
        table.append([key, len(depth_dict[key])])

    table_headers = ["Depth", "Count"]
    table_str = tabulate(table, headers=table_headers, tablefmt="grid")

print(table_str)
# Out:
# 0 26
# 1 861
# 2 1468
# 3 4594
# 4 1456
# 5 213
# 6 27
# +---------+---------+
# |   Depth |   Count |
# +=========+=========+
# |       0 |      26 |
# +---------+---------+
# |       1 |     861 |
# +---------+---------+
# |       2 |    1468 |
# +---------+---------+
# |       3 |    4594 |
# +---------+---------+
# |       4 |    1456 |
# +---------+---------+
# |       5 |     213 |
# +---------+---------+
# |       6 |      27 |
# +---------+---------+

# %% [markdown]
# # all nodes

# %% [markdown]
# ## description

# %%
all_nodes_descriptions = [node["CodeDescription"] for node in thema_codes]
all_nodes_descriptions
# Out:
# ['The Arts',
#  'The arts: general topics',
#  'Theory of art',
#  'Conservation, restoration and care of artworks',
#  'Forgery, falsification and theft of artworks',
#  'Art: financial aspects',
#  'The Arts: art forms',
#  'Paintings and painting',
#  'Paintings and painting in watercolours or pastels',
#  'Paintings and painting in oils',
#  'Murals and wall paintings',
#  'Paintings and painting in ink',
#  'Drawing and drawings',
#  'Drawing and drawings in pencil, charcoal, crayon or pastel',
#  'Drawing and drawings in pen or brush and ink',
#  'Prints and printmaking',
#  'Other graphic or visual art forms',
#  'Body art and tattoos',
#  'Non-graphic and electronic art forms',
#  'Sculpture',
#  'Carvings, masks, reliefs',
#  'Precious metal, precious stones and jewellery: artworks and design',
#  'Installation art',
#  'Performance art',
#  'Digital, video and new media arts',
#  'Ceramics, mosaic and glass: artworks',
#  'Decorative arts',
#  'Textile artworks',
#  'The Arts: treatments and subjects',
#  'History of art',
#  'Individual artists, art monographs',
#  'Exhibition catalogues and specific collections',
#  'Human figures depicted in art',
#  'Portraits and self-portraiture in art',
#  'Nudes depicted in art',
#  'Erotic art',
#  'Small-scale, secular and domestic scenes in art',
#  'Nature in art',
#  'Animals in art',
#  'Botanical art',
#  'Landscapes / seascapes',
#  'Still life',
#  'Man-made objects depicted in art',
#  'Religious and ceremonial art',
#  'Public art',
#  'Urban arts',
#  'The Arts: techniques and principles',
#  'Colours and colour theory',
#  'Photography and photographs',
#  'Photographs: collections',
#  'Individual photographers',
#  'Photography: portraits and self-portraiture',
#  'Erotic and nude photography',
#  'Photojournalism and documentary photography',
#  'Photographic equipment and techniques: general',
#  'Camera-specific manuals',
#  'Photography: subject-specific techniques and principles',
#  'Digital photography',
#  'Monochrome photography',
#  'Light and lighting',
#  'Video photography / videography',
#  'Design, Industrial and commercial arts, illustration',
#  'Individual designers or design groups',
#  'Graphic design',
#  'Typography and lettering',
#  'Book design and Bookbinding',
#  'Manuscripts and illumination',
#  'Illustration and commercial art',
#  'Illustration',
#  'Comic book and cartoon artwork',
#  'Graphic novel and Manga artwork',
#  'Computer game art',
#  'Poster art',
#  'Product design',
#  'Furniture design',
#  'Fashion and textile design',
#  'Fashion and textile design: accessories',
#  'National or regional costume / textiles',
#  'History of design',
#  'Architecture',
#  'Theory of architecture',
#  'Individual architects and architectural firms',
#  'Architectural structure and design',
#  'Architectural details, components and motifs',
#  'Materials in architecture',
#  'Environmentally-friendly (‘green’) architecture and design',
#  'Architecture: professional practice',
#  'Architecture: public, commercial and industrial buildings',
#  'Architecture: residential and domestic buildings',
#  'Architecture: small-scale domestic buildings',
#  'Architecture: castles and fortifications',
#  'Architecture: palaces, stately homes and mansions',
#  'Architecture: religious buildings',
#  'Architecture: interior design',
#  'Landscape architecture and design',
#  'City and town planning: architectural aspects',
#  'History of architecture',
#  'Performing arts',
#  'Individual actors and performers',
#  'Theatre studies',
#  'Acting techniques',
#  'Theatre direction and production',
#  'Theatre: technical and background skills',
#  'Theatre management',
#  'Films, cinema',
#  'Film history, theory or criticism',
#  'Individual film directors, film-makers',
#  'Film scripts and screenplays',
#  'Film guides and reviews',
#  'Film: styles and genres',
#  'Documentary films',
#  'Animated films and animation',
#  'Anime',
#  'Filmmaking and production: technical and background skills',
#  'Television',
#  'Television screenplays, scripts and performances',
#  'Television: styles and genres',
#  'Television: reality shows',
#  'Television production: technical and background skills',
#  'Radio / podcasts',
#  'Radio plays, scripts and performances',
#  'Film, television, radio and performing arts genres',
#  'Film, television, radio genres: Action, adventure, crime and thrillers',
#  'Film, television, radio genres: Comedy and humour',
#  'Film, television, radio genres: Drama',
#  'Film, television, radio genres: Historical',
#  'Film, television, radio genres: Science fiction, fantasy and horror',
#  'Film, television, radio genres: Superhero and comic book inspired',
#  'Internet and digital media: arts and performance',
#  'Dance',
#  'Choreography',
#  'Ballet',
#  'Ballroom dancing',
#  'Contemporary dance',
#  'Dancers / choreographers',
#  'Folk dancing',
#  'Performing arts: makeup',
#  'Performing arts: costume / props',
#  'Other performing arts',
#  'Drag culture and performance',
#  'Circus and circus skills',
#  'Comedy and stand-up',
#  'Conjuring and magic',
#  'Puppetry, miniature and toy theatre',
#  'Pageants, parades, festivals',
#  'Animal spectacles, performing animals',
#  'Bullfighting',
#  'History of Performing Arts',
#  'Film, television, radio and performing arts: companion works',
#  'Music',
#  'Theory of music and musicology',
#  'Music reviews and criticism',
#  'Discographies and buyer’s guides',
#  'Music: styles and genres',
#  'Art music, orchestral and formal music',
#  'Choral music',
#  'Opera',
#  'Sacred and religious music',
#  'Music of film and stage',
#  'Popular music',
#  'Traditional and folk music',
#  'Other global and regional music styles',
#  'Electronic music',
#  'History of music',
#  'Composers and songwriters',
#  'Musicians, singers, bands and groups',
#  'Musical scores, lyrics and libretti',
#  'Songbooks',
#  'Musical instruments',
#  'Keyboard instruments',
#  'Piano',
#  'Percussion instruments',
#  'String instruments',
#  'Guitar',
#  'Plucked instruments',
#  'Violin and violin family instruments',
#  'Wind instruments',
#  'Brass instruments',
#  'Woodwind instruments',
#  'Mechanical musical instruments',
#  'Electronic musical instruments',
#  'Techniques of music / music tutorials / teaching of music',
#  'Singing: techniques',
#  'Music composition',
#  'Music recording and reproduction',
#  'Language and Linguistics',
#  'Language: reference and general',
#  'Dictionaries',
#  'Bilingual and multilingual dictionaries',
#  'Thesauri',
#  'Usage and grammar guides',
#  'Speaking in public: advice and guides',
#  'Creative writing and creative writing guides',
#  'Screenwriting techniques',
#  'Writing and editing guides',
#  'Language: history and general works',
#  'Linguistics',
#  'Philosophy of language',
#  'Sociolinguistics',
#  'Literacy',
#  'Psycholinguistics and cognitive linguistics',
#  'Language acquisition',
#  'Bilingualism and multilingualism',
#  'Historical and comparative linguistics',
#  'Dialect, slang and jargon',
#  'Semantics, discourse analysis, stylistics',
#  'Phonetics, phonology',
#  'Grammar, syntax and morphology',
#  'Palaeography',
#  'Writing systems, alphabets',
#  'Lexicography',
#  'Translation and interpretation',
#  'Computational and corpus linguistics',
#  'Sign languages, Braille and other linguistic communication',
#  'Language teaching and learning',
#  'Language teaching theory and methods',
#  'Language teaching and learning: first or native languages',
#  'Language teaching and learning: second or additional languages',
#  'Language teaching and learning material and coursework',
#  'Language teaching and learning material and coursework: culture / civilisation',
#  'Language learning: grammar, vocabulary and pronunciation',
#  'Language readers',
#  'Language self-study',
#  'Language learning: specific skills',
#  'Language learning: speaking skills',
#  'Language learning: listening skills',
#  'Language learning: reading skills',
#  'Language learning: writing skills',
#  'Language learning for specific purposes',
#  'Language learning for business, professional and vocational',
#  'Language learning for academic, technical and scientific purposes',
#  'Biography, Literature and Literary studies',
#  'Ancient, classical and medieval texts',
#  'Ancient Sagas and epics',
#  'Ancient Greek and Roman literature',
#  'Icelandic and Old Norse sagas',
#  'Poetry',
#  'Classic and pre-20th century poetry',
#  'Modern and contemporary poetry (c 1900 onwards)',
#  'Poetry by individual poets',
#  'Poetry anthologies (various poets)',
#  'Poetry by form',
#  'Poetry by form: Haiku',
#  'Poetry by form: Tanka',
#  'Poetry by form: Ghazal',
#  'Poetry by form: Calligram',
#  'Poetry by form: Limerick',
#  'Poetry by form: Sonnet',
#  'Plays, playscripts',
#  'Classic and pre-20th century plays',
#  'Modern and contemporary plays (c 1900 onwards)',
#  'Comedic plays',
#  'Tragic plays',
#  'Monologues / Duologues',
#  'Biography and non-fiction prose',
#  'Biography: general',
#  'Autobiography: general',
#  'Biography: business and industry',
#  'Autobiography: business and industry',
#  'Biography: arts and entertainment',
#  'Autobiography: arts and entertainment',
#  'Biography: social media',
#  'Autobiography: social media',
#  'Biography: historical, political and military',
#  'Autobiography: historical, political and military',
#  'Biography: writers',
#  'Autobiography: writers',
#  'Biography: philosophy and social sciences',
#  'Autobiography: philosophy and social sciences',
#  'Biography: adventurers and explorers',
#  'Autobiography: adventurers and explorers',
#  'Biography: royalty',
#  'Autobiography: royalty',
#  'Biography: sport',
#  'Autobiography: sport',
#  'Biography: science, technology and medicine',
#  'Autobiography: science, technology and medicine',
#  'Biography: religious and spiritual',
#  'Autobiography: religious and spiritual',
#  'Collected biographies',
#  'Memoirs',
#  'Diaries, letters and journals',
#  'Animal life stories',
#  'Literary essays',
#  'Reportage, journalism or collected columns',
#  'Interviews / discussions',
#  'Speeches',
#  'Anthologies: general',
#  'True stories: general',
#  'True crime',
#  'True crime: serial killers and murderers',
#  'True stories of discovery',
#  'True war and combat stories',
#  'True stories of heroism, endurance and survival',
#  'True stories of survival of abuse and injustice',
#  'Erotic confessions and true stories',
#  'Literature: history and criticism',
#  'Literary theory',
#  'Literary studies: general',
#  'Literary studies: ancient, classical and medieval',
#  'Literary studies: c 1400 to c 1600',
#  'Literary studies: c 1600 to c 1800',
#  'Literary studies: c 1800 to c 1900',
#  'Literary studies: c 1900 to c 2000',
#  'Literary studies: postcolonial literature',
#  'Literary studies: from c 2000',
#  'Literary studies: poetry and poets',
#  'Literary studies: plays and playwrights',
#  'Literary studies: fiction, novelists and prose writers',
#  'Comparative literature',
#  'Literary reference works',
#  'Literary companions, book reviews and guides',
#  'Children’s and teenage literature studies: general',
#  'Children’s and teenage book reviews and guides',
#  'Fiction and Related items',
#  'Fiction: general and literary',
#  'Modern and contemporary fiction: general and literary',
#  'Street fiction / urban fiction',
#  'Classic fiction: general and literary',
#  'Biographical fiction / autobiographical fiction',
#  'Speculative fiction',
#  'Dystopian and utopian fiction',
#  'Alternative history fiction',
#  'Afrofuturism / Black Speculative fiction',
#  'Metaphysical / philosophical fiction',
#  'Crime and mystery fiction',
#  'Classic crime and mystery fiction',
#  'Crime and mystery: private investigator / amateur detectives',
#  'Historical crime and mysteries',
#  'Crime and mystery: cosy mystery',
#  'Comic (humorous) crime and mystery',
#  'Crime and mystery: hard-boiled crime, noir fiction',
#  'Crime and mystery: police procedural',
#  'Crime and mystery: women sleuths',
#  'Sports fiction',
#  'Thriller / suspense fiction',
#  'Espionage and spy thriller',
#  'Technothriller',
#  'Medical thriller',
#  'Political / legal thriller',
#  'Esoteric thriller',
#  'Thriller: organised crime',
#  'Thriller: serial killers',
#  'Thriller: terrorism',
#  'Psychological thriller',
#  'Adventure / action fiction',
#  'Martial arts fiction',
#  'Historical adventure fiction',
#  'War, combat and military adventure fiction',
#  'Napoleonic War fiction',
#  'First World War fiction',
#  'Second World War fiction',
#  'Vietnam War fiction',
#  'Sea stories',
#  'Adventure fiction: Westerns',
#  'Horror and supernatural fiction',
#  'Classic horror and ghost stories',
#  'Contemporary horror and ghost stories',
#  'Occult fiction',
#  'Science fiction',
#  'Classic science fiction',
#  'Science fiction: time travel',
#  'Hard science fiction',
#  'Science fiction: steampunk',
#  'Science fiction: near future',
#  'Science fiction: cyberpunk / biopunk',
#  'Science fiction: apocalyptic and post-apocalyptic',
#  'Science fiction: military',
#  'Science fiction: space opera',
#  'Science fiction: aliens / UFOs',
#  'Science fiction: space exploration',
#  'Fantasy',
#  'Epic fantasy / heroic fantasy',
#  'Historical fantasy',
#  'Comic (humorous) fantasy',
#  'Magical realism',
#  'Fantasy romance',
#  'Superhero stories',
#  'Dark fantasy',
#  'Contemporary fantasy',
#  'Urban fantasy',
#  'Fiction: Traditional stories, myths and fairy tales',
#  'Fairy and Folk tales / Fairy tale retellings',
#  'Myths and Legends / Mythic fiction',
#  'Erotic fiction',
#  'Contemporary lifestyle fiction',
#  'Romance',
#  'Modern and Contemporary romance',
#  'Romance: wholesome',
#  'Historical romance',
#  'Romance: ‘western’, rural or ‘outback’',
#  'Romantic suspense',
#  'Romance in uniform',
#  'Romance: medical',
#  'Romance: the rich / famous / powerful',
#  'Romance: fantasy and paranormal',
#  'Romance: time travel',
#  'Dark romance',
#  'Erotic romance',
#  'Family life fiction',
#  'Saga fiction (family / generational sagas)',
#  'Humorous fiction',
#  'Satirical fiction and parodies',
#  'Historical fiction',
#  'Religious and spiritual fiction',
#  'Fiction: narrative themes',
#  'Narrative theme: Coming of age',
#  'Narrative theme: Love and relationships',
#  'Narrative theme: Environmental issues / the natural world',
#  'Narrative theme: Health and illness',
#  'Narrative theme: Death, grief, loss',
#  'Narrative theme: Interior life',
#  'Narrative theme: Identity / belonging',
#  'Narrative theme: Politics',
#  'Narrative theme: Displacement, exile, migration',
#  'Narrative theme: Sense of place',
#  'Narrative theme: Social issues',
#  'Narrative theme: Diversity, equality, inclusion',
#  'Narrative theme: Journeys and voyages',
#  'Fiction: special features',
#  'Short stories',
#  'Novella (Short Novel)',
#  'Epistolary fiction',
#  'Fiction: pastiche',
#  'Fiction: mashup',
#  'Fiction based on or inspired by true events',
#  'Fiction: special features: Yaoi / BL novels',
#  'Category fiction',
#  'Fiction: special features: ranobe (‘light novels’)',
#  'Fiction in translation',
#  'Fiction: inspired by or adapted from other media',
#  'Fiction: special features: game-related',
#  'Fiction companions',
#  'Reference, Information and Interdisciplinary subjects',
#  'Encyclopaedias and reference works',
#  'General encyclopaedias',
#  'Reference works',
#  'Dictionaries of biography',
#  'Subject dictionaries',
#  'Quotations, proverbs and sayings',
#  'Bibliographies, catalogues',
#  'Serials, periodicals, abstracts, indexes',
#  'Directories',
#  'Yearbooks, annuals, almanacs',
#  'Miscellanies and compendia',
#  'Library and information sciences / Museology',
#  'Library, archive and information management',
#  'Information retrieval and access',
#  'IT, Internet and electronic resources in libraries',
#  'Acquisitions and collection development',
#  'Bibliographic and subject control',
#  'Library and information services',
#  'Archiving, preservation and digitization',
#  'Museology and heritage studies',
#  'Research and information: general',
#  'Information theory',
#  'Cybernetics and systems theory',
#  'Data science and analysis: general',
#  'Coding theory and cryptology',
#  'Decision theory: general',
#  'Risk assessment',
#  'Research methods: general',
#  'Interdisciplinary studies',
#  'History of scholarship (principally of social sciences and humanities)',
#  'Communication studies',
#  'Semiotics / semiology',
#  'Cognitive studies',
#  'Regional / International studies',
#  'Development studies',
#  'Globalization',
#  'Decolonisation of knowledge / Decoloniality',
#  'Flags, emblems, symbols, logos',
#  'Peace studies and conflict resolution',
#  'Institutions and learned societies: general',
#  'General studies and General knowledge',
#  'Society and Social Sciences',
#  'Society and culture: general',
#  'Cultural and media studies',
#  'Cultural studies',
#  'Popular culture',
#  'Material culture',
#  'Cultural studies: dress and society',
#  'Cultural studies: food and society',
#  'Cultural studies: customs and traditions',
#  'Cross-cultural / Intercultural studies and topics',
#  'Cultural policies and debates',
#  'History of ideas',
#  'Media studies',
#  'Media studies: internet, digital media and society',
#  'Media studies: TV and society',
#  'Media studies: advertising and society',
#  'Media studies: journalism',
#  'Disinformation and misinformation',
#  'Social and ethical issues',
#  'Social discrimination and social justice',
#  'Racism and racial discrimination / Anti-racism',
#  'Social Integration and assimilation',
#  'Poverty and precarity',
#  'Housing and homelessness',
#  'Social impact of disasters / accidents (natural or man-made)',
#  'Refugees and political asylum',
#  'Aiding escape and evasion',
#  'Migration, immigration and emigration',
#  'Human trafficking',
#  'Violence and abuse in society',
#  'Child abuse',
#  'Sexual abuse and harassment',
#  'Domestic abuse',
#  'Bullying and harassment',
#  'Control, privacy and safety in society',
#  'Disability: social aspects',
#  'Health, illness and addiction: social aspects',
#  'Drugs and alcohol: social aspects',
#  'Social mobility',
#  'Consumerism',
#  'Animals and society',
#  'Ethical issues and debates',
#  'Ethical issues: abortion and birth control',
#  'Ethical issues: capital punishment',
#  'Ethical issues: censorship',
#  'Ethical issues: euthanasia and right to die',
#  'Ethical issues: scientific, technological and medical developments',
#  'Sex and sexuality, social aspects',
#  'Social attitudes',
#  'Social forecasting, future studies',
#  'Popular beliefs and controversial knowledge',
#  'Folklore studies / Study of myth (mythology)',
#  'Conspiracy theories',
#  'Social groups, communities and identities',
#  'Social classes',
#  'Rural communities',
#  'Urban communities',
#  'Gender studies, gender groups',
#  'Gender studies: women and girls',
#  'Feminism and feminist theory',
#  'Gender studies: men and boys',
#  'Gender studies: ‘trans’, transgender people and gender variance',
#  'LGBTQ+ Studies / topics',
#  'LGBTQ+ topics: coming out',
#  'Ethnic studies',
#  'Ethnic groups and multicultural studies',
#  'Indigenous peoples',
#  'Mixed heritage / mixed race groups or people',
#  'Age groups and generations',
#  'Age groups: children',
#  'Age groups: adolescents',
#  'Age groups: adults',
#  'Age groups: the elderly',
#  'Social groups: religious groups and communities',
#  'Social groups: alternative lifestyles',
#  'Secret societies',
#  'Social groups: clubs and societies',
#  'Sociology and anthropology',
#  'Sociology',
#  'Social theory',
#  'Social research and statistics',
#  'Population and demography',
#  'Sociology: family and relationships',
#  'Sociology: work and labour',
#  'Sociology: sport and leisure',
#  'Sociology: death and dying',
#  'Anthropology',
#  'Social and cultural anthropology',
#  'Social services and welfare, criminology',
#  'Social welfare and social services',
#  'Welfare and benefit systems',
#  'Child welfare and youth services',
#  'Adoption and fostering',
#  'Care of the elderly',
#  'Care of people with specific needs',
#  'Care of people with mental health issues',
#  'Social work',
#  'Charities, voluntary services and philanthropy',
#  'Social counselling and advice services',
#  'Aid and relief programmes',
#  'Emergency services',
#  'Police and security services',
#  'Fire services',
#  'Ambulance and rescue services',
#  'Crime and criminology',
#  'Causes and prevention of crime',
#  'Criminal investigation and detection',
#  'Forensic science',
#  'Drugs trade / drug trafficking',
#  'Street crime',
#  'Corporate crime / white-collar crime',
#  'Organized crime',
#  'Violent crimes',
#  'Penology and punishment',
#  'Offenders',
#  'Rehabilitation of offenders',
#  'Juvenile offenders',
#  'Probation services',
#  'Victimology and victims of crime',
#  'Psychology',
#  'Psychological theory, systems, schools and viewpoints',
#  'Psychoanalytical and Freudian psychology',
#  'Lacanian psychoanalysis',
#  'Analytical and Jungian psychology',
#  'Behaviourism, Behavioural theory',
#  'Humanistic psychology',
#  'Positive psychology',
#  'Cognitivism, cognitive theory',
#  'Psychological methodology',
#  'Psychological testing and measurement',
#  'Child, developmental and lifespan psychology',
#  'Psychology of ageing',
#  'Family psychology',
#  'Psychology of gender',
#  'Social, group or collective psychology',
#  'Interpersonal communication and skills',
#  'Occupational and industrial psychology',
#  'Criminal or forensic psychology',
#  'Experimental psychology',
#  'Physiological and neuro-psychology, biopsychology',
#  'Abnormal psychology',
#  'Psychology: emotions',
#  'Cognition and cognitive psychology',
#  'Psychology: the self, ego, identity, personality',
#  'Psychology: states of consciousness',
#  'Psychology: sexual behaviour',
#  'Parapsychological studies',
#  'Education',
#  'Philosophy and theory of education',
#  'Moral and social purpose of education',
#  'Progressive education',
#  'History of education',
#  'Educational psychology',
#  'Educational systems and structures',
#  'Curriculum planning and development',
#  'Education: examinations and assessment',
#  'Social pedagogy',
#  'Educational strategies and policy',
#  'Counselling and care of students',
#  'Educational strategies and policy: inclusion',
#  'Early childhood care and education',
#  'Home schooling',
#  'Educational administration and organization',
#  'Funding of education and student finance',
#  'Teaching staff',
#  'Schools and pre-schools',
#  'Pre-school and kindergarten',
#  'Primary and middle schools',
#  'Secondary schools',
#  'Independent schools, private education',
#  'Residential educational institutions',
#  'Faith (religious) schools',
#  'Outdoor schools / education',
#  'Higher education, tertiary education',
#  'Teacher training',
#  'Adult education, continuous learning',
#  'Open learning, distance education',
#  'Careers guidance',
#  'Work experience, placements and internships',
#  'Industrial or vocational training',
#  'Teaching of students with different educational needs',
#  'Teaching of students with physical impairments or disabilities',
#  'Teaching of students with learning difficulties',
#  'Teaching of students with social, emotional or behavioural difficulties',
#  'Teaching of gifted or talented students',
#  'Remedial education and teaching',
#  'Education of bilingual or multilingual students',
#  'Teaching skills and techniques',
#  'Competence development',
#  'Project-based learning',
#  'Play-based learning',
#  'Teaching of reading, writing and numeracy',
#  'Teaching of a specific subject',
#  'Teachers’ classroom resources and material',
#  'Lesson plans',
#  'Educational equipment and technology, computer-aided learning (CAL)',
#  'Extra-curricular activities',
#  'Study and learning skills: general',
#  'Politics and government',
#  'Political science and theory',
#  'Comparative politics',
#  'Political ideologies and movements',
#  'Green politics / ecopolitics / environmentalism',
#  'Anarchism',
#  'Far-left political ideologies and movements',
#  'Left-of-centre democratic ideologies',
#  'Centrist democratic ideologies',
#  'Right-of-centre democratic ideologies',
#  'Nationalism',
#  'Pan-nationalism',
#  'Far-right political ideologies and movements',
#  'Religious and theocratic ideologies',
#  'Political structure and processes',
#  'Constitution: government and the state',
#  'Elections and referenda / suffrage',
#  'Political leaders and leadership',
#  'Political structures: democracy',
#  'Political structures: totalitarianism and dictatorship',
#  'Political parties and party platforms',
#  'Indigenous people: governance and politics',
#  'Public administration',
#  'Central / national / federal government',
#  'Central / national / federal government policies',
#  'Regional, state and other local government',
#  'Regional, state and other local government policies',
#  'International relations',
#  'Diplomacy',
#  'Arms negotiation and control',
#  'Espionage and secret services',
#  'Geopolitics',
#  'International institutions',
#  'Municipal / city government',
#  'Political control and freedoms',
#  'Civics and citizenship',
#  'Human rights, civil rights',
#  'Political oppression and persecution',
#  'Political abduction, imprisonment, ‘Disappearance’ and assassination',
#  'Political activism / Political engagement',
#  'Public opinion and polls',
#  'Public affairs / Lobbying',
#  'Political campaigning and advertising',
#  'Pressure groups, protest movements and non-violent action',
#  'Non-governmental organizations (NGOs)',
#  'Terrorism, armed struggle',
#  'Revolutionary groups and movements',
#  'Armed conflict',
#  'Corruption in politics, government and society',
#  'Warfare and defence',
#  'Theory of warfare and military science',
#  'Military forces and sectors',
#  'Land forces and warfare',
#  'Irregular or guerrilla forces and warfare',
#  'Naval forces and warfare',
#  'Air forces and warfare',
#  'Special and elite forces',
#  'Information warfare / Cyberwarfare',
#  'Military administration',
#  'Military and defence strategy',
#  'Military intelligence',
#  'War and defence operations',
#  'Battles and campaigns',
#  'Peacekeeping operations',
#  'Weapons and equipment',
#  'Chemical and biological weapons',
#  'Nuclear weapons',
#  'Military vehicles',
#  'Military institutions',
#  'Military uniforms / insignia',
#  'Other warfare and defence issues',
#  'Arms trade',
#  'Non-combatants',
#  'War crimes',
#  'Mercenaries',
#  'Prisoners of war',
#  'Mutiny',
#  'Military veterans',
#  'Combat / defence skills and manuals',
#  'Economics, Finance, Business and Management',
#  'Economics',
#  'Economic theory and philosophy',
#  'Macroeconomics',
#  'Monetary economics',
#  'Microeconomics',
#  'Domestic or internal trade',
#  'Economics of industrial organization',
#  'Labour / income economics',
#  'Economic growth',
#  'Econometrics and economic statistics',
#  'Economic forecasting',
#  'Behavioural economics',
#  'International economics',
#  'International trade and commerce',
#  'Development economics and emerging economies',
#  'Political economy',
#  'Economic systems and structures',
#  'Capitalism',
#  'Mixed economic systems',
#  'Planned economic systems',
#  'Circular economic systems',
#  'Economics of specific sectors',
#  'Agricultural and rural economics',
#  'Environmental economics',
#  'Health economics',
#  'Welfare economics',
#  'Digital or internet economics',
#  'Knowledge / Information / Data economics',
#  'Service sector economics',
#  'Regional / urban economics',
#  'Economic and financial crises and disasters',
#  'Popular economics',
#  'Economic history',
#  'Finance and accounting',
#  'Accounting',
#  'Cost accounting',
#  'Financial accounting',
#  'Management accounting, bookkeeping and auditing',
#  'Auditing / Audits',
#  'Valuation (finance)',
#  'Public finance accounting',
#  'Financial reporting, financial statements',
#  'Tax planning and compliance',
#  'Accounting: study and revision guides',
#  'Finance and the finance industry',
#  'Fundraising, grants, donations',
#  'Public finance and taxation',
#  'Financial technology (fintech)',
#  'Corporate finance',
#  'Currency / Foreign exchange',
#  'Banking',
#  'Credit and credit institutions',
#  'Investment and securities',
#  'Insurance and actuarial studies',
#  'Pensions',
#  'Property and real estate',
#  'Green finance / sustainable finance',
#  'Private wealth management',
#  'Banking and finance: study and revision guides',
#  'Business and Management',
#  'Business studies: general',
#  'Business and management: study and revision guides',
#  'Business strategy',
#  'Business innovation',
#  'Disruptive innovation',
#  'E-commerce: business aspects',
#  'Business competition',
#  'Business ethics and social responsibility',
#  'Entrepreneurship / Start-ups',
#  'Business and the environment; ‘green’ approaches to business',
#  'International business',
#  'Consultancy',
#  'Management and management techniques',
#  'Management: leadership and motivation',
#  'Management decision making',
#  'Knowledge management',
#  'Business process / operations management',
#  'Project management',
#  'Quality Assurance (QA) and Total Quality Management (TQM)',
#  'Time management',
#  'Management of specific areas',
#  'Budgeting and financial management',
#  'Personnel and human resources management',
#  'Performance management / appraisals',
#  'Diversity, equality and inclusion in the workplace',
#  'IT and information systems management',
#  'Management of assets: real estate, property and plant',
#  'Production and quality control management',
#  'Research and development management',
#  'Sales and marketing management',
#  'Purchasing and supply management',
#  'Distribution and logistics management',
#  'Business negotiation',
#  'Business communication and presentation',
#  'Business mathematics and systems',
#  'Corporate governance: role and responsibilities of boards and directors',
#  'Sales and marketing',
#  'Advertising',
#  'Brands and branding',
#  'Online marketing / Social media marketing',
#  'Direct marketing / telemarketing',
#  'Market research',
#  'Public relations',
#  'Marketing for change / Cause-related marketing',
#  'Greenwashing and other forms of deceptive marketing',
#  'Customer services',
#  'Operational research',
#  'Organizational theory and behaviour',
#  'Ownership and organization of enterprises',
#  'Takeovers, mergers and buy-outs',
#  'Privatization',
#  'Franchises',
#  'Multinationals',
#  'Public ownership / nationalization',
#  'Monopolies',
#  'Family and Owner-Managed Companies',
#  'Small businesses and self-employment',
#  'Outsourcing and insourcing',
#  'Joint ventures',
#  'Employee-ownership and co-operatives',
#  'Non-profitmaking organizations',
#  'Office and workplace',
#  'Office management',
#  'Office systems and equipment',
#  'Secretarial, clerical and office skills',
#  'Working patterns and practices',
#  'History of specific companies / corporate history',
#  'Industry and industrial studies',
#  'Agribusiness and primary industries',
#  'Agriculture, agribusiness and food production industries',
#  'Fisheries and related industries',
#  'Forestry industry',
#  'Extractive industries',
#  'Energy industries and utilities',
#  'Electrical power generation and distribution industries',
#  'Petroleum, oil and gas industries',
#  'Alternative and renewable energy industries',
#  'Water industries',
#  'Manufacturing industries',
#  'Chemical, biotechnology and pharmaceutical industries',
#  'Apparel, garment and textile industries',
#  'Vehicle and transport manufacturing industries',
#  'Transport industries',
#  'Construction and heavy industry',
#  'Construction and building industry',
#  'Iron, steel and other metal industries',
#  'Retail and wholesale industries',
#  'Hospitality and service industries',
#  'Food and drink service industries',
#  'Hospitality, sports, leisure and tourism industries',
#  'Events management industry',
#  'Fashion and beauty industries',
#  'Deathcare and funeral industries',
#  'Media, entertainment, information and communication industries',
#  'Film, TV and Radio industries',
#  'Music industry',
#  'Publishing industry and journalism',
#  'Publishing and book trade',
#  'News media and journalism',
#  'Printing and reprographic industries',
#  'Computer and video game industry',
#  'Information technology industries',
#  'Civil service and public sector',
#  'Industrial relations, occupational health and safety',
#  'Health and safety in the workplace',
#  'Industrial arbitration and negotiation',
#  'Trade unions',
#  'Law',
#  'Jurisprudence and general issues',
#  'Methods, theory and philosophy of law',
#  'Systems of law',
#  'Systems of law: common law',
#  'Systems of law: civil codes / civil law',
#  'Systems of law: customary law',
#  'Systems of law: mixed systems',
#  'Systems of law: Roman law',
#  'Systems of law: Islamic law',
#  'Systems of law: Jewish Law',
#  'Systems of law: ecclesiastical (canon) law',
#  'Comparative law',
#  'Legal technology',
#  'Law and society, sociology of law',
#  'Law and society, gender issues',
#  'Legal aspects of criminology',
#  'Legal skills and practice',
#  'Legal skills: advocacy',
#  'Legal skills: drafting and legal writing',
#  'Legal skills: negotiating and interviewing',
#  'Legal skills: research methods',
#  'Legal practice: paralegals and paralegalism',
#  'Legal profession / practice of law: general',
#  'Legal ethics and professional conduct',
#  'Law as it applies to other professions and disciplines',
#  'Legal history',
#  'International law',
#  'Public international law',
#  'Public international law: treaties and other sources',
#  'Public International law: customary law',
#  'Public international law: diplomatic law',
#  'Public international law: jurisdiction and immunities',
#  'Public international law: territory and statehood',
#  'Public international law: law of the sea',
#  'Public International law: health',
#  'Public international law: economic and trade',
#  'Public international law, economic and trade: tariffs',
#  'Public international law, economic and trade: investment treaties and disputes',
#  'Public international law: energy and natural resources',
#  'Public international law, economic and trade: corporations',
#  'Public international law: environment',
#  'Public international law, environment: agricultural law',
#  'Public international law: administration',
#  'Public international law: human rights',
#  'Public international law, human rights: labour and social',
#  'Public international law: humanitarian law',
#  'Public international law: international organizations and institutions',
#  'Public international law: responsibility of states and other entities',
#  'Public international law: criminal law',
#  'International law: transport, communications and commerce',
#  'International law, transport: space and aerospace law',
#  'International law: transnational commerce and international sale of goods law',
#  'International law, transport and commerce: maritime law',
#  'International law: communications, telecommunications and media',
#  'Private international law and conflict of laws',
#  'International law: international disputes and civil procedure',
#  'International law: courts and procedures',
#  'International law: arbitration',
#  'International law: intellectual property',
#  'International law: sports',
#  'International law reports',
#  'Laws of specific jurisdictions and specific areas of law',
#  'Legal systems: general',
#  'Legal systems: courts and procedures',
#  'Legal systems: judges and judicial powers',
#  'Legal systems: lay and citizen judges / juries',
#  'Legal systems: law of contempt',
#  'Legal systems: civil procedure, litigation and dispute resolution',
#  'Civil remedies',
#  'Restitution',
#  'Damages and compensation',
#  'Injunctions and other orders',
#  'Civil procedure: law of evidence',
#  'Civil procedure: investigation and specific proceedings',
#  'Arbitration, mediation and alternative dispute resolution',
#  'Legal systems: General Part / General Provisions',
#  'Legal systems: costs and funding',
#  'Legal systems: regulation of legal profession',
#  'Private or civil law: general',
#  ...]

# %%
all_nodes_descriptions_preprocessed = utils.preprocess_theme_list(all_nodes_descriptions)
all_nodes_descriptions_preprocessed = list(set(all_nodes_descriptions_preprocessed))
print(all_nodes_descriptions_preprocessed)
# Out:
# ['nuxalk', 'hydroponics', 'haute-normandie', 'morelos', 'slovenian', 'wildlife:', 'comfort', 'beheira', 'nyankore', 'breda', 'lozère', 'bourgogne-franche-comté', 'signal', 'durham', 'nuremburg', 'biobío', 'communications', 'nicosia', 'lusaka', 'irregular', 'sanctioning', 'babylonia', 'lunigiana', 'macgillycuddy’s', 'nagasaki', 'vire-normandie', 'montenegrin', '13th', 'istria', 'realism', 'jharkhand', 'violin', '711–1492', 'apiculture', 'epic', 'wallonian', 'alsace', 'nepal', 'mallorca', 'tahitian', 'project-based', 'tremiti', 'media', 'revolutions', 'mathematics', 'fauske', 'pomeranian', 'hebei', 'archaeological', 'cardiothoracic', 'republic', 'holocaust', 'tokyo', '1945–1989', 'dublin', '1861–1877', 'spanish-based', 'ithaca', 'hokkaido', 'santo', 'mathematical', 'thionville', 'tagalog', 'montevideo', 'military', 'windsor', 'cooking', 'mauritania', 'arachnids', 'development', 'blues', 'dunkirk', 'kursk', 'lent', 'mumbai', 'kendo', 'bergisches', 'hospitality', 'manufacturing', 'vegan', 'montgomery', 'atlanta', 'malaysia', '1975', 'tianjin', 'martial', 'montreux', 'brasilia', 'arles', 'møre', 'jalisco', 'locarno', 'alabama', '1485–1603', 'chilomwe', 'bloomsbury', 'private', 'schweizerischer', 'emmen', 'designed', 'haemodialysis', 'kosice', 'lesbos', 'weapons', 'carpathian', 'minas', 'animated', 'passover', 'czechia:', 'macroeconomics', 'sarcelles', 'sannio', 'orthodontics', 'belize', 'phthiotis', 'brahui', 'retirement', 'bochum', 'rajasthan', 'aomori', 'stone', 'rivers', 'surfing', 'amrum', 'motorcycle', 'way', 'mining', 'faith', 'jyväskylä', 'cholet', 'age', 'gotland', 'croatian', 'sainte-menehould', 'duala', 'saint-dizier', 'nanterre', 'salta', 'béarn', 'zug', 'bournemouth', 'hobart', 'roussillion', 'castres', 'saint-laurent-du-maroni', 'secession', 'fosnavåg', 'sustainability', 'inupiaq', 'prison', 'antiques', 'kristiansund', 'malawi', '1772–1809', 'quebec:', 'psychopharmacology', 'accounting', 'topics', 'sinhalese', 'ghosts', 'pirkanmaa', 'korea', 'physics:', 'learning', 'opec', 'medicine:\xa0diabetes', 'walking', 'åndalsnes', 'wellington', 'dessau', 'cushitic', 'mortagne-au-perche', 'mysen', 'péronne', 'gaborone', 'sør-trøndelag', 'gourdon', 'malaga:', 'pays', 'azerbaijan', 'pentecostal', 'hydraulic', 'skopje', 'frosinone', 'polesine', 'impact', 'loch', 'bangkok', 'postmodernism', 'ulsan', 'rabat-salé-kenitra', 'arlberg', 'eu', 'farsund', 'pau', 'florence', 'columbia', 'shanxi', 'jessheim', 'alpine', 'lillestrøm', 'language', 'defamation', 'inorganic', 'cochabamba', 'far-left', 'otorhinolaryngology', 'limoges', 'geometry', 'drenthe', 'homoeopathy', 'dating', 'manche', 'urban', 'rayonism', '1701–1796', 'papua', 'argentan', 'mosjøen', 'europe:', 'larvik', 'palmyra', 'vernacular', 'grammar', 'whitby', 'gyeonggi-do', 'photographs:', 'freiberg', 'veneto', 'vilnius', 'latvia', 'jilin', 'structuralism', 'córdoba', 'bordeaux', 'south', 'kazimierz', 'oklahoma', 'skudeneshavn', 'roraima', 'hague', 'competence', 'massif', 'saint-pierre', 'tyrol', 'minimalist', 'harlem', 'aragon', 'cordillera', 'tanzania', 'sandnessjøen', 'potenza', 'criminal', 'stołowe', 'events', 'algebra', 'animism', 'paderborn', 'campania', 'regulatory', 'riom', 'perche', 'kannada', 'carnival', 'camden', 'quercy', 'pan-nationalism', 'sounds', 'drâa-tafilalet', 'mayenne', 'dominican', 'stratigraphy', 'serbian', 'heilongjiang', 'osaka', 'rollerblading', 'dermatology', 'expert', 'charity', 'i', 'japan', 'romani', 'environmentalist', 'economics', 'dairy', 'micronesia', 'aircraft', 'chemistry', 'ethiopic', 'avignon', 'helgeland', 'brønnøysund', 'mixed', 'rodez', 'breton', 'yupik', 'marine', 'cybernetics', 'cultural', 'yerupaja', 'corinth', 'rhodes', 'chablais', 'odda', 'étampes', 'hyogo', 'countryside', 'puebla', 'hasselt', 'leiden', 'techniques', 'zakynthos', 'moscow', 'menopause', 'illinois', 'michigan', 'chad', 'yellowstone', 'retro', 'interdisciplinary', 'guadeloupe', 'digital', 'trade', 'prayer', 'veszprém', 'suez', 'otjiherero', 'lyric', 'flowering', 'burkina', 'd ...

# %%
len(all_nodes_descriptions_preprocessed)
# Out:
# 4914

# %% [markdown]
# ## description and notes

# %%
all_nodes_descriptions_notes_raw = {}
for node in thema_codes:
    all_nodes_descriptions_notes_raw[node["CodeDescription"]] = node["CodeNotes"]

# %%
all_nodes_descriptions_notes_raw
# Out:
# {'Arts': 'Utilisez tous les codes A* pour les ouvrages spécialisés et généraux, qu’ils soient richement illustrés ou majoritairement textuel. Préférez les codes WF* pour les ouvrages liés à un loisir ou un passe-temps, en le complétant au besoin par le(s) code(s) A*. Utilisez au besoin tous les codes A* avec d’autres codes et qualificateurs, particulièrement avec les qualificateurs de style 6*, de lieux 1* et historiques 3*',
#  'Arts : généralités': '',
#  'Théorie de l’art': 'Lié : QDTN',
#  'Conservation, restauration et entretien d’œuvres d’art': 'Utilisez tous les codes A* pour les ouvrages sur la conservation, la préservation, la rénovation, la restauration ou l’entretien de tout type d’art, y compris les bâtiments, les structures, les sculptures, les photos, les peintures, les arts décoratifs, etc.',
#  'Contrefaçon, falsification et vol d’œuvres d’art': '',
#  'Art : aspects financiers': 'Classez ici : les ventes d’art et vente aux enchères, le financement, le parrainage et le sponsoring, les ventes organisées, le marché crypto-art et NFT, le marché de l’art blockchain, l’art en tant qu’investissement financier ou spéculatif, la valeur commerciale de l’art, le commerce de l’art',
#  'Arts : formes d’art': 'Utilisez pour les ouvrages sur les beaux-arts, les arts visuels et appliqués. Utilisez pour tous les codes AF*, le(s) code(s) AG* approprié(s), AGA pour l’histoire de l’art et des œuvres, AGZ pour les ouvrages spécialisés sur la technique, et au besoin le(s) qualificateur(s) de style 6*. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#  'Peinture et tableaux': 'Classez ici : la peinture ou les peintures, ou tout support sans catégorie plus spécifique se trouvant ci-dessous. Utilisez tous les codes AFC* pour les ouvrages concernant la ou les peintures, réalisé(es) par une personne ou un groupe de personnes, l’histoire de peintures spécifiques ou du style spécifique de la peinture. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s). Utilisez avec AGA pour l’histoire des œuvres d’art, AGB pour les monographies sur les peintres, AGZ pour les ouvrages spécialisés sur la technique, etc. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#  'Tableaux, aquarelle et pastels': 'Classez ici : la gouache',
#  'Tableaux et peinture à l’huile': 'Classez ici : les tableaux et peintures acryliques',
#  'Peintures murales et fresques': 'Classez ici : le trompe l’œil, les fresques, les peintures au plafond, le muralisme, le marouflage',
#  'Tableaux et peinture à l’encre': 'Classez ici : le lavis d’encre Lié : AFFK',
#  'Dessin et dessins': 'Classez ici : les croquis. Utilisez tous les codes AFF* pour les ouvrages concernant le ou les dessin(s), réalisé(s) par une personne ou un groupe de personnes, l’histoire de dessins spécifiques ou du style spécifique du dessin. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s). Utilisez avec AGA pour l’histoire des œuvres d’art, AGB pour les monographies sur les peintres, AGZ pour les ouvrages spécialisés sur la technique. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#  'Dessin et dessins au crayon, fusain ou pastel': 'Classez ici : le crayon graphite, la craie, Conté',
#  'Dessin et dessins à la plume, au pinceau et à l’encre': 'Lié : AFCP',
#  'Estampes et gravure': 'Classez ici : l’eau-forte, les sérigraphies les gravures sur bois, les lithographies, les gravures au trait, les aquatintes, la pointe sèche, la manière noire, les monotypes, les blocs de bois',
#  'Autres formes d’art graphique ou visuel': 'Classez ici : le collage, le montage photographique. Utilisez pour les ouvrages généraux ou pour les formes d’arts qui n’ont pas de code spécifique dans les codes AFC*, AFF* ou AFH*',
#  'Body art et tatouage': 'Classez ici : le body piercing, la peinture sur corps en tant qu’art. Utilisez avec le code AFKP pour les performances artistiques',
#  'Formes d’art non graphique et électroniques': 'Utilisez pour les ouvrages généraux sur les formes d’art non graphique ou pour les formes d’art non listées ci-dessous, y compris les nouvelles formes de média',
#  'Sculpture': 'Classez ici : les statues, les figurines, les sculptures monumentales. Utilisez pour les ouvrages sur les arts en trois dimensions dans n’importe quel matériau, sur la forme d’art, ou sur les traditions et techniques associées',
#  'Sculptures, masques, reliefs': 'Classez ici : les pétroglyphes, les sculptures à petite échelle et monumentales. Utilisez pour les ouvrages aussi bien sur la technique, que sur les objets sculptés spécifiques ou les réalisations sculptées dans n’importe quel matériau',
#  'Métal précieux, pierres précieuses et bijoux : techniques et procédés': 'Classez ici : l’Orfèvrerie, Fabergé, etc. Lié : WFJ WCP WCR WFP',
#  'Installation artistique': 'Classez ici : le land art, l’art in situ, l’art environnemental',
#  'Performance artistique': '',
#  'Art digital, vidéo et des nouveaux médias': 'Classez ici : les arts informatique, électronique, holographique, virtuel, cyborg, interactif, en ligne, génératif, télématique, sonore et évolutionnaire, le crypto-art, l’art du jeu vidéo, l’art logiciel Lié : UG*',
#  'Céramique, mosaïque et verre : œuvres d’art': 'Classez ici : la poterie (inclut la porcelaine, la faïence, le grès, le biscuit), les vitraux, carreaux ou émail considérés comme œuvres d’art Lié : WFN',
#  'Arts décoratifs': 'Classez ici : les ornements, les motifs ornementaux, les détails décoratifs, les motifs ou les formes, la fausse peinture ou finition, la ferronnerie, la laque et les autres arts décoratifs. Utilisez pour les ouvrages qui abordent le sujet sous l’angle des beaux-arts ou de l’histoire de l’art, ou qui visent un public plus professionnel, technique ou qualifié Lié : WF*',
#  'Arts du textile': 'Classez ici : les tapis, les tapisseries, les kilims, les moquettes, les courtepointes et les autres arts du textile considérés comme œuvres d’art Lié : AKT WFB* WFF WFG',
#  'Arts : techniques et sujets': 'Utilisez pour les ouvrages sur les beaux-arts, les arts visuels et appliqués. Utilisez tous les codes AG* avec le(s) code(s) AB*, AF*, AG*, AJ* approprié(s) et au besoin avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* approprié(s)',
#  'Histoire de l’art': 'Utilisez avec les autres codes Arts A* et également avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3*',
#  'Artistes, monographies': 'Utilisez pour les ouvrages sur des artistes individuels et des ateliers ou des ateliers produisent sous le nom d’un seul artiste',
#  'Catalogues d’exposition et collections': 'Utilisez pour les catalogues d’exposition temporaire ou permanente de galeries d’art, musées ou de collectionneurs. Utilisez avec d’autres codes A* pour indiquer la forme d’art et également le(s) qualificateurs(s) de lieux si le catalogue est lié à un lieu permanent comme pour une galerie spécifique ou un musée Lié : WTHM GLZ',
#  'Figures humaines dans l’art': 'Classez ici : les peintures ou dessins de figures humaines, les illustrations par des artistes de l’anatomie humaine, les dessins anatomiques, ou tout art qui représente l’humain ou une partie du corps humain. Utilisez avec AGZ pour les ouvrages sur la technique du dessin',
#  'Portraits et autoportraits dans l’art': '',
#  'Nus dans l’art': '',
#  'Art érotique': 'Utilisez le qualificateur 5X approprié Lié : AJCX',
#  'Scènes de vie, profanes et domestiques dans l’art': 'Classez ici : les scènes de genre, les scènes et évènements quotidiens dans l’art',
#  'Nature dans l’art': 'Utilisez pour les représentations de la nature sous n’importe quelle forme ou tradition artistique. Utilisez avec AKLB pour l’illustration, ou PS* pour l’art qui est ou a été créée à des fins scientifiques',
#  'Animaux dans l’art': 'Classez ici : les peintres animaliers, l’art de la faune, les oiseaux, les insectes, les poissons, etc. dans l’art. Utilisez pour les représentations de la faune sous n’importe quelle forme ou tradition artistique. Utilisez avec AKLB pour l’illustration, ou PS* pour l’art qui est ou a été créée à des fins scientifiques',
#  'Plantes dans l’art': 'Classez ici : les illustrations botaniques. Utilisez pour : tous les types de représentation artistique et précise d’arbres, de fleurs ou de plantes dans n’importe quelle forme ou tradition artistique. Utilisez avec PST pour l’art botanique à vocation scientifique, en général des oeuvres contenant du textes sur les plantes ou des reproductions d’oeuvres botaniques historiques, ou avec AKLB pour les œuvres sur l’art botanique comme exemples de l’art de l’illustration',
#  'Paysages, paysages marins dans l’art': 'Classez ici : les paysages célestes, les paysages nuageux, les paysages fluviaux, les scènes fluviales, l’art du paysage, la veduta, les paysages urbains, les paysages urbains, les paysages lunaires, les paysages aquatiques, les paysages intérieurs, les Weltlandschaft. Utilisez pour : les œuvres sur les types de paysages dans les arts visuels, ou des exemples individuels',
#  'Natures mortes': 'Classez ici : les vanités, les natures mortes, les memento mori. Utilisez pour la représentation des scènes à petite échelle de sujets principalement inanimés, naturels ou faits par l’homme, essentiellement, un sujet qui ne bouge pas ou qui est mort dans une peinture, une photo, une sculpture ou une autre forme d’art de nature morte',
#  'Réalisations humaines dans l’art': 'Classez ici : les immeubles, les paysages urbains, les machines, les transports, etc. représenté(e)s sous n’importe quelle forme ou tradition artistique',
#  'Art religieux': 'Classez ici : l’art sacré ou rituel, les icônes, les images votives. Utilisez pour : les œuvres sur l’imagerie artistique utilisant une inspiration ou des motifs religieux, la représentation artistique de figures, de motifs, de formes, de calligraphie, etc. à des fins spirituelles ou religieuses. Utilisez au besoin les codes QR* pour indiquer une religion particulière et d’autres codes A* pour les ouvrages sur des types d’art particuliers',
#  'Art public': 'Utilisez pour les ouvrages sur tout art qui a été conçu et exécuté dans l’intention d’être diffusé dans l’espace public, le plus souvent à l’extérieur et accessible à tous, pouvant être permanent ou temporaire, et spécialement commandé pour un lieu ou non-officiel ou non autorisé',
#  'Arts urbains': 'Classez ici : l’art de la guérilla, les graffitis, le flyposting, le sticker art, le bombardement de fils, les installations dans la rue, les styles urbains, etc. Utilisez pour les ouvrages sur les formes d’art visuel ou appliqué à l’espace urbain, inspirés des modes de vie urbain ou l’environnement et présent dans l’espace public',
#  'Arts : techniques et principes': 'Utilisez pour les manuels, les études et ouvrages spécialisés sur les techniques, la perspective, etc. Utilisez avec le(s) code(s) AF* ou AK* approprié(s) pour indiquer la forme d’art, par exemple AFF pour les techniques en dessin. Pour les ouvrages destinés aux amateurs ou liés à un loisir ou passe-temps, préférez les codes WF* Lié : WFA',
#  'Théorie des couleurs': 'Classez ici : la science de la couleur dans l’art. Utilisez avec le(s) code(s) P* ou T* pour une approche plus scientifique ou technique',
#  'Photographie et photographies': '',
#  'Photographies : collections': 'Utilisez pour les ouvrages qui sont ou au sujet d’une collection ou une sélection réfléchie de photographies généralement autour d’un thème, d’un concept ou représentant la collection d’un musée, d’une galerie, d’une agence ou d’un collectionneur. Utilisez avec le(s) code(s) AG* pour les traitements plus spécifiques ou tout autre code pour indiquer le code approprié Lié : WQP',
#  'Photographes': 'Classez ici : les monographies de photographies',
#  'Photographie : art du portrait et de l’autoportrait': 'Utilisez pour les ouvrages de photographies présentant une personne, des personnes ou un groupe de personnes, y compris les selfies et les modèles, et également les portraits. Utilisez avec AJTF pour les techniques pratiques du portrait',
#  'Nus et photographies érotiques': 'Utilisez le qualificateur 5X approprié Lié : AGHX',
#  'Photoreportage et photographie documentaire': 'Classez ici : les reportages photographiques, la photographie documentaire / sociale et de rue, la photographie d’évènements et de célébrités Lié : DNP',
#  'Equipement photographique et techniques : généralités': 'Classez ici : les appareils photographiques, les objectifs, l’éclairage, la pellicule, le flash, les techniques de chambre noire et le traitement photographique, la retouche et la manipulation numérique, les principes de couleurs, la composition, le noir et blanc, etc. Lié : UGP',
#  'Manuels spécifiques pour appareils photo': 'Utilisez pour les ouvrages au sujet d’un type ou marque d’appareil photographique',
#  'Photographie : techniques et principes pour sujets spécifiques': 'Classez ici : la photographie aérienne, avec drone, en studio, de rue, de paysage, de la nature et de la faune, du portrait, sous-marine, les techniques et guides de micro et astrophotographie. Utilisez pour les ouvrages sur la composition, etc.',
#  'Photographie numérique': '',
#  'Photographie monochrome': 'Classez ici : la photographie monochrome en niveaux de gris, noir et blanc, sépia, cyanotype, monochrome marron. Utilisez avec AJTV pour les techniques monochromes pour le film / la vidéo',
#  'Lumière et éclairage': 'Classez ici : la photographie au flash, l’utilisation de la lumière ou de l’éclairage naturel ou artificiel. Utilisez avec AJTV pour les techniques d’éclairage pour le film / la vidéo ou avec les codes AT* pour les techniques d’éclairage ou la conception d’éclairage dans les arts de la scène',
#  'Direction de la photographie et de la vidéo': 'Lié : AFKV ATFX ATJX',
#  'Design, arts industriel et commercial, illustration': 'Utilisez tous les codes AK* pour les ouvrages qui abordent le sujet sous l’angle des beaux-arts ou de l’histoire de l’art, ou qui visent un public plus professionnel, technique ou qualifié. Utilisez avec le(s) qualificateur(s) de style 6*, de lieux 1* ou historique(s) 3* appropriés. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps',
#  'Designers ou collectif de designers': 'Classez ici : les agences de design, les marques, les entreprises, les firmes et maisons et les personnes. Utilisez au besoin ce code avec d’autres codes pour indiquer le domaine concerné, par exemple le code AKT pour le design dans la mode et le textile ou avec le code AGA pour l’approche historique',
#  'Graphisme': '',
#  'Typographie et lettrage': 'Classez ici : les polices d’écriture, les polices de caractères et leur conception, la peinture de signes, le shufa, le shodo, le khatt et les autres formes de calligraphie considérées comme un art Lié : WFU',
#  'Conception et reliure des livres': 'Classez ici : la conception de la couverture, l’art de la reliure, le papier marbré, etc. en tant qu’art. Utilisez pour les ouvrages sur l’art de concevoir et réaliser des livres Lié : WFT AKLB KNTP1',
#  'Manuscrits et enluminures': 'Classez ici : les miniatures, les manuscrits enluminés ou les manuscrits à peintures, les parchemins et codex',
#  'Illustration et dessin publicitaire': '',
#  'Illustration': 'Classez ici : les illustrations de livres et les graphiques d’informations d’art. Utilisez pour les ouvrages sur les illustrations d’art aussi bien que les illustrations, contemporaines ou historiques, réalisées à des fins scientifiques, techniques, de narration ou autres Lié : AFF',
#  'Comics et bandes dessinées': 'Utilisez les codes AKLC* avec les codes X* pour indiquer le style de bandes dessinées impliqué, avec AGZ pour les ouvrages spécialisés dans la technique du de la bande dessinée ou des personnages, avec AKX pour l’histoire de la bandes dessinées. Préférez les codes WF* pour les ouvrages destinés aux amateurs et liés à un loisir ou passe-temps ou UGL pour les illustrations numériques plus techniques Lié : AFF',
#  'Roman graphique et manga': 'Associez au besoin la forme de l’œuvre à l’aide du code X* approprié Lié : XA* XR* AFF',
#  'Jeux vidéos': 'Utilisez pour les ouvrages sur les aspects artistiques de la conception du jeu vidéo, les dessins, le graphisme, l’art, etc. Lié : UGG',
#  'Art de l’affiche': '',
#  'Conception de produit': 'Classez ici : la conception universelle et accessible des produits, la conception industriel. Utilisez pour les ouvrages sur la conception de produits en général, y compris les noms de commerces ou de marques associés, sur la conception d’un produit ou d’un type de produits, et sur la fonctionnalité, sécurité et conception durable des produits, etc. Lié : TBD UGC',
#  'Art du mobilier': '',
#  'Mode et textiles': 'Utilisez pour : les styles et tendances de la mode, les ouvrages généraux et de référence, les ouvrages sur des pièces vestimentaires spécifiques, les ouvrages illustrés sur la mode, etc. Utilisez tous les codes AKT* avec AKB pour les créateurs, avec AGZ pour l’histoire de la mode, en y associant le(s) qualificateur(s) de style 6*, de lieux et historique(s) approprié(s), avec AJC* pour les photographies de et sur la mode, avec AGZ pour les ouvrages techniques pour les étudiants en mode et créateurs. Préférez les codes WF* pour les ouvrages destinés au grand public sur la façon de s’habiller, les guides pour un look élégant et conseils pratiques Lié : TDPF* KNDD KNSX WJF',
#  'Mode et textiles : accessoires': 'Classez ici : la chapellerie, la cordonnerie, la ganterie, les sacs, les chapeaux, les chaussures, les baskets et autres accessoires. Utilisez pour les ouvrages, généralement illustrés, qui abordent les aspects de la conception ou de l’esthétique des différents accessoires de mode ou de costume',
#  'Costume/textile national ou régional': 'Classez ici : les costumes / vêtements / habits folkloriques, ethniques, nationaux ou traditionnels, les textiles ou tissus traditionnels associés à des groupes ou régions particuliers, etc. Utilisez pour les ouvrages qui abordent les costumes du passé autant que contemporains. Utilisez avec des qualificateurs de lieux 1* appropriés',
#  'Histoire du design': 'Utilisez avec les autres codes AK* et également avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés',
#  'Architecture': 'Utilisez tous les codes AM* avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés, avec TNKK ou ABC pour les ouvrages concernant la réutilisation adaptative, la réaffectation, la restauration ou la conservation des bâtiments et des structures, avec d’autres codes TNK* pour les ouvrages plus techniques sur le bâtiment et la construction',
#  'Théorie de l’architecture': '',
#  'Architectes et cabinets d’architecture': 'Classez ici : les monographies d’architecture',
#  'Structure architecturale et conception': 'Classez ici : les dessins d’architecture, les dessins de section ou en coupe, les élévations, les matériaux, le génie architectural, les rendus architecturaux, les plans d’étage. Utilisez pour les ouvrages qui abordent le sujet d’un point de vue architectural. Utilisez avec le(s) qualificateur(s) de style 6* approprié(s), Préférez les codes TN* pour les ouvrages qui examinent la technique du bâtiment et de la construction Lié : TN*',
#  'Détails, composants et motifs architecturaux': 'Utilisez pour les ouvrages concernant les éléments individuels d’un bâtiment ou d’une structure, par exemple les fenêtres, les portes, la conception d’un toit, l’ornementation, etc.',
#  'Architecture : matériau': 'Utilisez pour les ouvrages, généralement très illustrés, qui abordent les structures d’un point de vue du matériau dans lequel elles sont construites, tels que le béton, la brique, l’acier, le verre, le bois, etc. Préférez les codes TN* pour les approches plus techniques ou d’ingénierie Lié : TN*',
#  'Architecture durable': 'Classez ici : l’architecture à faible impact, l’architecture durable et économe en énergie, la conception et les technologies du bâtiment et de l’intérieur, l’arcologie, les bâtiments verts, l’écoconception et la conception environnementale, l’architecture biophilique et biomimétisme, les plans de maisons durables, les techniques de construction neutres en carbone, les guides pratiques sur les matériaux, les projets de construction écologique, la conception d’habitats passifs, etc. Utilisez avec le code RNU pour les ouvrages sur la durabilité et les codes TNK* pour les ouvrages sur la conception et la construction durables',
#  'Architecture : pratique professionnelle': '',
#  'Architecture : bâtiments publics, commerciaux et industriels': 'Classez ici : les édifices publics, commerciaux et industriels ; également les salles de concerts, stades, mémoriaux, monuments, hôpitaux, phares, bibliothèques, musées, galeries, espaces d’exposition, gares, aéroports, les hôtels, les spas, les usines, les entrepôts, les bureaux, les magasins, les boutiques, etc. Utilisez pour les ouvrages sur les bâtiments qui ont une fonction principale autre que résidentielle ou domestique, et qui sont accessibles à un grand groupe de personnes. Utilisez avec AMR si approprié Lié : JWT WTHM',
#  'Architecture : constructions résidentiels ou domestiques': 'Classez ici : les maisons privées, les demeures, les immeubles, les appartements, les lofts, les cottages, les villas. Utilisez pour les ouvrages sur la conception de maisons ou de logements résidentiels, contemporains et historiques, qui peuvent être des structures construites à cet effet ou converties. Utilisez au besoin avec le code AMR d’architecture d’intérieur Lié : WJK AMR',
#  'Architecture : petites constructions domestiques': 'Classez ici : les chalets, les huttes, les remises, les cabanes dans les arbres, les folies, les petites maisons, les maisons d’été, les dépendances, les hangars à bateaux, etc. Utilisez pour les ouvrages qui abordent les petites constructions, mais pas nécessairement résidentielles, les constructions et structures qui sont généralement liés aux loisirs, aux vacances, à la détente et au plaisir',
#  'Architecture : châteaux et fortifications': '',
#  'Architecture : palais, maisons de maître et hôtels particuliers': '',
#  'Architecture : édifices religieux': 'Classez ici : les aspects architecturaux des abbayes, des cathédrales, des églises, des mosquées, des synagogues, des temples, et autres constructions et structures religieuses',
#  'Architecture d’intérieur': 'Utilisez pour les ouvrages qui abordent le sujet d’un point de vue des arts décoratifs, généralement des beaux livres d’art et destinés à un public de professionnels ou qualifié, cela inclut les études sur l’architecture et le design d’intérieur, la conception de l’éclairage et les autres spécialisations du design d’intérieur résidentiel ou commercial. Utilisez avec AKB pour les architectes d’intérieur. Préférez WJK pour les approches plus amateurs et domestiques Lié : WJK',
#  'Paysagisme (architecture & design)': 'Lié : WMD',
#  'Aménagement urbain : aspects architecturaux': 'Lié : RPC',
#  'Histoire de l’architecture': 'Associez au besoin des qualificateurs de style, de lieux et historiques',
#  'Arts du spectacle': 'Utilisez tous les codes AT* avec le(s) qualificateur(s) de style 6*, de lieux 1* et historique(s) 3* appropriés',
#  'Acteurs et artistes / interprètes': 'Classez ici : les personnalités médiatiques, les présentateurs. Utilisez le code AT* approprié afin d’indiquer s’il s’agit de théâtre, cinéma, télévision, radio, etc. Lié : DNBF*',
#  'Etudes sur le théâtre': 'Lié : DD*',
#  'Techniques de jeu d’acteurs': 'Classez ici : les monologues, la documentation pour les auditions, les conseils et techniques, le doublage, les techniques vocales, les méthodes de jeu, le jeu devant caméra, les techniques d’improvisation, les techniques de mouvement pour acteurs, etc.',
#  'Production et mise en scène': '',
#  'Théâtre : régie et techniques de scène': 'Classez ici : les techniques de la scène, les costumes et le maquillage, la conception et la réalisation de la lumière, les décors et les accessoires, la conception et la création scénique, des scènes et des décors, la régie, les effets spéciaux, la conception et la production sonores théâtrales',
#  'Gestion de théâtre': '',
#  'Films, cinéma': 'Utilisez les codes ATF* pour les aspects artistiques uniquement, à la fois pour le grand écran que pour les téléfilms ou pour les long-métrages venant des nouveaux médias, y compris le streaming, les films à la demande et autres services (mais cela exclut les présentations par épisodes) Lié : KNTC',
#  'Histoire, théorie ou critique cinématographique': 'Utilisez pour les ouvrages sur les cinémas nationaux, l’histoire ou la critique de films, les studios de cinéma, les franchises de films',
#  'Réalisateurs et producteurs de films': '',
#  'Scripts et scénarios': '',
#  'Guides et critiques de film': '',
#  'Film : styles et genres': 'Utilisez pour les études sur les genres ou les styles. Utilisez avec les codes ATM* ou les autres codes ATF* pour spécifier au besoin le style ou le genre du film Lié : ATM*',
#  'Documentaires': 'Utilisez pour les ouvrages sur les documentaires courts ou longs, destinés au petit ou grand écran, et sur les programmes scénarisés largement factuels',
#  'Films d’animations': 'Utilisez pour les ouvrages sur les films ou courts-métrages animés. Utilisez avec AGZ pour les techniques de l’animation Lié : UGN',
#  'Anime (japanimation)': 'Utilisez pour les films d’animation de style japonais Lié : AKLC1',
#  'Réalisation et production de film : techniques de plateau / studio': 'Classez ici : la cinématographie, le montage, la lumière, les décors, les costumes, les effets spéciaux, l’art et la conception, le maquillage et la coiffure, les accessoires, le casting Lié : CBVS UG*',
#  'Télévision': 'Utilisez les codes ATJ* : pour les aspects artistiques uniquement, à la fois pour la télévision traditionnelle et des nouveaux médias, y compris le streaming, la télévision à la demande ou les autres formes de consommation de divertissement sur le petit écran (y compris les présentations par épisodes) Lié : KNTC',
#  'Scripts et scénarios pour la télévision et programmes télévisés': 'Lié : WHG',
#  'Télévisions : styles et genres': 'Classez ici : les études sur les séries, les soap opéras, les pièces de théâtre pour la télévision, les comédies de situation, les émissions de télévision, etc. à la fois en direct et animées, fiction ou non, les œuvres dramatiques, la téléréalité, les documentaires, les informations et actualités, etc. Utilisez pour les ouvrages sur n’importe quel genre ou style de divertissements à la télévision ou sur petit écran. Utilisez avec les codes ATM* ou d’autres codes AT* pour spécifier au besoin le style ou le genre Lié : ATM*',
#  'Télévision : téléréalité': 'Classez ici : les émissions de talents, les concours ou les jeux télévisés de téléréalité, les émissions de téléréalité de style documentaire, les émissions de téléréalité scénarisée, les émissions de rencontres, les émissions d’amélioration, les émissions-débats, etc. Utilisez pour les ouvrages concernant les aspects de la téléréalité ou des émissions spécifiques ou des personnes qui participent à des émissions de téléréalité à la télévision, sur des services de streaming, sur des médias en ligne, etc. Utilisez avec DNBF pour les biographies d’artistes de téléréalité, avec des codes AV* pour des types spécifiques d’émissions de téléréalité, etc',
#  'Production pour la télévision : techniques de plateau / studio': 'Classez ici : la prise de vue à la télévision, le montage, la lumière, les décors, les costumes, les effets spéciaux, l’art et la conception, le maquillage et la coiffure, les accessoires, le casting',
#  'Radio / podcasts': 'Utilisez les codes ATL* pour les aspects artistiques uniquement, à la fois pour la radio traditionnelle et des nouveaux médias, y compris le streaming, la télévision à la demande ou les autres formes de consommation de divertissement audio Lié : KNT',
#  'Pièces radiophoniques, scripts et représentations': 'Classez ici : les pièces de théâtre radiophoniques, le théâtre audio, les spectacles de créations orales uniquement',
#  'Cinéma, télévision, radio et arts du spectacle : genres': 'Utilisez pour les aspects artistiques uniquement. Utilisez avec les autres codes AT* pour spécifier le genre du film, de l’émission de télévision, de la performance audio, de la production théâtrale, etc. Préférez les codes F* pour les ouvrages de fiction sur ces genres, et ce qui s’y rapporte ou avec AVLM pour les ouvrages sur les films musicaux Lié : ATJS ATFN',
#  'Cinéma, télévision, radio : genres : action, aventure, policier and thrillers': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les arts martiaux, les catastrophes, les mystères, le suspense, les gangsters, les braquages, les espions, l’espionnage, les westerns, les films de guerre basés sur l’action',
#  'Cinéma, télévision, radio : genres : comédie et humour': 'Classez ici : les ouvrages sur les comédies romantiques, les romcoms, les infodivertissements humoristiques. Utilisez pour les ouvrages concernant les films, émissions, programmes ou séries humoristiques ou légères. Utilisez avec ATJS pour les ouvrages concernant les sitcoms télé',
#  'Cinéma, télévision, radio : genres : drames': 'Classez ici : les drames romantiques, de la vie quotidienne ou réaliste. Utilisez pour les ouvrages concernant des films, des émissions, des programmes ou des séries. Utilisez avec ATJS pour les ouvrages sur les feuilletons télévisés ou les séries dramatiques, ou avec ATN pour les séries ou les émissions web',
#  'Cinéma, télévision, radio : genres : historique': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les drames historiques, les péplums, les biographies historiques, les épopées, les samouraïs, etc. Utilisez pour les ouvrages sur les films, émissions, programmes ou séries où la période historique est l’un des aspects le plus important',
#  'Cinéma, télévision, radio : genres : science fiction, fantasy et horreur': '',
#  'Cinéma, télévision, radio : genres : super héros et inspirés des bandes dessinées': 'Classez ici : les ouvrages sur les films, émissions, programmes ou séries sur les personnages ou histoires inspirés par les bandes dessinées',
#  'Internet et médias numériques : art et pratiques': 'Classez ici : tous les aspects de l’internet en tant que vecteur médiatique, en particulier pour le contenu d’origine numérique : les célébrités provenant de l’internet, les blogueurs, les vloggers, les podcasts, etc. Lié : UD* KNTV KNTX',
#  'Danse': 'Utilisez pour les ouvrages sur les techniques, les études, les ouvrages de référence. Utilisez avec JBC* pour les aspects des études culturelles ou les ouvrages académiques. Utilisez tous les codes AT* avec au besoin le(s) qualificateur(s) de style 6* appropriés',
#  'Chorégraphie': '',
#  'Ballet': '',
#  'Danse de salon': 'Classez ici : les danses latines',
#  'Danse contemporaine': '',
#  'Danseurs / chorégraphes': 'Classez ici : les troupes de danse, les groupes de danse, les compagnies',
#  'Danse folklorique': 'Classez ici : les danses traditionnelles',
#  'Arts de la scène : le maquillage': 'Classez ici : le maquillage d’effets spéciaux, le maquillage SFX, le maquillage prothétique, la conception de cheveux, le maquillage artistique professionnel et médiatique, le maquillage de scène et de théâtre, les ouvrages professionnels pour les maquilleurs, le maquillage cosplay. Utilisez avec d’autres codes AT* pour les ouvrages destinées à des arts spécifiques de la scène ou avec d’autres codes A* si l’ouvrage concerne l’art du maquillage pour la mode, la photographie ou avec 4CP* ou d’autres qualificateurs éducatifs 4* pour les ouvrages professionnels Lié : ATDH ATFX ATJX',
#  'Arts de la scène : costume et accessoires': 'Classez ici : la conception et la fabrication de costumes ou d’accessoires, le jeu de costumes ou le cosplay, les déguisements. Utilisez avec d’autres codes AT* pour les ouvrages destinées à des arts spécifiques de la scène ou avec 4CP* ou avec d’autres qualificateurs éducatifs 4* pour les ouvrages professionnels Lié : ATDH ATFX ATJX',
#  'Autres arts du spectacle': 'Classez ici : le mime, le nô, le théâtre de rue, les spectacles de variété, le music hall, le cabaret, le jonglage, la ventriloquie, etc.',
#  'Culture et performance drag': 'Classez ici : les drag artistes, les drag bals, les drag queens, les drag kings Lié : JBCC3',
#  'Arts du cirque': 'Classez ici : les clowns, le funambulisme, les acrobaties Lié : ATXZ',
#  'Comédie et stand-up': 'Classez ici : l’improvisation, le théâtre impressionniste, la comédie alternative, les sketches, les comiques',
#  'Prestidigitation et magie': 'Classez ici : les illusions, la prestidigitation, les tours de cartes, les magiciens en tant qu’artistes Lié : QRYX2 VXWM',
#  'Théâtre de marionnettes et d’animation': '',
#  'Spectacles historiques, parades, festivals': '',
#  'Spectacles d’animaux, animaux savants': '',
#  'Tauromachie': '',
#  'Histoires des arts du spectacle': 'Utilisez au besoin avec les autres codes AT*',
#  'Cinéma, télévision, radio et arts du spectacle : guides': 'Utilisez pour la non-fiction, les guides sur les séries, les films, les émissions, les franchises, etc. Ceux-ci sont généralement non critiques, tels que les recueils de personnages ou de lieux, ou des guides d’objets, de machines, de véhicules, d’armes, d’accessoires, des costumes (même s’ils sont purement fictifs) ou les guides du making-of, ou l’art d’une série. Utilisez au besoin avec les autres codes AT*. Préférez FYV ou FZ pour les œuvres dérivées, les novélisations, ou les œuvres inspirées par un film, une série, une émission ou une franchise Lié : FYV FZ YFZZ',
#  'Musique': 'Utilisez tous les codes AV* avec le(s) qualificateur(s) de style 6* pour indiquer le style ou genre de musique, avec le(s) qualificateur(s) de lieux si spécifique à une région particulière et avec le(s) qualificateur(s) historique(s) s’il y a un aspect historique',
#  'Théorie de la musique et musicologie': 'Classez ici : les ouvrages sur le solfège, l’analyse musicale, la psychologie de la musique, les théories du solfège, le contrepoint, l’harmonie, les mélodies, les intervalles, les gammes et les modes, les motifs, les cadences, les refrains, l’ethnomusicologie, la formation auditive ou de l’oreille, etc.',
#  'Critiques musicales': '',
#  'Discographies et guide des acheteurs': '',
#  'Musique : styles et genres': '',
#  'Musique d’art, musique orchestrale et formelle': 'Classez ici : les ouvrages sur les traditions musicales classiques de différentes cultures, telles que la « musique classique occidentale », la musique classique indienne, la musique de chambre, les concertos, les symphonies, les sonates, les compositions pour voix et instrument telles que les chants, les Lieder. Utilisez avec d’autres codes AV*, des qualificateurs de style 6* pour indiquer le style ou le genre spécifique de musique, des qualificateurs de lieux 1* s’ils sont spécifiques à une région particulière et au besoin des qualificateurs historiques 3*',
#  'Musique chorale': 'Classez ici : la musique chorale de toute période et tradition, la musique pour chœurs. Utilisez avec AVLK pour la musique chorale religieuse, comme le chant grégorien ou ambrosien, ou avec d’autres codes AV*, des qualificateurs de style 6* pour indiquer le style ou le genre spécifique de musique, des qualificateurs de lieux 1* s’ils sont spécifiques à une région particulière et au besoin des qualificateurs historiques 3*',
#  'Opéra': 'Classez ici : l’opéra-comique, l’opérette, l’Opéra comique la sainete, Singspiel, Zarzuela',
#  'Musique sacrée et religieuse': 'Classez ici : les spirituals, les cantiques, la musique chorale, les oratorios, la prière mise en musique, le chant religieux, la musique liturgique, la danse sacrée ou rituelle. Utilisez pour les ouvrages sur la musique associée à, ou utilisée dans la musique sacrée ou l’observance religieuse. Utilisez au besoin avec les codes QR* et les qualificateurs de style 5PG* et 6*',
#  'Musique de film et de spectacle': 'Classez ici : les ouvrages sur les comédies musicales, les musiques de film, les mélodies, ouvrages sur les bandes sonores de musiques de films, de télévision ou de scène',
#  'Musique populaire': 'Classez ici : le jazz, le rock et la pop musique, la soul, le rap, la musique latine, le blues, le easy listening, la country, le reggae et formes associées Utilisez pour toutes les formes de musique populaire, par opposition à la musique d’art et à la musique traditionnelle. Utilisez avec le(s) qualificateur(s) de style 6* pour indiquer le style ou le genre de musique populaire',
#  'Musique folklorique et traditionnelle': 'Classez ici : les chants et chansons de marins, les cycles de chants traditionnels, les chants à boire, les chants sportifs, les chants guerriers ou anti-guerre, les chants de protestation, les chants basés sur les traditions orales, etc. Utilisez pour les ouvrages sur les chansons ou mélodies qui ont été jouées, par coutume, sur une longue période (généralement sur plusieurs générations). Elles sont le plus souvent des chansons folkloriques, des danses country ou d’un genre musical similaire, et souvent associées au folklore, à la tradition ou à l’héritage culturel d’une région. Utilisez avec le(s) qualificateur(s) de lieux 1* et de style 6* approprié(s)',
#  'Musique du monde et styles régionaux': 'Classez ici : les musiques du monde, la worldbeat, la global fusion ou la world fusion. Utilisez pour les ouvrages sur la musique issue d’un mélange de deux ou plusieurs styles de musique ou de traditions culturelles ou les ouvrages sur la musique qui n’entrent dans aucune autre catégorie. Utilisez avec le(s) qualificateur(s) de lieux 1* approprié(s)',
#  'Musique électronique': 'Utilisez pour les ouvrages sur toutes les formes de musiques produites en utilisant des instruments musicaux électroniques, des instruments numériques ou une technologie musicale basée sur un système de circuits Lié : AVRS',
#  'Histoire de la musique': 'Utilisez des qualificateurs de style, historiques ou de lieux appropriés',
#  'Auteurs et compositeurs': '',
#  'Musiciens, chanteurs et groupes': 'Classez ici : les chefs d’orchestre, les orchestres et les individus ou les autres ensembles de musique ou chants, fanfares, groupes pop, musiciens de jazz, musiciens classiques, etc. Utilisez avec d’autres codes AV* et qualificateurs de style 6* pour indiquer les genres de musique associés au musicien, avec DNBF pour les biographies de musiciens ou de groupes',
#  'Partitions musicales, paroles et librettos': 'Classez ici : les partitions, les partitions pour voix, ensembles, groupes, chœurs, orchestres, groupes, etc. Utilisez avec les codes AVR* pour indiquer si la musique est destinée à un instrument en particulier et d’autres codes AV* et qualificateurs de style 6* pour indiquer genre de musique',
#  'Recueils de chansons': 'Classez ici : les chansons pour piano facile, la guitare facile, les autres instruments et voix, etc. Utilisez avec d’autres codes AV* et qualificateurs de style 6* pour indiquer genre de musique Lié : AVSA',
#  'Instruments de musique': 'Utilisez pour : les ouvrages sur un instrument en particulier ou leurs formes historiques et territoriales associées. Utilisez tous les codes AVR* avec les codes AVQ* pour les partitions musicales d’instruments spécifiques, avec le code AVP pour les ouvrages sur des groupes, des ensembles ou des musiciens associés à un type d’instrument en particulier, avec les codes AVL* pour des styles de musique associés à des instruments, avec le code AVS pour les ouvrages sur l’apprentissage pour jouer d’un instrument, et au besoin les qualificateurs de style 6* ou de lieux 1*',
#  'Instruments à clavier': 'Classez ici : le clavecin, l’orgue, l’ accordéon, le célesta, le clavicorde, le clavier électronique. Utilisez pur les ouvrages généraux sur instruments à clavier ou les partitions pour instruments à clavier ou les types d’instruments à clavier, de toute culture ou tradition musicale, lorsqu’il n’y a pas de code plus spécifique. Utilisez avec les codes AVQ* pour les partitions musicales, avec les codes AVL* et les qualificateurs de style 6* si cela concerne un style de musique spécifique associé aux instruments à clavier',
#  'Piano': '',
#  'Instruments à percussions': 'Classez ici : la batterie, les bodhrans, les cloches, les cymbales, les gongs, le xylophone, le glockenspiel, les bongos, les marimbas, le vibraphone, le tambourin, les castagnettes, les maracas, les timbales. Utilisez pour les ouvrages généraux sur les instruments à percussions ou les partitions pour instruments à percussions ou les types d’instruments à percussions, de toute culture ou tradition musicale, lorsqu’il n’y a pas de code plus spécifique. Utilisez avec les codes AVQ* pour les partitions musicales, avec les codes AVL* et les qualificateurs de style 6* si cela concerne un style de musique spécifique associé aux instruments à percussions',
#  'Instruments à cordes': 'Classez ici : le sitar, le setâr, la mandoline, le bouzouki, le mandole, le shamisen, le sanxian, le pipa, la balalaïka, le charango, etc. Utilisez pour les ouvrages généraux sur les instruments à cordes ou les partitions pour instruments à cordes ou les types d’instruments à cordes, de toute culture ou tradition musicale, lorsqu’il n’y a pas de code plus spécifique. Utilisez avec les codes AVQ* pour les partitions musicales, avec les codes AVL* et les qualificateurs de style 6* si cela concerne un style de musique spécifique associé aux instruments à cordes',
#  'Guitare': 'Classez ici : la guitare classique, la guitare acoustique, la guitare électrique, la guitare basse, la guitare en métal, la Guitarra de golpe, le guitarrón mexicano, le jarana, etc.',
#  'Instruments à cordes pincées': 'Classez ici : la harpe, la harpe celtique, la lyre, la cithare, la dulcimer',
#  'Violon et les instruments de la famille des violons': 'Classez ici : le violoncelle, l’alto, la contrebasse, le fiddle, le violon alto, la viole de gambe, les instruments à cordes frottées',
#  'Instruments à vent': 'Utilisez pour les ouvrages généraux sur les instruments à vent ou les partitions pour instruments à vent ou les types d’instruments à vent de toute culture ou tradition musicale, lorsqu’il n’y a pas de code plus spécifique. Utilisez avec les codes AVQ* pour les partitions musicales, avec les codes AVL* et les qualificateurs de style 6* si cela concerne un style de musique spécifique associé aux instruments à vent',
#  'Cuivres': 'Classez ici : l’euphonium, le tuba, le bugle, le soubassophone, le clairon, le cor, le trompette, le cornet, le trombone, etc.',
#  'Instruments à anche': 'Classez ici : les instruments à anches, toutes les flûtes, le piccolo, la cornemuse, le cor anglais, le contrebasson, le basson, la clarinette, le hautbois, la flûte à bec, le saxophone, etc.',
#  'Instruments mécaniques': '',
#  'Instruments électroniques': 'Classez ici : le thérémine, le synthétiseur, les ondes Martenot Lié : AVLX',
#  'Techniques musicales, tutoriels, enseignement de la musique': 'Classez ici : l’apprentissage d’un instrument, les manuels et les ouvrages d’auto-apprentissage pour ou autour de l’enseignement de la musique, les techniques de direction',
#  'Chant : techniques': 'Classez ici : l’apprentissage du chant, la voix comme instrument, les techniques vocales ou les chants pour chœurs ou voix chorales, les voix solistes, duos ou trios, les voix masculines ou féminines, les ensembles vocaux, etc. Utilisez avec les codes AVQ* pour les partitions pour voix et avec les codes AVR* pour les partitions vocales ou voix plus instrument, les codes AVL* pour des genres spécifiques ou avec le qualificateurs de style 6* pour des styles de musique particuliers associés au chant Lié : AVQS',
#  'Composition musicale': 'Classez ici : l’orchestration, l’arrangement musical, la transposition, l’écriture de chansons',
#  'Enregistrement et production musicale': 'Utilisez pour les ouvrages sur l’enregistrement ou la reproduction de musique ou de sons, aussi bien les ouvrages généraux que les approches pratiques. Pour les ouvrages plus techniques associez ou préférez les codes T* ou U* appropriés Lié : KNT TTA UDM UGM',
#  'Langage et linguistique': 'Utilisez tous les codes C* pour les ouvrages spécialisés et généraux. Ne pas utiliser le code C, mais sélectionnez une catégorie spécifique de la section C*. Utilisez tous les codes C* avec d’autres catégories et au besoin un qualificateur, en particulier les qualificateurs de langue 2*, de lieux 1*, historiques 3* et éducatifs 4*',
#  'Langage : références et généralités': 'Utilisez tous les codes CB* avec le(s) qualificateur(s) de langue 2* appropriés',
#  'Dictionnaires': 'Classez ici : les glossaires. Utilisez avec le(s) qualificateur(s) de langue 2* appropriés',
#  'Dictionnaires bilingues et multilingues': 'Utilisez avec le(s) qualificateur(s) de langue 2* appropriés',
#  'Thesaurus': 'Utilisez avec le(s) qualificateur(s) de langue 2* appropriés',
#  'Usages et guides grammaticaux': 'Utilisez avec le(s) qualificateur(s) de langue 2* appropriés',
#  'Guides et conseils pour parler en public': 'Utilisez pour les guides généraux pour parler en public, des exemples de discours et de citations, pour préparer ou donner une présentation. Utilisez avec WJW pour les discours de témoins à l’occasion d’un mariage ou avec KJP pour les présentations professionnelles',
#  'Création littéraire et guides de création littéraire': '',
#  'Techniques d’écriture de scénarios': '',
#  'Arts de l’écriture et techniques de rédaction': 'Classez ici : les guides généraux, les guides de technique journalistique, les techniques de rédaction, les guides de correspondance, etc.',
#  'Langage : histoire et travaux généraux': 'Utilisez pour les ouvrages généraux ou grand public sur le langage. Préférez les codes CF* pour les études plus scientifiques ou académiques',
#  'Linguistique': 'Classez ici : les études scientifiques sur le langage, la philologie. Utilisez pour les ouvrages plus spécialisés et académiques',
#  'Philosophie du langage': 'Lié : GTD',
#  'Sociolinguistique': '',
#  'Alphabétisation': 'Classez ici : les compétences, les théories et les sujets liés à l’alphabétisation, l’alphabétisation alphabétique, l’analphabétisme fonctionnelle, les aspects sociaux et culturels de la lecture et de l’écriture Lié : JNTS VSL',
#  'Psycholinguistique et linguistique cognitive': 'Classez ici : la neurolinguistique, la psychologie du langage',
#  'Acquisition du langage': '',
#  'Bilinguisme et multilinguisme': 'Classez ici : le plurilinguisme, l’alternance codique, l’alternance linguistique',
#  'Linguistique historique et comparée': 'Classez ici : l’étymologie, les études sur les familles de langue Lié : CBX',
#  'Dialecte, argot et jargon': 'Utilisez avec les codes CB* pour les dictionnaires, etc. et le(s) qualificateur(s) de lieux 1* et de langue 2* appropriés Lié : WHL',
#  'Sémantique, analyse du discours, stylistique': 'Classez ici : la pragmatique, la lexicologie, la rhétorique',
#  'Phonétique, phonologie': '',
#  'Grammaire, syntaxe et morphologie': '',
#  'Paléographie (étude et histoire de l’écriture)': 'Classez ici : l’étude de l’écriture et des systèmes d’écriture',
#  'Systèmes d’écriture et alphabets': '',
#  'Lexicographie': '',
#  'Traduction et interprétation': 'Classez ici : l’herméneutique',
#  'Linguistique informatique et linguistique de corpus': '',
#  'Langue des signes, braille et autres moyens de communication': '',
#  'Apprentissage et enseignement des langues': 'Utilisez tous les codes CJ* pour tous les supports d’apprentissage d’une ou plusieurs langues. Utilisez avec le(s) qualificateur(s) de langue 2* et éducatifs appropriés. Utilisez avec les codes JN* pour les différents aspects de l’apprentissage d’une langue. Préférez les codes YPC* ou YRD* pour les supports d’apprentissage destinés aux enfants ou adolescents Lié : YPC* 4LE* 4LZ*',
# ...
#  'industries de l’eau': 'Classez ici : les entreprises de services publics et privés, les industries de l’eau potable et des eaux usées. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TQSR TQSW',
#  'Industries manufacturières': 'Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TDP*',
#  'Industries chimique, biotechnologique et pharmaceutique': 'Classez ici : la pétrochimie, les industries plastiques. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TDC*',
#  'Industries du vêtement, de l’habillement et du tissu': 'Utilisez pour les ouvrages abordant le commerce ou l’industrie vestimentaire, la confection de vêtements, de tissus, etc. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TDPF AKT',
#  'Industries de fabrication de véhicules et transport': 'Classez ici : l’industrie automobile, la construction navale, l’industrie aéronautique et l’industrie ferroviaire. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles. Utilisez avec des codes WG* appropriés pour indiquer le type de véhicule ou de transport Lié : TR*',
#  'Industries des transports': 'Classez ici : toutes les industries des transports ; route, navigation, chemin de fer, aérospatiale, etc. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles. Utilisez avec des codes WG* appropriés pour indiquer le type de véhicule Lié : KNDR TR* WG*',
#  'Construction et industrie lourde': 'Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles',
#  'Industries de la construction et du bâtiment': 'Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TN*',
#  'Industries du fer, de l’acier et des autres métaux': 'Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TDPM',
#  'Industries au détail et de gros': 'Classez ici : la distribution, l’entreposage et le stockage. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : KJMV9',
#  'Industries touristique, hôtelière et de la restauration': 'Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : TTVC',
#  'Industries de services d’alimentation et de boisson': 'Classez ici : le service de traiteur Lié : TDCT TTVC2',
#  'Industries de l’hôtellerie, des sports, des loisirs et du tourisme': 'Classez ici : l’hôtellerie, la gestion hôtelière, les parcs à thème, le marché du fitness, la gestion des parcs et des loisirs, les secteurs de la gym et du fitness, l’industrie de l’expérience et d’autres industries ou secteurs liés. Utilisez pour les ouvrages abordant le commerce ou l’industrie des loisirs; Lié : TTVC WT*',
#  'Industrie de l’événementiel': 'Classez ici : l’industrie du mariage, les congrès, les conférences, les festivals, les cérémonies. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles',
#  'Industries de la mode et de la beauté': 'Classez ici : les industries du maquillage, du parfum, des soins personnels, des soins de beauté, des cosmétiques et des soins de la peau, des soins capillaires, le secteur de la mode de luxe et toutes les industries liées à la mode ou à la beauté. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : AKT JBCC3 KNDD TTVH WJF',
#  'Industries des soins de la mort et des pompes funèbres': 'Classez ici : l’industrie funéraire. Utilisez pour les travaux qui examinent les entreprises, les organisations qui fournissent des services liés à la mort, tels que les pompes funèbres, les funérailles, la crémation, l’embaumement, les enterrements, les mémoriaux, les cimetières ou qui examinent des sujets liés aux soins de la mort, tels que la finance, la prestation de services, le business de la mort, le travail dans les secteurs liés à la mort, le secteur alternatif de la mort, les enterrements verts ou naturels, les métiers autour du décès et du deuil, etc.',
#  'Industries des médias, du divertissement, de l’information et de la communication': 'Classez ici : les industries de la poste, des télécommunications, etc. Utilisez pour les ouvrages abordant ces secteurs du point de vue du commerce ou d’études industrielles Lié : GTC JBCT',
#  'Industries du cinéma, de la télévision et de la radio': 'Utilisez pour les ouvrages abordant les industries, les compagnies et technologies associées à la télévision, au cinéma, à la vidéo, à la radio, au podcast, et les services de streaming associés',
#  'Industrie de la musique': 'Classez ici : les secteurs du disque et de la représentation musicale, l’édition de musique, les services de streaming',
#  'Industrie de l’édition et de la presse': '',
#  'Edition et commerce du livre': 'Classez ici : les livres papiers, électroniques et l’édition numérique. Utilisez avec NHTB pour l’histoire des livres, de l’édition, etc.',
#  'Nouveaux médias et journalisme': 'Classez ici : l’actualité imprimée ou en ligne, les journaux et les magazines',
#  'Industries de l’impression et de la reprographie': 'Classez ici : les industries de l’emballage imprimé et de l’étiquetage',
#  'Industrie des jeux informatiques et vidéo': 'Classez ici : l’industrie du divertissement interactif',
#  'Industries de technologie de l’information': 'Classez ici : le secteur des technologies, la Silicon Valley, les industries des données, les industries de l’intelligence artificielle, les secteurs de l’informatique et du développement de logiciels, etc. Lié : KJE',
#  'Fonction publique et secteur public': 'Lié : JPP',
#  'Relations industrielles, santé et sécurité au travail': 'Classez ici : les syndicats, les mouvements de grève, l’arbitrage et la négociation industriel, l’industrie de la santé et de la sécurité, etc. Utilisez pour tous les lieux de travail industriels et commerciaux et pas uniquement pour l’industrie manufacturière ou lourde',
#  'Santé et sécurité au travail': 'Utilisez pour les travaux qui traitent de tous les aspects de la sécurité et de la santé physique et mentale sur le lieu de travail et des employés, les conseils pour créer des lieux de travail sains et sûrs, le respect des réglementations nécessaires, la formation et la sensibilisation à la santé et à la sécurité, travailler au bien-être psychologique et physique des employés, etc. Lié : JMJ LNHH',
#  'Arbitrage et négociation': '',
#  'Syndicats': 'Classez ici : les organisations syndicales',
#  'Droit': 'Utilisez tous les codes L* pour les ouvrages universitaires, professionnels ou spécialisés. Ne pas utiliser le code L, mais sélectionnez une catégorie spécifique de la section L*. La section L* n’est pas censée refléter un système juridique en particulier et beaucoup d’ouvrages auront besoin d’au moins deux codes pour créer la catégorie appropriée. Utilisez tous les codes L* avec le(s) qualificateur(s) de lieux 1* pour indiquer la juridiction (en particulier avec les codes LN*) et avec au besoin d’autre(s) qualificateur(s). Préférez les codes VS* pour les ouvrages plus généraux',
#  'Jurisprudence et questions générales': '',
#  'Méthodes, théorie et philosophie du droit': 'Classez ici : la jurisprudence analytique, la théorie du droit naturel, le positivisme juridique, le réalisme juridique, l’interprétativisme juridique, la jurisprudence normative et les approches philosophiques des problèmes juridiques, les principes généraux du droit, la théorie de l’élaboration du droit, etc.',
#  'Systèmes juridiques': 'Utilisez pour les ouvrages abordant les différents systèmes juridiques ou pour indiquer un type de droit en particulier d’un système en particulier. Utilisez pour les codes LAF* avec d’autres codes L* et le(s) qualificateur(s) de lieux approprié(s) pour indiquer le type de système juridique, le type de droit et de juridiction',
#  'Systèmes juridiques : Common law (systèmes de droit coutumier)': 'Classez ici : la jurisprudence, la loi créée par le juge ou le précédent judiciaire en tant que systèmes de droit',
#  'Systèmes juridiques : codes civils / droit civil': 'Utilisez pour les ouvrages abordant les organismes du droit ou des systèmes de droit civil basés sur un code de droit, des codes juridiques ou des codes de lois Lié : LAFR',
#  'Systèmes juridiques : droit coutumier': 'Utilisez pour les ouvrages abordant les organismes du droit ou des systèmes de droit basés entièrement ou partiellement sur des coutumes ou des précédents',
#  'Systèmes juridiques : systèmes mixtes': 'Utilisez pour les ouvrages abordant les organismes du droit ou des systèmes de droit basés sur plus d’un système juridique',
#  'Systèmes juridiques : droit romain': '',
#  'Systèmes juridiques : droit islamique': 'Lié : LW',
#  'Systèmes juridiques : droit juif': '',
#  'Systèmes juridiques : droit canonique': '',
#  'Droit comparé': '',
#  'Technologie juridique': 'Utilisez pour les travaux qui examinent l’utilisation de la technologie dans le droit et le secteur juridique, les nouvelles technologies dans le secteur des services juridiques, l’impact de la technologie sur les services juridiques, la technologie juridique et la pratique juridique, les services juridiques virtuels, la technologie des cabinets d’avocats. Utilisez avec les codes U* pour les approches techniques',
#  'Droit et société, sociologie du droit': '',
#  'Droit et société, questions de l’identité sexuelle': '',
#  'Aspects juridiques de la criminologie': '',
#  'Compétences et pratique juridiques': '',
#  'Plaidoirie': '',
#  'Ecrits et rédaction juridiques': 'Classez ici : la rédaction juridique académique',
#  'Compétences juridiques : négociation et entrevue': 'Classez ici : la communication orale en tant que compétence juridique',
#  'Compétences juridiques : méthodes de recherche': 'Classez ici : l’utilisation d’outils en ligne, les bases de données juridiques, etc.',
#  'Auxiliaires juridiques': '',
#  'Profession juridique / pratique du droit : généralités': 'Classez ici : les ouvrages qui portent sur les professionnels du droit et ceux qui pratiquent le droit, comme un avocat. Utilisez tous les codes LAT* pour les travaux sur les professionnels du droit, leurs rôles, la nature de leur travail, leurs responsabilités Lié : LNAL',
#  'Déontologie et conduite professionnelle': '',
#  'Droit s’appliquant à d’autres professions et disciplines': 'Lié : VSD',
#  'Histoire du droit': '',
#  'Droit international': '',
#  'Droit international public': '',
#  'Droit international public : traités et autres sources': '',
#  'Droit international public : droit coutumier': '',
#  'Droit international public : droit diplomatique': '',
#  'Droit international public : juridiction et immunité': '',
#  'Droit international public : territoire et structure de l’Etat': '',
#  'Droit international public : droit de la mer': 'Classez ici : les lois concernant les frontières maritimes, les ressources maritimes, etc. affectant les états souverains Lié : LBDM LNCB5',
#  'Droit international public : santé': '',
#  'Droit international public : économie et commerce': '',
#  'Droit international public, économie et commerce : droits de douane': '',
#  'Droit international public, économie et commerce : traités d’investissement et conflits': 'Classez ici : les lois et réglementations internationales en matière d’investissement, les accords internationaux d’investissement, le règlement des différends entre investisseurs et états, l’arbitrage des traités d’investissement',
#  'Droit international public : énergie et ressources naturelles': '',
#  'Droit international public, économie et commerce : sociétés': '',
#  'Droit international public : environnement': '',
#  'Droit international public, environnement : droit agricole': '',
#  'Droit international public : administration': '',
#  'Droit international public : droits de l’homme': 'Classez ici : les droits substantiels et les droits inaliénables en droit international',
#  'Droit international public, droits de l’homme : travail et droits sociaux': '',
#  'Droit international public : droit humanitaire': 'Classez ici : le droit des réfugiés, le droit de la guerre',
#  'Droit international public : organisations et institutions internationales': '',
#  'Droit international public : responsabilité des états et des autres entités': '',
#  'Droit international public : droit pénal': '',
#  'Droit international : transport, communications et commerce': '',
#  'Droit international, transport : droit de l’espace et de l’aérospatiale': '',
#  'Droit international : droit du commerce transnational et de la vente internationale de marchandises': '',
#  'Droit international, transport et commerce : droit maritime': 'Classez ici : les lois concernant la navigation, le fret, les assurances, la piraterie, etc. affectant les organismes commerciaux et non les états souverains Lié : LBBK LNCB5',
#  'Droit international : communications, télécommunications et média': '',
#  'Droit international privé et conflit de lois': '',
#  'Droit international : conflits internationaux et procédure civile': '',
#  'Droit international : tribunaux et procédures': '',
#  'Droit international : arbitrage': '',
#  'Droit international : propriété intellectuelle': '',
#  'Droit international : sports': '',
#  'Rapports de droit international': '',
#  'Droit des juridictions spécialisées et domaines particuliers du droit': 'Avec les codes LN*, associez également des qualificateurs de lieux appropriés pour indiquer la juridiction',
#  'Systèmes juridiques : généralités': '',
#  'Systèmes juridiques : tribunaux et procédure': 'Classez ici : le système inquisitoire, le système accusatoire, les règles des tribunaux. Utilisez pour les ouvrages sur différents types de tribunaux, lois et aspects juridiques des procédures et processus de ces tribunaux',
#  'Systèmes juridiques : juges et pouvoirs judiciaires': 'Classez ici : le juge d’instruction. Utilisez pour les différents types de juges, la magistrature et les ouvrages sur les pouvoirs judiciaires',
#  'Systèmes juridiques : juges/jurés non professionnels et citoyens': 'Classez ici : les assesseurs et les magistrats non professionnels, les jurés, etc. Utilisez pour les ouvrages sur ou pour des citoyens qui ne sont pas des professionnels du droit, ou qui ont une formation juridique minimale et qui participent à des procès en tant que citoyens ou juges non professionnels ou en tant que membres du jury',
#  'Systèmes juridiques : délit d’outrage': '',
#  'Systèmes juridiques : procédure civile, litige et règlement des conflits': 'Classez ici : le délai de prescription, le droit réparateur, les règles de procédure, le droit des adjectifs, le droit procédural Lié : LNFX',
#  'Recours civils': 'Classez ici : l’enrichissement injuste / injustifié, le traçage équitable',
#  'Réparation': '',
#  'Dommages-intérêts et indemnisation': '',
#  'Injonctions et autres ordres des tribunaux': '',
#  'Procédure civile : droit de la preuve': '',
#  'Procédure civile : instruction et procédures particulières': '',
#  'Arbitrage, médiation et modes de règlement alternatif des conflits': 'Classez ici : la modération et la négociation juridique',
#  'Systèmes juridiques : partie générale / dispositions générales': 'Utilisez pour les ouvrages sur les systèmes juridiques, les codes civils, les constitutions, qui contiennent des sections générales de règles et de définitions de base, des réglementations généralement applicables. Utilisez, au besoin, avec d’autres codes L* pour les ouvrages sur l’application de ces règles à des domaines spécifiques du droit',
#  'Systèmes juridiques : coûts et financement': '',
#  'Systèmes juridiques : règlementation des professions juridiques': '',
#  'Droit privé ou civil : généralités': '',
#  ...}

# %%
import json

# Specify the path to the JSON file
file_path = 'thema_all_nodes_descriptions_notes_raw_fr.json'

# Create a dictionary

# Dump the dictionary to JSON
with open(file_path, 'w') as file:
    json.dump(all_nodes_descriptions_notes_raw, file)

# %% [markdown]
# # root nodes

# %%
root_nodes = [node for node in thema_codes if node["CodeParent"] == ""]
root_nodes
# Out:
# [{'CodeValue': 'A',
#   'CodeDescription': 'The Arts',
#   'CodeNotes': 'Use all A* codes for: specialist and general adult titles, including both highly illustrated and more text-based works. For a hobby or recreational approach, prefer a WF* code as the main subject and supplement with A* code(s) where appropriate. Use all A* codes with: other subject categories and qualifiers as appropriate, in particular STYLE 6*, plus PLACE 1* and TIME PERIOD 3* Qualifiers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'C',
#   'CodeDescription': 'Language and Linguistics',
#   'CodeNotes': 'Use all C* codes for: specialist and general adult titles. DO NOT USE: code ‘C’ itself, but select specific categories from section C*. Use all C* codes with: other subject categories and qualifiers where appropriate, in particular LANGUAGE 2* Qualifiers plus PLACE 1*, TIME PERIOD 3* and EDUCATIONAL PURPOSE 4* Qualifiers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'D',
#   'CodeDescription': 'Biography, Literature and Literary studies',
#   'CodeNotes': 'Use all D* codes for: specialist and general adult titles. DO NOT USE: code ‘D’ itself, but select specific categories from section D*. Use all D* codes with: other subject categories and qualifiers where appropriate, in particular STYLE 6*, PLACE 1*, LANGUAGE 2* or TIME PERIOD 3* Qualifiers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'F',
#   'CodeDescription': 'Fiction and Related items',
#   'CodeNotes': 'DO NOT USE: code ‘F’ itself, but select specific categories from section F*. Use all F* codes with: other subject categories and qualifiers where appropriate, in particular PLACE 1* and/or TIME PERIOD 3* Qualifiers where these aspects are particularly pertinent and significant. N.B. F* codes may be used with appropriate non-fiction categories to indicate key settings or topics of the narrative, but for all adult fiction the primary category must be an F* code. FX* codes may be used to indicate a strong underlying theme. Also use with 5H*, 5J*, 5L* or 5P* qualifiers when these represent a significant topic or part of the appeal of the narrative. FY* codes may be used to indicate special features of a fiction title',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'G',
#   'CodeDescription': 'Reference, Information and Interdisciplinary subjects',
#   'CodeNotes': 'Use all G* codes for: specialist and general adult titles. DO NOT USE: code ‘G’ itself, but select specific categories from section G*. Use all G* codes with: other subject categories and qualifiers where appropriate',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'J',
#   'CodeDescription': 'Society and Social Sciences',
#   'CodeNotes': 'Use all J* codes for: specialist and some general adult titles, but see also V* codes for practical approaches to many topics. Use all J* codes with: other subject categories and qualifiers where appropriate. In J* use the most appropriate code(s) available, as many social sciences are broad topics that can have many alternative terms or names',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'K',
#   'CodeDescription': 'Economics, Finance, Business and Management',
#   'CodeNotes': 'Use all K* codes for: specialist (professional and academic) and general adult titles, but see also VS* codes for practical approaches to many topics. Use all K* codes with: other subject categories and qualifiers where appropriate',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'L',
#   'CodeDescription': 'Law',
#   'CodeNotes': 'Use all L* codes for: academic, professional or specialist titles only. DO NOT USE: code ‘L’ itself, but select specific categories from section L*. The L* section is not meant to reflect any particular legal system and many titles will need at least two codes to create the appropriate category. Use all L* codes with: PLACE 1* Qualifiers to indicate jurisdiction (especially with LN* codes), plus other qualifiers as appropriate. Prefer: VS* codes for more general adult titles',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'M',
#   'CodeDescription': 'Medicine and Nursing',
#   'CodeNotes': 'Use all M* codes for: academic, technical and specialist healthcare and medical material only. Use with: EDUCATIONAL PURPOSE 4* Qualifiers as appropriate. Prefer: V* codes for health topics aimed at a broad general adult audience',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'N',
#   'CodeDescription': 'History and Archaeology',
#   'CodeNotes': 'Use all N* codes for: specialist and general adult titles. DO NOT USE: code ‘N’ itself, but select specific categories from section N*. Use all N* codes with: other subject categories and qualifiers where appropriate, in particular PLACE 1* and TIME PERIOD 3* Qualifiers. A History work will usually need more than one subject category, from either History or non-History subjects to give greater detail, for example categories from Social Sciences (J*) with NHTB',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'P',
#   'CodeDescription': 'Mathematics and Science',
#   'CodeNotes': 'Use all P* codes for: mostly academic, technical and specialist titles and some general adult works. Qualifiers are mostly not required with P* codes. DO NOT USE: code ‘P’ itself, but select specific categories from section P*. Prefer: WN* codes for general interest adult titles where appropriate',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'Q',
#   'CodeDescription': 'Philosophy and Religion',
#   'CodeNotes': 'Use all Q* codes for: academic, specialist and general adult titles. DO NOT USE: code ‘Q’ itself, but select specific categories from section Q*. QRA* and QRV* codes should be used with other QR* codes to denote which particular religion, See also: VX*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'R',
#   'CodeDescription': 'Earth Sciences, Geography, Environment, Planning',
#   'CodeNotes': 'Use all R* codes for: academic, technical, specialist and general adult titles. DO NOT USE: code ‘R’ itself, but select specific categories from section R*. Use all R* codes with: other subject categories and qualifiers where appropriate, in particular PLACE 1* Qualifiers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'S',
#   'CodeDescription': 'Sports and Active outdoor recreation',
#   'CodeNotes': 'Use all S* codes for: general adult and specialist titles. Use all S* codes with: other subject categories and qualifiers where appropriate, in particular PLACE 1* Qualifiers, for example with WT* for adventure holidays, or VFM for a sport as part of a fitness regime',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'T',
#   'CodeDescription': 'Technology, Engineering, Agriculture, Industrial processes',
#   'CodeNotes': 'Class here: associated skills, trades and professions. Use all T* codes for: academic, technical, specialist and general adult titles. DO NOT USE: code ‘T’ itself, but select specific categories from section T*. Use all T* codes with: other subject categories and qualifiers where appropriate, in particular EDUCATIONAL PURPOSE 4* qualifiers for vocational, professional or apprenticeship style education titles',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'U',
#   'CodeDescription': 'Computing and Information Technology',
#   'CodeNotes': 'Use all U* codes for: academic, technical, specialist and some general adult titles. DO NOT USE: code ‘U’ itself, but select specific categories from section U*. Use all U* codes with: other subject categories and qualifiers where appropriate, in particular EDUCATIONAL PURPOSE 4* qualifiers for vocational educational titles',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'V',
#   'CodeDescription': 'Health, Relationships and Personal development',
#   'CodeNotes': 'Use all V* codes for: general adult titles. DO NOT USE: code ‘V’ itself, but select specific categories from section V*. Use all V* codes with: other subject categories and qualifiers where appropriate, in particular INTEREST 5* Qualifiers. Prefer: codes from C*, J*, K*, L*, M*, Q*, R* for specialist works. NB: if mixing V* codes with specialist codes to give greater detail, then a V* code should be designated as the Main Subject to indicate the content is for a broad general readership rather than specialist, professional or academic',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'W',
#   'CodeDescription': 'Lifestyle, Hobbies and Leisure',
#   'CodeNotes': 'Use all W* codes for: popular accounts for general adult readership. DO NOT USE: code ‘W’ itself, but select specific categories from section W*. Use all W* codes with: other subject categories and qualifiers where appropriate. Prefer: codes from A*, K*, P*, R*, T*, etc, for specialist, technical and academic works',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 'X',
#   'CodeDescription': 'Graphic novels, Comic books, Manga, Cartoons',
#   'CodeNotes': 'Use all X* codes for: general adult, teenage or children’s titles. DO NOT USE: code ‘X’ itself, but select specific categories from section X*. Use all X* codes with: other subject A* – W* OR Y* categories (but not both) and qualifiers where appropriate, in particular with PLACE 1*, TIME PERIOD 3* and INTEREST 5* Qualifiers. Use an XA* code to indicate the tradition, an XQ* to indicate genre plus other codes to give greater detail. NB: INTEREST AGE 5A* Qualifiers MUST be used with titles aimed at children or teenagers',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 'Y',
#   'CodeDescription': 'Children’s, Teenage and Educational',
#   'CodeNotes': 'Use all Y* codes for: material aimed at, or purposefully written or created for a juvenile or adolescent audience (except for graphic novels, comic books, manga in X*). DO NOT USE: code ‘Y’ itself, but select specific categories from section Y*. Use all Y* codes with: only one INTEREST AGE 5A* Qualifier to indicate a guideline starting interest age (detailed age ranges should be included in other metadata) – or for YP* use EDUCATIONAL PURPOSE 4* qualifiers. All other qualifiers can be used as appropriate with Y* codes. DO NOT USE for: material intended primarily for adults that may also appeal to older teenagers. For ‘new adult’ content see note at 5LKE, for ‘Young Adult’ use the most appropriate 5A* Qualifier according to local usage of the term. NB: Y* codes should be used along with X* codes for graphic novels, comic books, manga. Y* codes may be used in combination with A*– W* codes but always prefer Y* codes and if mixing Y* codes with A*– W* codes, the Y* code must ALWAYS be designated as the Main Subject and sent with one 5A* qualifier. If sending A*– W* codes as Main Subject, then Y* codes should NOT be included except for JNU / JNUM with YP* or DSYC for reviews or critiques',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 1,
#   'CodeDescription': 'Place qualifiers',
#   'CodeNotes': 'Use PLACE 1* Qualifier codes WITH appropriate subject codes for: indicating the geographical scope and applicability of the content, such as the location of a travel guide, the setting of a novel, the jurisdiction to which laws apply, the history of a particular place, the peoples, arts, traditions, or culture of a particular geographical location, etc. Where options exist, e.g. terms representing actual, historical, cultural, administrative, or geophysical entities, use the expression that best suits the content. Where no code exists for a specific location, use the nearest most appropriate broader code that includes it. DO NOT USE: to indicate any geographical aspect that is not to do with the content or subject of a book (e.g. place of publication, market availability, nationality of author – this is described in other metadata, etc). National extensions (i.e. 1*-xx- format codes, where ‘xx’ indicates a country code) can be assigned by any user, and are not exclusive to users in the indicated country. This section is not intended as an exhaustive gazetteer of all places but a list of commonly used locations in the global book supply chain. DO NOT USE: code “1” itself, but select appropriate specific qualifiers from section 1*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.5},
#  {'CodeValue': 2,
#   'CodeDescription': 'Language qualifiers',
#   'CodeNotes': 'Use LANGUAGE 2* Qualifier codes WITH appropriate subject codes for: indicating the language(s) to which the book content applies – that is, the language the book is ABOUT, not the language the book is IN (the latter is described in other metadata) – such as a linguistics or literary studies work, a method for learning a language, a phrasebook or a dictionary. National extensions (i.e. 2*-xx- format codes, where ‘xx’ indicates a country code) can be assigned by any user, and are not exclusive to users in the indicated country. DO NOT USE: code “2” itself, but select appropriate specific qualifiers from section 2*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 3,
#   'CodeDescription': 'Time period qualifiers',
#   'CodeNotes': 'Use TIME PERIOD 3* Qualifier codes WITH appropriate subject codes for: indicating the time period range of a works content, such as the period covered by an art book (A*), a history book (N*), a memoir or biography (DN*), historical fiction (FV*), a Children’s history book (YNH*), etc. National extensions (i.e. 3*-xx- format codes, where ‘xx’ indicates a country code) are for specific named periods of time that are important in particular markets but do not necessarily fit neatly into the structure of the general TIME PERIOD qualifiers. All national extensions are sub-categories of a core time period code, so can be mapped back to a standard period. National extensions can be assigned by any user, and are not exclusive to users in the indicated country. TIME PERIOD qualifiers are usually used in conjunction with PLACE 1* qualifiers. (Specific historical events or individual years would be conveyed in detail elsewhere in a products metadata, for example by the title, the table of contents, the descriptive text or keywords). DO NOT USE: for indicating the year of an annual or road atlas or travel guide or the year a work was originally published in, (this is described in other metadata). DO NOT USE: code “3” itself, but select appropriate specific qualifiers from section 3*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 4,
#   'CodeDescription': 'Educational purpose qualifiers',
#   'CodeNotes': 'Use EDUCATIONAL PURPOSE 4* Qualifier codes WITH appropriate subject codes for: indicating the curriculum, examination or level for which educational material is specifically designed, such as school textbooks, language learning coursework, study aids, revision material, vocational training material etc. Use 4Z- national extensions when available for material written or created for a specific countries education system. 4Z codes may be used for material that is used in multiple countries, for example, the GMAT exam. Always use a 4* Qualifier when using a YP* codes. DO NOT USE: to indicate educational institutions that are the subject of a book, eg, a history of specific university. DO NOT USE: code “4” itself, but select appropriate specific qualifiers from section 4*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 5,
#   'CodeDescription': 'Interest qualifiers',
#   'CodeNotes': 'Use INTEREST 5* Qualifier codes WITH appropriate subject codes for: indicating a variety of characteristics relating to the main content of the particular work. 5A* age codes to qualify Y* codes, 5H* to indicate content about a particular holiday or event, 5L* to indicate content about a particular age group / generation, 5P* to indicate content about a particular grouping of people, etc. National extensions (i.e. 5*-xx- format codes, where ‘xx’ indicates a country code) can be assigned by any user, and are not exclusive to users in the indicated country. All 5* codes must be used to describe a main content or topic of the work. DO NOT USE: as a marketing target audience code, the 5* Qualifier must relate to the main content of a work. DO NOT USE: code “5” itself, but select appropriate specific qualifiers from section 5*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4},
#  {'CodeValue': 6,
#   'CodeDescription': 'Style qualifiers',
#   'CodeNotes': 'Use STYLE 6* Qualifier codes WITH appropriate subject codes for: indicating the particular style of artistic or creative expression covered by the works content, such as a book on art, architecture, fashion, dance, music, (all A* categories) or with literary studies, e.g. use 6RA with DC* to indicate Romantic Poetry or 6EH to indicate Epic poetry. Use with: A*, D* and YN* and other categories as appropriate and with PLACE 1* Qualifiers when the content is about the style in a particular country or region. DO NOT USE: code “6” itself, but select appropriate specific qualifiers from section 6*',
#   'CodeParent': '',
#   'IssueNumber': 1,
#   'Modified': 1.4}]

# %%
root_nodes_descriptions = [node["CodeDescription"] for node in root_nodes]
root_nodes_descriptions
# Out:
# ['The Arts',
#  'Language and Linguistics',
#  'Biography, Literature and Literary studies',
#  'Fiction and Related items',
#  'Reference, Information and Interdisciplinary subjects',
#  'Society and Social Sciences',
#  'Economics, Finance, Business and Management',
#  'Law',
#  'Medicine and Nursing',
#  'History and Archaeology',
#  'Mathematics and Science',
#  'Philosophy and Religion',
#  'Earth Sciences, Geography, Environment, Planning',
#  'Sports and Active outdoor recreation',
#  'Technology, Engineering, Agriculture, Industrial processes',
#  'Computing and Information Technology',
#  'Health, Relationships and Personal development',
#  'Lifestyle, Hobbies and Leisure',
#  'Graphic novels, Comic books, Manga, Cartoons',
#  'Children’s, Teenage and Educational',
#  'Place qualifiers',
#  'Language qualifiers',
#  'Time period qualifiers',
#  'Educational purpose qualifiers',
#  'Interest qualifiers',
#  'Style qualifiers']

# %%
utils.preprocess_theme_list(root_nodes_descriptions)
# Out:
# ['arts',
#  'language',
#  'biography',
#  'fiction',
#  'reference',
#  'society',
#  'economics',
#  'law',
#  'medicine',
#  'history',
#  'mathematics',
#  'philosophy',
#  'earth',
#  'sports',
#  'technology',
#  'computing',
#  'health',
#  'lifestyle',
#  'graphic',
#  'children’s',
#  'place',
#  'language',
#  'time',
#  'educational',
#  'interest',
#  'style']

# %%
node_descriptions = [node["CodeDescription"] for node in thema_codes]
node_descriptions
# Out:
# ['The Arts',
#  'The arts: general topics',
#  'Theory of art',
#  'Conservation, restoration and care of artworks',
#  'Forgery, falsification and theft of artworks',
#  'Art: financial aspects',
#  'The Arts: art forms',
#  'Paintings and painting',
#  'Paintings and painting in watercolours or pastels',
#  'Paintings and painting in oils',
#  'Murals and wall paintings',
#  'Paintings and painting in ink',
#  'Drawing and drawings',
#  'Drawing and drawings in pencil, charcoal, crayon or pastel',
#  'Drawing and drawings in pen or brush and ink',
#  'Prints and printmaking',
#  'Other graphic or visual art forms',
#  'Body art and tattoos',
#  'Non-graphic and electronic art forms',
#  'Sculpture',
#  'Carvings, masks, reliefs',
#  'Precious metal, precious stones and jewellery: artworks and design',
#  'Installation art',
#  'Performance art',
#  'Digital, video and new media arts',
#  'Ceramics, mosaic and glass: artworks',
#  'Decorative arts',
#  'Textile artworks',
#  'The Arts: treatments and subjects',
#  'History of art',
#  'Individual artists, art monographs',
#  'Exhibition catalogues and specific collections',
#  'Human figures depicted in art',
#  'Portraits and self-portraiture in art',
#  'Nudes depicted in art',
#  'Erotic art',
#  'Small-scale, secular and domestic scenes in art',
#  'Nature in art',
#  'Animals in art',
#  'Botanical art',
#  'Landscapes / seascapes',
#  'Still life',
#  'Man-made objects depicted in art',
#  'Religious and ceremonial art',
#  'Public art',
#  'Urban arts',
#  'The Arts: techniques and principles',
#  'Colours and colour theory',
#  'Photography and photographs',
#  'Photographs: collections',
#  'Individual photographers',
#  'Photography: portraits and self-portraiture',
#  'Erotic and nude photography',
#  'Photojournalism and documentary photography',
#  'Photographic equipment and techniques: general',
#  'Camera-specific manuals',
#  'Photography: subject-specific techniques and principles',
#  'Digital photography',
#  'Monochrome photography',
#  'Light and lighting',
#  'Video photography / videography',
#  'Design, Industrial and commercial arts, illustration',
#  'Individual designers or design groups',
#  'Graphic design',
#  'Typography and lettering',
#  'Book design and Bookbinding',
#  'Manuscripts and illumination',
#  'Illustration and commercial art',
#  'Illustration',
#  'Comic book and cartoon artwork',
#  'Graphic novel and Manga artwork',
#  'Computer game art',
#  'Poster art',
#  'Product design',
#  'Furniture design',
#  'Fashion and textile design',
#  'Fashion and textile design: accessories',
#  'National or regional costume / textiles',
#  'History of design',
#  'Architecture',
#  'Theory of architecture',
#  'Individual architects and architectural firms',
#  'Architectural structure and design',
#  'Architectural details, components and motifs',
#  'Materials in architecture',
#  'Environmentally-friendly (‘green’) architecture and design',
#  'Architecture: professional practice',
#  'Architecture: public, commercial and industrial buildings',
#  'Architecture: residential and domestic buildings',
#  'Architecture: small-scale domestic buildings',
#  'Architecture: castles and fortifications',
#  'Architecture: palaces, stately homes and mansions',
#  'Architecture: religious buildings',
#  'Architecture: interior design',
#  'Landscape architecture and design',
#  'City and town planning: architectural aspects',
#  'History of architecture',
#  'Performing arts',
#  'Individual actors and performers',
#  'Theatre studies',
#  'Acting techniques',
#  'Theatre direction and production',
#  'Theatre: technical and background skills',
#  'Theatre management',
#  'Films, cinema',
#  'Film history, theory or criticism',
#  'Individual film directors, film-makers',
#  'Film scripts and screenplays',
#  'Film guides and reviews',
#  'Film: styles and genres',
#  'Documentary films',
#  'Animated films and animation',
#  'Anime',
#  'Filmmaking and production: technical and background skills',
#  'Television',
#  'Television screenplays, scripts and performances',
#  'Television: styles and genres',
#  'Television: reality shows',
#  'Television production: technical and background skills',
#  'Radio / podcasts',
#  'Radio plays, scripts and performances',
#  'Film, television, radio and performing arts genres',
#  'Film, television, radio genres: Action, adventure, crime and thrillers',
#  'Film, television, radio genres: Comedy and humour',
#  'Film, television, radio genres: Drama',
#  'Film, television, radio genres: Historical',
#  'Film, television, radio genres: Science fiction, fantasy and horror',
#  'Film, television, radio genres: Superhero and comic book inspired',
#  'Internet and digital media: arts and performance',
#  'Dance',
#  'Choreography',
#  'Ballet',
#  'Ballroom dancing',
#  'Contemporary dance',
#  'Dancers / choreographers',
#  'Folk dancing',
#  'Performing arts: makeup',
#  'Performing arts: costume / props',
#  'Other performing arts',
#  'Drag culture and performance',
#  'Circus and circus skills',
#  'Comedy and stand-up',
#  'Conjuring and magic',
#  'Puppetry, miniature and toy theatre',
#  'Pageants, parades, festivals',
#  'Animal spectacles, performing animals',
#  'Bullfighting',
#  'History of Performing Arts',
#  'Film, television, radio and performing arts: companion works',
#  'Music',
#  'Theory of music and musicology',
#  'Music reviews and criticism',
#  'Discographies and buyer’s guides',
#  'Music: styles and genres',
#  'Art music, orchestral and formal music',
#  'Choral music',
#  'Opera',
#  'Sacred and religious music',
#  'Music of film and stage',
#  'Popular music',
#  'Traditional and folk music',
#  'Other global and regional music styles',
#  'Electronic music',
#  'History of music',
#  'Composers and songwriters',
#  'Musicians, singers, bands and groups',
#  'Musical scores, lyrics and libretti',
#  'Songbooks',
#  'Musical instruments',
#  'Keyboard instruments',
#  'Piano',
#  'Percussion instruments',
#  'String instruments',
#  'Guitar',
#  'Plucked instruments',
#  'Violin and violin family instruments',
#  'Wind instruments',
#  'Brass instruments',
#  'Woodwind instruments',
#  'Mechanical musical instruments',
#  'Electronic musical instruments',
#  'Techniques of music / music tutorials / teaching of music',
#  'Singing: techniques',
#  'Music composition',
#  'Music recording and reproduction',
#  'Language and Linguistics',
#  'Language: reference and general',
#  'Dictionaries',
#  'Bilingual and multilingual dictionaries',
#  'Thesauri',
#  'Usage and grammar guides',
#  'Speaking in public: advice and guides',
#  'Creative writing and creative writing guides',
#  'Screenwriting techniques',
#  'Writing and editing guides',
#  'Language: history and general works',
#  'Linguistics',
#  'Philosophy of language',
#  'Sociolinguistics',
#  'Literacy',
#  'Psycholinguistics and cognitive linguistics',
#  'Language acquisition',
#  'Bilingualism and multilingualism',
#  'Historical and comparative linguistics',
#  'Dialect, slang and jargon',
#  'Semantics, discourse analysis, stylistics',
#  'Phonetics, phonology',
#  'Grammar, syntax and morphology',
#  'Palaeography',
#  'Writing systems, alphabets',
#  'Lexicography',
#  'Translation and interpretation',
#  'Computational and corpus linguistics',
#  'Sign languages, Braille and other linguistic communication',
#  'Language teaching and learning',
#  'Language teaching theory and methods',
#  'Language teaching and learning: first or native languages',
#  'Language teaching and learning: second or additional languages',
#  'Language teaching and learning material and coursework',
#  'Language teaching and learning material and coursework: culture / civilisation',
#  'Language learning: grammar, vocabulary and pronunciation',
#  'Language readers',
#  'Language self-study',
#  'Language learning: specific skills',
#  'Language learning: speaking skills',
#  'Language learning: listening skills',
#  'Language learning: reading skills',
#  'Language learning: writing skills',
#  'Language learning for specific purposes',
#  'Language learning for business, professional and vocational',
#  'Language learning for academic, technical and scientific purposes',
#  'Biography, Literature and Literary studies',
#  'Ancient, classical and medieval texts',
#  'Ancient Sagas and epics',
#  'Ancient Greek and Roman literature',
#  'Icelandic and Old Norse sagas',
#  'Poetry',
#  'Classic and pre-20th century poetry',
#  'Modern and contemporary poetry (c 1900 onwards)',
#  'Poetry by individual poets',
#  'Poetry anthologies (various poets)',
#  'Poetry by form',
#  'Poetry by form: Haiku',
#  'Poetry by form: Tanka',
#  'Poetry by form: Ghazal',
#  'Poetry by form: Calligram',
#  'Poetry by form: Limerick',
#  'Poetry by form: Sonnet',
#  'Plays, playscripts',
#  'Classic and pre-20th century plays',
#  'Modern and contemporary plays (c 1900 onwards)',
#  'Comedic plays',
#  'Tragic plays',
#  'Monologues / Duologues',
#  'Biography and non-fiction prose',
#  'Biography: general',
#  'Autobiography: general',
#  'Biography: business and industry',
#  'Autobiography: business and industry',
#  'Biography: arts and entertainment',
#  'Autobiography: arts and entertainment',
#  'Biography: social media',
#  'Autobiography: social media',
#  'Biography: historical, political and military',
#  'Autobiography: historical, political and military',
#  'Biography: writers',
#  'Autobiography: writers',
#  'Biography: philosophy and social sciences',
#  'Autobiography: philosophy and social sciences',
#  'Biography: adventurers and explorers',
#  'Autobiography: adventurers and explorers',
#  'Biography: royalty',
#  'Autobiography: royalty',
#  'Biography: sport',
#  'Autobiography: sport',
#  'Biography: science, technology and medicine',
#  'Autobiography: science, technology and medicine',
#  'Biography: religious and spiritual',
#  'Autobiography: religious and spiritual',
#  'Collected biographies',
#  'Memoirs',
#  'Diaries, letters and journals',
#  'Animal life stories',
#  'Literary essays',
#  'Reportage, journalism or collected columns',
#  'Interviews / discussions',
#  'Speeches',
#  'Anthologies: general',
#  'True stories: general',
#  'True crime',
#  'True crime: serial killers and murderers',
#  'True stories of discovery',
#  'True war and combat stories',
#  'True stories of heroism, endurance and survival',
#  'True stories of survival of abuse and injustice',
#  'Erotic confessions and true stories',
#  'Literature: history and criticism',
#  'Literary theory',
#  'Literary studies: general',
#  'Literary studies: ancient, classical and medieval',
#  'Literary studies: c 1400 to c 1600',
#  'Literary studies: c 1600 to c 1800',
#  'Literary studies: c 1800 to c 1900',
#  'Literary studies: c 1900 to c 2000',
#  'Literary studies: postcolonial literature',
#  'Literary studies: from c 2000',
#  'Literary studies: poetry and poets',
#  'Literary studies: plays and playwrights',
#  'Literary studies: fiction, novelists and prose writers',
#  'Comparative literature',
#  'Literary reference works',
#  'Literary companions, book reviews and guides',
#  'Children’s and teenage literature studies: general',
#  'Children’s and teenage book reviews and guides',
#  'Fiction and Related items',
#  'Fiction: general and literary',
#  'Modern and contemporary fiction: general and literary',
#  'Street fiction / urban fiction',
#  'Classic fiction: general and literary',
#  'Biographical fiction / autobiographical fiction',
#  'Speculative fiction',
#  'Dystopian and utopian fiction',
#  'Alternative history fiction',
#  'Afrofuturism / Black Speculative fiction',
#  'Metaphysical / philosophical fiction',
#  'Crime and mystery fiction',
#  'Classic crime and mystery fiction',
#  'Crime and mystery: private investigator / amateur detectives',
#  'Historical crime and mysteries',
#  'Crime and mystery: cosy mystery',
#  'Comic (humorous) crime and mystery',
#  'Crime and mystery: hard-boiled crime, noir fiction',
#  'Crime and mystery: police procedural',
#  'Crime and mystery: women sleuths',
#  'Sports fiction',
#  'Thriller / suspense fiction',
#  'Espionage and spy thriller',
#  'Technothriller',
#  'Medical thriller',
#  'Political / legal thriller',
#  'Esoteric thriller',
#  'Thriller: organised crime',
#  'Thriller: serial killers',
#  'Thriller: terrorism',
#  'Psychological thriller',
#  'Adventure / action fiction',
#  'Martial arts fiction',
#  'Historical adventure fiction',
#  'War, combat and military adventure fiction',
#  'Napoleonic War fiction',
#  'First World War fiction',
#  'Second World War fiction',
#  'Vietnam War fiction',
#  'Sea stories',
#  'Adventure fiction: Westerns',
#  'Horror and supernatural fiction',
#  'Classic horror and ghost stories',
#  'Contemporary horror and ghost stories',
#  'Occult fiction',
#  'Science fiction',
#  'Classic science fiction',
#  'Science fiction: time travel',
#  'Hard science fiction',
#  'Science fiction: steampunk',
#  'Science fiction: near future',
#  'Science fiction: cyberpunk / biopunk',
#  'Science fiction: apocalyptic and post-apocalyptic',
#  'Science fiction: military',
#  'Science fiction: space opera',
#  'Science fiction: aliens / UFOs',
#  'Science fiction: space exploration',
#  'Fantasy',
#  'Epic fantasy / heroic fantasy',
#  'Historical fantasy',
#  'Comic (humorous) fantasy',
#  'Magical realism',
#  'Fantasy romance',
#  'Superhero stories',
#  'Dark fantasy',
#  'Contemporary fantasy',
#  'Urban fantasy',
#  'Fiction: Traditional stories, myths and fairy tales',
#  'Fairy and Folk tales / Fairy tale retellings',
#  'Myths and Legends / Mythic fiction',
#  'Erotic fiction',
#  'Contemporary lifestyle fiction',
#  'Romance',
#  'Modern and Contemporary romance',
#  'Romance: wholesome',
#  'Historical romance',
#  'Romance: ‘western’, rural or ‘outback’',
#  'Romantic suspense',
#  'Romance in uniform',
#  'Romance: medical',
#  'Romance: the rich / famous / powerful',
#  'Romance: fantasy and paranormal',
#  'Romance: time travel',
#  'Dark romance',
#  'Erotic romance',
#  'Family life fiction',
#  'Saga fiction (family / generational sagas)',
#  'Humorous fiction',
#  'Satirical fiction and parodies',
#  'Historical fiction',
#  'Religious and spiritual fiction',
#  'Fiction: narrative themes',
#  'Narrative theme: Coming of age',
#  'Narrative theme: Love and relationships',
#  'Narrative theme: Environmental issues / the natural world',
#  'Narrative theme: Health and illness',
#  'Narrative theme: Death, grief, loss',
#  'Narrative theme: Interior life',
#  'Narrative theme: Identity / belonging',
#  'Narrative theme: Politics',
#  'Narrative theme: Displacement, exile, migration',
#  'Narrative theme: Sense of place',
#  'Narrative theme: Social issues',
#  'Narrative theme: Diversity, equality, inclusion',
#  'Narrative theme: Journeys and voyages',
#  'Fiction: special features',
#  'Short stories',
#  'Novella (Short Novel)',
#  'Epistolary fiction',
#  'Fiction: pastiche',
#  'Fiction: mashup',
#  'Fiction based on or inspired by true events',
#  'Fiction: special features: Yaoi / BL novels',
#  'Category fiction',
#  'Fiction: special features: ranobe (‘light novels’)',
#  'Fiction in translation',
#  'Fiction: inspired by or adapted from other media',
#  'Fiction: special features: game-related',
#  'Fiction companions',
#  'Reference, Information and Interdisciplinary subjects',
#  'Encyclopaedias and reference works',
#  'General encyclopaedias',
#  'Reference works',
#  'Dictionaries of biography',
#  'Subject dictionaries',
#  'Quotations, proverbs and sayings',
#  'Bibliographies, catalogues',
#  'Serials, periodicals, abstracts, indexes',
#  'Directories',
#  'Yearbooks, annuals, almanacs',
#  'Miscellanies and compendia',
#  'Library and information sciences / Museology',
#  'Library, archive and information management',
#  'Information retrieval and access',
#  'IT, Internet and electronic resources in libraries',
#  'Acquisitions and collection development',
#  'Bibliographic and subject control',
#  'Library and information services',
#  'Archiving, preservation and digitization',
#  'Museology and heritage studies',
#  'Research and information: general',
#  'Information theory',
#  'Cybernetics and systems theory',
#  'Data science and analysis: general',
#  'Coding theory and cryptology',
#  'Decision theory: general',
#  'Risk assessment',
#  'Research methods: general',
#  'Interdisciplinary studies',
#  'History of scholarship (principally of social sciences and humanities)',
#  'Communication studies',
#  'Semiotics / semiology',
#  'Cognitive studies',
#  'Regional / International studies',
#  'Development studies',
#  'Globalization',
#  'Decolonisation of knowledge / Decoloniality',
#  'Flags, emblems, symbols, logos',
#  'Peace studies and conflict resolution',
#  'Institutions and learned societies: general',
#  'General studies and General knowledge',
#  'Society and Social Sciences',
#  'Society and culture: general',
#  'Cultural and media studies',
#  'Cultural studies',
#  'Popular culture',
#  'Material culture',
#  'Cultural studies: dress and society',
#  'Cultural studies: food and society',
#  'Cultural studies: customs and traditions',
#  'Cross-cultural / Intercultural studies and topics',
#  'Cultural policies and debates',
#  'History of ideas',
#  'Media studies',
#  'Media studies: internet, digital media and society',
#  'Media studies: TV and society',
#  'Media studies: advertising and society',
#  'Media studies: journalism',
#  'Disinformation and misinformation',
#  'Social and ethical issues',
#  'Social discrimination and social justice',
#  'Racism and racial discrimination / Anti-racism',
#  'Social Integration and assimilation',
#  'Poverty and precarity',
#  'Housing and homelessness',
#  'Social impact of disasters / accidents (natural or man-made)',
#  'Refugees and political asylum',
#  'Aiding escape and evasion',
#  'Migration, immigration and emigration',
#  'Human trafficking',
#  'Violence and abuse in society',
#  'Child abuse',
#  'Sexual abuse and harassment',
#  'Domestic abuse',
#  'Bullying and harassment',
#  'Control, privacy and safety in society',
#  'Disability: social aspects',
#  'Health, illness and addiction: social aspects',
#  'Drugs and alcohol: social aspects',
#  'Social mobility',
#  'Consumerism',
#  'Animals and society',
#  'Ethical issues and debates',
#  'Ethical issues: abortion and birth control',
#  'Ethical issues: capital punishment',
#  'Ethical issues: censorship',
#  'Ethical issues: euthanasia and right to die',
#  'Ethical issues: scientific, technological and medical developments',
#  'Sex and sexuality, social aspects',
#  'Social attitudes',
#  'Social forecasting, future studies',
#  'Popular beliefs and controversial knowledge',
#  'Folklore studies / Study of myth (mythology)',
#  'Conspiracy theories',
#  'Social groups, communities and identities',
#  'Social classes',
#  'Rural communities',
#  'Urban communities',
#  'Gender studies, gender groups',
#  'Gender studies: women and girls',
#  'Feminism and feminist theory',
#  'Gender studies: men and boys',
#  'Gender studies: ‘trans’, transgender people and gender variance',
#  'LGBTQ+ Studies / topics',
#  'LGBTQ+ topics: coming out',
#  'Ethnic studies',
#  'Ethnic groups and multicultural studies',
#  'Indigenous peoples',
#  'Mixed heritage / mixed race groups or people',
#  'Age groups and generations',
#  'Age groups: children',
#  'Age groups: adolescents',
#  'Age groups: adults',
#  'Age groups: the elderly',
#  'Social groups: religious groups and communities',
#  'Social groups: alternative lifestyles',
#  'Secret societies',
#  'Social groups: clubs and societies',
#  'Sociology and anthropology',
#  'Sociology',
#  'Social theory',
#  'Social research and statistics',
#  'Population and demography',
#  'Sociology: family and relationships',
#  'Sociology: work and labour',
#  'Sociology: sport and leisure',
#  'Sociology: death and dying',
#  'Anthropology',
#  'Social and cultural anthropology',
#  'Social services and welfare, criminology',
#  'Social welfare and social services',
#  'Welfare and benefit systems',
#  'Child welfare and youth services',
#  'Adoption and fostering',
#  'Care of the elderly',
#  'Care of people with specific needs',
#  'Care of people with mental health issues',
#  'Social work',
#  'Charities, voluntary services and philanthropy',
#  'Social counselling and advice services',
#  'Aid and relief programmes',
#  'Emergency services',
#  'Police and security services',
#  'Fire services',
#  'Ambulance and rescue services',
#  'Crime and criminology',
#  'Causes and prevention of crime',
#  'Criminal investigation and detection',
#  'Forensic science',
#  'Drugs trade / drug trafficking',
#  'Street crime',
#  'Corporate crime / white-collar crime',
#  'Organized crime',
#  'Violent crimes',
#  'Penology and punishment',
#  'Offenders',
#  'Rehabilitation of offenders',
#  'Juvenile offenders',
#  'Probation services',
#  'Victimology and victims of crime',
#  'Psychology',
#  'Psychological theory, systems, schools and viewpoints',
#  'Psychoanalytical and Freudian psychology',
#  'Lacanian psychoanalysis',
#  'Analytical and Jungian psychology',
#  'Behaviourism, Behavioural theory',
#  'Humanistic psychology',
#  'Positive psychology',
#  'Cognitivism, cognitive theory',
#  'Psychological methodology',
#  'Psychological testing and measurement',
#  'Child, developmental and lifespan psychology',
#  'Psychology of ageing',
#  'Family psychology',
#  'Psychology of gender',
#  'Social, group or collective psychology',
#  'Interpersonal communication and skills',
#  'Occupational and industrial psychology',
#  'Criminal or forensic psychology',
#  'Experimental psychology',
#  'Physiological and neuro-psychology, biopsychology',
#  'Abnormal psychology',
#  'Psychology: emotions',
#  'Cognition and cognitive psychology',
#  'Psychology: the self, ego, identity, personality',
#  'Psychology: states of consciousness',
#  'Psychology: sexual behaviour',
#  'Parapsychological studies',
#  'Education',
#  'Philosophy and theory of education',
#  'Moral and social purpose of education',
#  'Progressive education',
#  'History of education',
#  'Educational psychology',
#  'Educational systems and structures',
#  'Curriculum planning and development',
#  'Education: examinations and assessment',
#  'Social pedagogy',
#  'Educational strategies and policy',
#  'Counselling and care of students',
#  'Educational strategies and policy: inclusion',
#  'Early childhood care and education',
#  'Home schooling',
#  'Educational administration and organization',
#  'Funding of education and student finance',
#  'Teaching staff',
#  'Schools and pre-schools',
#  'Pre-school and kindergarten',
#  'Primary and middle schools',
#  'Secondary schools',
#  'Independent schools, private education',
#  'Residential educational institutions',
#  'Faith (religious) schools',
#  'Outdoor schools / education',
#  'Higher education, tertiary education',
#  'Teacher training',
#  'Adult education, continuous learning',
#  'Open learning, distance education',
#  'Careers guidance',
#  'Work experience, placements and internships',
#  'Industrial or vocational training',
#  'Teaching of students with different educational needs',
#  'Teaching of students with physical impairments or disabilities',
#  'Teaching of students with learning difficulties',
#  'Teaching of students with social, emotional or behavioural difficulties',
#  'Teaching of gifted or talented students',
#  'Remedial education and teaching',
#  'Education of bilingual or multilingual students',
#  'Teaching skills and techniques',
#  'Competence development',
#  'Project-based learning',
#  'Play-based learning',
#  'Teaching of reading, writing and numeracy',
#  'Teaching of a specific subject',
#  'Teachers’ classroom resources and material',
#  'Lesson plans',
#  'Educational equipment and technology, computer-aided learning (CAL)',
#  'Extra-curricular activities',
#  'Study and learning skills: general',
#  'Politics and government',
#  'Political science and theory',
#  'Comparative politics',
#  'Political ideologies and movements',
#  'Green politics / ecopolitics / environmentalism',
#  'Anarchism',
#  'Far-left political ideologies and movements',
#  'Left-of-centre democratic ideologies',
#  'Centrist democratic ideologies',
#  'Right-of-centre democratic ideologies',
#  'Nationalism',
#  'Pan-nationalism',
#  'Far-right political ideologies and movements',
#  'Religious and theocratic ideologies',
#  'Political structure and processes',
#  'Constitution: government and the state',
#  'Elections and referenda / suffrage',
#  'Political leaders and leadership',
#  'Political structures: democracy',
#  'Political structures: totalitarianism and dictatorship',
#  'Political parties and party platforms',
#  'Indigenous people: governance and politics',
#  'Public administration',
#  'Central / national / federal government',
#  'Central / national / federal government policies',
#  'Regional, state and other local government',
#  'Regional, state and other local government policies',
#  'International relations',
#  'Diplomacy',
#  'Arms negotiation and control',
#  'Espionage and secret services',
#  'Geopolitics',
#  'International institutions',
#  'Municipal / city government',
#  'Political control and freedoms',
#  'Civics and citizenship',
#  'Human rights, civil rights',
#  'Political oppression and persecution',
#  'Political abduction, imprisonment, ‘Disappearance’ and assassination',
#  'Political activism / Political engagement',
#  'Public opinion and polls',
#  'Public affairs / Lobbying',
#  'Political campaigning and advertising',
#  'Pressure groups, protest movements and non-violent action',
#  'Non-governmental organizations (NGOs)',
#  'Terrorism, armed struggle',
#  'Revolutionary groups and movements',
#  'Armed conflict',
#  'Corruption in politics, government and society',
#  'Warfare and defence',
#  'Theory of warfare and military science',
#  'Military forces and sectors',
#  'Land forces and warfare',
#  'Irregular or guerrilla forces and warfare',
#  'Naval forces and warfare',
#  'Air forces and warfare',
#  'Special and elite forces',
#  'Information warfare / Cyberwarfare',
#  'Military administration',
#  'Military and defence strategy',
#  'Military intelligence',
#  'War and defence operations',
#  'Battles and campaigns',
#  'Peacekeeping operations',
#  'Weapons and equipment',
#  'Chemical and biological weapons',
#  'Nuclear weapons',
#  'Military vehicles',
#  'Military institutions',
#  'Military uniforms / insignia',
#  'Other warfare and defence issues',
#  'Arms trade',
#  'Non-combatants',
#  'War crimes',
#  'Mercenaries',
#  'Prisoners of war',
#  'Mutiny',
#  'Military veterans',
#  'Combat / defence skills and manuals',
#  'Economics, Finance, Business and Management',
#  'Economics',
#  'Economic theory and philosophy',
#  'Macroeconomics',
#  'Monetary economics',
#  'Microeconomics',
#  'Domestic or internal trade',
#  'Economics of industrial organization',
#  'Labour / income economics',
#  'Economic growth',
#  'Econometrics and economic statistics',
#  'Economic forecasting',
#  'Behavioural economics',
#  'International economics',
#  'International trade and commerce',
#  'Development economics and emerging economies',
#  'Political economy',
#  'Economic systems and structures',
#  'Capitalism',
#  'Mixed economic systems',
#  'Planned economic systems',
#  'Circular economic systems',
#  'Economics of specific sectors',
#  'Agricultural and rural economics',
#  'Environmental economics',
#  'Health economics',
#  'Welfare economics',
#  'Digital or internet economics',
#  'Knowledge / Information / Data economics',
#  'Service sector economics',
#  'Regional / urban economics',
#  'Economic and financial crises and disasters',
#  'Popular economics',
#  'Economic history',
#  'Finance and accounting',
#  'Accounting',
#  'Cost accounting',
#  'Financial accounting',
#  'Management accounting, bookkeeping and auditing',
#  'Auditing / Audits',
#  'Valuation (finance)',
#  'Public finance accounting',
#  'Financial reporting, financial statements',
#  'Tax planning and compliance',
#  'Accounting: study and revision guides',
#  'Finance and the finance industry',
#  'Fundraising, grants, donations',
#  'Public finance and taxation',
#  'Financial technology (fintech)',
#  'Corporate finance',
#  'Currency / Foreign exchange',
#  'Banking',
#  'Credit and credit institutions',
#  'Investment and securities',
#  'Insurance and actuarial studies',
#  'Pensions',
#  'Property and real estate',
#  'Green finance / sustainable finance',
#  'Private wealth management',
#  'Banking and finance: study and revision guides',
#  'Business and Management',
#  'Business studies: general',
#  'Business and management: study and revision guides',
#  'Business strategy',
#  'Business innovation',
#  'Disruptive innovation',
#  'E-commerce: business aspects',
#  'Business competition',
#  'Business ethics and social responsibility',
#  'Entrepreneurship / Start-ups',
#  'Business and the environment; ‘green’ approaches to business',
#  'International business',
#  'Consultancy',
#  'Management and management techniques',
#  'Management: leadership and motivation',
#  'Management decision making',
#  'Knowledge management',
#  'Business process / operations management',
#  'Project management',
#  'Quality Assurance (QA) and Total Quality Management (TQM)',
#  'Time management',
#  'Management of specific areas',
#  'Budgeting and financial management',
#  'Personnel and human resources management',
#  'Performance management / appraisals',
#  'Diversity, equality and inclusion in the workplace',
#  'IT and information systems management',
#  'Management of assets: real estate, property and plant',
#  'Production and quality control management',
#  'Research and development management',
#  'Sales and marketing management',
#  'Purchasing and supply management',
#  'Distribution and logistics management',
#  'Business negotiation',
#  'Business communication and presentation',
#  'Business mathematics and systems',
#  'Corporate governance: role and responsibilities of boards and directors',
#  'Sales and marketing',
#  'Advertising',
#  'Brands and branding',
#  'Online marketing / Social media marketing',
#  'Direct marketing / telemarketing',
#  'Market research',
#  'Public relations',
#  'Marketing for change / Cause-related marketing',
#  'Greenwashing and other forms of deceptive marketing',
#  'Customer services',
#  'Operational research',
#  'Organizational theory and behaviour',
#  'Ownership and organization of enterprises',
#  'Takeovers, mergers and buy-outs',
#  'Privatization',
#  'Franchises',
#  'Multinationals',
#  'Public ownership / nationalization',
#  'Monopolies',
#  'Family and Owner-Managed Companies',
#  'Small businesses and self-employment',
#  'Outsourcing and insourcing',
#  'Joint ventures',
#  'Employee-ownership and co-operatives',
#  'Non-profitmaking organizations',
#  'Office and workplace',
#  'Office management',
#  'Office systems and equipment',
#  'Secretarial, clerical and office skills',
#  'Working patterns and practices',
#  'History of specific companies / corporate history',
#  'Industry and industrial studies',
#  'Agribusiness and primary industries',
#  'Agriculture, agribusiness and food production industries',
#  'Fisheries and related industries',
#  'Forestry industry',
#  'Extractive industries',
#  'Energy industries and utilities',
#  'Electrical power generation and distribution industries',
#  'Petroleum, oil and gas industries',
#  'Alternative and renewable energy industries',
#  'Water industries',
#  'Manufacturing industries',
#  'Chemical, biotechnology and pharmaceutical industries',
#  'Apparel, garment and textile industries',
#  'Vehicle and transport manufacturing industries',
#  'Transport industries',
#  'Construction and heavy industry',
#  'Construction and building industry',
#  'Iron, steel and other metal industries',
#  'Retail and wholesale industries',
#  'Hospitality and service industries',
#  'Food and drink service industries',
#  'Hospitality, sports, leisure and tourism industries',
#  'Events management industry',
#  'Fashion and beauty industries',
#  'Deathcare and funeral industries',
#  'Media, entertainment, information and communication industries',
#  'Film, TV and Radio industries',
#  'Music industry',
#  'Publishing industry and journalism',
#  'Publishing and book trade',
#  'News media and journalism',
#  'Printing and reprographic industries',
#  'Computer and video game industry',
#  'Information technology industries',
#  'Civil service and public sector',
#  'Industrial relations, occupational health and safety',
#  'Health and safety in the workplace',
#  'Industrial arbitration and negotiation',
#  'Trade unions',
#  'Law',
#  'Jurisprudence and general issues',
#  'Methods, theory and philosophy of law',
#  'Systems of law',
#  'Systems of law: common law',
#  'Systems of law: civil codes / civil law',
#  'Systems of law: customary law',
#  'Systems of law: mixed systems',
#  'Systems of law: Roman law',
#  'Systems of law: Islamic law',
#  'Systems of law: Jewish Law',
#  'Systems of law: ecclesiastical (canon) law',
#  'Comparative law',
#  'Legal technology',
#  'Law and society, sociology of law',
#  'Law and society, gender issues',
#  'Legal aspects of criminology',
#  'Legal skills and practice',
#  'Legal skills: advocacy',
#  'Legal skills: drafting and legal writing',
#  'Legal skills: negotiating and interviewing',
#  'Legal skills: research methods',
#  'Legal practice: paralegals and paralegalism',
#  'Legal profession / practice of law: general',
#  'Legal ethics and professional conduct',
#  'Law as it applies to other professions and disciplines',
#  'Legal history',
#  'International law',
#  'Public international law',
#  'Public international law: treaties and other sources',
#  'Public International law: customary law',
#  'Public international law: diplomatic law',
#  'Public international law: jurisdiction and immunities',
#  'Public international law: territory and statehood',
#  'Public international law: law of the sea',
#  'Public International law: health',
#  'Public international law: economic and trade',
#  'Public international law, economic and trade: tariffs',
#  'Public international law, economic and trade: investment treaties and disputes',
#  'Public international law: energy and natural resources',
#  'Public international law, economic and trade: corporations',
#  'Public international law: environment',
#  'Public international law, environment: agricultural law',
#  'Public international law: administration',
#  'Public international law: human rights',
#  'Public international law, human rights: labour and social',
#  'Public international law: humanitarian law',
#  'Public international law: international organizations and institutions',
#  'Public international law: responsibility of states and other entities',
#  'Public international law: criminal law',
#  'International law: transport, communications and commerce',
#  'International law, transport: space and aerospace law',
#  'International law: transnational commerce and international sale of goods law',
#  'International law, transport and commerce: maritime law',
#  'International law: communications, telecommunications and media',
#  'Private international law and conflict of laws',
#  'International law: international disputes and civil procedure',
#  'International law: courts and procedures',
#  'International law: arbitration',
#  'International law: intellectual property',
#  'International law: sports',
#  'International law reports',
#  'Laws of specific jurisdictions and specific areas of law',
#  'Legal systems: general',
#  'Legal systems: courts and procedures',
#  'Legal systems: judges and judicial powers',
#  'Legal systems: lay and citizen judges / juries',
#  'Legal systems: law of contempt',
#  'Legal systems: civil procedure, litigation and dispute resolution',
#  'Civil remedies',
#  'Restitution',
#  'Damages and compensation',
#  'Injunctions and other orders',
#  'Civil procedure: law of evidence',
#  'Civil procedure: investigation and specific proceedings',
#  'Arbitration, mediation and alternative dispute resolution',
#  'Legal systems: General Part / General Provisions',
#  'Legal systems: costs and funding',
#  'Legal systems: regulation of legal profession',
#  'Private or civil law: general',
#  ...]
