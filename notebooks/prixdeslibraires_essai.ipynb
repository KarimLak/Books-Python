# %%
import pandas as pd
import rdflib

# your file path
file = "../output_prixdeslibraires_essai.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    https://schema.org/Book753bab4c-ca6e-48c0-aee9...  \
# 1    https://schema.org/Book753bab4c-ca6e-48c0-aee9...
# 2    https://schema.org/Book88ef265b-6cb1-4a0f-9aac...
# 3    https://schema.org/Book9d8ea186-1088-4b6f-83b5...
# 4    https://schema.org/Book9d8ea186-1088-4b6f-83b5...
# ..                                                 ...
# 100  https://schema.org/Book783a1c57-62e1-4e91-b511...
# 101  https://schema.org/Booka1527d22-42c4-49f3-9eae...
# 102  https://schema.org/Book88ef265b-6cb1-4a0f-9aac...
# 103  https://schema.org/Book753bab4c-ca6e-48c0-aee9...
# 104  https://schema.org/Book1a9d83b3-3b4e-4b68-b320...
#
#                            Predicate
# 0              http://schema.org/url  \
# 1            http://schema.org/genre
# 2           http://schema.org/author
# 3    http://schema.org/datePublished
# 4             http://schema.org/name
# ..                               ...
# 100          http://schema.org/genre
# 101    http://schema.org/description
# 102  http://schema.org/datePublished
# 103    http://schema.org/description
# 104  http://schema.org/datePublished
#
#                                                 Object
# 0    https://prixdeslibraires.qc.ca/zoom-demo/?bigt...
# 1                                                Essai
# 2                          Andréane Frenette-Vallières
# 3                                                 2022
# 4    L’habitude des ruines : Le sacré de l’oubli et...
# ..                                                 ...
# 100                                              Essai
# 101             Prix des libraires : Préliminaire 2023
# 102                                               2022
# 103          Prix des libraires : Finaliste 2023 essai
# 104                                               2022
#
# [105 rows x 3 columns]
