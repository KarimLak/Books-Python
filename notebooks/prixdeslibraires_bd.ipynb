# %%
import pandas as pd
import rdflib

# your file path
file = "../output_prixdeslibraires_bd.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    https://schema.org/Bookf3507152-4f7d-4c09-90ef...  \
# 1    https://schema.org/Bookec9c041c-a261-40d6-ad7e...
# 2    https://schema.org/Book9489fe71-a1c4-43be-ba1c...
# 3    https://schema.org/Book9489fe71-a1c4-43be-ba1c...
# 4    https://schema.org/Book5f9fe1dc-2caf-496d-a025...
# ..                                                 ...
# 413  https://schema.org/Book4f9b8483-d2dc-4059-be5f...
# 414  https://schema.org/Bookbf18e04e-defd-400d-a9d3...
# 415  https://schema.org/Book3593af2c-0b73-47a4-b546...
# 416  https://schema.org/Bookfbadc949-bff3-434e-b1ac...
# 417  https://schema.org/Bookfbadc949-bff3-434e-b1ac...
#
#                                            Predicate
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 1                       http://schema.org/inLanguage
# 2                      http://schema.org/description
# 3                       http://schema.org/inLanguage
# 4                      http://schema.org/description
# ..                                               ...
# 413                          http://schema.org/genre
# 414                  http://schema.org/datePublished
# 415                          http://schema.org/genre
# 416                            http://schema.org/url
# 417                     http://schema.org/inLanguage
#
#                                                 Object
# 0                               http://schema.org/Book
# 1                                             Français
# 2    Prix des libraires : Préliminaire BD Jeunesse ...
# 3                                             Français
# 4    Prix des libraires : Préliminaire volet adulte...
# ..                                                 ...
# 413                                                 BD
# 414                                               2022
# 415                                                 BD
# 416  https://prixdeslibraires.qc.ca/zoom-demo/?bigt...
# 417                                           Français
#
# [418 rows x 3 columns]
