# %%
import pandas as pd
import rdflib

# your file path
file = "../output_fmdoc.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    https://schema.org/Book93001cac-bf81-4c3a-8efb...  \
# 1    https://schema.org/Book93001cac-bf81-4c3a-8efb...
# 2    https://schema.org/Bookd490346b-6dc6-4f39-99ad...
# 3    https://schema.org/Book74bbbd24-364b-4f54-9291...
# 4    https://schema.org/Booked7633a9-0ec8-4566-bfc0...
# ..                                                 ...
# 474  https://schema.org/Bookc2dc72cf-ff2d-49bd-a348...
# 475  https://schema.org/Book42fd3172-8fd5-4663-ac18...
# 476  https://schema.org/Book9d33bc7f-7118-402f-9416...
# 477  https://schema.org/Book265fd4e1-991c-47b9-81a7...
# 478  https://schema.org/Bookc8e33173-95d3-4769-930f...
#
#                                            Predicate
# 0                             http://schema.org/name  \
# 1                           http://schema.org/author
# 2                             http://schema.org/name
# 3                       http://schema.org/inLanguage
# 4    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ..                                               ...
# 474                  http://schema.org/datePublished
# 475                          http://schema.org/genre
# 476                          http://schema.org/genre
# 477                         http://schema.org/author
# 478                           http://schema.org/name
#
#                                       Object
# 0                                    Guerres
# 1                          Charlotte Gingras
# 2    La vraie histoire du chien de Clara Vic
# 3                                   Français
# 4                     http://schema.org/Book
# ..                                       ...
# 474                                     1974
# 475                               0 à 17 ans
# 476                                 Jeunesse
# 477                    Marie-Francine Hébert
# 478                      Le visiteur du soir
#
# [479 rows x 3 columns]
