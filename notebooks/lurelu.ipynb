# %%
import pandas as pd
import rdflib

# your file path
file = "../output_lurelu.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                 Subject
# 0     https://schema.org/Book00970f12-4d50-4abe-adec...  \
# 1     https://schema.org/Book3c46480e-6310-4e03-8511...
# 2     https://schema.org/Book5a00e6c5-083d-47cb-bf80...
# 3     https://schema.org/Booka23686f6-23dc-4f93-9aa9...
# 4     https://schema.org/Book7050b9ee-de74-4318-83d3...
# ...                                                 ...
# 5411  https://schema.org/Book6febdd47-1e72-4303-96eb...
# 5412  https://schema.org/Book3b219652-5b54-4360-9726...
# 5413  https://schema.org/Book3ade7768-2a37-4f2d-8580...
# 5414  https://schema.org/Book64bdfb2b-2912-47d6-8d2f...
# 5415  https://schema.org/Book62eebcdf-679e-44c4-a73c...
#
#                            Predicate
# 0       http://schema.org/inLanguage  \
# 1            http://schema.org/award
# 2           http://schema.org/author
# 3            http://schema.org/award
# 4            http://schema.org/genre
# ...                              ...
# 5411         http://schema.org/award
# 5412           http://schema.org/url
# 5413         http://schema.org/award
# 5414     http://schema.org/publisher
# 5415  http://schema.org/dateReceived
#
#                                                  Object
# 0                                              Français
# 1                                   Prix Alvine-Bélisle
# 2                                            Serge Déry
# 3                 Prix Jeunesse Des Libraires Du Québec
# 4                                              Jeunesse
# ...                                                 ...
# 5411  Prix Illustration Jeunesse — Salon Du Livre De...
# 5412  https://www.lurelu.net/prixlitt_alvinebelisle....
# 5413          Concours Communication-Jeunesse / Culinar
# 5414                                          Soulières
# 5415                                               2004
#
# [5416 rows x 3 columns]
