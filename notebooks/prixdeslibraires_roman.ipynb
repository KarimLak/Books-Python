# %%
import pandas as pd
import rdflib

# your file path
file = "../output_prixdeslibraires_roman.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    https://schema.org/Book27fce1f6-4c1b-475d-ba94...  \
# 1    https://schema.org/Bookf5d858be-c063-40e1-8b91...
# 2    https://schema.org/Book81f9fe21-c7f9-4072-b005...
# 3    https://schema.org/Bookf9804649-b667-4597-ad01...
# 4    https://schema.org/Book10b0474c-72b5-4345-91ee...
# ..                                                 ...
# 321  https://schema.org/Book6ddc8ec5-ac71-42be-b2e2...
# 322  https://schema.org/Book464fed98-3525-4806-9b2b...
# 323  https://schema.org/Bookedbf9cb1-56a2-48c1-995f...
# 324  https://schema.org/Bookf9804649-b667-4597-ad01...
# 325  https://schema.org/Book9cc05e9e-39cf-4ba0-ae89...
#
#                                            Predicate                  Object
# 0                             http://schema.org/name            Mr. Loverman
# 1                       http://schema.org/inLanguage                Français
# 2                    http://schema.org/datePublished                    2022
# 3    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://schema.org/Book
# 4                            http://schema.org/genre                   Roman
# ..                                               ...                     ...
# 321                           http://schema.org/name                Stardust
# 322                     http://schema.org/inLanguage                Français
# 323                  http://schema.org/datePublished                    2022
# 324                         http://schema.org/author             Karine Tuil
# 325                  http://schema.org/datePublished                    2022
#
# [326 rows x 3 columns]
