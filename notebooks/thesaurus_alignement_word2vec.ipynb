# %%
from pprint import pprint

# %%
ecole_des_loisir_themes_preprocessed = ['donkey',
 'animals',
 'various',
 'pets',
 'spider',
 'ostrich',
 'whale',
 'weasel',
 'bison',
 'badger',
 'chameleon',
 'duck',
 'beaver',
 'deer',
 'camel',
 'chamois',
 'cat',
 'bat',
 'horse',
 'dog',
 'pig',
 'coyote',
 'crab',
 'crocodile',
 'dolphin',
 'animals',
 'turkey',
 'dinosaur',
 'squirrel',
 'elephant',
 'snail',
 'various',
 'giraffe',
 'wildebeest',
 'frog',
 'hamster',
 'hedgehog',
 'owl',
 'seahorse',
 'hippopotamus',
 'various',
 'kangaroo',
 'koala',
 'manatee',
 'rabbit',
 'lizard',
 'lion',
 'dormouse',
 'wolf',
 'otter',
 'lynx',
 'mammoth',
 'marmot',
 'walrus',
 'sheep',
 'various',
 'opossum',
 'platypus',
 'killer',
 'bear',
 'panda',
 'butterfly',
 'lazy',
 'seal',
 'octopus',
 'penguin',
 'various',
 'chicken',
 'raccoon',
 'fox',
 'shark',
 'rhinoceros',
 'wild',
 'snake',
 'monkey',
 'mouse',
 'meerkat',
 'armadillo',
 'mole',
 'tiger',
 'tortoise',
 'cow',
 'earthworm',
 'yeti',
 'zebra',
 'parietal',
 'traditional',
 'movie',
 'circus',
 'clown',
 'commedia',
 'creativity',
 'dance',
 'tightrope',
 'puppet',
 'literature',
 'puppet',
 'mime',
 'music',
 'opera',
 'paint',
 'photography',
 'photography',
 'sculpture',
 'street',
 'theater',
 'tooth',
 'hand',
 'body',
 'skeleton',
 'hygiene',
 'pee',
 'jar',
 'lice',
 'beauty',
 'coquetry',
 'body',
 'autism',
 'body',
 'disability',
 'glasses',
 'pregnancy',
 'birth',
 'accident',
 'alcoholism',
 'anorexia',
 'appetite',
 'bobo',
 'bulimia',
 'drug',
 'epidemic',
 'hospitalization',
 'disease',
 'wet',
 'health',
 'aids',
 'homosexuality',
 'puberty',
 'sexuality',
 'sleep',
 'fear',
 'dream',
 'the',
 'prevention',
 'space-time',
 'size',
 'learning',
 'learning',
 'first',
 'baby',
 'crib',
 'nipple',
 'language',
 'nature',
 'college',
 'truant',
 'school',
 'boarding',
 'back',
 'school',
 'university',
 'dead',
 'taking',
 'time',
 'old',
 'genealogy',
 'search',
 'foolery',
 'parental',
 'siblings',
 'fugue',
 'grandmother',
 'grandfather',
 'grand',
 'same-sex',
 'twins',
 'birth',
 'relationship',
 'relationship',
 'child',
 'sisters',
 'moving',
 'mess',
 'everyday',
 'adoption',
 'dispute',
 'divorce',
 'with',
 'abandoned',
 'abused',
 'host',
 'broken',
 'single',
 'stepfamily',
 'family',
 'marriage',
 'orphan',
 'family',
 'family',
 'adventure',
 'cloak',
 'police',
 'travel',
 'adventure',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'tales',
 'stories',
 'fables',
 'abbreviated',
 'classic',
 'picture',
 'fantastic',
 'fantasy',
 'science',
 'fables',
 'medieval',
 'novel',
 'cowboy',
 'super',
 'angel',
 'knight',
 'devil',
 'dragon',
 'ghost',
 'fairy',
 'giant',
 'genius',
 'unicorn',
 'elf',
 'wizard',
 'monster',
 'dwarf',
 'ogre',
 'storybook',
 'prince',
 'king',
 'mermaid',
 'wizard',
 'vampire',
 'sketch',
 'classical',
 'contemporary',
 'theater',
 'atlas',
 'autobiography',
 'adventure',
 'comic',
 'biography',
 'nursery',
 'tale',
 'riddles',
 'terror',
 'extraterrestrial',
 'humor',
 'newspaper',
 'letters',
 'book',
 'ukrainian',
 'game',
 'mooc',
 'mythology',
 'parody',
 'philosophy',
 'poetry',
 'proverb',
 'collection',
 'collection',
 'rhyme',
 'cap',
 'founding',
 'africa',
 'north',
 'south',
 'algeria',
 'egypt',
 'kenya',
 'libya',
 'madagascar',
 'maghreb',
 'mali',
 'morocco',
 'seychelles',
 'sudan',
 'tanzania',
 'tunisia',
 'zanzibar',
 'west',
 'costa',
 'cuba',
 'guatemala',
 'haiti',
 'mexico',
 'porto',
 'alaska',
 'canada',
 'united',
 'argentina',
 'bolivia',
 'brazil',
 'chile',
 'colombia',
 'ecuador',
 'peru',
 'venezuela',
 'afghanistan',
 'arabia',
 'armenia',
 'asia',
 'bahrain',
 'bangladesh',
 'burma',
 'borneo',
 'cambodia',
 'china',
 'korea',
 'emirates',
 'far',
 'india',
 'indonesia',
 'iraq',
 'iran',
 'israel',
 'japan',
 'jordan',
 'kyrgyzstan',
 'kuwait',
 'laos',
 'lebanon',
 'malaysia',
 'mongolia',
 'middle',
 'nepal',
 'oman',
 'pakistan',
 'philippines',
 'sri',
 'syria',
 'taiwan',
 'thailand',
 'tibet',
 'vietnam',
 'yemen',
 'georgia',
 'uzbekistan',
 'russia',
 'türkiye',
 'ussr',
 'eskimo',
 'gallic',
 'indian',
 'american',
 'mayan',
 'arab',
 'tuareg',
 'vikings',
 'germany',
 'austria',
 'balkans',
 'belgium',
 'denmark',
 'spain',
 'europe',
 'finland',
 'france',
 'britain',
 'greece',
 'hungary',
 'iceland',
 'italy',
 'norway',
 'nordic',
 'the',
 'poland',
 'portugal',
 'romania',
 'sweden',
 'swiss',
 'czechoslovakia',
 'ukraine',
 'amazon',
 'ice',
 'desert',
 'forest',
 'island',
 'jungle',
 'mountain',
 'river',
 'sahara',
 'volcano',
 'australia',
 'new',
 'new',
 'new',
 'polynesia',
 'arctic',
 'concentration',
 'municipality',
 'conquest',
 'deportation',
 'between',
 'fascism',
 'armenian',
 'khmer',
 'war',
 'hiroshima',
 'mafia',
 'nazism',
 'first',
 'revolution',
 'french',
 'second',
 'terrorism',
 'antiquity',
 'antiquity:',
 'antiquity:',
 'antiquity:',
 'antiquity:',
 'gaul',
 'history',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'prehistory',
 'martin',
 'castle',
 'caveman',
 'dinosaur',
 'world',
 'mesopotamia',
 'historic',
 'pioneers',
 'noises',
 'singing',
 'opposite',
 'colors',
 'etymology',
 'story',
 'images',
 'imagine',
 'language',
 'counting',
 'metamorphosis',
 'ball',
 'hide',
 'kite',
 'race',
 'disguise',
 'doudou',
 'game',
 'toys',
 'mask',
 'teddy',
 'doll',
 'robot',
 'abc',
 'almanac',
 'coloring',
 'roleplay',
 'video',
 'chess',
 'animated',
 'bath',
 'birth',
 'puzzle',
 'chief',
 'brave',
 'greedy',
 'curiosity',
 'self-centered',
 'fantasy',
 'joker',
 'ingenious',
 'lazy',
 'spoiler',
 'responsible',
 'dreamer',
 'cunning',
 'boastful',
 'imaginary',
 'friendship',
 'love',
 'whims',
 'anger',
 'eco-anxiety',
 'emotion',
 'boredom',
 'gratitude',
 'harassment',
 'shame',
 'mood',
 'jealousy',
 'wickedness',
 'lie',
 'mockery',
 'nostalgia',
 'fear',
 'look',
 'rivalry',
 'feeling',
 'feeling',
 'tenderness',
 'timidity',
 'sadness',
 'revenge',
 'assertiveness',
 'gender',
 'imagination',
 'initiation',
 'the',
 'portrait',
 'search',
 'identity',
 'secret',
 'memory',
 'telepathy',
 'therapy',
 'transgender',
 'transmission',
 'hibernation',
 'instinct',
 'food',
 'animal',
 'trace',
 'zoology',
 'tree',
 'mushrooms',
 'flower',
 'fruit',
 'vegetable',
 'natural',
 'bad',
 'weather',
 'snow',
 'cloud',
 'rain',
 'sun',
 'wind',
 'autumn',
 'cycle',
 'summer',
 'hour',
 'winter',
 'spring',
 'week',
 'biology',
 'waste',
 'water',
 'ecology',
 'space',
 'fire',
 'metamorphosis',
 'naturalist',
 'night',
 'rock',
 'earth',
 'environmental',
 'plant',
 'underwater',
 'underground',
 'astronomy',
 'air',
 'sky',
 'space',
 'cosmonaut',
 'star',
 'moon',
 'species',
 'printing',
 'learned',
 'technology',
 'plane',
 'boat',
 'truck',
 'traffic',
 'various',
 'metro',
 'hot',
 'means',
 'port',
 'train',
 'archeology',
 'architecture',
 'human',
 'computer',
 'physical',
 'seismology',
 'potholing',
 'processing',
 'internet',
 'media',
 'advertisement',
 'social',
 'television',
 'social',
 'poverty',
 'work',
 'sects',
 'witchcraft',
 'bohemian',
 'candy',
 'hat',
 'kitchen',
 'culture',
 'gluttony',
 'food',
 'garment',
 'social',
 'birthday',
 'carnival',
 'funfair',
 'king',
 'halloween',
 'christmas',
 'christmas',
 'easter',
 'santa',
 'picnic',
 'diy',
 'camping',
 'role',
 'video',
 'book',
 'merry-go-round',
 'scouting',
 'slavery',
 'exile',
 'immigration',
 'integration',
 'refugee',
 'apartheid',
 'communism',
 'political',
 'democracy',
 'dictatorship',
 'khmer',
 'totalitarianism',
 "noah's",
 'bible',
 'faith',
 'fundamentalism',
 'jewish',
 'religions',
 'martial',
 'boxing',
 'horse',
 'sporting',
 'soccer',
 'olympic',
 'swimming',
 'ice',
 'roller',
 'rugby',
 'ski',
 'sport',
 'surf',
 'tennis',
 'bike',
 'yoga',
 'incest',
 'forbidden',
 'justice',
 'mistreatment',
 'prison',
 'violence',
 'sexual',
 'thief',
 'money',
 'pocket',
 'baby',
 'baker',
 'casting',
 'unemployment',
 'hairdresser',
 'detective',
 'doctor',
 'writer',
 'explorer',
 'postman',
 'journalism',
 'judge',
 'various',
 'barge',
 'odd',
 'firefighter',
 'work',
 'child',
 'veterinarian',
 'summer',
 'world',
 'vacation',
 'vacation',
 'vacation',
 'seaside',
 'mountain',
 'journey',
 'money',
 'citizenship',
 'communication',
 'confinement',
 'pool',
 'power',
 'transhumanism',
 'campaign',
 'farm',
 'fishing',
 'back',
 'rural',
 'sea',
 'shipwreck',
 'pirate',
 'beach',
 'living',
 'public',
 'store',
 'walk',
 'museum',
 'job',
 'street',
 'urban',
 'city',
 'zoo',
 'hut',
 'garden',
 'places',
 'house']

# %%
ricochet_themes_preprocessed = ['abandonment',
 'abecedary',
 'bee',
 'aboriginal',
 'absence',
 'absurd',
 'sexual',
 'accident',
 'manual',
 'activities',
 'adaptation',
 'adolescence',
 'adoption',
 'adultery',
 'affection',
 'assertiveness',
 'afghanistan',
 'africa',
 'north',
 'south',
 'humanitarian',
 'alaska',
 'album',
 'album',
 'alcohol',
 'algeria',
 'food',
 'germany',
 'literacy',
 'mountaineering',
 'north',
 'latin',
 'friendship',
 'amnesia',
 'love',
 'text',
 'donkey',
 'angel',
 'animals',
 'birthday',
 'anorexia',
 'west',
 'antiquity',
 'antiquity',
 'antiquity',
 'anti-semitism',
 'apartheid',
 'learning',
 'learning',
 'spider',
 'tree',
 'archeology',
 'architecture',
 'money',
 'argentina',
 'armenia',
 'art',
 'art',
 'urban',
 'asia',
 'astrology',
 'astronomy',
 'writing',
 'australia',
 'autism',
 'autobiography',
 'autumn',
 'automotive',
 'austria',
 'ostrich',
 'adventure',
 'plane',
 'bath',
 'comic',
 'comic',
 'bandit',
 'suburb',
 'boat',
 'beauty',
 'baby',
 'belgium',
 'lullaby',
 'bestiary',
 'stupidity',
 'bhutan',
 'bible',
 'bibliography',
 'library',
 'youth',
 'bicycle',
 'animal',
 'jewel',
 'biography',
 'kiss',
 'bison',
 'badger',
 'bolivia',
 'happiness',
 'botanical',
 'buddhism',
 'boxing',
 'brazil',
 'brittany',
 'noises',
 'bulgaria',
 'burundi',
 'pebble',
 'calligraphy',
 'cambodia',
 'cameroon',
 'countryside',
 'camping',
 'canada',
 'duck',
 'caprice',
 'carnival',
 'beaver',
 'natural',
 'nuclear',
 'blindness',
 'celebrity',
 'censorship',
 'kite',
 'deer',
 'camel',
 'mushroom',
 'song',
 'hat',
 'cat',
 'castle',
 'warm',
 'bat',
 'caterpillar',
 'horse',
 'knight',
 'dog',
 'digit',
 'chemistry',
 'china',
 'chocolate',
 'unemployment',
 'owl',
 'sky',
 'cinema',
 'five',
 'circus',
 'quote',
 'citizenship',
 'clown',
 'ladybug',
 'pig',
 'hairdresser',
 'anger',
 'collection',
 'college',
 'colombia',
 'summer',
 'colonization',
 'coloring',
 'musical',
 'communication',
 'competition',
 'nursery',
 'concentration',
 'death',
 'female',
 'social',
 'conformism',
 'congo',
 'conquest',
 'consumption',
 'tale',
 'tale',
 'opposite',
 'korea',
 'body',
 'correspondence',
 'bullfight',
 'corsica',
 'color',
 'courage',
 'crocodile',
 'cuba',
 'cooking',
 'guilt',
 'curiosity',
 'swan',
 'denmark',
 'dance',
 'dolphin',
 'landing',
 'discovery',
 'disguise',
 'delinquency',
 'moving',
 'tooth',
 'depression',
 'desert',
 'despair',
 'design',
 'drawing',
 'cartoon',
 'relaxation',
 'sustainable',
 'riddle',
 'devil',
 'dictatorship',
 'difference',
 'dinosaur',
 'disappearance',
 'documentary',
 'sleep',
 'double',
 'comforter',
 'dragon',
 'drug',
 'right',
 "children's",
 'human',
 'dyslexia',
 'dystopia',
 'water',
 'school',
 'kindergarten',
 'primary',
 'ecology',
 'economy',
 'scotland',
 'writing',
 'squirrel',
 'editing',
 'edition',
 'education',
 'equality',
 'selfishness',
 'egypt',
 'ancient',
 'momentum',
 'electricity',
 'elephant',
 'emotions',
 'encyclopedia',
 'energy',
 'childhood',
 'street',
 'wild',
 'enigma',
 'abduction',
 'boredom',
 'investigation',
 'mutual',
 'environment',
 'test',
 'ecuador',
 'snail',
 'slavery',
 'space',
 'spain',
 'espionage',
 'hope',
 'united',
 'summer',
 'ethiopia',
 'ethics',
 'star',
 'europe',
 'eastern',
 'excision',
 'exclusion',
 'exile',
 'feat',
 'exposure',
 'extraterrestrial',
 'fable',
 'family',
 'host',
 'stepfamily',
 'fantasy',
 'fantastic',
 'ghost',
 'fascism',
 'fairy',
 'woman',
 'funfair',
 'fire',
 'girl',
 'finland',
 'flower',
 'soccer',
 'forest',
 'shape',
 'ant',
 'france',
 'fruit',
 'fugue',
 'genealogy',
 'generosity',
 'geography',
 'giraffe',
 'gypsy',
 'gluttony',
 'great',
 'grandmother',
 'grandfather',
 'big',
 'britain',
 'greece',
 'frog',
 'strike',
 'grimace',
 'fat',
 'guatemala',
 'war',
 'guide',
 'guyana',
 'dwelling',
 'halloween',
 'hamster',
 'disability',
 'harassment',
 'hedgehog',
 'hero',
 'hour',
 'hippopotamus',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'the',
 'winter',
 'holocaust',
 'homosexuality',
 'hungary',
 'shame',
 'hospital',
 'humor',
 'hygiene',
 'identify',
 'illiteracy',
 'drawing',
 'imagining',
 'imagination',
 'immigration',
 'immortality',
 'printing',
 'inca',
 'india',
 'indian',
 'individualism',
 'indonesia',
 'inequality',
 'information',
 'insect',
 'music',
 'integration',
 'interculturality',
 'internet',
 'inuit',
 'iraq',
 'iran',
 'ireland',
 'iceland',
 'israel',
 'italy',
 'jealousy',
 'jamaica',
 'japan',
 'garden',
 'gardening',
 'jazz',
 'optical',
 'finger',
 'play',
 'video',
 'game',
 'olympic',
 'personal',
 'journalism',
 'judaism',
 'twins',
 'justice',
 'kamishibai',
 'kangaroo',
 'koala',
 'kosovo',
 'the',
 'lake',
 'sign',
 'foreign',
 'language',
 'rabbit',
 'image',
 'arthurian',
 'legends',
 'vegetable',
 'lemming',
 'leopard',
 'get',
 'lebanon',
 'freedom',
 'library',
 'unicorn',
 'lion',
 'list',
 'literature',
 "children's",
 'lithuania',
 'animated',
 'game',
 'book',
 'london',
 'wolf',
 'werewolf',
 'light',
 'moon',
 'elf',
 'luxembourg',
 'high',
 'madagascar',
 'store',
 'magic',
 'disease',
 'malaysia',
 'mali',
 'abuse',
 'mammoth',
 'carousel',
 'manga',
 'handling',
 'genetic',
 'marriage',
 'forced',
 'puppet',
 'morocco',
 'mask',
 'mathematical',
 'wickedness',
 'physician',
 'medicine',
 'melancholy',
 'lie',
 'menstruation',
 'sea',
 'metamorphosis',
 'weather',
 'job',
 'metro',
 'mexico',
 'thousand',
 'mine',
 'misery',
 'fashion',
 'arab',
 'mongolia',
 'monster',
 'mountain',
 'mockery',
 'death',
 'fly',
 'seagull',
 'mill',
 'sheep',
 'middle',
 'museum',
 'music',
 'mystery',
 'mythology',
 'birth',
 'napoleon',
 'narrator',
 'nature',
 'shipwreck',
 'snow',
 'nepal',
 'new',
 'christmas',
 'normandy',
 'norway',
 'nanny',
 'food',
 'new',
 'new',
 'new',
 'night',
 'obesity',
 'oceania',
 'smell',
 'egg',
 'ogre',
 'bird',
 'opera',
 'computer',
 'origami',
 'orphan',
 'hearing',
 'bear',
 'peace',
 'pakistan',
 'palestine',
 'panda',
 'butterfly',
 'easter',
 'laziness',
 'scent',
 'paris',
 'parody',
 'sharing',
 'paternity',
 'patience',
 'the',
 'landscape',
 'fishing',
 'pedagogy',
 'pedophilia',
 'painter',
 'paint',
 'santa',
 'peru',
 'persian',
 'perseverance',
 'early',
 'fear',
 'fear',
 'philosophy',
 'seal',
 'photography',
 'penguin',
 'picnic',
 'pirate',
 'pool',
 'planet',
 'plant',
 'rain',
 'poetry',
 'poison',
 'fish',
 'police',
 'politeness',
 'policy',
 'pollution',
 'poland',
 'polynesia',
 'firefighter',
 'port',
 'portrait',
 'portugal',
 'hen',
 'doll',
 'power',
 'lice',
 'artistic',
 'prehistory',
 'prejudices',
 'first',
 'prince',
 'spring',
 'prison',
 'literary',
 'ride',
 'provence',
 'proverb',
 'psychology',
 'advertisement',
 'chip',
 'punishment',
 'quebec',
 'questions',
 'racism',
 'racketeering',
 'refugee',
 'child',
 'child',
 'brother',
 'grandmother',
 'grandparent',
 'grandfather',
 'human',
 'mother',
 'mother',
 'mother',
 'father',
 'father',
 'father',
 'elderly',
 'religion',
 'fox',
 'resistance',
 'respect',
 'responsibility',
 'dream',
 'revolt',
 'wealth',
 'ritournel',
 'rivalry',
 'robot',
 'king',
 'novel',
 'historical',
 'detective',
 'romania',
 'street',
 'rumor',
 'cunning',
 'russia',
 'rwanda',
 'wisdom',
 'saint',
 'season',
 'health',
 'fir',
 'science',
 'science',
 'sculpture',
 'secret',
 'sect',
 'road',
 'racial',
 'senegal',
 'separation',
 'snake',
 'sexuality',
 'aids',
 'silence',
 'monkey',
 'company',
 'sun',
 'solitude',
 'sleep',
 'sound',
 'wizard',
 'suffering',
 'mouse',
 'memory',
 'potholing',
 'spirituality',
 'sport',
 'steampunk',
 'sugar',
 'sweden',
 'suicide',
 'swiss',
 'super',
 'superstition',
 'deafness',
 'survival',
 'suspense',
 'syria',
 'tobacco',
 'taiwan',
 'mole',
 'phone',
 'television',
 'time',
 'earth',
 'terrorism',
 'thailand',
 'theater',
 'shadow',
 'tibet',
 'tiger',
 'timidity',
 'tolerance',
 'tortoise',
 'touch',
 'tradition',
 'translation',
 'train',
 'transidentity',
 'transport',
 'work',
 'child',
 'treasure',
 'trisomy',
 'sadness',
 'gypsy',
 'tunisia',
 'türkiye',
 'typography',
 'tyranny',
 'ukraine',
 'universe',
 'vacation',
 'cow',
 'vampire',
 'vegetarianism',
 'venezuela',
 'revenge',
 'venice',
 'wind',
 'garment',
 'everyday',
 'old',
 'vietnam',
 'viking',
 'city',
 'rape',
 'violence',
 'neighborhood',
 'theft',
 'volcano',
 'journey',
 'view',
 'yeti',
 'yoga',
 'zebra',
 'zombie',
 'zoo',
 'zoology']

# %%
thema_root_nodes_preprocessed = ['arts',
 'language',
 'biography',
 'fiction',
 'reference',
 'society',
 'economics',
 'law',
 'medicine',
 'history',
 'mathematics',
 'philosophy',
 'earth',
 'sports',
 'technology',
 'computing',
 'health',
 'lifestyle',
 'graphic',
 'children’s',
 'place',
 'language',
 'time',
 'educational',
 'interest',
 'style']

# %%
thema_all_nodes_preprocessed = ['serials', 'shimla', 'gettysburg', 'asian', 'drôme', 'mexican', 'trois-rivières', 'tungusic', 'confidential', 'ecological', 'preschool', 'tsimshianic', 'uruguay:', 'amoy', 'vietnamese', 'papiamento', 'animal', 'wyandot', 'psychopharmacology', 'customer', 'hammerfest', 'czech', 'darien', 'rusyn', 'lure', 'tallahassee', 'mercantour', 'system', 'ingolstadt', 'rogaland', 'bilingualism', 'animism', 'finno-ugric', 'readings', 'nostalgia:', 'teaching', 'nahuatl', 'issoire', 'ural', 'sologne', 'omaha', 'society', 'systems', 'developmental', 'cosmetics', 'helsinki', 'horse', 'france', 'vorarlberg', 'vatican', 'marrakesh-safi', 'oahu', 'running', 'franco-provençal', 'armenian', 'turkic', 'railway', 'work', 'traditional', 'mauriac', 'andorra', 'day', 'cook', 'mumbai', 'macroeconomics', 'wörthersee', 'prog', 'hyperborean', 'rabat', 'first', 'bagnères-de-bigorre', 'inuinnaqtun', 'mandal', 'jackson', 'silk', 'caretakers', 'valencia', 'indus', 'miami', 'judaism', 'brive-la-gaillarde', 'virginia', 'russia', 'teramo', 'massif', 'miyazaki', 'inuktitut', 'nature', 'southeast', 'molsheim', 'dating', 'plymouth', 'e-commerce:', 'tucuman', 'carpentry', 'mannheim', 'stralsund', 'intergenerational', 'radio-controlled', 'zoology', 'trade', 'guam', 'medicine:\xa0diabetes', 'coahuila', 'medicine', 'ancash', 'democratic', 'discographies', 'nouvelle-aquitaine', 'karst', 'retro', 'venezuela:', 'nottinghamshire', 'distributed', 'lagos', 'tahiti', 'bar', 'magic', 'atlantic', 'far-right', 'all', 'arachnids', 'reptiles', 'molecular', 'camping', 'jiangxi', 'nogent-sur-seine', 'rauma', 'bahrain', '1968', 'zurich', 'deathcare', 'niigata', 'valparaíso', 'tigris', 'nubia', 'achaea', 'sacramento', 'novara', 'verdun', 'unexplained', 'sandefjord', 'cincinnati', 'baleares', 'die', 'mysticism', 'surrey', 'gardening:', 'groningen', 'dunkirk', 'bouches-du-rhône', 'ireland', 'sao', 'optical', 'oloron-sainte-marie', 'dadra', 'karlskrona', 'interlake', 'behavioural', 'administrative', 'digne-les-bains', 'norrland', 'washington', 'vicenza', 'malaga:', 'catalonia', 'trusts', 'fasting', 'badminton', 'old', 'chartres', 'aconcagua', 'normandy:', 'feminism', 'biographical', 'bas-rhin', 'aix-en-provence', 'zanzibar', 'annapolis', 'jeollanam-do', 'nicaragua', 'wetlands', 'alençon', 'imaging', 'palestine', 'honam', 'brahui', 'woods', 'harare', 'minimalism', 'bodø', 'messina', 'cairo', 'slavery', 'mekong', 'engadine', 'rotterdam', 'quedlinburg', 'haida', 'sudoku', 'athabaskan', 'interfaith', 'jawahar', 'paderborn', '1946–1968', 'château-gontier', 'carnac', 'asheville', 'bogota', 'mughal', 'maine-et-loire', 'miracles', 'pays', 'india', 'dresden', 'savoy', 'australasia:', 'slang', 'yearbooks', 'mauritius', 'akita', 'denver', 'leipzig', 'macgillycuddy’s', 'homoeopathy', 'company', 'ushuaia', 'sylt', 'vinstra', 'sale', 'kolkata', 'kosovo', 'book', 'classical', 'sindh', 'shawinigan', 'oxfordshire', 'francophonie', 'albany', 'malay', 'arlberg', 'härnösand', 'privacy', 'quakers', 'taunus', 'mahalangur', 'iroquoian', 'australasia', 'bohuslän', 'manipur', 'basketball', 'aramaic', 'mechanical', 'uppsala', 'return', 'saint-jean-d’angély', 'sturm', 'teso', 'folk', 'decolonisation', '1772–1809', 'drøbak', 'tajikistan', 'mykonos', 'sino-tibetan', 'petroleum', 'suffolk', 'naskapi', 'cadiz', 'iran', 'origami', 'guyana', 'lot-et-garonne', '1989', 'midnight', 'ben', 'romance:', 'savanna', 'biography:', 'fermo', 'aalborg', 'kauai', '1880–1916', 'speed', 'institutions', 'government', 'baltimore', 'potsdam', 'pentecostal', 'giza', 'chitumbuka', 'havelland', 'right-of-centre', 'epirus', 'wu', '1660', 'emancipation', 'hungary:', '1569–1795', 'japan', 'mariehamn', 'amalfi', 'shetland', 'haguenau', 'data', 'tegernsee', 'yangtze', 'bronze', 'auvergne', 'earth', 'sarajevo', 'innlandet', 'asylum', 'surat', 'jamaica', 'baby', 'sources', 'williamsburg', 'rhine', 'kyoto', 'mariachi', 'amapa', 'swabian', 'psychiatry', 'tampa', 'chiloé', 'warsaw', 'belfast', 'jessheim', 'positive', 'gnosticism', 'rap', 'chromatography', 'heligoland', 'international', 'thessaloniki', 'rocky', 'thermochemistry', 'visigoth', 'pittsburgh', 'battery', 'amazon', 'residential', 'melun', 'rug', 'zambia', 'employment', 'laois', 'trnava', 'haute-saône', 'dundee', 'south-central', 'bar-le-duc', 'rhône', 'ismailia', 'phytochemistry', 'fractal', 'physical', 'pirkanmaa', 'ibero-america', 'macchiaioli', 'electoral', 'working', 'cornouaille', 'cantabrian', 'bhutan', 'suwalki', 'niue', 'fantasy', 'hochschwab', 'competition', 'pennine', 'greater', 'engineering', 'kuwait', 'humanist', 'caving', 'częstochowa', 'puzzles', 'client–server', 'granada', 'indo-iranian', 'canadian', 'bucharest', 'surface', 'enterprise', 'fürth', 'pittura', 'maine', 'education', 'shipping', 'fraud', 'veluwe', 'latin-american', 'swing', 'porsgrunn', 'fujian', 'artificial', 'jurisprudence', 'environment', 'busan', 'essaouira', 'heating', 'corse-du-sud', 'catamarca', 'pragmatism', 'zadar', 'credit', 'alonnisos', 'architecture', 'faroese', 'memoirs', 'slavonia', 'santiago', 'haifa', 'kinshasa', 'twelve', 'mingan', 'grenada', 'liguria', 'paraíba', 'croatian', '1861', 'charente', 'puebla', 'sligo', 'bauhaus', 'baja', 'tachism', 'madison', 'argentina', 'cambodian', 'belluno', 'tohoku', 'york', 'parenting:', 'kuyavian-pomeranian', 'infertility', 'faiyum', 'soviet', 'techniques', 'dordrecht', 'beskid', 'siswati', '1930–1943', 'burgenland', 'time', 'aargau', 'fibre', 'corinth', 'unified', 'casablanca', 'sarlat-la-canéda', 'national', 'imperia', '1943–1955', 'education:', 'almere', 'dakar', 'iowa', 'acadia', 'psychotherapy:', 'condensed', 'lubusz', 'cytology', 'ireland:', 'holi', 'mendoza', 'henan', 'management:', 'county', 'bellac', 'annecy', 'leeds', 'eastern', 'cagliari', 'győr', 'transformation', 'bournemouth', 'split', 'richmond', 'agen', 'nogent-sur-marne', 'spiritualism', 'pamplona', 'sucre', 'spyware', 'guingamp', 'davos', 'cie', 'nontron', 'tiber', 'life', 'nantucket', 'insects', 'šibenik', 'charleroi', 'armagnac', 'tasmanian', 'clermont', 'tlaxcala', 'apt', 'groene', 'devon', 'baghdad', 'psychic', '13th', 'seoul', 'second', 'portugal', 'northeast', 'podlasie', 'genoa', 'vannes', 'var', 'pieria', 'guerrero', 'reference', 'communication', 'picture', 'vendôme', 'hauts-de-seine', 'battlefield', 'indo-european', 'software', 'somme', 'saumur', 'coventry', 'catania', 'saint-omer', 'paintings', 'lons-le-saunier', 'op', 'naples', 'myths', 'niger', '1950–1953', 'belfort', 'news', 'vire-normandie', 'niagara', 'encyclopaedias', 'saint-flour', 'language:', 'pisa', 'oita', 'togo', 'sepedi', 'kythira', 'hebrew', 'banska', '1701–1796', 'aust-agder', 'vosges', 'basel-landschaft', 'kalmar', 'heraklion', 'quintana', 'stavanger', 'neural', 'fuzzy', 'advertising', 'diseases', 's-hertogenbosch', 'zealand', 'greece', 'maharashtra', 'sulawesi', 'trier', 'maryland', 'confucianism', 'hudson', 'fiction:', 'sikhism', 'thionville', 'bayonne', 'settlement', 'brevik', 'nuevo', 'cundinamarca', 'hesse', 'kalaallisut', 'pyrénées-orientales', 'isizulu', 'syracuse', 'oder', 'chinese', 'spirits', 'basel', 'nyköping', 'hydropower', 'material', 'photojournalism', 'åndalsnes', 'mosjøen', 'bengaluru', 'skiing', 'nelson', 'victorian', 'leinster', 'durham', 'val-d’oise', 'theoretical', 'soil', 'french-based', 'computer-aided', 'auvergne-rhône-alpes:', 'pamiers', 'addis', 'archaeology', 'wallonia', 'telemedicine', 'ophthalmology', 'chubu', 'goias', 'volgograd', 'krakow-częstochowa', 'terni', 'melaka', 'saitama', 'histopathology', 'ille-et-vilaine', 'earthquake', 'alabama', 'urology', 'battles', 'cobra', 'bourgogne-franche-comté', 'langesund', 'brescia', 'tianjin', 'mental', 'lozère', 'haarlem', 'thai', 'chiropractic', 'shipbuilding', 'navigation', 'dentistry', 'rügen', 'mainz', 'verona', 'connecticut', 'lutheran', 'bergisches', 'zuni', 'telangana', 'mozarabic', 'algonquin', 'yom', 'ruhr', 'ancona', 'keyboard', 'victoria', '1169', '1960', '1918', 'secession', 'charity', 'alternative', 'database', 'lecce', 'leather', 'pointe-à-pitre', '1796–1848', 'beers', 'aranese', 'bergstrasse', 'privatization', 'patmos', 'wjec', 'pilsen', 'consumer', 'weather', 'microeconomics', 'pilgrimage', 'wachau', 'television', 'scotland', '19th', 'grand-est', 'mesozoic', 'neuro', 'bulgaria', 'doctor', 'utah', 'mystras', 'palma', 'political', 'solothurn', 'kristiansand', 'nicosia', 'kampala', 'fly', 'fukui', 'loire', 'leicestershire', 'fukushima', 'olomouc', 'caucasian', 'peredvizhniki', 'crime', 'lexicography', 'loiret', 'semiotics', 'sperrin', 'villach', 'history', 'perth', 'val', 'kanto', 'meath', 'disruptive', 'north-central', 'corunna', 'computational', 'lower', 'creuse', 'kazakhstan', 'econometrics', 'translation', 'soft', '1940–1945', 'forcalquier', 'lesotho', 'podhale', 'corruption', 'dolomites', 'autobiography:', 'naval', 'law:', 'château-chinon', 'eleven', 'structuralism', 'niger-congo', 'smart', 'extremadura', 'ayurveda', 'archangel', 'bourbonnais', 'yerevan', 'roussillion', 'audio', 'zakopane', 'phuket', 'okinawa', 'delaware', 'pella', 'burgundian', 'béthune', 'westmeath', 'porto', 'asia-pacific', 'territoire', 'caucasus', 'halkomelem', 'state', 'île-de-france:', 'rothenburg', '1916–1922', 'yvelines', 'siksika', 'ganges', 'jaen', 'kristiansund', 'muret', 'esperanto', 'dogs', 'saint-claude', 'pluto', 'negligence', 'arbitration', 'matterhorn', 'honduras', '14th', 'luganda', 'mazatlan', 'limburgan', 'savonia', 'berliner', 'kenya', 'otta', 'independent', 'cartography', 'perpignan', 'huelva', 'laon', 'reflexology', 'baking', 'forlì-cesena', 'fosnavåg', 'judicial', 'lincoln', 'labrador', 'trondheim', 'leicester', 'philosophical', 'blekinge', 'altermodernism', 'teutoburg', 'sartène', 'hautes-alpes', 'jungfrau', 'yemen', 'mobile', 'lefkada', 'essen', 'soul', 'email:', 'quimper', 'anarchism', 'gard', 'benevento', 'largentière', 'level', 'georgia', 'castile', 'kentucky', 'theosophy', 'organizational', 'polymer', 'robotics', 'renal', 'forez', 'dreux', 'elbe', 'steinkjer', 'pernambuco', 'kos', 'meuse', 'po', 'isixhosa', 'orkanger', 'balearic', 'population', 'luxembourg', 'rhode', 'friesland', 'speech', 'potosi', 'liestal', 'naxos', 'papua', 'valdivia', 'secondary', '16th', 'kilimanjaro', 'marathon', 'eindhoven', 'rajasthani', 'later', 'synthetic', 'novella', 'contract', 'heilbronn', 'tamaulipas', 'diaries', 'brignoles', 'pyrénées-atlantiques', 'angoulême', 'conservation', 'røros', 'malta', 'it', 'canavese', 'smolensk', 'rio', 'australia', 'langres', 'abruzzo', 'tournon-sur-rhône', 'misiones', 'larvik', 'gaza', 'hereditary', 'middle', 'mid-autumn', 'barcelona', 'lapland', 'troyes', 'udine', 'rhythm', 'particle', 'klagenfurt', 'revolutionary', 'longford', 'montdidier', 'neurosciences', 'cusco', 'asteroids', 'restitution', 'historical', 'gaelic', 'literary', 'assembly', 'vysocina', 'involuntary', 'vienne', 'pathology', 'thonon-les-bains', 'matruh', 'messenia', 'humour', 'chiyao', 'redon', 'hainaut', 'drenthe', 'askim', 'gauteng', 'kingston', 'violin', 'clamecy', 'grid', 'father’s', 'sound', 'distribution', 'moon', 'card', 'romanticism', 'container', 'mende', 'umeå', 'monterey', 'cardiothoracic', 'garden', 'biochemical', 'kirkenes', 'menorca', 'statistical', 'divination', 'marshall', 'far-left', 'rabat-salé-kenitra', 'bulgarian', 'gyeongsangnam-do', 'åland', 'sub-saharan', 'cuyo', 'concepción', 'child', 'alessandria', 'aubrac', 'javanese', 'aegina', 'saint-girons', 'diving', 'tragic', 'north', 'bologna', 'kannada', 'baroque', 'milos', 'warfare', 'cognition', 'underwater', 'wakashan', 'ciudad', 'outer', 'samothrace', 'c', 'commonwealth', 'thematic', 'otago', 'loches', 'monferrat', 'british', 'pageants', 'sentencing', 'yamanashi', 'academic', 'les', 'south', 'enschede', 'feldkirch', 'rovigo', 'algonquian', 'philadelphia', 'colombia', 'certification', 'icibemba', 'nosql', 'sélestat', 'abnormal', 'turkey:', 'périgueux', 'sumer', 'indie', 'springfield', 'biofuels', 'marche', 'christianity:', 'non-graphic', 'molluscs', 'hindi', 'optimization', 'idealism', 'petrology', 'employee-ownership', 'guipuzcoa', 'mongolia', 'endangered', 'extreme', 'east', 'orne', 'sanskrit', 'collected', 'secretarial', 'seinäjoki', 'mycology', 'pain', 'board', 'péronne', 'databases', 'materno-foetal', 'connaught', 'karlstad', 'aswan', 'podgorica', 'louth', 'apulia', 'mongolian', 'corporate', 'aspen', 'camargue', 'semmering', 'manchester', 'lyric', 'violent', 'household', 'hauts-de-france:', 'turkmen', 'sami', 'hull', 'bernay', 'nunavik', 'lace', 'medicolegal', 'plumbing', 'sex', 'fontainebleau', 'gers', 'cosmetic', 'altmühltal', 'music', 'sustainability', 'salzkammergut', 'białystok', 'żuławy', 'turkey', 'quito', 'algebraic', 'treviso', 'satirical', 'berlin', 'telephone', 'faith', 'evolutionary', 'roman', 'capoeira', 'limoges', 'stord', 'lanzarote', 'monte', 'friulian', 'archean', 'queen', 'sinai', 'criticism', 'greek', 'disability', 'ccea', 'k2', 'coping', 'vegetarian', 'bolivia', 'cardiovascular', 'dogrib', 'vestland', 'brecon', 'bodybuilding', 'forensic', 'narbonne', 'lofoten', 'tamil', 'agency', 'kerala', 'como', 'holocaust', 'switzerland:', 'ascension', 'mesquakie-sauk-kickapoo', 'protestantism', 'physics:', 'lgbtq+', 'linköping', 'aqa', 'occult', 'alta', 'orense', 'groups', 'gdańsk', 'tenerife', 'colón', 'living', 'hanover', 'dachstein', '1534–1763', 'progressive', 'senlis', 'bremerhaven', 'sesotho', 'arbeitsrat', 'defamation', 'munster', 'rhodes', 'oristano', 'cardiff', 'racism', 'intermediate', 'chachapoyas', 'communications', 'cross-country', 'sardinia', 'uppland', 'côte', 'self-help', 'shamanism', 'nitra', 'kinki', '1926–1989', 'queretaro', 'bankruptcy', 'tarn', 'cornwall', 'ostwestfalen-lippe', 'writing', 'kamouraska', 'electronics:', 'manners:', 'trigonometry', 'souss-massa', 'divisionism', 'moravian-silesian', 'bletchley', 'vouziers', 'guangdong', 'ixtapa-zihuatanejo', 'handball', 'brunei', 'odda', 'lifestyle', 'bobigny', 'perche', 'geothermal', 'mysen', 'skopje', 'millau', 'mathematics', 'reford', '7th', 'prehistoric', 'lacrosse', 'gauchoesque', 'complex', 'restoration', 'azores', 'stonehenge', 'creative', 'algorithms', 'vesoul', 'toyama', 'sledding', '5th', 'marne', 'bayreuth', 'soria', 'minya', 'set', 'space', 'hurling', 'ordnance', 'vogtland', 'hamar', 'office', 'silesian', 'lisboa', 'alexandria', 'reiki', 'sortland', 'gangwon-do', 'wildlife:', 'inari', 'archaeological', 'polynesia', 'bratislava', 'solomon', 'mars', 'kabul', 'cyclades', 'scientific', 'mohawk', 'tai', 'asturian', 'dortmund', 'true', 'assertiveness', 'ships:', 'villefranche-sur-saône', 'cher', 'loch', 'games', 'organic', 'hadith', 'viken', 'aromatherapy', 'saintes', 'newfoundland:', 'judo', 'moelv', 'malaga', 'lusaka', 'pomeranian', 'aletsch', 'dragon', 'indian', 'retail', 'eswatini', 'alicante', 'plastic', 'drag', 'tornedalen', 'himalayas', 'lyon', 'dagbani', 'kendo', 'ravenna', 'pistoia', 'venice', 'nice', 'graphic', 'germany', 'darmstadt', 'vehicle', 'torcy', 'tampere', 'photo', 'arequipa', 'ocr', 'lüneburg', 'aspect', 'turkish', 'motorcycles:', 'third', 'évreux', 'clermont-ferrand', 'interrelated', 'eritrea', 'spain', 'hérault', 'collecting', 'toulon', 'skiathos', 'fire', 'sardinian', 'breisgau', 'hydrology', 'cariban', 'southampton', '1899–1917', 'theravada', 'biebrza', 'kiikaonde', 'individual', 'brandenburg', 'scuba', 'transplant', 'krkonoše', 'designs', 'pavia', 'biella', 'hobbies', 'zeeland', 'job', 'tripolitania', 'roztocze', 'hautes-pyrénées', 'indo-pacific', 'chilomwe', 'drakensberg', 'seine-et-marne', 'archery', 'automatic', 'lugo', 'indonesian', 'anglican', 'slovakia:', 'danube–tisza', 'cleveland', 'potawatomi', 'naturalism', 'chiemsee', 'oklahoma', 'integral', 'media', 'asean', 'avesnes-sur-helpe', 'vervins', 'consultancy', 'topology', 'irregular', 'der', 'accessibility', 'wap', 'coutances', 'syria', 'ain', 'sarrebourg', 'spain:', 'forestry', 'ships', 'critical', 'galway', 'oslofjorden', 'antarctica', 'gävle', 'leiden', 'number', 'haute-savoie', 'indre-et-loire', 'öland', 'istria', 'laser', 'virtual', 'auvergne-rhône-alpes', 'lappi', 'quebec', 'serengeti', 'climatic', 'romani', 'cushitic', 'religious', 'neonatal', 'chartered', 'weddings', 'drammen', 'peniny', 'midlands:', '1940–1949', 'bay', 'mid-century', 'graphics', 'belgium', 'austin', 'franconia', 'rothaar', 'lodi', 'recife', 'allotments', 'saint-émilion', 'scanning', 'grisons', 'choral', 'tokyo', 'vilnius', 'islam:', 'cinque', 'crosswords', 'umbria', 'sicily', 'mata-utu', 'snorkelling', 'harstad', 'rondônia', 'mecklenburg', 'eid', 'surrealism', 'oceans', 'durango', 'cookery:', 'delphi', '1861–1877', 'chiemgau', 'espace', 'guangxi', 'analytical', 'gharbia', 'garfagnana', 'humanistic', 'thann', 'semantics', 'ice', 'programming', 'mombasa', 'sahel', 'sancerre', 'capri', 'gravity', 'privas', 'cochabamba', 'network', 'gilbert', 'radiotherapy', 'reproductive', 'ladin', 'agribusiness', 'pécs', 'sydney', 'pharmacy', 'dubrovnik', 'trinidad', 'deux-sèvres', 'thanksgiving', 'bregenz', 'industrialisation', 'man-made', 'microsoft', 'tarn-et-garonne', 'dark', 'netherlands', 'london', 'sondrio', 'sporting', 'heidelberg', 'oruro', 'sopron', 'andaman', 'massachusetts', 'rhaeto-romance', 'zug', 'colombia:', 'autism', 'botany', 'spirit', 'biochemistry', 'photographic', 'remedial', 'beauvais', 'telemark', 'geological', 'marshallese', 'marine', 'masovian', 'hittite', 'tangier', 'abu', 'shanxi', 'nyoro-ganda', 'health', 'ntlakyapamuk', 'carnival', 'atlanta', 'flores', 'tambopata', 'criminal', 'jyväskylä', 'tripura', 'carving', 'crimea', 'pongau', 'condom', 'agadir', 'puerto', 'brazzaville', 'tuvalu', 'oto-manguean', 'infectious', 'romania:', 'theatre:', 'mozambique', 'colima', 'cotswolds', 'cheyenne', 'föhr', 'chinon', 'moravia', 'virgin', 'mexico:', 'serbia', 'practical', 'madrid', 'artois', 'industry', 'literature:', 'palliative', 'manx', 'spatialism', 'photography', 'åkrehamn', 'accounting:', 'vardø', 'interior', 'novgorod', 'china', 'marketing', 'video', 'technology:', 'albania', 'color', 'fairy', 'hobart', 'bohemia', 'brooklyn', 'occitan', 'northamptonshire', 'prairies', 'paramaribo', 'pensions', 'science:', 'personality', 'créteil', 'mauritania', 'viking', 'rennes-le-château', 'brekstad', 'montreuil', 'vestfold', 'careers', 'oxford', 'huesca', 'hospitality', 'rehabilitation', 'houston', 'ju-jitsu', 'cost', 'nunavut:', 'offenders', 'worship', 'missolonghi', 'cosne-cours-sur-loire', 'mâcon', 'jutland', 'malaysia', 'nicaragua:', 'holocene', 'uruguay', 'danube', 'hunan', 'southern', 'jacksonville', 'akershus', 'latin', 'english', 'zambesi', 'tasmania', 'nairobi', 'rugby', 'psychotherapy', 'portraits', 'illustration', 'painting', 'chuquisaca', 'ascona', 'pre-clinical', 'textiles', 'jugendstil', 'edexcel', 'blackpool', 'livorno', 'sudetes', '1185–1333', 'precious', 'construction', 'yellow', 'laval', 'arendal', 'calculus', 'braunschweig', 'crete', 'mali', 'minneapolis-st.', 'rural', 'fossil', 'assemblage', 'partnership', 'supercomputers', 'burgos', 'avannaata', 'beijing', 'sumatra', 'faroe', 'shopping', 'intensive', 'menopause', 'horten', 'police', 'corte', 'indiana', 'caspian', 'technology', 'digital', 'waste', 'wessex', 'raleigh', 'oregon', 'james', 'lent', 'hildesheim', 'kaliningrad', 'symbolist', 'fougères', 'comfort', 'equestrian', 'percussion', 'service', 'glaciers', 'azerbaijan', 'kilkenny', '1933–1945', 'harvest', 'masorti', 'americas', 'groupings', 'goa', 'roanne', 'turkmenistan', 'sarawak', 'newark', 'monochrome', 'uluru', 'wines', 'damascus', 'namibia', 'parliamentary', 'shannon', 'melilla', '1789–1791', 'lk20s', 'country', 'fens', 'landlord', 'classic', 'lunéville', 'cavan', 'lucerne', 'kotka', 'sweden', 'chalcis', 'european', 'microwave', 'de', 'hairdressing', 'electrician', 'england', 'montbrison', 'styria', 'hokkien', 'salt', 'saint-benoît', 'rosh', 'role-playing', 'sumo', 'specialised', 'lucca', 'providence', 'dry', 'apparel', 'licensing', 'doubs', 'gastrointestinal', 'issoudun', 'neptune', 'personal', 'florø', 'tripoli', 'malmö', 'tierra', 'juvenile', 'decision', 'northeastern', 'biomedical', 'firewalls', 'reims', 'persian', 'urdu', 'engagement', 'saxony-anhalt', 'jørpeland', 'hokkaido', 'arabic', 'ga', 'sri', 'belgrade', 'vadsø', 'lahti', 'boeotia', 'bavarian', 'chios', 'left-of-centre', 'mainframes', 'korean', 'luxor', 'montargis', 'bmx', '1947–1989', 'germany:', 'poultry', 'kazakh', 'wexford', 'haute-normandie', 'asia', 'céret', 'holidays', 'occupational', 'rheingau', 'berchtesgaden', 'nashville', 'saga', 'beaujolais', 'uganda', 'austro-hungarian', 'oromo', 'canterbury', 'diets', 'finistère', 'mahon', 'outdoor', 'boating:', 'pontivy', 'hot', 'dallas', 'svalbard', 'michoacán', 'yugoslavia', 'needlework', 'epistolary', 'foggia', 'culebra', 'bergamo', 'offences', 'aichi', 'circular', 'sarreguemines', 'table', 'organized', 'numerical', 'boreal', 'genetic', 'geochemistry', 'amiens', 'netherlands:', 'murray-darling', 'slovenian', 'zend', 'blues', 'nursing', 'rodrigues', 'hallowe’en', 'bamboo', 'rating', 'fitness', 'apple', 'graphology', 'chinyanja', 'winter', 'fula', 'spanish-based', 'tirana', 'swiss', 'west', 'obesity:', 'women’s', 'separation', 'sarcelles', 'flood', 'wiltshire', 'parthenay', 'taos', 'panama', 'kiribati', 'impressionism', 'guatemala:', 'aberdeen', 'clairvoyance', 'regional', '1845', 'veterinary', 'ethical', 'espoo', 'architectural', 'roofing', 'alphen', 'åsgårdstrand', 'samba', 'pori', 'barletta', 'ecuador:', 'central', 'technical', 'orienteering', 'traunviertel', 'indigenous', 'saône-et-loire', 'feng', 'greenwich', 'pre-calculus', 'sermons', 'thames', 'valencian', '2d', 'ångermanland', 'chungcheongbuk-do', 'ashanti', 'pre-secondary', 'arcachon', 'morbihan', 'boise', 'hong', 'châteaulin', 'svolvær', 'way', 'iwate', 'saint-pierre', 'edm', 'algebra', 'essonne', 'vascular', 'labour', 'cork', 'mortuary', 'tristan', 'purism', '1922–1923', 'stationery', 'caserta', 'qalyubia', 'business', 'art', 'transport', 'fuerteventura', 'milan', 'cremona', 'geography', 'eger', 'collaboration', 'libourne', 'bruck', 'eisenach', 'nepali', '1566–1648', 'mother’s', 'herbal', 'haute-marne', 'confolens', 'elverum', 'bangladesh', 'amazonas', 'guadeloupe', 'examination', 'combinatorics', 'limerick', 'medelpad', 'avila', 'rostock', 'phonetics', 'brussels', 'biscay', 'kwazulu-natal', 'intellectual', 'manga', 'labrador:', 'sergipe', '710', 'essex', 'civics', 'research', 'europe', 'friuli', 'lisieux', 'english-based', 'tennengau', 'stirling', '1976–1983', 'foreign', 'staffordshire', 'nagasaki', 'maputo', '1903–1968', 'kazimierz', 'gifu', 'advice', 'lemnos', 'currency', 'kutenai', 'bioethics', 'moldova', 'ostrobothnia', 'amharic', 'sumerian', 'xitsonga', 'padua', 'kigali', 'debrecen', 'prague', 'ko', 'quotations', 'hälsingland', 'bydgoszcz', 'tavoliere', 'men’s', 'berber', 'militaria', 'schwyz', 'community', 'memory', 'raufoss', 'tonga', 'bluegrass', 'amritsar', 'africa', 'haemodialysis', 'worcestershire', 'derby', 'children’s:', 'wakayama', 'illinois', 'görlitz', 'aztec', 'tabasco', 'peak', 'stratigraphy', 'postcolonial', 'galicia', 'red', 'pollution', 'rhinn', 'jena', 'rabbits', 'yellowstone', 'nanosciences', 'nuoro', 'kurdish', 'ålesund', 'acting', 'outsider', 'cigars', 'châtellerault', 'beni', 'afrihili', 'midlands', 'aomori', 'killarney', 'sun', 'seychelles', 'feast', 'riding', 'grampians', 'arts:', 'biomechanics', 'american', 'hawaii', 'vitoria', 'calvados', 'audiology', 'fabric', 'medina', 'northwestern', '1830–1831', 'materials', 'esbjerg', 'yamagata', 'falklands', 'coming', 'ramadan', 'tropics', '711–1492', 'snowboarding', 'meaux', 'bonaire', 'qeqqata', 'lahore', 'hampshire', 'wisconsin', 'dialect', 'secondary-after-secondary', 'expert', 'argenteuil', 'whitby', 'westerwald', 'agra', 'discrete', 'non-governmental', 'sewing', 'scottish', 'dauphiné', 'ceramics', 'windsor', 'fado', 'cairngorms', 'vienna', 'sør-trøndelag', 'inner', 'västerbotten', 'plauen', 'waterford', 'isernia', 'austria', 'cakes', 'metabolism', 'limburg', 'bremen', 'rostov-on-don', 'capitalism', 'xinjiang', 'documentary', 'bebop', 'gastroenterology', 'pottery', 'gallura', 'mexico', 'taxidermy', 'experimental', 'bilingual', 'chakras', 'broadleaf', 'paediatric', 'nantes', 'czechoslovakia', 'icaae', 'meteorology', 'satanism', 'hedmark', 'ghana', 'military', 'punjab', 'mythical', 'cambridgeshire', 'gift', 'active', 'parapsychological', 'crystals', 'locarno', 'caceres', 'forests', 'biosensors', 'patras', 'sled', 'stoke-on-trent', 'gujarat', 'surfing', 'sharjah', 'purchasing', 'finland', 'vierzon', 'dubai', 'tanzania', 'biskupiec', 'congenital', 'châteaubriant', 'market', 'handicrafts', 'zen', 'neuquén', 'haematology', 'cloud', 'odisha', 'ligurian', 'arte', 'decorative', 'sinaloa', '1923–1930', 'østfold', 'behaviourism', 'gjøvik', 'kanagawa', 'halmstad', 'terrorism', 'estonia', 'instruments', 'care', 'southland', 'papuan', 'venezuela', 'ottoman', 'plant', 'coral', 'hejaz', 'nuisance', 'frisian', 'nijmegen', 'cordoba', 'castelsarrasin', 'alsace', 'causses', 'vibo', 'palau', 'methodist', 'jämtland', 'tel-aviv', 'assam', 'hygiene', 'yunnan', 'darwin', 'oceanic', 'zagreb', 'djibouti', 'riga', 'kyiv', 'leeward', 'judeo-spanish', 'gospel', 'pau', 'yorkshire', 'aspects', 'nordic', 'banking', 'environmentally-friendly', 'tourism', 'boxing', 'exercise', 'hinduism', 'election', 'flower', 'mosi-oa-tunya', 'segovia', 'quechuan', 'sogn', 'basque', 'lima', 'constitution', 'hydroponics', 'weight', 'tunisia', 'nazca', 'kikuyu', 'wuppertal', 'hidalgo', 'funchal', 'paraná-río', 'mayo', 'accra', 'volleyball', 'urban', 'giving', 'västergötland', 'sotho-tswana', 'paper', 'rodez', 'hunting', '12th', 'seine-maritime', 'ussel', 'aid', 'play-based', 'gardens', 'salisbury', 'arkansas', 'squamish', 'ishikawa', 'sleep', 'skolt', 'seine-saint-denis', 'multinationals', 'antique', 'mesoscopic', 'knitting', 'puy-de-dôme', 'languedoc', 'leoben', 'norse', 'florac', 'tilburg', 'parasport', 'comedic', 'dieppe', 'tvedestrand', 'chiapas', 'venus', 'environmental', 'santa', 'cookery', 'syros', 'rayonism', 'saint-malo', 'dinan', 'dokdo', 'castres', 'linear', 'saint-gotthard', 'herefordshire', 'bautzen', 'tarot', 'maluku', 'kuopio', 'flamenco', 'trencin', 'vah', 'nuuk', 'goes', 'b-stream', 'thiers', 'judaism:', 'countryside', '1772–1795', 'bayesian', 'snowdonia', 'buffalo', 'sauda', 'salishan', 'funding', 'euclidean', 'psycholinguistics', 'reykjavík', 'speeches', 'globalization', 'saint-étienne', 'trøndelag', 'charleston', 'kagoshima', 'quick', 'learning', 'lao', 'villefranche-de-rouergue', 'intelligent', 'wicklow', 'hypnotherapy', 'flekkefjord', 'jazz', 'palmistry', 'cumbria', 'mannerism', 'swedish', 'neorealism', 'gaulish', 'nonlinear', 'darjeeling', 'foix', 'salzburg', 'logroño', 'wiesbaden', 'taxation', 'cuba:', 'l’aquila', 'arms', 'swabia', 'theology', 'kyrgyzstan', 'burkina', 'wellington', 'gibraltar', 'newgrange', 'austronesian', 'antony', 'vitry-le-françois', 'immunology', 'conspiracy', 'nérac', 'gloucestershire', 'mid', 'uzbek', 'maremma', 'linguistics', 'östergötland', 'library', 'aarau', 'mont-de-marsan', 'versilia', 'saarland', 'terminal', 'orange', 'gabon', 'graz', 'plock', 'complementary', 'chambéry', 'sensory', 'radar', 'innviertel', 'conifers', 'norte', 'birds', 'chhattisgarh', 'ewe', 'xenobiotics', 'netball', 'florence', 'thesauri', 'frosinone', 'pre-raphaelite', 'oji-cree', 'khartoum', 'chilterns', 'los', 'electrical', 'saxon', 'computer', 'teachers’', 'mind', 'laws', 'porvoo', 'astronomical', 'venlo', 'sámi', 'bergen', 'lesbos', 'magdeburg', 'freiburg', 'cuneo', 'malagasy', 'field', 'style', 'västerås', 'baseball', 'saint-laurent-du-maroni', 'chechen', 'tundra', 'seattle', 'bayeux', 'växjö', 'mount', 'chichen', 'nordland', 'bowls', 'grenoble', 'conakry', 'greenhouse', 'anaesthetics', 'nottingham', 'atmospheric', 'transtisza', 'ghent', 'manga:', 'nueva', 'small-scale', 'horses', 'gap', 'abstract', 'miyagi', 'svelvik', 'ascoli', 'california', 'somali', 'taranto', 'plays', 'egypt:', 'nevers', 'speyer', 'caltanissetta', 'personnel', 'mahayana', 'burgundy', 'saint-gaudens', 'konstanz', 'ayutthaya', 'anatomy', 'monza', 'taiwan', 'sea', 'extra-curricular', 'pressure', 'soissons', 'ambulance', 'cantal', 'berchtesgadener', 'neurology', 'charlotte', 'qena', 'montbéliard', 'macedonia', 'nara', 'minas', '3rd', 'embroidery', 'aiding', 'addiction', 'tyrone', 'boulogne-billancourt', 'borneo', 'geopolitics', 'fribourg', 'brutalism', 'hoboken', 'geophysics', 'property', 'radiography', 'karachi', 'heilongjiang', 'jersey', 'qigong', 'vernacular', 'tagalog', 'cold', 'model-making', 'balochistan', 'object-oriented', 'durban', 'apachean', 'huaraz', 'anglo-saxon', 'winterthur', 'injunctions', 'district', 'neo-classicism', 'olympic', 'interdisciplinary', 'catalysis', 'salerno', 'székesfehérvár', 'smallholdings', 'maritime', 'psychology', 'rock', 'industrial', 'lorraine', 'zamora', 'bibles', 'rimini', 'puducherry', 'texas', 'lens', '1821–1903', 'expeditions:', '21st', 'nouméa', 'gironde', 'special', 'chemical', 'nayarit', 'säntis', 'mycenae', 'jewellery', 'salamanca', 'slovenia', 'hertfordshire', 'shikoku', 'chicago', 'cherokee', 'orthotics', 'louisville', 'myanmar', 'birth', 'dominican', 'serbian', 'epidemiology', 'jujuy', 'gujarati', 'calvinist', 'dordogne', 'gansu', '1916–1930', 'arunachal', 'kalahari', 'neuroimaging', 'nova', 'pentecost', 'atalanti', 'chaco', 'surveying', 'bullfighting', 'madagascar', 'integrated', 'boulogne', 'yucatan', 'ball', 'diplomas', 'ojibwe\xa0', 'kerry', 'glarus', 'sporades', 'sqa', 'entrepreneurship', 'neurosurgery', 'montmorillon', 'bali', 'drug', 'appenzell', 'chennai', 'bernese', 'usedom', 'macedonian', '1975', 'weser', 'juneau', 'vltava', 'hard', 'parque', 'leknes', 'maranhão', 'armed', 'bce', 'nuclear', 'haut-rhin', 'auxerre', 'abbeville', 'albertville', 'somerset', 'montbard', 'ce', 'genealogy', 'screenwriting', 'advent', 'algiers', 'anchorage', 'skyros', 'uralic', 'management', 'brazil:', 'electricity', 'climbing', 'adventure', 'füssen', 'pinzgau', 'dynamics', 'geology', 'windows', 'montauban', 'hawke‘s', 'interpersonal', '1917–1923', 'chalon-sur-saône', 'regency', 'perugia', 'grimstad', 'måløy', 'fiction', 'metals', 'surgery', 'corinthia', 'francisco', 'patagonia', 'non-combatants', 'snooker', 'dutch', 'dalarna', 'førde', 'mi’kmaq', 'medicinal', 'dessau', 'vaasa', 'rovaniemi', 'ibiza', 'arno', 'koblenz', 'lakshadweep', 'angola', 'karen', 'leitrim', 'yosemite', 'reading', 'migration', 'occitanie:', 'spirituality', 'setswana', 'electrophysiology', 'museology', 'payroll', 'golf', 'game', 'kyushu', 'belize', 'norwegian', 'guanajuato', 'melanesia', 'potenza', 'agrichemicals', 'northern', 'cozumel', '2019', 'equatorial', 'petra', 'irpinia', 'nurse', 'volcanology', 'ouarzazate', 'moral', 'pontoise', 'istanbul', 'balinese', 'astronomy', 'arras', '1814–1830', 'anguilla', 'body', 'playa', 'regulatory', 'lillesand', 'greifswald', 'colmar', 'squash', 'tremiti', 'bosnian', 'bruges', 'mons', 'lacanian', 'styles', 'christian', 'lindau', 'still', 'mutiny', 'thriller', 'abdominal', 'cognitivism', 'luberon', 'shawnee', 'situationist', 'photography:', 'vorticism', 'päijät-häme', 'sedan', '15th', '1900–1914', '1808–1813', 'sustainable', 'châlons-en-champagne', 'devotional', 'probation', 'asturias', 'hyogo', 'pennsylvania', 'crochet', 'silozi', 'trains', 'planned', 'athletics', 'limnology', 'trees', 'värmland', 'chugoku', 'middlesbrough', 'coastlines', 'chile:', 'uto-aztecan', '1837–1901', 'asante', 'drâa-tafilalet', 'gatineau', 'arid', 'carcassonne', 'joint', 'meghalaya', 'florida', 'würzburg', 'fisheries', 'oldenburg', 'emergency', 'hønefoss', 'gangwon', 'châteaudun', 'penology', 'asia:', 'wendish', 'solid', 'monaghan', 'reggae', 'islam', 'solingen', '1714–1837', 'outsourcing', 'constructivism', 'burns', 'assen', 'pescara', 'tromsø', 'segré', 'sofia', 'thailand', 'casablanca-settat', 'manitoba', 'sololá', 'riviera', 'northumberland', 'korea', 'ussr', 'commercial', 'agile', 'wavre', 'krabi', 'fez', '1940–1951', 'appalachian', 'reportage', 'besançon', 'napa', 'non-euclidean', 'embedded', 'agder', 'paris', 'ergonomics', 'nyankore', 'physics', 'copenhagen', 'gozo', 'prostate', 'morocco', 'ehime', 'azerbaijani', 'fermanagh', 'hausruckviertel', 'boats', 'aosta', 'philosophy', 'satellite', 'highway', 'briançon', 'zhejiang', 'humorous', '1926–1945', 'charleville-mézières', 'macerata', 'biogeography', 'tarragona', 'quality', 'palauan', 'quaternary', 'zielona', 'performing', 'palaeontology', 'dog', 'music:', 'probability', 'buckinghamshire', 'survivalism', 'lisbon', 'phrenology', 'iberian', 'eclectic', 'georgetown', 'siberia:', 'windward', 'cameroon', 'chitonga', 'épernay', 'maldivian', 'orléans', 'nunavut', 'wallis', 'violence', 'saramaccan', 'mortagne-au-perche', 'hordaland', 'hellenic', 'racket', 'pleistocene', '10th', 'inventions', 'samos', 'france:', 'newcastle', 'odenwald', 'automotive', 'polar', 'kopervik', '1809–1917', 'argos', 'martha’s', 'nantua', 'sranan', 'latvia', 'test', 'liverpool', 'russian', 'geographical', 'mostviertel', 'chungcheongnam-do', 'bonneville', 'greenland', 'biodiversity', 'brazilian', 'dictionaries', 'euboea', 'skien', 'takeovers', 'inca', 'austria:', 'basilicata', 'nepal', 'war', 'manila', 'monaco', 'offaly', 'pacific', '1559–1714', 'cottbus', 'lille', 'chandigarh', 'machu', 'sharqia', 'economics', 'miscellanies', 'gévaudan', 'catanzaro', 'funen', 'albanian', 'wismar', 'jury', 'kielce', 'tocantins', 'hepatology', 'midi-pyrénées', 'lerida', 'parties', 'stochastics', 'transdanubia', 'innsbruck', 'toggenburg', 'compilers', 'kirghiz', 'saskatchewan', 'fuels', 'kursk', 'sonora', 'differential', 'drought', 'gobi', 'algarve', 'thule', 'minnesota', 'baku', 'bangkok', 'chaos', 'pop', 'zimbabwe', 'weinviertel', 'arab', 'tupian', 'naive', 'trauma', 'qatar', 'jalisco', 'poster', 'politics', 'gyeonggi-do', 'troms', 'oceanography', 'hradec', 'libya', 'comoros', 'switzerland', 'portland', 'contains', 'christianity', 'montluçon', 'federated', 'inupiaq', 'napoleonic', 'manhattan', 'chemnitz', 'thebes', 'formosan', 'development', 'lithuania', 'abstractism', 'ariège', 'tuscany', 'tegucigalpa', 'estonian', 'phnom', 'ibaraki', 'grosseto', 'monetary', 'calabria', 'cantonese', 'local', '1297–1305', 'jilin', 'southwest', 'ausserfern', 'pre-school', 'greenhouses', 'leon', 'baltic', 'espionage', 'romance', 'darts', '.net', 'marlborough', 'rococo', 'pattern', 'kalimantan', 'compiègne', 'raratonga', 'nauru', '1931–1936', 'walking', 'mo', 'hungarian', 'liaoning', 'astronautics', 'sichuan', 'sounds', 'buddhist', 'interviews', 'ufos', 'niort', 'turin', 'eiger', 'product', 'thuringia', 'rhenish', 'portuguese-based', 'revision', 'kabbalah:', 'aurillac', 'suez', 'elis', 'córdoba', 'blasphemy', 'montafon', 'bressuire', 'valence', 'jupiter', 'paxos', 'motor', 'draguignan', 'dodecanese', 'prayers', 'odense', 'bielefeld', 'aviation', 'gästrikland', 'malecite-passamaquoddy', 'duala', 'chamonix', 'haute-corse', 'car', 'sarthe', 'armenia', 'process', 'stokmarknes', 'may', 'wallonian', 'na-dene', 'asti', 'applied', 'biology', 'rhône-alpes', 'norway', 'lazio', 'centrist', 'columbus', 'albuquerque', 'tatra', 'aikido', 'republic', 'tokelauan', 'curaçao', 'flowering', 'sexual', 'jeollabuk-do', 'diplomacy', 'lake', 'engineering:', 'karlsruhe', 'stjørdal', 'confirmation', 'italian', 'brie', 'tochigi', 'cornish', 'tulsa', 'victimology', 'fresno', 'pre-primary', 'quercy', 'vercelli', 'carpentras', 'cuba', 'loire-atlantique', 'distrito', 'loir-et-cher', 'san', 'indoor', 'corsica', 'gourdon', 'boatbuilding', 'aude', 'cats', 'touraine', 'fort-de-france', 'nuxalk', 'apiculture', 'tulle', 'solar', 'maori', 'oral', '1968–1989', 'egadi', 'animals', 'comic', 'spectrum', 'down', 'baden-württemberg', 'sannio', 'zion', 'mérida', 'telugu', 'sikkim', 'aymara', 'lascaux', 'denali', 'student', 'vaud', 'teacher', 'operating', 'celtic', 'salvador', 'tours', '1871–1914', 'honningsvåg', '18th', 'rieti', 'poverty', 'alpine', 'welfare', 'bicycles', 'fehmarn', 'centro', 'potomac', 'buddhism:', 'aquaculture', 'puppetry', 'transylvania', 'shanghai', 'astrophysics', 'périgord', 'russia:', 'cholet', 'norfolk', 'antioquia', 'uttarakhand', 'sedimentology', 'duisburg', 'moselle', 'brisbane', 'masai', 'precision', 'aisne', 'anatolia', 'berry', 'equine', 'shimane', 'peru:', 'place', 'occitanie', 'ural-altaic', 'phocis', 'fredrikstad', 'ammersee', 'lappeenranta', 'strasbourg', 'blaye', 'chile', 'dar', 'barbizon', 'baha’i', 'copan', 'buskerud', 'motorcycle', 'sintra', 'sociology:', 'roadcraft', 'self-sufficiency', 'kashmiri', 'mourne', 'stavern', 'franchises', 'sarpsborg', 'auditing', 'sensors', 'psychosomatics', 'val-de-briey', 'bloomsbury', 'computing', 'oise', 'moulins', 'häme', 'diversity', 'saint-quentin', 'ulsteinvik', 'donegal', 'akwapim', 'varese', 'lika-karlovac', 'basse-normandie', 'fagernes', 'hydrogen', 'paros', 'saint-paul', 'dax', 'kafr', 'palaiseau', 'pardubice', 'yoruba', 'ukraine', 'hunsrück', 'analytic', 'nord-pas-de-calais', 'tongan', 'molde', 'zoos', 'esoteric', 'travel', 'gene', 'image', 'association', 'fortune-telling', 'farm', 'småland', 'moscow', 'azuay', 'flachgau', 'île-de-france', 'parma', 'gender', 'tbilisi', 'paraguay', 'provence', 'halberstadt', 'zwickau', 'vietnam', 'microbiology', 'mindfulness', 'saint-julien-en-genevois', 'manawatu-whanganui', 'albi', 'world', 'wind', 'transport:', 'nuremburg', 'châteauroux', 'gorizia', 'carpathian', 'knowledge', 'guizhou', 'daegu', 'shintoism', 'slavey', 'epic', 'ownership', 'samoan', 'isère', 'rutland', 'denmark', 'swansea', 'botswana', 'retirement', 'polish', 'housing', 'chiropody', 'guyenne', 'piacenza', 'trapani', 'arizona', 'swampy', 'inorganic', 'bristol', 'flemish', 'security', 'seine', 'anthologies:', 'greenwashing', 'carniola', '1918–1933', 'regulation', 'protozoa', 'professional', 'haryana', 'warmia-masuria', 'stuckism', 'biedermeier', 'maturation', 'educational:', 'aragon', 'giant’s', 'bachelor', 'isindebele', 'entre', 'madre', 'regensburg', 'civil', 'tribology', 'invasion', 'ship', 'mackenzie', 'babylonia', 'buenos', 'matera', 'hauts-de-france', 'climate', 'castellane', 'scheldt', 'campania', 'kagawa', 'floorball', 'palaeography', 'goslar', 'caribbean', 'machine', 'acoustic', 'easy', 'virtualization', 'gambia', 'fante', 'sainte-menehould', '1943–1945', 'bullying', 'specific', 'harz', 'planning', 'biarritz', 'acre', 'ethology', 'polesine', 'new', 'lodève', 'oaxaca', 'ancestors’', 'tahitian', 'dada', 'electrochemistry', 'haute-loire', 'science', 'chongqing', 'tijuana', '2nd', 'lillestrøm', 'nudes', 'morlaix', 'poitiers', 'wendland', 'ungava', 'brittany', 'hainan', 'latina', 'football', 'ardennes', 'girona', 'climatology', 'track', 'films', 'catalan', 'altai', 'tottori', 'lolland-falster', 'performance', 'magnetic', 'passover', 'string', 'reggaeton', 'cartagena', 'saar', 'mesopotamia', 'therapy', 'sioux', 'yucatán', 'lot', 'molise', 'halle', 'myrtle', 'andhra', 'dublin', 'halland', 'geriatric', 'electronic', 'colonialism', 'pest', 'psychology:', 'arlon', 'aromanian', 'peru', 'idaho', 'finnmark', 'cannes', 'canoeing', 'radio', 'seville', '1688', 'kongsberg', 'ecumenism', 'swimming', 'pesaro', 'bamberg', 'la', 'cubo-futurism', 'chubut', 'exhibition', 'toulouse', 'sabah', 'chaumont', 'uranus', 'jutish', 'franciacorta', 'reutlingen', 'weightlifting', 'superhero', 'functional', 'lannion', 'kildare', 'stathelle', 'budget', 'study', 'belley', 'tshivenda', 'green', 'nanotechnology', 'economic', 'corrientes', 'kochi', 'bihar', 'genocide', 'bahia', 'cycling:', 'cenozoic', 'yssingeaux', 'chieti', 'krakow', 'stołowe', 'numerology', 'yeongnam', 'cricket', 'ghosts', 'bieszczady', 'lithuanian', 'internet', '1943', 'harlem', 'piedmont', 'tv', 'indianapolis', 'protection', 'kommune', 'colonial', 'nationalism', 'baton', 'lk20', 'hanukkah', 'hokksund', 'siena', 'bolivar', 'tokelau', 'eure', 'mantua', 'sila', 'immigration', 'breads', 'ancient', 'neckar', 'philippines', 'opera', 'alpes-de-haute-provence', 'gyeongsangbuk-do', 'structural', 'psychoanalytical', 'causes', 'topics', 'multidiscipline', 'taoism', 'cree', 'parodies', 'tasman', 'penang', 'fang', 'magna', 'speaking', 'birthing', 'physiological', 'guernsey', 'marrakesh', 'ontario', 'martinique', 'cyprus', 'elegy', 'engines', 'midsummer', '1912–1926', 'musicians', 'installation', 'armagh', 'volta-congo', 'irrigation', 'dzaoudzi', 'caroline', 'andean', 'investment', 'karate', 'social', 'picard', 'fauvism', 'animated', 'syriac', 'chippewa', 'gaborone', 'parallel', 'blois', 'aube', 'saint-amand-montrond', 'monufia', 'munich', 'spatial', 'beaune', 'everglades', 'chronic', 'tehran', 'pantanal', 'testing', 'hadrian’s', 'orphism', 'reno', 'el', 'natural', 'furniture', 'côte-d’or', 'forbach', 'limousin', 'hospital-acquired\xa0infections', 'technothriller', 'agrigento', 'rajasthan', 'germanic', 'thurgau', 'realism', 'nevada', 'czechia', 'constitution:', 'horror', 'rhineland-palatinate', 'toul', 'bavaria', 'mechatronics', 'composers', 'alès', 'bishkek', 'holy', 'kathmandu', 'woodwind', 'katowice', 'merida', 'hebei', 'stone', 'jack', 'adult', 'drugs', 'ferns', 'provence-alpes-côte', 'risk', 'electronics', 'brioude', 'wolverhampton', 'caen', 'disinformation', 'toys:', 'twente', 'wrestling', 'sanitary', 'spessart', 'valais', 'avant-garde', 'upcycling', 'kent', 'moss', 'atomic', 'philosophy:', 'panamá', 'susuami', 'faro', 'medieval', 'expressionism', 'okayama', 'afghanistan', 'brest', 'falconry', '1945–1989', 'romanian', 'palatinate', 'musculoskeletal', 'eure-et-loir', 'formentera', 'lugano', 'thorshavn', 'bergerac', 'namsos', 'dominica', 'psychiatric', 'kongsvinger', 'presentation', 'schwerin', 'bug', 'antigua', 'bohemian', 'siberia', 'maltese', 'canal', 'musical', 'gwangju', 'pyrenees', 'sculpture', 'altkirch', 'svealand', 'ciociaria', 'bourg-en-bresse', 'brass', 'nassau', 'ski', 'calligraphy', 'uusimaa', 'ice-skating', 'nagaland', 'norman', 'attica', 'law', 'shariah', 'indonesia', 'micronesia', 'canada:', 'geometry', 'dinosaurs', 'meurthe-et-moselle', 'szczecin', 'comets', 'elections', 'ring', 'rochechouart', 'götaland', 'montserrat', 'languedoc-roussillon', 'hämeenlinna', 'fès-meknès', 'obwalden', 'procurement', 'pando', 'asunción', 'java', 'disaster', 'évry', 'haute-vienne', 'iguazu', 'cosmology', 'archiving', 'crystallography', 'kumamoto', 'zermatt', 'assistive', 'haitian', 'château-thierry', 'macintosh', 'macao', 'water', 'bermuda', 'provins', 'pembrokeshire', 'weimar', 'turku', 'kymenlaakso', 'santo', 'waikato', 'baptism', 'cosenza', '8th', 'israel', 'african', 'surgical', 'afterlife', 'arezzo', 'crustaceans', 'val-de-marne', 'jonzac', 'cuenca', 'burmese', 'innu-aimun', 'lombok', 'arles', 'acquisitions', 'las', 'ajaccio', 'orthodox', 'emilia', 'bloemfontein', 'stuttgart', 'food', 'asyut', 'marmande', 'fencing', 'capital', 'toledo', 'eu', 'photographs:', 'liberal', 'fichtel', 'gulf', 'spanish', 'ways', 'before', 'teotihuacan', 'rouen', 'eight', 'avallon', 'sahara', 'entertainment', 'psychological', 'channel', 'mercenaries', 'botanical', 'hinduism:', 'altiplano', 'conjuring', 'chalkidiki', 'aerodynamics', 'montana', 'competence', 'sales', 'milwaukee', 'sailing', 'rwanda', 'legal', 'orkney', 'shaker', 'prince', 'prayer', 'forgery', 'kongo', 'trademarks', 'days', 'global', 'mountains', 'siegen', 'leros', 'mississippi-missouri', 'malawi', 'erotic', 'namur', 'landscape', 'alava', 'granada:', 'art:', 'fundraising', 'icelandic', 'curling', 'holmestrand', 'thessaly', 'beirut', 'yukon', 'tulum', 'guinea-bissau', 'boyaca', 'lelystad', 'cotopaxi', 'centre-val', 'egyptian', 'hausa', 'mandarin', 'lomellina', 'avellino', 'freiberg', 'ethnic', 'maui', 'medicine:\xa0hiv', 'magical', 'phycology', 'evolution', 'edi', 'montenegrin', 'chablais', 'vendée', 'kempten', 'nord-trøndelag', 'semitic', 'charolles', 'gascony', 'tyrol', 'shandong', 'chur', 'vest-agder', 'film', 'villeneuve-sur-lot', 'zakynthos', 'murals', 'domestic', 'campobasso', 'dead', 'vermont', 'locomotives', 'choreography', 'egypt', 'antiques', 'morelos', 'singen', 'tractors', 'missouri', 'tanger-tetouan-al', 'religion', 'gaul', 'relating', 'makua', 'extractive', 'ho', 'gardening', 'fijian', 'kajaani', '11th', 'okavango', 'ningxia', 'weapons', 'hydrobiology', 'mie', 'ulsan', 'khyber', 'dole', 'argolis', 'liège', 'medicine:', 'girona:', 'galapagos', 'saint-germain-en-laye', 'murcia', 'kvarner', 'subarctic', 'romorantin-lanthenay', 'other', 'language', 'witchcraft', 'arnhem', 'aguascalientes', 'montreux', 'mande', 'birthdays', 'sandnes', 'jodhpur', 'small', 'jokes', 'storage', 'croatia', 'cabo', 'arts', 'athens', 'são', 'aveyron', 'shaanxi', 'versailles', 'tennessee', 'bahamas', 'islamic', 'primary', 'guéret', 'adelaide', 'bantu', 'ceramic', 'strip', 'cryogenics', 'daman', 'saint-dié-des-vosges', 'hindu', 'sudan', 'argot', 'mikkeli', 'hollywood', 'guinea', 'gelderland', 'taranaki', 'glasgow', 'fort', 'chihuahua', 'franche-comté', 'religion:', 'sedona', 'notodden', 'dakahlia', 'festivals', 'agnosticism', 'achterhoek', 'jura', 'scandinavian', '1876', 'margarita', 'berkshire', 'närke', 'tyrrhenian', 'belarusian', 'celle', 'kommuneqarfik', 'reggio', 'guitar', 'chaleur', 'aruba', 'prussia', 'slovak', 'opec', 'rennes', 'regenerative', 'cognitive', 'german', 'österlen', 'bar-sur-aube', 'financial', 'higher', 'bonn', 'møre', 'romanesque', 'hmong', 'pordenone', 'iron', 'byzantine', 'phoenicia', 'detroit', 'maghreb', 'discrimination', 'impact', 'karelia', 'yonne', 'brindisi', 'geomorphology', 'carolingian', 'mediterranean', 'k-pop', 'early', 'annapurna', 'bochum', 'vichy', 'prosthetics', 'fontenay-le-comte', 'vanuatu', 'agricultural', 'sport', 'web', 'timbuktu', 'writings', 'lillooet', 'combat', 'haugesund', 'kl06', 'freedom', 'typography', 'benin', 'interest', 'nyons', 'jakarta', 'waldviertel', 'lincolnshire', 'poitou', 'orthodontics', 'finnish', '1603–1649', 'taekwondo', 'savona', 'mulhouse', 'futurism', 'marseille', 'ulster', 'cultural', 'pan-nationalism', 'ionian', 'honolulu', 'anhui', 'gambling:', 'black', 'lesson', 'hungary', 'linux', 'ore', 'cognac', 'langon', 'cooking', 'basse', 'corrèze', 'energy', 'pontarlier', 'brittany:', 'lourdes', 'normandy', 'grasse', 'thriller:', 'monrovia', 'aubusson', 'poitou-charentes', 'bialowieza', 'toruń', 'auckland', 'hague', 'alagoas', 'leeuwarden', 'luvale', 'mühlviertel', 'shuswap', 'amsterdam', 'damages', 'ferrara', 'julian', 'maths', 'roraima', 'pali', 'mathematical', 'muralism', 'agronomy', 'gex', 'champagne-ardenne', 'saturn', 'pichincha', 'sherbrooke', 'finance', 'siem', 'histology', 'esports', 'laconia', 'mercosur', 'mokilese', 'occidental', 'category', 'mizoram', 'parana', 'coptic', 'ibm', 'trentino', 'respiratory', 'cahors', 'lunda', 'shizuoka', 'tallinn', '1385–1572', 'rabbinic', 'quebec:', 'metal', 'ballet', 'havana', 'jharkhand', 'aerospace', 'yupik', 'relationships:', 'romania', 'chichewa', 'grand-est:', 'mecklenburg-western', 'pohnpeian', 'romantic', 'literacy', 'bibliographic', 'karnataka', 'saint', 'carnia', 'saguenay', '1969–1980', 'carlow', 'christmas', 'viticulture', 'fashion', 'lesparre-médoc', 'uttar', 'eifel', 'barbados', 'allgäu', 'kainuu', 'badajoz', 'palermo', 'cayman', 'bilbao', 'shiraz', 'tlingit', 'earth:', 'hotel', 'industrieviertel', 'oviedo', 'presov', 'accident', 'manufacturing', 'navarre', 'thrace', 'rhön', 'islamabad', 'chiang', 'monopolies', 'alpes-maritimes', 'synthetism', 'mayenne', 'oslo', 'utrechtse', 'lesser', 'skudeneshavn', 'modernism', 'zacatecas', 'zoroastrianism', 'albacete', 'anticosti', 'medical', 'columbia', 'punjabi', 'damietta', 'little', 'södermanland', 'aetolia-acarnania', 'metz', 'acadian', 'cilento', 'rocks', 'bastia', 'flags', 'maker', 'lettrism', 'danish', 'saint-dizier', 'wyoming', 'kuala', 'oceania', 'örebro', 'saint-lô', 'mining', 'alps', 'hubei', 'finnsnes', 'vistula', 'tax', 'tibet', 'kassel', 'gijon', 'accounting', 'online', 'pharmacology', 'quiltmaking', 'post-graduate', 'embryology', 'operational', 'gisborne', 'light', 'chimborazo', 'lublin', 'visby', 'astral', 'salta', 'veracruz', 'mato', 'peloponnese', 'juices', 'risør', 'verdal', 'brazil', 'valuation', 'hyderabad', 'human–computer', 'apeldoorn', 'karakoram', 'history:', 'castellon', 'cambodia', 'västmanland', 'port', 'naturopathy', 'nanterre', 'jaipur', 'kokkola', 'mississippi', 'biography', 'children’s', 'cali', 'non-semitic', 'augsburg', 'honduras:', 'oncology', 'münster', 'subject', 'narvik', 'bari', 'gothic', 'popular', 'street', 'blank', 'saint-nazaire', 'belarus', '1837–1838', 'wedding', 'spam', 'nîmes', 'back', 'modern', 'wales', 'rainforest', 'galaxies', 'orlando', 'tango', 'emotions', 'guadalajara', 'nancy', 'vlissingen', 'city', 'pakistan', 'edible', 'kolvereid', 'directories', 'wernigerode', 'beheira', 'pretoria', 'circus', 'fishing', 'sparta', 'vieques', 'relationships', 'buses', 'psychedelic', 'dance', 'methods', 'farsund', 'hydraulic', 'saudi', 'dhaka', 'magallanes', '1977', 'anjou', 'dissection', 'plastics', 'saint-brieuc', 'saint-denis', 'perfume', 'düsseldorf', 'emmen', 'dalsland', 'ithaca', 'punk', 'lungau', 'usage', 'isles', 'romansh', 'thuringian', 'poland', 'champagne', 'servers', 'sunderland', 'rehabilitation:', 'regions', 'charlevoix', 'okanagan', 'lyngdal', 'brighton', 'nidwalden', 'sociology', 'sohag', 'acapulco', 'carinthia', 'papeete', 'insurance', 'dreams', 'lac', 'biblical', 'ragusa', 'singapore', 'revolutions', 'heat', 'zaragoza', 'us', 'madeira', 'sinhalese', 'comox', 'santander', 'animal-assisted', 'ohio', 'educational', 'peer-to-peer', 'real', 'valenciennes', 'mesoamerican', 'autun', 'dancers', '1944', 'cybernetics', 'bosnia-herzegovina', 'jeddah', '3d', 'manuscripts', 'model', 'argentan', 'stockholm', 'maastricht', 'death', 'rollerblading', 'oppland', 'theory', 'béziers', 'dairy', 'somalia', 'phoenix', 'biotechnology', 'lutherstadt', 'managua', 'limpopo', 'jan', 'jammu', 'beverly', 'comedy', 'shona', 'erfurt', 'lecco', 'buddhism', 'linz', 'environmentalist', 'levanger', 'refugees', 'tunis', 'palm', 'dingle', 'cayenne', 'conceptualism', 'brands', 'yoga', 'isle', 'inuit', 'i', 'zwolle', '1808', 'acupuncture', 'anthropology', 'mongol', 'speculative', 'air', 'petan', 'himachal', 'zuliana', 'viterbo', 'general', 'roskilde', 'bengali', 'bridges', 'montevideo', 'serbo-croatian', 'schleswig-holstein', 'ibo', 'nile', 'french', 'great', 'iraq', 'mirande', 'angkor', 'reliability', 'e-commerce', 'alzheimer’s', 'narrative', 'sap', 'burren', 'st.', 'thun', 'cyrenaica', 'chemotherapy', 'augmented', 'relational', 'public', 'freshwater', 'rheumatology', 'stock', 'espirito', 'pitcairn', 'assyrian', 'minimalist', 'free', 'signal', 'montgomery', '1st', 'aquitaine', 'oulu', 'newfoundland', 'for', 'bedfordshire', 'content', 'elt:', 'vaccination', 'united', 'latvian', '1850–1861', 'suriname', 'age', 'gynaecology', 'planets', 'vantaa', 'bibliographies', 'kanta-häme', 'poznan', 'networking', 'ropework', 'helgeland', 'uckermark', 'clinical', '1868–1912', 'timber', 'canary', '1990–1999', 'lule', 'coding', 'dermatology', 'norwich', 'transavanguardia', 'arctic', 'arapaho', 'a-stream', 'karlovy', 'westminster', 'olbia', 'massa-carrara', 'falun', 'saba', 'camera-specific', 'desktop', 'physiology', 'brumunddal', 'television:', 'rhineland', 'uzbekistan', 'port-au-prince', 'dravidian', 'chipewyan', 'épinal', 'rethel', 'monologues', 'iceland', 'yiddish', 'auch', 'calais', 'zydeco', 'luleå', 'salem', 'optometry', 'relativity', 'pidgins', 'figure', 'härjedalen', 'biophysics', 'sport:', 'gothenburg', 'welsh', 'bonsai', 'carvings', 'glacier', 'rambouillet', 'plucked', 'plasma', 'rimouski', 'zlin', 'hawaiian', 'epiphany', 'tibetan', 'tea', 'salamis', 'non-monogamy', 'afrofuturism', 'ambert', 'nièvre', 'cherbourg-en-cotentin', 'kashubia', 'land', 'postmodernism', 'prato', 'worms', 'colombo', 'rivers', 'charlottesville', 'organometallic', 'hasselt', 'initial', 'eleusis', 'corfu', 'teenagers:', 'clare', 'italy', 'yamaguchi', 'disability:', 'galician', 'franchising', 'eating', 'province', 'vocational', 'trivia', 'comparative', 'quantum', 'explosives', 'jewish', 'neufchâteau', 'spreewald', 'mallorca', 'spreadsheet', 'colorado', 'orleans', 'haiti', 'betuwe', 'cordillera', 'edinburgh', 'formosa', 'afro-asiatic', 'tucson', 'lillehammer', 'senegal', 'proterozoic', 'making', 'patient', 'allier', 'minsk', 'ica', 'steigerwald', 'pontevedra', 'nogent-le-rotrou', 'prades', 'theatre', 'direct', 'lancashire', 'budapest', 'boulder', 'etruria', 'empire', 'astrology', 'transdanubian', 'nubian', 'kingdom', 'frankfurt', 'langhe', 'sejong', 'ukiyo-e', 'mont', 'sápmi', 'ede', 'kragerø', 'user', 'gran', 'contemporary', 'zilina', 'salento', 'antwerp', 'publishing', 'daejeon', 'sexually', 'bible', 'fishes', 'kansas', 'bergslagen', 'home', 'landes', 'overijssel', 'sussex', 'tarija', 'beat', '4th', 'baptist', 'post-impressionism', 'vegan', 'watches', 'adriatic', 'osaka', 'enna', 'river', 'nagano', 'consumerism', 'castile-la', 'connemara', 'warwickshire', 'palmyra', 'sanctioning', 'montpellier', 'laos', 'benghazi', 'mpumalanga', 'zoology:', 'bio-catalysis', 'dorset', 'béarn', 'antrim', 'basic', 'interlingua', 'massage', 'midwinter', 'schaffhausen', 'cephalonia', 'citizenship', 'commercy', 'singing:', 'glastonbury', 'hel', 'pregnancy', 'yerupaja', 'ottawa', 'geneva', 'plains', 'peace', 'orientalism', 'eigersund', 'cologne', 'schools', 'camden', 'graphical', 'abnaki', 'hiroshima', 'word', 'endocrinology', 'events', 'modena', 'breton', 'boston', 'abidjan', 'project-based', 'alaska', 'medellin', 'ausangate', 'le', 'kiswahili', '1558–1603', 'spinning', 'cévennes', 'osnabrück', 'rochefort', '1649–1653', 'elementary', 'excise', 'mecsek', 'saverne', 'phenomenology', 'satakunta', 'open', 'elba', 'pondicherry', 'jiangsu', 'flagstaff', 'bourges', 'confederate', 'safety', 'palencia', 'inverness', 'karpathos', 'islands', 'afrikaans', 'derry', 'sint', 'aircraft', 'curriculum', 'tokushima', 'sheffield', 'roscommon', 'burundi', 'johannesburg', 'norrbotten', 'biobío', 'hortobágy', 'indic', 'volga', 'cellular', 'printing', 'mayan', 'diwali', 'copyright', 'passau', 'liechtenstein', 'star', 'sandvika', 'middelburg', 'derbyshire', 'palaeozoic', 'irish', 'canberra', 'colours', 'haptic', 'lowland', 'hartford', 'interlaken', 'para', 'ceuta', 'cubism', 'compulsory', 'delft', 'teenage', 'sauerland', 'vaucluse', 'lodz', 'bolzano', 'rome', 'pcs', 'mugello', 'kangerlussuaq', 'piano', 'conveyancing', 'istres', 'northland', 'registry', 'ceara', '1936–1939', 'adoption', 'object', 'aleut', 'l’haÿ-les-roses', 'patents', 'jurassic', 'georgian', 'uri', 'tartessian', 'grammar', 'cheshire', 'göttingen', 'malbork', '9th', 'jeju-do', 'coastal', 'maldives', 'internet:', 'figeac', 'tuscia', 'lebanon', 'balkans', 'étampes', 'cantabria', 'piraeus', 'tarbes', 'nilo-saharan', 'martial', 'nord', 'gunma', 'udaipur', 'aragonese', 'lausanne', 'africa:', 'rjukan', 'graduation', 'chiba', 'slavic', 'catering', '1939–1944', 'skåne', 'brasilia', 'pennines', 'melbourne', 'otorhinolaryngology', 'saronic', 'khoisan', 'low', 'ecuador', 'pithiviers', 'lombardy', 'sports', 'valentine’s', 'arabian', 'mercury', 'almeria', 'teruel', 'brønnøysund', 'côtes-d’armor', 'southwestern', 'anime', 'cape', 'atikamekw', 'veneto', 'cross-cultural', 'riyadh', 'songbooks', 'temperate', '1929', 'historiography', 'bryne', 'varanasi', 'portuguese', 'sassari', 'sandomierz', 'genetics', 'film:', 'afro-american', 'fischland-darss-zingst', 'jordan', 'tok', 'montenegro', 'tübingen', 'lorient', 'czechia:', 'ethiopia', 'orinoco', 'queensland', 'easter', 'cloisonnism', 'project', 'avignon', 'neuchâtel', 'trieste', 'slovakia', 'birmingham', 'halden', 'michigan', 'designed', 'memphis', 'taxonomy', 'louisiana', 'avranches', 'paraguay:', 'kouvola', 'usti', 'riom', 'grand', '6th', 'cycle', 'sacred', 'fauske', 'australian', 'vaisakhi', 'shiga', 'europe:', 'marathi', 'chad', 'algeria', 'tropical', 'manche', 'kruger', 'midwifery', 'scuola', 'scots', 'indre', 'tigrinya', 'leuven', 'church', 'guatemala', 'cancun', 'stratford-upon-avon', 'wroclaw', 'cambridge', 'qinghai', 'counselling', 'nebraska', 'tessin', 'road', 'folklore', 'andes', 'nato', 'alentejo', 'japanese', 'poetry', 'aestheticism', 'drawing', 'pre-columbian', 'mergers', 'ijsselmeer', 'electric', 'metaphysical', 'siouan–catawban', '20th', 'microscopy', 'masonry', 'dijon', 'sierra', 'bath', 'saint-jean-de-maurienne', 'sociolinguistics', 'breda', 'utrecht', 'prints', 'bern', 'szeged', 'valladolid', 'newport', 'tennis', 'zapotec', 'gas', 'oman', 'ballroom', 'bellinzona', 'congo', '1910', 'saxony', 'aleppo', 'valle', 'chianti', 'alicante:', 'alkmaar', 'grindelwald', 'australasian', '17th', 'barcelonnette', 'trento', 'farne', 'mamers', 'mir', 'family', 'pointillism', 'navajo', 'kosice', 'fiji', 'northwest', 'dystopian', 'limoux', '1485–1603', 'joensuu', 'tigullio', 'veszprém', 'biathlon', 'piaui', 'thermodynamics', 'long', 'bordeaux', 'prisoners', 'madhya', 'evenki', 'santorini', 'dalmatia', 'prehistory', 'st', 'flanders', 'western', 'bisayan', 'jainism', 'places', 'argelès-gazost', 'sandnessjøen', 'bornholm', 'wave', 'alberta', 'architecture:', 'denominations', 'luxembourgish', 'nazarene', 'haute-garonne', 'aarhus', 'hanoi', 'assyro-babylonian', 'human', 'turks', 'vexin', 'nizhny', 'rowing', 'mantes-la-jolie', 'andalusia', 'e-book', 'aschaffenburg', 'textbook', 'shropshire', 'building', 'douai', 'peacekeeping', 'seasonal', '1922–1937', 'filmmaking', 'koran', 'carbonia-iglesias', 'canada', 'utilities', 'savannah', 'corsican', 'atlas', 'secret', 'otjiherero', 'zona', 'gotland', 'dinka', '1918–1943', 'tønsberg', 'crotone', 'ukrainian', 'design', 'nigeria', 'deforestation', 'olsztyn', 'incheon', 'upper', 'cambrai', 'ljubljana', 'jerusalem', 'schweizerischer', 'ethiopic', 'solo', 'dietetics', 'ulm', 'ethics', 'charities', 'pharmaceutical', 'colloid', 'physiotherapy', 'municipal', 'target', 'liberia', 'charente-maritime', 'louhans', 'walloon', 'angers', 'kampinoski', 'flevoland', 'hydraulics', 'esztergom', 'ardèche', 'liberec', 'section', 'non-profitmaking', 'saint-tropez', 'aachen', 'nouvelle-aquitaine:', 'dartmoor', 'amrum', 'dyestuffs', 'control', 'amersfoort', 'suprematism', 'arcadia', 'chemistry', 'mixtecan', 'peri-operative', 'gymnastics', 'mixed', 'renaissance', 'pompeii', 'malayalam', 'picardy', 'sacatepéquez', 'pas-de-calais', 'prison', 'tipperary', 'zoetermeer', 'private', 'independence', 'lunigiana', 'landscapes', 'short', 'information', 'textile', 'diy:', 'cytopathology', 'agriculture', 'phthiotis', 'pashto', 'sign', 'djerba', 'neo-impressionism', 'budgeting', 'mayotte', 'aeolian', 'constitutional', 'fukuoka', 'campeche', 'hamburg', 'guantánamo', 'manchu', 'costa', 'production', 'calvi', 'mecca', 'östersund', 'montreal']

# %% [markdown]
# # model selection

# %%
import gensim.downloader as api
print(list(api.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
word_vectors = api.load("glove-wiki-gigaword-300")
# word_vectors.save_word2vec_format('word_vectors_glove-wiki-gigaword-300.bin', binary=True)

# %% [markdown]
# # model quick test

# %%
word_vectors.similarity("economy", "finance")
# Out:
# 0.475985

# %%
word_vectors.similarity("horse", "donkey")
# Out:
# 0.43909532

# %% [markdown]
# # align with closest words

# %%
import numpy as np
from gensim.models import KeyedVectors, Word2Vec
from tqdm import tqdm
# Load the pre-trained word embedding model from the online library
def align_lists_with_synonyms(list1, list2, word_vectors):
    # Create a matrix to store the similarities between words
    similarities = np.zeros((len(list1), len(list2)))

    # Calculate the similarity between each pair of words
    for i in tqdm(range(len(list1)), desc="Calculating similarities"):
        for j in range(len(list2)):
            try:
                similarity = word_vectors.similarity(list1[i], list2[j])
            except KeyError:
                similarity = 0  # Set similarity to 0 if word is not in the vocabulary
            similarities[i, j] = similarity

    # Find the closest synonym for each word in list1
    alignment = []
    for i in tqdm(range(len(list1)), desc="Finding closest synonyms"):
        closest_word_index = np.argmax(similarities[i])
        alignment.append((list1[i], list2[closest_word_index]))

    return alignment

# Example usage
list1 = ['apple', 'banana', 'orange']
list2 = ['granny', 'mandarin', 'plantain']
# list1 = ['pomme', 'banane', 'orange']
# list2 = ['granny', 'mandarine', 'plantain']
alignment = align_lists_with_synonyms(list1, list2, word_vectors)
print(alignment)
# Out:
# ...
# Finding closest synonyms: 100%|██████████| 3/3 [00:00<?, ?it/s]
# [('apple', 'granny'), ('banana', 'plantain'), ('orange', 'mandarin')]

# %%
align_lists_with_synonyms(ecole_des_loisir_themes_preprocessed, thema_root_nodes_preprocessed)
# Out:
# ...
# Finding closest synonyms: 100%|██████████| 744/744 [00:00<00:00, 366349.16it/s]
# [('donkey', 'style'),
#  ('animals', 'earth'),
#  ('various', 'educational'),
#  ('pets', 'lifestyle'),
#  ('spider', 'earth'),
#  ('ostrich', 'style'),
#  ('whale', 'earth'),
#  ('weasel', 'fiction'),
#  ('bison', 'sports'),
#  ('badger', 'biography'),
#  ('chameleon', 'lifestyle'),
#  ('duck', 'place'),
#  ('beaver', 'sports'),
#  ('deer', 'place'),
#  ('camel', 'lifestyle'),
#  ('chamois', 'sports'),
#  ('cat', 'style'),
#  ('bat', 'time'),
#  ('horse', 'place'),
#  ('dog', 'time'),
#  ('pig', 'reference'),
#  ('coyote', 'earth'),
#  ('crab', 'style'),
#  ('crocodile', 'reference'),
#  ('dolphin', 'sports'),
#  ('animals', 'earth'),
#  ('turkey', 'time'),
#  ('dinosaur', 'history'),
#  ('squirrel', 'earth'),
#  ('elephant', 'earth'),
#  ('snail', 'earth'),
#  ('various', 'educational'),
#  ('giraffe', 'fiction'),
#  ('wildebeest', 'society'),
#  ('frog', 'earth'),
#  ('hamster', 'earth'),
# ...

# %%
align_lists_with_synonyms(ricochet_themes_preprocessed, thema_root_nodes_preprocessed)
# Out:
# ...
# Finding closest synonyms: 100%|██████████| 716/716 [00:00<00:00, 229789.71it/s]
# [('abandonment', 'law'),
#  ('abecedary', 'arts'),
#  ('bee', 'language'),
#  ('aboriginal', 'language'),
#  ('absence', 'interest'),
#  ('absurd', 'fiction'),
#  ('sexual', 'language'),
#  ('accident', 'time'),
#  ('manual', 'reference'),
#  ('activities', 'educational'),
#  ('adaptation', 'fiction'),
#  ('adolescence', 'lifestyle'),
#  ('adoption', 'law'),
#  ('adultery', 'law'),
#  ('affection', 'interest'),
#  ('assertiveness', 'lifestyle'),
#  ('afghanistan', 'time'),
#  ('africa', 'time'),
#  ('north', 'place'),
#  ('south', 'place'),
#  ('humanitarian', 'educational'),
#  ('alaska', 'history'),
#  ('album', 'biography'),
#  ('album', 'biography'),
#  ('alcohol', 'health'),
#  ('algeria', 'place'),
#  ('food', 'health'),
#  ('germany', 'time'),
#  ('literacy', 'educational'),
#  ('mountaineering', 'sports'),
#  ('north', 'place'),
#  ('latin', 'language'),
#  ('friendship', 'society'),
# ...

# %%
align_lists_with_synonyms(ecole_des_loisir_themes_preprocessed, thema_all_nodes_preprocessed, word_vectors)
# Out:
# ...
# Finding closest synonyms: 100%|██████████| 744/744 [00:00<00:00, 146422.77it/s]
# [('donkey', 'horse'),
#  ('animals', 'animals'),
#  ('various', 'other'),
#  ('pets', 'cats'),
#  ('spider', 'superhero'),
#  ('ostrich', 'leather'),
#  ('whale', 'fishing'),
#  ('weasel', 'rabbits'),
#  ('bison', 'yellowstone'),
#  ('badger', 'rabbits'),
#  ('chameleon', 'madagascar'),
#  ('duck', 'birds'),
#  ('beaver', 'lake'),
#  ('deer', 'rabbits'),
#  ('camel', 'horse'),
#  ('chamois', 'niort'),
#  ('cat', 'dog'),
#  ('bat', 'ball'),
#  ('horse', 'horse'),
#  ('dog', 'dog'),
#  ('pig', 'animal'),
#  ('coyote', 'rabbits'),
#  ('crab', 'cakes'),
#  ('crocodile', 'reptiles'),
#  ('dolphin', 'endangered'),
#  ('animals', 'animals'),
#  ('turkey', 'turkey'),
#  ('dinosaur', 'dinosaurs'),
#  ('squirrel', 'rabbits'),
#  ('elephant', 'animal'),
#  ('snail', 'freshwater'),
#  ('various', 'other'),
#  ('giraffe', 'masai'),
#  ('wildebeest', 'serengeti'),
#  ('frog', 'reptiles'),
#  ('hamster', 'rabbits'),
# ...

# %% [markdown]
# # plot and navigate embedding visualisation

# %%
import numpy as np
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
def compute_embeddings(word_list, model):
    # Load the pre-trained word embedding model
    # Compute embeddings for each word in the list
    embeddings = []
    for word in word_list:
        if word in model:
            embeddings.append(model[word])
        else:
            print(word, "out of vocabulary")
            embeddings.append(np.zeros(model.vector_size))  # Use zero vector for out-of-vocabulary words

    return np.array(embeddings)

def plot_embeddings(embeddings1, embeddings2, labels1, labels2):
    plt.clf()
    # Plot embeddings of list 1 in blue
    plt.scatter(embeddings1[:, 0], embeddings1[:, 1], color='blue', label='List 1')

    # Plot embeddings of list 2 in red
    plt.scatter(embeddings2[:, 0], embeddings2[:, 1], color='red', label='List 2')

    # Add labels for each word in list 1
    for i, label in enumerate(labels1):
        plt.annotate(label, (embeddings1[i, 0], embeddings1[i, 1]), color='blue')

    # Add labels for each word in list 2
    for i, label in enumerate(labels2):
        plt.annotate(label, (embeddings2[i, 0], embeddings2[i, 1]), color='red')

    # Add legend and labels
    plt.legend()
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    # Show the plot
    plt.show()
    plt.close()
    

# Example usage
word_list1 = ['apple', 'banana', 'orange']
word_list2 = ['granny', 'mandarin', 'plantain']

embeddings1 = compute_embeddings(word_list1, word_vectors)
embeddings2 = compute_embeddings(word_list2, word_vectors)

plot_embeddings(embeddings1, embeddings2, word_list1, word_list2)
plt.clf()

# %%
import plotly.graph_objects as go

def plot_interactive_embeddings(embeddings1, embeddings2, labels1, labels2, list1_name, list2_name):
    fig = go.Figure()

    # Add scatter trace for embeddings of list 1
    fig.add_trace(go.Scatter(
        x=embeddings1[:, 0],
        y=embeddings1[:, 1],
        mode='markers',
        name=list1_name,
        text=labels1,
        marker=dict(color='blue')
    ))

    # Add scatter trace for embeddings of list 2
    fig.add_trace(go.Scatter(
        x=embeddings2[:, 0],
        y=embeddings2[:, 1],
        mode='markers',
        name=list2_name,
        text=labels2,
        marker=dict(color='red')
    ))

    # Set layout options
    fig.update_layout(
        title='Embeddings',
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        hovermode='closest'
    )

    # Show the plot
    fig.show()

embeddings1 = compute_embeddings(ricochet_themes_preprocessed, word_vectors)
embeddings2 = compute_embeddings(ecole_des_loisir_themes_preprocessed, word_vectors)

plot_interactive_embeddings(embeddings1, embeddings2, ricochet_themes_preprocessed, ecole_des_loisir_themes_preprocessed, "Ricochet", "Ecole des loisirs")
# Out:
# abecedary out of vocabulary
# children's out of vocabulary
# interculturality out of vocabulary
# kamishibai out of vocabulary
# children's out of vocabulary
# ritournel out of vocabulary
# potholing out of vocabulary
# transidentity out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# eco-anxiety out of vocabulary
# potholing out of vocabulary
# noah's out of vocabulary

# %% [markdown]
# # wordnet

# %%
import nltk
import pprint
nltk.download('wordnet')
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
from nltk.corpus import wordnet
def get_synonyms(word, language='eng'):
    synonyms = []
    for syn in wordnet.synsets(word, lang=language):
        for lemma in syn.lemmas(language):
            synonyms.append(lemma.name())
    return synonyms

word = "car"
synonyms = get_synonyms(word)
pprint.pprint(synonyms)
# Out:
# ['car',
#  'auto',
#  'automobile',
#  'machine',
#  'motorcar',
#  'car',
#  'railcar',
#  'railway_car',
#  'railroad_car',
#  'car',
#  'gondola',
#  'car',
#  'elevator_car',
#  'cable_car',
#  'car']

# %% [markdown]
# # fine tune word2vec with wordnet

# %% [markdown]
# ##### https://datascience.stackexchange.com/questions/97568/fine-tuning-pre-trained-word2vec-model-with-gensim-4-0

# %%
# uncomment to retrain fine-tuned model

from gensim.models import Word2Vec
from nltk.corpus import wordnet
import numpy as np
from tqdm import tqdm
synsets = list(wordnet.all_synsets())

model = Word2Vec(vector_size=word_vectors.vector_size)


# Extract the words and their contexts
data = []
for synset in synsets:
    words = [lemma.name() for lemma in synset.lemmas()]
    data.append(words)

# Update the model with the new data
model.build_vocab(data) # model does not contain training metadata (vocab frequency, loss, etc.)

model.wv.vectors_lockf = np.ones(len(model.wv))
model.wv.intersect_word2vec_format('../book_themes_alignment_data/word_vectors_glove-wiki-gigaword-300.bin', binary=True)



# Train the model with progress bar
with tqdm(total=len(data), desc="Training model") as pbar:
    for i, words in enumerate(data):
        model.train([words], total_examples=1, epochs=model.epochs)
        pbar.update(1)

# Save the fine-tuned model
model.save("word2vec_glove-wiki-300_wordnet.model")
word2vec_wordnet = model.wv
# Out:
# Training model: 100%|██████████| 117659/117659 [14:30<00:00, 135.09it/s]

# %%
# Load the fine-tuned Word2Vec model
word2vec_wordnet = Word2Vec.load("../book_themes_alignment_data/word2vec_glove-wiki-300_wordnet.model")

# %%
print(word_vectors.most_similar("car"))
# Out:
# [('cars', 0.7827162146568298), ('vehicle', 0.7655367851257324), ('truck', 0.7350621819496155), ('driver', 0.7114784717559814), ('driving', 0.6442225575447083), ('vehicles', 0.6328005194664001), ('motorcycle', 0.6022513508796692), ('automobile', 0.595572829246521), ('parked', 0.5910030603408813), ('drivers', 0.5778359770774841)]

# %%
print(word2vec_wordnet.wv.most_similar("car"))
# Out:
# [('scooter', 0.6381530165672302), ('van', 0.6115673780441284), ('driver', 0.577939510345459), ('tire', 0.4941665828227997), ('pickup', 0.48767825961112976), ('motor', 0.4810173213481903), ('bus', 0.4693371057510376), ('wheel', 0.45954588055610657), ('hood', 0.4447837173938751), ('trunk', 0.44462618231773376)]

# %%
word = "history"
print(word_vectors.most_similar(word))
synonyms = get_synonyms(word)
print(synonyms)
print(word2vec_wordnet.wv.most_similar(word))
# Out:
# [('historical', 0.6356455683708191), ('ever', 0.5561050772666931), ('career', 0.5299124121665955), ('modern', 0.5202743411064148), ('decades', 0.5195845365524292), ('first', 0.5122755765914917), ('most', 0.5101179480552673), ('tradition', 0.5084711313247681), ('book', 0.5072575211524963), ('years', 0.5052721500396729)]
# ['history', 'history', 'account', 'chronicle', 'story', 'history', 'history', 'history']
# [('record', 0.44240590929985046), ('lineage', 0.3730401396751404), ('culture', 0.3615289032459259), ('modern', 0.3599395453929901), ('chapter', 0.35942503809928894), ('worst', 0.33779799938201904), ('one', 0.33320415019989014), ('most', 0.33037394285202026), ('first', 0.32545924186706543), ('antecedent', 0.3206702172756195)]

# %%
align_lists_with_synonyms(ecole_des_loisir_themes_preprocessed, thema_root_nodes_preprocessed, word2vec_wordnet.wv)
# Out:
# ...
# Finding closest synonyms: 100%|██████████| 744/744 [00:00<00:00, 371849.64it/s]
# [('donkey', 'arts'),
#  ('animals', 'arts'),
#  ('various', 'arts'),
#  ('pets', 'arts'),
#  ('spider', 'arts'),
#  ('ostrich', 'arts'),
#  ('whale', 'arts'),
#  ('weasel', 'arts'),
#  ('bison', 'arts'),
#  ('badger', 'arts'),
#  ('chameleon', 'arts'),
#  ('duck', 'style'),
#  ('beaver', 'language'),
#  ('deer', 'arts'),
#  ('camel', 'arts'),
#  ('chamois', 'arts'),
#  ('cat', 'medicine'),
#  ('bat', 'time'),
#  ('horse', 'time'),
#  ('dog', 'place'),
#  ('pig', 'graphic'),
#  ('coyote', 'arts'),
#  ('crab', 'earth'),
#  ('crocodile', 'arts'),
#  ('dolphin', 'arts'),
#  ('animals', 'arts'),
#  ('turkey', 'arts'),
#  ('dinosaur', 'arts'),
#  ('squirrel', 'arts'),
#  ('elephant', 'arts'),
#  ('snail', 'arts'),
#  ('various', 'arts'),
#  ('giraffe', 'arts'),
#  ('wildebeest', 'arts'),
#  ('frog', 'arts'),
#  ('hamster', 'arts'),
#  ('hedgehog', 'arts'),
#  ('owl', 'arts'),
#  ('seahorse', 'arts'),
# ...

# %% [markdown]
# # wordnet in french

# %%
from nltk.corpus import wordnet as wn
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dre\AppData\Roaming\nltk_data...
# [['canis_familiaris', 'chien'],
#  ['aboyeur', 'chien', 'chienchien', 'clébard', 'toutou'],
#  ['chien', 'chien_de_chasse'],
#  ['chien'],
#  ['chien', 'clic', 'cliquer', 'cliquet'],
#  ['chien', 'franc', 'hot-dog'],
#  ['achille', 'chien', 'quignon', 'talon'],
#  ['chien'],
#  ['chien']]

# %%
get_synonyms("cheval", language='fra')
# Out:
# ['cheval',
#  'cheval',
#  'equus_caballus',
#  'cheval',
#  'cheval',
#  "cheval_d'arçons",
#  'peste',
#  'équidés',
#  'cavalier',
#  'cheval',
#  'chevalier',
#  'peste',
#  'équidés',
#  'cheval',
#  'chevalet',
#  'tréteau',
#  'bœuf',
#  'cavalerie',
#  'cheval']

# %%
get_synonyms("abandon", language='fra')
# Out:
# ['abandon',
#  'désertion',
#  'abandon',
#  'arrachage',
#  'abandon',
#  'désertion',
#  'abandon',
#  'abandon',
#  'cession',
#  'abandon',
#  'négligence',
#  'négligence_coupable',
#  'abandon',
#  'concession',
#  'abandon',
#  'départ',
#  'expiration',
#  'sortie',
#  'abandon',
#  'abandon',
#  'intimité',
#  'secret']
