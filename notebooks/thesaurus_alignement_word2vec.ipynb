# %%
from pprint import pprint

# %%
ecole_des_loisir_themes_preprocessed = ['donkey',
 'animals',
 'various',
 'pets',
 'spider',
 'ostrich',
 'whale',
 'weasel',
 'bison',
 'badger',
 'chameleon',
 'duck',
 'beaver',
 'deer',
 'camel',
 'chamois',
 'cat',
 'bat',
 'horse',
 'dog',
 'pig',
 'coyote',
 'crab',
 'crocodile',
 'dolphin',
 'animals',
 'turkey',
 'dinosaur',
 'squirrel',
 'elephant',
 'snail',
 'various',
 'giraffe',
 'wildebeest',
 'frog',
 'hamster',
 'hedgehog',
 'owl',
 'seahorse',
 'hippopotamus',
 'various',
 'kangaroo',
 'koala',
 'manatee',
 'rabbit',
 'lizard',
 'lion',
 'dormouse',
 'wolf',
 'otter',
 'lynx',
 'mammoth',
 'marmot',
 'walrus',
 'sheep',
 'various',
 'opossum',
 'platypus',
 'killer',
 'bear',
 'panda',
 'butterfly',
 'lazy',
 'seal',
 'octopus',
 'penguin',
 'various',
 'chicken',
 'raccoon',
 'fox',
 'shark',
 'rhinoceros',
 'wild',
 'snake',
 'monkey',
 'mouse',
 'meerkat',
 'armadillo',
 'mole',
 'tiger',
 'tortoise',
 'cow',
 'earthworm',
 'yeti',
 'zebra',
 'parietal',
 'traditional',
 'movie',
 'circus',
 'clown',
 'commedia',
 'creativity',
 'dance',
 'tightrope',
 'puppet',
 'literature',
 'puppet',
 'mime',
 'music',
 'opera',
 'paint',
 'photography',
 'photography',
 'sculpture',
 'street',
 'theater',
 'tooth',
 'hand',
 'body',
 'skeleton',
 'hygiene',
 'pee',
 'jar',
 'lice',
 'beauty',
 'coquetry',
 'body',
 'autism',
 'body',
 'disability',
 'glasses',
 'pregnancy',
 'birth',
 'accident',
 'alcoholism',
 'anorexia',
 'appetite',
 'bobo',
 'bulimia',
 'drug',
 'epidemic',
 'hospitalization',
 'disease',
 'wet',
 'health',
 'aids',
 'homosexuality',
 'puberty',
 'sexuality',
 'sleep',
 'fear',
 'dream',
 'the',
 'prevention',
 'space-time',
 'size',
 'learning',
 'learning',
 'first',
 'baby',
 'crib',
 'nipple',
 'language',
 'nature',
 'college',
 'truant',
 'school',
 'boarding',
 'back',
 'school',
 'university',
 'dead',
 'taking',
 'time',
 'old',
 'genealogy',
 'search',
 'foolery',
 'parental',
 'siblings',
 'fugue',
 'grandmother',
 'grandfather',
 'grand',
 'same-sex',
 'twins',
 'birth',
 'relationship',
 'relationship',
 'child',
 'sisters',
 'moving',
 'mess',
 'everyday',
 'adoption',
 'dispute',
 'divorce',
 'with',
 'abandoned',
 'abused',
 'host',
 'broken',
 'single',
 'stepfamily',
 'family',
 'marriage',
 'orphan',
 'family',
 'family',
 'adventure',
 'cloak',
 'police',
 'travel',
 'adventure',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'twisted',
 'tales',
 'stories',
 'fables',
 'abbreviated',
 'classic',
 'picture',
 'fantastic',
 'fantasy',
 'science',
 'fables',
 'medieval',
 'novel',
 'cowboy',
 'super',
 'angel',
 'knight',
 'devil',
 'dragon',
 'ghost',
 'fairy',
 'giant',
 'genius',
 'unicorn',
 'elf',
 'wizard',
 'monster',
 'dwarf',
 'ogre',
 'storybook',
 'prince',
 'king',
 'mermaid',
 'wizard',
 'vampire',
 'sketch',
 'classical',
 'contemporary',
 'theater',
 'atlas',
 'autobiography',
 'adventure',
 'comic',
 'biography',
 'nursery',
 'tale',
 'riddles',
 'terror',
 'extraterrestrial',
 'humor',
 'newspaper',
 'letters',
 'book',
 'ukrainian',
 'game',
 'mooc',
 'mythology',
 'parody',
 'philosophy',
 'poetry',
 'proverb',
 'collection',
 'collection',
 'rhyme',
 'cap',
 'founding',
 'africa',
 'north',
 'south',
 'algeria',
 'egypt',
 'kenya',
 'libya',
 'madagascar',
 'maghreb',
 'mali',
 'morocco',
 'seychelles',
 'sudan',
 'tanzania',
 'tunisia',
 'zanzibar',
 'west',
 'costa',
 'cuba',
 'guatemala',
 'haiti',
 'mexico',
 'porto',
 'alaska',
 'canada',
 'united',
 'argentina',
 'bolivia',
 'brazil',
 'chile',
 'colombia',
 'ecuador',
 'peru',
 'venezuela',
 'afghanistan',
 'arabia',
 'armenia',
 'asia',
 'bahrain',
 'bangladesh',
 'burma',
 'borneo',
 'cambodia',
 'china',
 'korea',
 'emirates',
 'far',
 'india',
 'indonesia',
 'iraq',
 'iran',
 'israel',
 'japan',
 'jordan',
 'kyrgyzstan',
 'kuwait',
 'laos',
 'lebanon',
 'malaysia',
 'mongolia',
 'middle',
 'nepal',
 'oman',
 'pakistan',
 'philippines',
 'sri',
 'syria',
 'taiwan',
 'thailand',
 'tibet',
 'vietnam',
 'yemen',
 'georgia',
 'uzbekistan',
 'russia',
 'türkiye',
 'ussr',
 'eskimo',
 'gallic',
 'indian',
 'american',
 'mayan',
 'arab',
 'tuareg',
 'vikings',
 'germany',
 'austria',
 'balkans',
 'belgium',
 'denmark',
 'spain',
 'europe',
 'finland',
 'france',
 'britain',
 'greece',
 'hungary',
 'iceland',
 'italy',
 'norway',
 'nordic',
 'the',
 'poland',
 'portugal',
 'romania',
 'sweden',
 'swiss',
 'czechoslovakia',
 'ukraine',
 'amazon',
 'ice',
 'desert',
 'forest',
 'island',
 'jungle',
 'mountain',
 'river',
 'sahara',
 'volcano',
 'australia',
 'new',
 'new',
 'new',
 'polynesia',
 'arctic',
 'concentration',
 'municipality',
 'conquest',
 'deportation',
 'between',
 'fascism',
 'armenian',
 'khmer',
 'war',
 'hiroshima',
 'mafia',
 'nazism',
 'first',
 'revolution',
 'french',
 'second',
 'terrorism',
 'antiquity',
 'antiquity:',
 'antiquity:',
 'antiquity:',
 'antiquity:',
 'gaul',
 'history',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'history:',
 'prehistory',
 'martin',
 'castle',
 'caveman',
 'dinosaur',
 'world',
 'mesopotamia',
 'historic',
 'pioneers',
 'noises',
 'singing',
 'opposite',
 'colors',
 'etymology',
 'story',
 'images',
 'imagine',
 'language',
 'counting',
 'metamorphosis',
 'ball',
 'hide',
 'kite',
 'race',
 'disguise',
 'doudou',
 'game',
 'toys',
 'mask',
 'teddy',
 'doll',
 'robot',
 'abc',
 'almanac',
 'coloring',
 'roleplay',
 'video',
 'chess',
 'animated',
 'bath',
 'birth',
 'puzzle',
 'chief',
 'brave',
 'greedy',
 'curiosity',
 'self-centered',
 'fantasy',
 'joker',
 'ingenious',
 'lazy',
 'spoiler',
 'responsible',
 'dreamer',
 'cunning',
 'boastful',
 'imaginary',
 'friendship',
 'love',
 'whims',
 'anger',
 'eco-anxiety',
 'emotion',
 'boredom',
 'gratitude',
 'harassment',
 'shame',
 'mood',
 'jealousy',
 'wickedness',
 'lie',
 'mockery',
 'nostalgia',
 'fear',
 'look',
 'rivalry',
 'feeling',
 'feeling',
 'tenderness',
 'timidity',
 'sadness',
 'revenge',
 'assertiveness',
 'gender',
 'imagination',
 'initiation',
 'the',
 'portrait',
 'search',
 'identity',
 'secret',
 'memory',
 'telepathy',
 'therapy',
 'transgender',
 'transmission',
 'hibernation',
 'instinct',
 'food',
 'animal',
 'trace',
 'zoology',
 'tree',
 'mushrooms',
 'flower',
 'fruit',
 'vegetable',
 'natural',
 'bad',
 'weather',
 'snow',
 'cloud',
 'rain',
 'sun',
 'wind',
 'autumn',
 'cycle',
 'summer',
 'hour',
 'winter',
 'spring',
 'week',
 'biology',
 'waste',
 'water',
 'ecology',
 'space',
 'fire',
 'metamorphosis',
 'naturalist',
 'night',
 'rock',
 'earth',
 'environmental',
 'plant',
 'underwater',
 'underground',
 'astronomy',
 'air',
 'sky',
 'space',
 'cosmonaut',
 'star',
 'moon',
 'species',
 'printing',
 'learned',
 'technology',
 'plane',
 'boat',
 'truck',
 'traffic',
 'various',
 'metro',
 'hot',
 'means',
 'port',
 'train',
 'archeology',
 'architecture',
 'human',
 'computer',
 'physical',
 'seismology',
 'potholing',
 'processing',
 'internet',
 'media',
 'advertisement',
 'social',
 'television',
 'social',
 'poverty',
 'work',
 'sects',
 'witchcraft',
 'bohemian',
 'candy',
 'hat',
 'kitchen',
 'culture',
 'gluttony',
 'food',
 'garment',
 'social',
 'birthday',
 'carnival',
 'funfair',
 'king',
 'halloween',
 'christmas',
 'christmas',
 'easter',
 'santa',
 'picnic',
 'diy',
 'camping',
 'role',
 'video',
 'book',
 'merry-go-round',
 'scouting',
 'slavery',
 'exile',
 'immigration',
 'integration',
 'refugee',
 'apartheid',
 'communism',
 'political',
 'democracy',
 'dictatorship',
 'khmer',
 'totalitarianism',
 "noah's",
 'bible',
 'faith',
 'fundamentalism',
 'jewish',
 'religions',
 'martial',
 'boxing',
 'horse',
 'sporting',
 'soccer',
 'olympic',
 'swimming',
 'ice',
 'roller',
 'rugby',
 'ski',
 'sport',
 'surf',
 'tennis',
 'bike',
 'yoga',
 'incest',
 'forbidden',
 'justice',
 'mistreatment',
 'prison',
 'violence',
 'sexual',
 'thief',
 'money',
 'pocket',
 'baby',
 'baker',
 'casting',
 'unemployment',
 'hairdresser',
 'detective',
 'doctor',
 'writer',
 'explorer',
 'postman',
 'journalism',
 'judge',
 'various',
 'barge',
 'odd',
 'firefighter',
 'work',
 'child',
 'veterinarian',
 'summer',
 'world',
 'vacation',
 'vacation',
 'vacation',
 'seaside',
 'mountain',
 'journey',
 'money',
 'citizenship',
 'communication',
 'confinement',
 'pool',
 'power',
 'transhumanism',
 'campaign',
 'farm',
 'fishing',
 'back',
 'rural',
 'sea',
 'shipwreck',
 'pirate',
 'beach',
 'living',
 'public',
 'store',
 'walk',
 'museum',
 'job',
 'street',
 'urban',
 'city',
 'zoo',
 'hut',
 'garden',
 'places',
 'house']

# %%
ricochet_themes_preprocessed = ['abandonment',
 'abecedary',
 'bee',
 'aboriginal',
 'absence',
 'absurd',
 'sexual',
 'accident',
 'manual',
 'activities',
 'adaptation',
 'adolescence',
 'adoption',
 'adultery',
 'affection',
 'assertiveness',
 'afghanistan',
 'africa',
 'north',
 'south',
 'humanitarian',
 'alaska',
 'album',
 'album',
 'alcohol',
 'algeria',
 'food',
 'germany',
 'literacy',
 'mountaineering',
 'north',
 'latin',
 'friendship',
 'amnesia',
 'love',
 'text',
 'donkey',
 'angel',
 'animals',
 'birthday',
 'anorexia',
 'west',
 'antiquity',
 'antiquity',
 'antiquity',
 'anti-semitism',
 'apartheid',
 'learning',
 'learning',
 'spider',
 'tree',
 'archeology',
 'architecture',
 'money',
 'argentina',
 'armenia',
 'art',
 'art',
 'urban',
 'asia',
 'astrology',
 'astronomy',
 'writing',
 'australia',
 'autism',
 'autobiography',
 'autumn',
 'automotive',
 'austria',
 'ostrich',
 'adventure',
 'plane',
 'bath',
 'comic',
 'comic',
 'bandit',
 'suburb',
 'boat',
 'beauty',
 'baby',
 'belgium',
 'lullaby',
 'bestiary',
 'stupidity',
 'bhutan',
 'bible',
 'bibliography',
 'library',
 'youth',
 'bicycle',
 'animal',
 'jewel',
 'biography',
 'kiss',
 'bison',
 'badger',
 'bolivia',
 'happiness',
 'botanical',
 'buddhism',
 'boxing',
 'brazil',
 'brittany',
 'noises',
 'bulgaria',
 'burundi',
 'pebble',
 'calligraphy',
 'cambodia',
 'cameroon',
 'countryside',
 'camping',
 'canada',
 'duck',
 'caprice',
 'carnival',
 'beaver',
 'natural',
 'nuclear',
 'blindness',
 'celebrity',
 'censorship',
 'kite',
 'deer',
 'camel',
 'mushroom',
 'song',
 'hat',
 'cat',
 'castle',
 'warm',
 'bat',
 'caterpillar',
 'horse',
 'knight',
 'dog',
 'digit',
 'chemistry',
 'china',
 'chocolate',
 'unemployment',
 'owl',
 'sky',
 'cinema',
 'five',
 'circus',
 'quote',
 'citizenship',
 'clown',
 'ladybug',
 'pig',
 'hairdresser',
 'anger',
 'collection',
 'college',
 'colombia',
 'summer',
 'colonization',
 'coloring',
 'musical',
 'communication',
 'competition',
 'nursery',
 'concentration',
 'death',
 'female',
 'social',
 'conformism',
 'congo',
 'conquest',
 'consumption',
 'tale',
 'tale',
 'opposite',
 'korea',
 'body',
 'correspondence',
 'bullfight',
 'corsica',
 'color',
 'courage',
 'crocodile',
 'cuba',
 'cooking',
 'guilt',
 'curiosity',
 'swan',
 'denmark',
 'dance',
 'dolphin',
 'landing',
 'discovery',
 'disguise',
 'delinquency',
 'moving',
 'tooth',
 'depression',
 'desert',
 'despair',
 'design',
 'drawing',
 'cartoon',
 'relaxation',
 'sustainable',
 'riddle',
 'devil',
 'dictatorship',
 'difference',
 'dinosaur',
 'disappearance',
 'documentary',
 'sleep',
 'double',
 'comforter',
 'dragon',
 'drug',
 'right',
 "children's",
 'human',
 'dyslexia',
 'dystopia',
 'water',
 'school',
 'kindergarten',
 'primary',
 'ecology',
 'economy',
 'scotland',
 'writing',
 'squirrel',
 'editing',
 'edition',
 'education',
 'equality',
 'selfishness',
 'egypt',
 'ancient',
 'momentum',
 'electricity',
 'elephant',
 'emotions',
 'encyclopedia',
 'energy',
 'childhood',
 'street',
 'wild',
 'enigma',
 'abduction',
 'boredom',
 'investigation',
 'mutual',
 'environment',
 'test',
 'ecuador',
 'snail',
 'slavery',
 'space',
 'spain',
 'espionage',
 'hope',
 'united',
 'summer',
 'ethiopia',
 'ethics',
 'star',
 'europe',
 'eastern',
 'excision',
 'exclusion',
 'exile',
 'feat',
 'exposure',
 'extraterrestrial',
 'fable',
 'family',
 'host',
 'stepfamily',
 'fantasy',
 'fantastic',
 'ghost',
 'fascism',
 'fairy',
 'woman',
 'funfair',
 'fire',
 'girl',
 'finland',
 'flower',
 'soccer',
 'forest',
 'shape',
 'ant',
 'france',
 'fruit',
 'fugue',
 'genealogy',
 'generosity',
 'geography',
 'giraffe',
 'gypsy',
 'gluttony',
 'great',
 'grandmother',
 'grandfather',
 'big',
 'britain',
 'greece',
 'frog',
 'strike',
 'grimace',
 'fat',
 'guatemala',
 'war',
 'guide',
 'guyana',
 'dwelling',
 'halloween',
 'hamster',
 'disability',
 'harassment',
 'hedgehog',
 'hero',
 'hour',
 'hippopotamus',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'history',
 'the',
 'winter',
 'holocaust',
 'homosexuality',
 'hungary',
 'shame',
 'hospital',
 'humor',
 'hygiene',
 'identify',
 'illiteracy',
 'drawing',
 'imagining',
 'imagination',
 'immigration',
 'immortality',
 'printing',
 'inca',
 'india',
 'indian',
 'individualism',
 'indonesia',
 'inequality',
 'information',
 'insect',
 'music',
 'integration',
 'interculturality',
 'internet',
 'inuit',
 'iraq',
 'iran',
 'ireland',
 'iceland',
 'israel',
 'italy',
 'jealousy',
 'jamaica',
 'japan',
 'garden',
 'gardening',
 'jazz',
 'optical',
 'finger',
 'play',
 'video',
 'game',
 'olympic',
 'personal',
 'journalism',
 'judaism',
 'twins',
 'justice',
 'kamishibai',
 'kangaroo',
 'koala',
 'kosovo',
 'the',
 'lake',
 'sign',
 'foreign',
 'language',
 'rabbit',
 'image',
 'arthurian',
 'legends',
 'vegetable',
 'lemming',
 'leopard',
 'get',
 'lebanon',
 'freedom',
 'library',
 'unicorn',
 'lion',
 'list',
 'literature',
 "children's",
 'lithuania',
 'animated',
 'game',
 'book',
 'london',
 'wolf',
 'werewolf',
 'light',
 'moon',
 'elf',
 'luxembourg',
 'high',
 'madagascar',
 'store',
 'magic',
 'disease',
 'malaysia',
 'mali',
 'abuse',
 'mammoth',
 'carousel',
 'manga',
 'handling',
 'genetic',
 'marriage',
 'forced',
 'puppet',
 'morocco',
 'mask',
 'mathematical',
 'wickedness',
 'physician',
 'medicine',
 'melancholy',
 'lie',
 'menstruation',
 'sea',
 'metamorphosis',
 'weather',
 'job',
 'metro',
 'mexico',
 'thousand',
 'mine',
 'misery',
 'fashion',
 'arab',
 'mongolia',
 'monster',
 'mountain',
 'mockery',
 'death',
 'fly',
 'seagull',
 'mill',
 'sheep',
 'middle',
 'museum',
 'music',
 'mystery',
 'mythology',
 'birth',
 'napoleon',
 'narrator',
 'nature',
 'shipwreck',
 'snow',
 'nepal',
 'new',
 'christmas',
 'normandy',
 'norway',
 'nanny',
 'food',
 'new',
 'new',
 'new',
 'night',
 'obesity',
 'oceania',
 'smell',
 'egg',
 'ogre',
 'bird',
 'opera',
 'computer',
 'origami',
 'orphan',
 'hearing',
 'bear',
 'peace',
 'pakistan',
 'palestine',
 'panda',
 'butterfly',
 'easter',
 'laziness',
 'scent',
 'paris',
 'parody',
 'sharing',
 'paternity',
 'patience',
 'the',
 'landscape',
 'fishing',
 'pedagogy',
 'pedophilia',
 'painter',
 'paint',
 'santa',
 'peru',
 'persian',
 'perseverance',
 'early',
 'fear',
 'fear',
 'philosophy',
 'seal',
 'photography',
 'penguin',
 'picnic',
 'pirate',
 'pool',
 'planet',
 'plant',
 'rain',
 'poetry',
 'poison',
 'fish',
 'police',
 'politeness',
 'policy',
 'pollution',
 'poland',
 'polynesia',
 'firefighter',
 'port',
 'portrait',
 'portugal',
 'hen',
 'doll',
 'power',
 'lice',
 'artistic',
 'prehistory',
 'prejudices',
 'first',
 'prince',
 'spring',
 'prison',
 'literary',
 'ride',
 'provence',
 'proverb',
 'psychology',
 'advertisement',
 'chip',
 'punishment',
 'quebec',
 'questions',
 'racism',
 'racketeering',
 'refugee',
 'child',
 'child',
 'brother',
 'grandmother',
 'grandparent',
 'grandfather',
 'human',
 'mother',
 'mother',
 'mother',
 'father',
 'father',
 'father',
 'elderly',
 'religion',
 'fox',
 'resistance',
 'respect',
 'responsibility',
 'dream',
 'revolt',
 'wealth',
 'ritournel',
 'rivalry',
 'robot',
 'king',
 'novel',
 'historical',
 'detective',
 'romania',
 'street',
 'rumor',
 'cunning',
 'russia',
 'rwanda',
 'wisdom',
 'saint',
 'season',
 'health',
 'fir',
 'science',
 'science',
 'sculpture',
 'secret',
 'sect',
 'road',
 'racial',
 'senegal',
 'separation',
 'snake',
 'sexuality',
 'aids',
 'silence',
 'monkey',
 'company',
 'sun',
 'solitude',
 'sleep',
 'sound',
 'wizard',
 'suffering',
 'mouse',
 'memory',
 'potholing',
 'spirituality',
 'sport',
 'steampunk',
 'sugar',
 'sweden',
 'suicide',
 'swiss',
 'super',
 'superstition',
 'deafness',
 'survival',
 'suspense',
 'syria',
 'tobacco',
 'taiwan',
 'mole',
 'phone',
 'television',
 'time',
 'earth',
 'terrorism',
 'thailand',
 'theater',
 'shadow',
 'tibet',
 'tiger',
 'timidity',
 'tolerance',
 'tortoise',
 'touch',
 'tradition',
 'translation',
 'train',
 'transidentity',
 'transport',
 'work',
 'child',
 'treasure',
 'trisomy',
 'sadness',
 'gypsy',
 'tunisia',
 'türkiye',
 'typography',
 'tyranny',
 'ukraine',
 'universe',
 'vacation',
 'cow',
 'vampire',
 'vegetarianism',
 'venezuela',
 'revenge',
 'venice',
 'wind',
 'garment',
 'everyday',
 'old',
 'vietnam',
 'viking',
 'city',
 'rape',
 'violence',
 'neighborhood',
 'theft',
 'volcano',
 'journey',
 'view',
 'yeti',
 'yoga',
 'zebra',
 'zombie',
 'zoo',
 'zoology']

# %% [markdown]
# # model selection

# %%
import gensim.downloader as api
print(list(api.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
word_vectors = api.load("word2vec-google-news-300")
# word_vectors.save_word2vec_format('word_vectors.bin', binary=True)

# %% [markdown]
# # model quick test

# %%
word_vectors.similarity("economy", "finance")
# Out:
# 0.3052268

# %%
word_vectors.similarity("horse", "donkey")
# Out:
# 0.5702754

# %% [markdown]
# # align with closest words

# %%
import numpy as np
from gensim.models import KeyedVectors, Word2Vec
from tqdm import tqdm
# Load the pre-trained word embedding model from the online library
def align_lists_with_synonyms(list1, list2):
    # Create a matrix to store the similarities between words
    similarities = np.zeros((len(list1), len(list2)))

    # Calculate the similarity between each pair of words
    for i in tqdm(range(len(list1)), desc="Calculating similarities"):
        for j in range(len(list2)):
            try:
                similarity = word_vectors.similarity(list1[i], list2[j])
            except KeyError:
                similarity = 0  # Set similarity to 0 if word is not in the vocabulary
            similarities[i, j] = similarity

    # Find the closest synonym for each word in list1
    alignment = []
    for i in tqdm(range(len(list1)), desc="Finding closest synonyms"):
        closest_word_index = np.argmax(similarities[i])
        alignment.append((list1[i], list2[closest_word_index]))

    return alignment

# Example usage
list1 = ['apple', 'banana', 'orange']
list2 = ['granny', 'mandarin', 'plantain']
# list1 = ['pomme', 'banane', 'orange']
# list2 = ['granny', 'mandarine', 'plantain']
alignment = align_lists_with_synonyms(list1, list2)
print(alignment)
# Out:
# Calculating similarities: 100%|██████████| 3/3 [00:00<00:00, 2990.95it/s]
# Finding closest synonyms: 100%|██████████| 3/3 [00:00<?, ?it/s]
# [('apple', 'plantain'), ('banana', 'plantain'), ('orange', 'mandarin')]

# %% [markdown]
# # plot and navigate embedding visualisation

# %%
import numpy as np
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
def compute_embeddings(word_list, model):
    # Load the pre-trained word embedding model
    # Compute embeddings for each word in the list
    embeddings = []
    for word in word_list:
        if word in model:
            embeddings.append(model[word])
        else:
            print(word, "out of vocabulary")
            embeddings.append(np.zeros(model.vector_size))  # Use zero vector for out-of-vocabulary words

    return np.array(embeddings)

def plot_embeddings(embeddings1, embeddings2, labels1, labels2):
    plt.clf()
    # Plot embeddings of list 1 in blue
    plt.scatter(embeddings1[:, 0], embeddings1[:, 1], color='blue', label='List 1')

    # Plot embeddings of list 2 in red
    plt.scatter(embeddings2[:, 0], embeddings2[:, 1], color='red', label='List 2')

    # Add labels for each word in list 1
    for i, label in enumerate(labels1):
        plt.annotate(label, (embeddings1[i, 0], embeddings1[i, 1]), color='blue')

    # Add labels for each word in list 2
    for i, label in enumerate(labels2):
        plt.annotate(label, (embeddings2[i, 0], embeddings2[i, 1]), color='red')

    # Add legend and labels
    plt.legend()
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    # Show the plot
    plt.show()
    plt.close()
    

# Example usage
word_list1 = ['apple', 'banana', 'orange']
word_list2 = ['granny', 'mandarin', 'plantain']

embeddings1 = compute_embeddings(word_list1, word_vectors)
embeddings2 = compute_embeddings(word_list2, word_vectors)

plot_embeddings(embeddings1, embeddings2, word_list1, word_list2)
plt.clf()

# %%
import plotly.graph_objects as go

def plot_interactive_embeddings(embeddings1, embeddings2, labels1, labels2, list1_name, list2_name):
    fig = go.Figure()

    # Add scatter trace for embeddings of list 1
    fig.add_trace(go.Scatter(
        x=embeddings1[:, 0],
        y=embeddings1[:, 1],
        mode='markers',
        name=list1_name,
        text=labels1,
        marker=dict(color='blue')
    ))

    # Add scatter trace for embeddings of list 2
    fig.add_trace(go.Scatter(
        x=embeddings2[:, 0],
        y=embeddings2[:, 1],
        mode='markers',
        name=list2_name,
        text=labels2,
        marker=dict(color='red')
    ))

    # Set layout options
    fig.update_layout(
        title='Embeddings',
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        hovermode='closest'
    )

    # Show the plot
    fig.show()

embeddings1 = compute_embeddings(ricochet_themes_preprocessed, word_vectors)
embeddings2 = compute_embeddings(ecole_des_loisir_themes_preprocessed, word_vectors)

plot_interactive_embeddings(embeddings1, embeddings2, ricochet_themes_preprocessed, ecole_des_loisir_themes_preprocessed, "Ricochet", "Ecole des loisirs")
# Out:
# abecedary out of vocabulary
# algeria out of vocabulary
# anti-semitism out of vocabulary
# armenia out of vocabulary
# bhutan out of vocabulary
# bolivia out of vocabulary
# bulgaria out of vocabulary
# burundi out of vocabulary
# cambodia out of vocabulary
# cameroon out of vocabulary
# corsica out of vocabulary
# guatemala out of vocabulary
# guyana out of vocabulary
# interculturality out of vocabulary
# inuit out of vocabulary
# arthurian out of vocabulary
# lithuania out of vocabulary
# luxembourg out of vocabulary
# madagascar out of vocabulary
# mongolia out of vocabulary
# normandy out of vocabulary
# oceania out of vocabulary
# polynesia out of vocabulary
# ritournel out of vocabulary
# rwanda out of vocabulary
# senegal out of vocabulary
# transidentity out of vocabulary
# tunisia out of vocabulary
# türkiye out of vocabulary
# space-time out of vocabulary
# same-sex out of vocabulary
# mooc out of vocabulary
# algeria out of vocabulary
# madagascar out of vocabulary
# maghreb out of vocabulary
# seychelles out of vocabulary
# tanzania out of vocabulary
# tunisia out of vocabulary
# zanzibar out of vocabulary
# guatemala out of vocabulary
# bolivia out of vocabulary
# armenia out of vocabulary
# borneo out of vocabulary
# cambodia out of vocabulary
# kyrgyzstan out of vocabulary
# mongolia out of vocabulary
# uzbekistan out of vocabulary
# türkiye out of vocabulary
# mayan out of vocabulary
# tuareg out of vocabulary
# balkans out of vocabulary
# czechoslovakia out of vocabulary
# polynesia out of vocabulary
# khmer out of vocabulary
# hiroshima out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# antiquity: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# history: out of vocabulary
# mesopotamia out of vocabulary
# doudou out of vocabulary
# self-centered out of vocabulary
# eco-anxiety out of vocabulary
# merry-go-round out of vocabulary
# khmer out of vocabulary
# noah's out of vocabulary

# %% [markdown]
# # wordnet

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dre\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet
def get_synonyms(word):
    synonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    return synonyms

word = "car"
synonyms = get_synonyms(word)
pprint.pprint(synonyms)
# Out:
# ['car',
#  'auto',
#  'automobile',
#  'machine',
#  'motorcar',
#  'car',
#  'railcar',
#  'railway_car',
#  'railroad_car',
#  'car',
#  'gondola',
#  'car',
#  'elevator_car',
#  'cable_car',
#  'car']

# %% [markdown]
# # fine tune word2vec with wordnet

# %%
from gensim.models import Word2Vec
model = Word2Vec(vector_size=word_vectors.vector_size)

# %% [markdown]
# ##### https://datascience.stackexchange.com/questions/97568/fine-tuning-pre-trained-word2vec-model-with-gensim-4-0

# %%
# uncomment to retrain fine-tuned model
'''
from nltk.corpus import wordnet
import numpy as np
from tqdm import tqdm
synsets = list(wordnet.all_synsets())

# Extract the words and their contexts
data = []
for synset in synsets:
    words = [lemma.name() for lemma in synset.lemmas()]
    data.append(words)

# Update the model with the new data
model.build_vocab(data) # model does not contain training metadata (vocab frequency, loss, etc.)

model.wv.vectors_lockf = np.ones(len(model.wv))
model.wv.intersect_word2vec_format('word_vectors.bin', binary=True)



# Train the model with progress bar
with tqdm(total=len(data), desc="Training model") as pbar:
    for i, words in enumerate(data):
        model.train([words], total_examples=1, epochs=model.epochs)
        pbar.update(1)

# Save the fine-tuned model
model.save("fine_tuned_word2vec_wordnet.model")
word_vectors_finetuned_model = model.wv
'''
# Out:
# Training model: 100%|██████████| 117659/117659 [18:01<00:00, 108.84it/s]

# %%
# Load the fine-tuned Word2Vec model
word_vectors_finetuned_model = Word2Vec.load("../book_themes_alignment_data/fine_tuned_word2vec_wordnet.model")

# %%
print(word_vectors.most_similar("car"))
# Out:
# [('vehicle', 0.7821096181869507),
#  ('cars', 0.7423831224441528),
#  ('SUV', 0.7160962224006653),
#  ('minivan', 0.6907036900520325),
#  ('truck', 0.6735789775848389),
#  ('Car', 0.6677608489990234),
#  ('Ford_Focus', 0.667320191860199),
#  ('Honda_Civic', 0.6626849174499512),
#  ('Jeep', 0.651133120059967),
#  ('pickup_truck', 0.6441438794136047)]

# %%
pprint.pprint(word_vectors_finetuned_model.wv.most_similar("car"))
# Out:
# [('scooter', 0.6381530165672302),
#  ('van', 0.6115673780441284),
#  ('driver', 0.577939510345459),
#  ('tire', 0.4941665828227997),
#  ('pickup', 0.48767825961112976),
#  ('motor', 0.4810173213481903),
#  ('bus', 0.4693371057510376),
#  ('wheel', 0.45954588055610657),
#  ('hood', 0.4447837173938751),
#  ('trunk', 0.44462618231773376)]

# %%
word = "history"
print(word_vectors.most_similar(word))
synonyms = get_synonyms(word)
print(synonyms)
print(word_vectors_finetuned.most_similar(word))
# Out:
# [('annals', 0.6059836745262146), ('lore', 0.5649883151054382), ('histories', 0.5634648203849792), ('storied', 0.5317221879959106), ('darkest_eras', 0.518702507019043), ('history.The', 0.49367886781692505), ('History', 0.4924328625202179), ('histroy', 0.476222962141037), ('female_ticketmate', 0.46001169085502625), ('prehistory', 0.459464967250824)]
# ['history', 'history', 'account', 'chronicle', 'story', 'history', 'history', 'history']
# [('record', 0.44240590929985046), ('lineage', 0.3730401396751404), ('culture', 0.3615289032459259), ('modern', 0.3599395453929901), ('chapter', 0.35942503809928894), ('worst', 0.33779799938201904), ('one', 0.33320415019989014), ('most', 0.33037394285202026), ('first', 0.32545924186706543), ('antecedent', 0.3206702172756195)]
