# %%
import pandas as pd
import rdflib

# your file path
file = "../output_ricochet.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                  Subject
# 0      http://schema.org/Book6c048d83-5d4b-4763-95b9-...  \
# 1      http://schema.org/Book96c372b6-8c55-4a8c-88e2-...
# 2      http://schema.org/Book20794681-c12d-4a3f-8968-...
# 3      http://schema.org/Bookc4c4b37d-7a3a-482c-9b7a-...
# 4      http://schema.org/Booked7a4921-0d39-4370-a445-...
# ...                                                  ...
# 23323  http://schema.org/Bookca2818b3-04a2-48a4-b3f4-...
# 23324  http://schema.org/Booked7a4921-0d39-4370-c445-...
# 23325  http://schema.org/Book5c6f3db7-48da-4d32-9988-...
# 23326  http://schema.org/Booked7a4921-0d39-4370-a445-...
# 23327  http://schema.org/Book4abccddc-f1c7-452f-862e-...
#
#                                              Predicate
# 0                         http://schema.org/inLanguage  \
# 1                          http://schema.org/publisher
# 2                               http://schema.org/name
# 3                             http://schema.org/author
# 4      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                                ...
# 23323                          http://schema.org/award
# 23324                           http://schema.org/name
# 23325  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 23326                   http://schema.org/dateReceived
# 23327                     http://schema.org/inLanguage
#
#                                                   Object
# 0                                               Français
# 1                                               Rouergue
# 2                                           Rue Stendhal
# 3                                   Jean-François Dumont
# 4                                 http://schema.org/Book
# ...                                                  ...
# 23323  Prix Franco-Allemand Pour La Littérature De Je...
# 23324        Le dossier Handle et Deux secondes en moins
# 23325                             http://schema.org/Book
# 23326                                               2015
# 23327                                           Français
#
# [23328 rows x 3 columns]
