# %%
import rdflib

file = "../output_bookcentre.ttl"

g = rdflib.Graph()

g.parse(file, format='turtle')

for subj, pred, obj in g:
    print(subj, pred, obj)
# Out:
# http://schema.org/Book883e43e5-0f5e-46a5-a8a7-7f8c7b0e4a15 http://schema.org/datePublished 2014
# http://schema.org/Bookb15b4d7d-6dcb-40d4-b882-073d2c4a9c41 http://schema.org/inLanguage Français
# http://schema.org/Bookc3a72983-5c7b-4c9b-98b1-94a23c17d6f5 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Book
# http://schema.org/Book0d4f2af3-5b68-4a37-a7b4-ff48d3a3e5c9 http://schema.org/illustrator Sydney Smith
# http://schema.org/Book4ec90321-5de5-4ec1-948f-5f9d0a3a6c25 http://schema.org/publisher Greystone Kids
# http://schema.org/Bookdbe2aa9e-4c19-4685-94ef-7734cf6df295 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Book
# http://schema.org/Bookb7a8f6fd-8d40-40c4-bd6f-431d6a9baf6c http://schema.org/genre Jeunesse
# http://schema.org/Book883e43e5-0f5e-46a5-a8a7-7f8c7b0e4a15 http://schema.org/genre Littérature canadienne
# http://schema.org/Bookd4a94ec9-7d33-49e3-97b5-4d17ad84db19 http://schema.org/genre Jeunesse
# ...
