# %%
import pandas as pd
import rdflib

# your file path
file = "../merged_output.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                  Subject
# 0      http://schema.org/Bookfbed1e77-84ff-46bc-a832-...  \
# 1      http://schema.org/Book20794681-c12d-4a3f-8968-...
# 2      http://schema.org/Book7dbf288d-6d0f-41fe-b39c-...
# 3      http://schema.org/Booked7a4921-0d39-4370-a445-...
# 4      http://schema.org/Booked7a4921-0d39-4370-a445-...
# ...                                                  ...
# 30933  http://schema.org/Bookd17eb624-9ed0-49d1-9261-...
# 30934  http://schema.org/Bookcbd636a6-1974-45d3-aa27-...
# 30935  http://schema.org/Bookc4c4b37d-7a3a-482c-9b7a-...
# 30936  http://schema.org/Bookb5aeb25-b6e4-4c72-b872-5...
# 30937  http://schema.org/Bookf1ab8dee-1a4d-4ac4-bd77-...
#
#                                              Predicate
# 0                          http://schema.org/publisher  \
# 1                              http://schema.org/award
# 2                          http://schema.org/publisher
# 3                          http://schema.org/publisher
# 4                       http://schema.org/dateReceived
# ...                                                ...
# 30933                     http://schema.org/inLanguage
# 30934  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 30935                   http://schema.org/dateReceived
# 30936                         http://schema.org/author
# 30937                      http://schema.org/publisher
#
#                                       Object
# 0                              Talents Hauts
# 1      Prix Chronos De Littérature : 4E - 3E
# 2                                   Triomphe
# 3                                     Bayard
# 4                                       2014
# ...                                      ...
# 30933                               Français
# 30934                 http://schema.org/Book
# 30935                                   2004
# 30936                  Sigrídur Björnsdóttir
# 30937                    L'École Des Loisirs
#
# [30938 rows x 3 columns]
