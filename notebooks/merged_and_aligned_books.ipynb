# %%
import pandas as pd
import rdflib

# your file path
file = "../merged_output.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                  Subject
# 0      http://schema.org/Bookfbed1e77-84ff-46bc-a832-...  \
# 1      http://schema.org/Book20794681-c12d-4a3f-8968-...
# 2      http://schema.org/Book7dbf288d-6d0f-41fe-b39c-...
# 3      http://schema.org/Booked7a4921-0d39-4370-a445-...
# 4      http://schema.org/Booked7a4921-0d39-4370-a445-...
# ...                                                  ...
# 28057  http://schema.org/Book20794681-c12d-4a3f-8968-...
# 28058  http://schema.org/Bookfacd3bc3-d5c0-4430-8290-...
# 28059  http://schema.org/Bookc4c4b37d-7a3a-482c-9b7a-...
# 28060  http://schema.org/Bookb5aeb25-b6e4-4c72-b872-5...
# 28061  https://schema.org/Book89274a64-758b-45d7-88ad...
#
#                                              Predicate
# 0                          http://schema.org/publisher  \
# 1                              http://schema.org/award
# 2                          http://schema.org/publisher
# 3                          http://schema.org/publisher
# 4                       http://schema.org/dateReceived
# ...                                                ...
# 28057                            http://schema.org/url
# 28058  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 28059                   http://schema.org/dateReceived
# 28060                         http://schema.org/author
# 28061                            http://schema.org/url
#
#                                                   Object
# 0                                          Talents Hauts
# 1                  Prix Chronos De Littérature : 4E - 3E
# 2                                               Triomphe
# 3                                                 Bayard
# 4                                                   2014
# ...                                                  ...
# 28057  https://www.ricochet-jeunes.org/prix-litterair...
# 28058                             http://schema.org/Book
# 28059                                               2004
# 28060                              Sigrídur Björnsdóttir
# 28061  https://prixdeslibraires.qc.ca/zoom-demo/?bigt...
#
# [28062 rows x 3 columns]
