# %%
import pandas as pd
import rdflib

# your file path
file = "../output_bookcentre.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    http://schema.org/Book0d4f2af3-5b68-4a37-a7b4-...  \
# 1    http://schema.org/Book6a3a5c3d-3cde-4b52-86b5-...
# 2    http://schema.org/Book7c62a413-39c5-4b76-8b5d-...
# 3    http://schema.org/Book4ec90321-5de5-4ec1-948f-...
# 4    http://schema.org/Book204fd1e5-9810-4d4e-8b89-...
# ..                                                 ...
# 369  http://schema.org/Bookb6a1f8c3-7da7-41fb-98ed-...
# 370  http://schema.org/Book6a9f3ed9-8af3-4b1c-87b1-...
# 371  http://schema.org/Book204fd1e5-9810-4d4e-8b89-...
# 372  http://schema.org/Bookc8147bde-5586-4e92-b40e-...
# 373  http://schema.org/Bookb7a8f6fd-8d40-40c4-bd6f-...
#
#                                            Predicate                  Object
# 0                            http://schema.org/genre                Jeunesse
# 1                       http://schema.org/inLanguage                Français
# 2                      http://schema.org/illustrator        Stéphane Jorisch
# 3                        http://schema.org/publisher          Greystone Kids
# 4                    http://schema.org/datePublished                    2018
# ..                                               ...                     ...
# 369                  http://schema.org/datePublished                    2020
# 370  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://schema.org/Book
# 371                           http://schema.org/name              Ebb & Flow
# 372                          http://schema.org/genre                Jeunesse
# 373                      http://schema.org/publisher  Dominique Et Compagnie
#
# [374 rows x 3 columns]
