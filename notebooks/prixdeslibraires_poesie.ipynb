# %%
import pandas as pd
import rdflib

# your file path
file = "../output_prixdeslibraires_poesie.ttl" 

# initialize graph and parse the file
g = rdflib.Graph()
g.parse(file, format='turtle')

data = []

# iterate over triples in graph and add them to our dataframe
for subj, pred, obj in g:
    data.append({"Subject": str(subj), "Predicate": str(pred), "Object": str(obj)})

# create the dataframe
df = pd.DataFrame(data)

# display the dataframe
df
# Out:
#                                                Subject
# 0    https://schema.org/Book200b7bf3-b9f2-45bc-97a4...  \
# 1    https://schema.org/Booka477d4d3-965f-4f79-bc9a...
# 2    https://schema.org/Book200b7bf3-b9f2-45bc-97a4...
# 3    https://schema.org/Book70ed5711-102f-4b20-a4e8...
# 4    https://schema.org/Book9a75b4dd-f1c9-4ce2-a166...
# ..                                                 ...
# 100  https://schema.org/Book11b9defe-90d9-487a-89ef...
# 101  https://schema.org/Book660b1528-978c-4c1e-b938...
# 102  https://schema.org/Book70ed5711-102f-4b20-a4e8...
# 103  https://schema.org/Book660b1528-978c-4c1e-b938...
# 104  https://schema.org/Book1ecbe59b-c9f5-495b-8c80...
#
#                                            Predicate
# 0                              http://schema.org/url  \
# 1    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2                    http://schema.org/datePublished
# 3                      http://schema.org/description
# 4                            http://schema.org/genre
# ..                                               ...
# 100                  http://schema.org/datePublished
# 101                           http://schema.org/name
# 102                            http://schema.org/url
# 103                         http://schema.org/author
# 104                           http://schema.org/name
#
#                                                 Object
# 0    https://prixdeslibraires.qc.ca/zoom-demo/?bigt...
# 1                               http://schema.org/Book
# 2                                                 2022
# 3           Prix des libraires : Finaliste 2023 poésie
# 4                                               Poésie
# ..                                                 ...
# 100                                               2022
# 101                                  Mouron des champs
# 102  https://prixdeslibraires.qc.ca/zoom-demo/?bigt...
# 103                                 Marie-Hélène Voyer
# 104                                  Exercices de joie
#
# [105 rows x 3 columns]
