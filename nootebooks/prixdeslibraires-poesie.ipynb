# %%
files = [
    "./output-prixdeslibraires-poesie.ttl"
]

for file in files:
    with open(file, 'r', encoding='utf-8') as f:
        for line in f:
            print(line.strip())
# Out:
# @prefix ns1: <http://schema.org/> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# schema:Book0de4ac0f-b6ef-46d6-b889-955c60e441ab a ns1:Book ;
# ns1:author "Stéphane Jean"^^xsd:string ;
# ns1:datePublished "2022"^^xsd:string ;
# ns1:description "Préliminaire 2023"^^xsd:string ;
# ns1:genre "Poésie"^^xsd:string ;
# ns1:name "Refuge pour ténèbres"^^xsd:string ;
# ns1:publisher "Les Herbes Rouges"^^xsd:string ;
# ns1:url "https://prixdeslibraires.qc.ca/zoom-demo/?bigtitle=Préliminaire 2023 Québec&firstid=10503&theme=poesie&book_id_list=a%3A8%3A%7Bi%3A0%3Bi%3A10501%3Bi%3A1%3Bi%3A10499%3Bi%3A2%3Bi%3A10498%3Bi%3A3%3Bi%3A10503%3Bi%3A4%3Bi%3A10500%3Bi%3A5%3Bi%3A10497%3Bi%3A6%3Bi%3A10496%3Bi%3A7%3Bi%3A10502%3B%7D"^^xsd:string .
#
# schema:Book11b9defe-90d9-487a-89ef-8ed976699188 a ns1:Book ;
# ns1:author "Emmanuelle Riendeau"^^xsd:string ;
# ns1:datePublished "2022"^^xsd:string ;
# ns1:description "Finaliste 2023 poésie"^^xsd:string ;
# ...
